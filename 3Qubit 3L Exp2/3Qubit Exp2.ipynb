# %%
import pennylane as qml
from pennylane import numpy as np
import scipy
import matplotlib.pyplot as plt
from globalVars import *
from model_3qubit import *

from GRADest_3Q import EstGrad
from EQFIMest_3Q import Est_EQFIM

# %% [markdown]
# ## Quantum Neural Network

# %%
random_state = np.random.rand(dim)
random_state = random_state /np.linalg.norm(random_state)
qml.draw_mpl(QNN)(np.zeros(nparams),random_state)
# Out:
# (<Figure size 1300x400 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### Model Initialization

# %%
S_pItr = 6  # no. of samples used per-iteration 

nStep = 350
nItr = 100
step_size = 0.0025

Bsize = S_pItr*nItr

# %%
phiTrain = np.load('3-qubitsPhiTrain_v1.npy')
labelTrain = np.load('3-qubitsLabelTrain_v1.npy')

phiTrain.requires_grad = False
labelTrain.requires_grad = False

# %%
'QNSCD Dataset'
phiTrainNCGD = phiTrain
labelTrainNCGD = labelTrain

'SGD Dataset'
phiTrainSGD = phiTrain
labelTrainSGD = labelTrain

# %%
### Optimal Expected Loss
Opt_cost = []
itrBatch = np.linspace(0,Bsize*nStep,nStep,endpoint = False,dtype = 'int').tolist()
for itr1 in itrBatch:
    expOperator = 0
    for itr2 in range(Bsize):
        temp_phi = phiTrain[:,itr1+itr2]
        op = np.matmul(temp_phi.reshape(dim,1),temp_phi.reshape(1,dim))
        expOperator = expOperator + labelTrain[itr1+itr2]*op
    expOperator = expOperator/Bsize
    opt_value = 0.5*(1-sum(abs(np.linalg.svd(expOperator)[1])))
    Opt_cost.append(opt_value)

file_name = "3Q-Minimum Expected Loss"
np.save(file_name,Opt_cost)

# %% [markdown]
# # Optimizers

# %%
'QNN outputs yhat'
dev = qml.device("default.qubit", wires=nqubits, shots=1)

@qml.qnode(dev,interface='autograd')
def circuit_test(params,state):
    QNN(params,state)
    return qml.sample(qml.Hermitian(M,wires=list(range(nqubits))))

# %%
init_params = np.random.uniform(low=0, high=2*np.pi, size=nparams, requires_grad=True)
init_params = np.array([1.32856251, 6.08211092, 4.11432613, 0.07024644, 0.52676639, 3.77414277,
 1.01944363, 4.58404229, 3.39006004], requires_grad=True)
'cost initialization'
phiTrain0 = phiTrain[:,-1*(Bsize+1):-1]
labelTrain0 = labelTrain[-1*(Bsize+1):-1]
temp_cost = sum([ps_expLoss(init_params,phiTrain0[:,itr],labelTrain0[itr]) for itr in range(Bsize)])/Bsize
print("Initial Average Per-Sample Expected Loss: ",temp_cost)

count = 0
for itr in range(Bsize):
    if circuit_test(init_params,phiTrain0[:,itr]) != labelTrain0[itr]:
        count += 1
temp_Ecost = count/Bsize
print("Initial Average Empirical Loss", temp_Ecost)
# Out:
# Initial Average Per-Sample Expected Loss:  0.5609244056946506
# Initial Average Empirical Loss 0.5816666666666667

# %% [markdown]
# ## Quantum Natural Stochastic Pairwise Coordinate Descent (2-QNSCD)

# %%
NCGDparams = np.array(init_params)
NCGD_cost = []
NCGD_Ecost = []

NCGD_cost.append(temp_cost)
NCGD_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainNCGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainNCGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a pair of coordinate
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())

        ### Gradient estimation
        y1, b1 = EstGrad(NCGDparams,phiT[:,itr3],idx[0])
        y2, b2 = EstGrad(NCGDparams,phiT[:,itr3+1],idx[1])
        b1 = (1-b1)/2
        b2 = (1-b2)/2

        grad = [-1*((-1)**b1)*loss(y1,labelT[itr3]),-1*((-1)**b2)*loss(y2,labelT[itr3+1])]
        
        ### E-QFIM estimation
        metric = Est_EQFIM(NCGDparams,idx,phiT[:,itr3+2:itr3+S_pItr])

        ### double-parameters update
        NCGDparams[idx] = NCGDparams[idx] - (step_size)*np.dot(np.linalg.inv(metric),grad) 
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(NCGDparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    NCGD_cost.append(energy)
    
    ### average empirical loss calculation
    NCGDcount = 0
    for itr in range(Bsize):
        if circuit_test(NCGDparams,phiT[:,itr]) != labelT[itr]:
            NCGDcount += 1
    NCGD_Ecost.append(NCGDcount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))

file_name1 = "3Q 2-QNSCD Expected Loss"
file_name2 = "3Q 2-QNSCD Empirical Loss"

np.save(file_name1,NCGD_cost)
np.save(file_name2,NCGD_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.56092
# Batch count:  1, Avg. per-sample expected Loss: 0.56623
# Batch count:  2, Avg. per-sample expected Loss: 0.55452
# Batch count:  3, Avg. per-sample expected Loss: 0.56686
# Batch count:  4, Avg. per-sample expected Loss: 0.55213
# Batch count:  5, Avg. per-sample expected Loss: 0.55527
# Batch count:  6, Avg. per-sample expected Loss: 0.55623
# Batch count:  7, Avg. per-sample expected Loss: 0.54534
# Batch count:  8, Avg. per-sample expected Loss: 0.54622
# Batch count:  9, Avg. per-sample expected Loss: 0.55462
# Batch count: 10, Avg. per-sample expected Loss: 0.55503
# Batch count: 11, Avg. per-sample expected Loss: 0.55989
# Batch count: 12, Avg. per-sample expected Loss: 0.54747
# Batch count: 13, Avg. per-sample expected Loss: 0.53949
# Batch count: 14, Avg. per-sample expected Loss: 0.55524
# Batch count: 15, Avg. per-sample expected Loss: 0.55659
# Batch count: 16, Avg. per-sample expected Loss: 0.55484
# Batch count: 17, Avg. per-sample expected Loss: 0.53749
# Batch count: 18, Avg. per-sample expected Loss: 0.54367
# Batch count: 19, Avg. per-sample expected Loss: 0.53813
# Batch count: 20, Avg. per-sample expected Loss: 0.53395
# Batch count: 21, Avg. per-sample expected Loss: 0.53668
# Batch count: 22, Avg. per-sample expected Loss: 0.52320
# Batch count: 23, Avg. per-sample expected Loss: 0.52642
# Batch count: 24, Avg. per-sample expected Loss: 0.52285
# Batch count: 25, Avg. per-sample expected Loss: 0.52694
# Batch count: 26, Avg. per-sample expected Loss: 0.51765
# Batch count: 27, Avg. per-sample expected Loss: 0.50617
# Batch count: 28, Avg. per-sample expected Loss: 0.50888
# Batch count: 29, Avg. per-sample expected Loss: 0.51211
# Batch count: 30, Avg. per-sample expected Loss: 0.51366
# Batch count: 31, Avg. per-sample expected Loss: 0.50474
# Batch count: 32, Avg. per-sample expected Loss: 0.50584
# Batch count: 33, Avg. per-sample expected Loss: 0.50664
# Batch count: 34, Avg. per-sample expected Loss: 0.50301
# Batch count: 35, Avg. per-sample expected Loss: 0.50472
# Batch count: 36, Avg. per-sample expected Loss: 0.51546
# Batch count: 37, Avg. per-sample expected Loss: 0.51225
# Batch count: 38, Avg. per-sample expected Loss: 0.50721
# Batch count: 39, Avg. per-sample expected Loss: 0.51152
# Batch count: 40, Avg. per-sample expected Loss: 0.50237
# Batch count: 41, Avg. per-sample expected Loss: 0.49299
# Batch count: 42, Avg. per-sample expected Loss: 0.49029
# Batch count: 43, Avg. per-sample expected Loss: 0.49065
# Batch count: 44, Avg. per-sample expected Loss: 0.48595
# Batch count: 45, Avg. per-sample expected Loss: 0.48226
# Batch count: 46, Avg. per-sample expected Loss: 0.47377
# Batch count: 47, Avg. per-sample expected Loss: 0.46781
# Batch count: 48, Avg. per-sample expected Loss: 0.46878
# Batch count: 49, Avg. per-sample expected Loss: 0.45750
# Batch count: 50, Avg. per-sample expected Loss: 0.45431
# Batch count: 51, Avg. per-sample expected Loss: 0.45316
# Batch count: 52, Avg. per-sample expected Loss: 0.44741
# Batch count: 53, Avg. per-sample expected Loss: 0.45318
# Batch count: 54, Avg. per-sample expected Loss: 0.45846
# Batch count: 55, Avg. per-sample expected Loss: 0.43597
# Batch count: 56, Avg. per-sample expected Loss: 0.42003
# Batch count: 57, Avg. per-sample expected Loss: 0.41840
# Batch count: 58, Avg. per-sample expected Loss: 0.42229
# Batch count: 59, Avg. per-sample expected Loss: 0.40153
# Batch count: 60, Avg. per-sample expected Loss: 0.40450
# Batch count: 61, Avg. per-sample expected Loss: 0.39480
# Batch count: 62, Avg. per-sample expected Loss: 0.39171
# Batch count: 63, Avg. per-sample expected Loss: 0.39347
# Batch count: 64, Avg. per-sample expected Loss: 0.38716
# Batch count: 65, Avg. per-sample expected Loss: 0.39681
# Batch count: 66, Avg. per-sample expected Loss: 0.38099
# Batch count: 67, Avg. per-sample expected Loss: 0.37976
# Batch count: 68, Avg. per-sample expected Loss: 0.38926
# Batch count: 69, Avg. per-sample expected Loss: 0.37215
# Batch count: 70, Avg. per-sample expected Loss: 0.37058
# Batch count: 71, Avg. per-sample expected Loss: 0.35346
# Batch count: 72, Avg. per-sample expected Loss: 0.35377
# Batch count: 73, Avg. per-sample expected Loss: 0.35693
# Batch count: 74, Avg. per-sample expected Loss: 0.34722
# Batch count: 75, Avg. per-sample expected Loss: 0.34504
# Batch count: 76, Avg. per-sample expected Loss: 0.32517
# Batch count: 77, Avg. per-sample expected Loss: 0.33257
# Batch count: 78, Avg. per-sample expected Loss: 0.31235
# Batch count: 79, Avg. per-sample expected Loss: 0.30267
# Batch count: 80, Avg. per-sample expected Loss: 0.29712
# Batch count: 81, Avg. per-sample expected Loss: 0.30340
# Batch count: 82, Avg. per-sample expected Loss: 0.28185
# Batch count: 83, Avg. per-sample expected Loss: 0.27668
# Batch count: 84, Avg. per-sample expected Loss: 0.27634
# Batch count: 85, Avg. per-sample expected Loss: 0.26040
# Batch count: 86, Avg. per-sample expected Loss: 0.26734
# Batch count: 87, Avg. per-sample expected Loss: 0.23959
# Batch count: 88, Avg. per-sample expected Loss: 0.23865
# Batch count: 89, Avg. per-sample expected Loss: 0.21739
# Batch count: 90, Avg. per-sample expected Loss: 0.22341
# Batch count: 91, Avg. per-sample expected Loss: 0.21339
# Batch count: 92, Avg. per-sample expected Loss: 0.19988
# Batch count: 93, Avg. per-sample expected Loss: 0.20606
# Batch count: 94, Avg. per-sample expected Loss: 0.20652
# Batch count: 95, Avg. per-sample expected Loss: 0.19019
# Batch count: 96, Avg. per-sample expected Loss: 0.18034
# Batch count: 97, Avg. per-sample expected Loss: 0.17176
# Batch count: 98, Avg. per-sample expected Loss: 0.16806
# Batch count: 99, Avg. per-sample expected Loss: 0.16820
# Batch count: 100, Avg. per-sample expected Loss: 0.15069
# Batch count: 101, Avg. per-sample expected Loss: 0.15109
# Batch count: 102, Avg. per-sample expected Loss: 0.15066
# Batch count: 103, Avg. per-sample expected Loss: 0.15759
# Batch count: 104, Avg. per-sample expected Loss: 0.14702
# Batch count: 105, Avg. per-sample expected Loss: 0.15974
# Batch count: 106, Avg. per-sample expected Loss: 0.15622
# Batch count: 107, Avg. per-sample expected Loss: 0.14385
# Batch count: 108, Avg. per-sample expected Loss: 0.14305
# Batch count: 109, Avg. per-sample expected Loss: 0.13711
# Batch count: 110, Avg. per-sample expected Loss: 0.13797
# Batch count: 111, Avg. per-sample expected Loss: 0.15070
# Batch count: 112, Avg. per-sample expected Loss: 0.13327
# Batch count: 113, Avg. per-sample expected Loss: 0.14845
# Batch count: 114, Avg. per-sample expected Loss: 0.13974
# Batch count: 115, Avg. per-sample expected Loss: 0.13870
# Batch count: 116, Avg. per-sample expected Loss: 0.13751
# Batch count: 117, Avg. per-sample expected Loss: 0.15600
# Batch count: 118, Avg. per-sample expected Loss: 0.13668
# Batch count: 119, Avg. per-sample expected Loss: 0.13148
# Batch count: 120, Avg. per-sample expected Loss: 0.12931
# Batch count: 121, Avg. per-sample expected Loss: 0.13978
# Batch count: 122, Avg. per-sample expected Loss: 0.13134
# Batch count: 123, Avg. per-sample expected Loss: 0.12876
# Batch count: 124, Avg. per-sample expected Loss: 0.13301
# Batch count: 125, Avg. per-sample expected Loss: 0.12281
# Batch count: 126, Avg. per-sample expected Loss: 0.12904
# Batch count: 127, Avg. per-sample expected Loss: 0.14643
# Batch count: 128, Avg. per-sample expected Loss: 0.14068
# Batch count: 129, Avg. per-sample expected Loss: 0.14227
# Batch count: 130, Avg. per-sample expected Loss: 0.14112
# Batch count: 131, Avg. per-sample expected Loss: 0.13276
# Batch count: 132, Avg. per-sample expected Loss: 0.15718
# Batch count: 133, Avg. per-sample expected Loss: 0.14427
# Batch count: 134, Avg. per-sample expected Loss: 0.14794
# Batch count: 135, Avg. per-sample expected Loss: 0.14349
# Batch count: 136, Avg. per-sample expected Loss: 0.14695
# Batch count: 137, Avg. per-sample expected Loss: 0.15521
# Batch count: 138, Avg. per-sample expected Loss: 0.14016
# Batch count: 139, Avg. per-sample expected Loss: 0.14478
# Batch count: 140, Avg. per-sample expected Loss: 0.15023
# Batch count: 141, Avg. per-sample expected Loss: 0.14454
# Batch count: 142, Avg. per-sample expected Loss: 0.13756
# Batch count: 143, Avg. per-sample expected Loss: 0.15107
# Batch count: 144, Avg. per-sample expected Loss: 0.14373
# Batch count: 145, Avg. per-sample expected Loss: 0.13459
# Batch count: 146, Avg. per-sample expected Loss: 0.14330
# Batch count: 147, Avg. per-sample expected Loss: 0.12250
# Batch count: 148, Avg. per-sample expected Loss: 0.12529
# Batch count: 149, Avg. per-sample expected Loss: 0.14064
# Batch count: 150, Avg. per-sample expected Loss: 0.12564
# Batch count: 151, Avg. per-sample expected Loss: 0.12674
# Batch count: 152, Avg. per-sample expected Loss: 0.13454
# Batch count: 153, Avg. per-sample expected Loss: 0.13634
# Batch count: 154, Avg. per-sample expected Loss: 0.12879
# Batch count: 155, Avg. per-sample expected Loss: 0.12958
# Batch count: 156, Avg. per-sample expected Loss: 0.13520
# Batch count: 157, Avg. per-sample expected Loss: 0.14630
# Batch count: 158, Avg. per-sample expected Loss: 0.13512
# Batch count: 159, Avg. per-sample expected Loss: 0.13663
# Batch count: 160, Avg. per-sample expected Loss: 0.14021
# Batch count: 161, Avg. per-sample expected Loss: 0.14381
# Batch count: 162, Avg. per-sample expected Loss: 0.14047
# Batch count: 163, Avg. per-sample expected Loss: 0.13247
# Batch count: 164, Avg. per-sample expected Loss: 0.13752
# Batch count: 165, Avg. per-sample expected Loss: 0.13805
# Batch count: 166, Avg. per-sample expected Loss: 0.13697
# Batch count: 167, Avg. per-sample expected Loss: 0.13492
# Batch count: 168, Avg. per-sample expected Loss: 0.13683
# Batch count: 169, Avg. per-sample expected Loss: 0.13346
# Batch count: 170, Avg. per-sample expected Loss: 0.13796
# Batch count: 171, Avg. per-sample expected Loss: 0.14040
# Batch count: 172, Avg. per-sample expected Loss: 0.12826
# Batch count: 173, Avg. per-sample expected Loss: 0.12782
# Batch count: 174, Avg. per-sample expected Loss: 0.13360
# Batch count: 175, Avg. per-sample expected Loss: 0.12588
# Batch count: 176, Avg. per-sample expected Loss: 0.13321
# Batch count: 177, Avg. per-sample expected Loss: 0.14231
# Batch count: 178, Avg. per-sample expected Loss: 0.13924
# Batch count: 179, Avg. per-sample expected Loss: 0.13121
# Batch count: 180, Avg. per-sample expected Loss: 0.14809
# Batch count: 181, Avg. per-sample expected Loss: 0.12830
# Batch count: 182, Avg. per-sample expected Loss: 0.13015
# Batch count: 183, Avg. per-sample expected Loss: 0.13490
# Batch count: 184, Avg. per-sample expected Loss: 0.12834
# Batch count: 185, Avg. per-sample expected Loss: 0.13285
# Batch count: 186, Avg. per-sample expected Loss: 0.13750
# Batch count: 187, Avg. per-sample expected Loss: 0.14063
# Batch count: 188, Avg. per-sample expected Loss: 0.13308
# Batch count: 189, Avg. per-sample expected Loss: 0.11955
# Batch count: 190, Avg. per-sample expected Loss: 0.12253
# Batch count: 191, Avg. per-sample expected Loss: 0.13511
# Batch count: 192, Avg. per-sample expected Loss: 0.14358
# Batch count: 193, Avg. per-sample expected Loss: 0.12626
# Batch count: 194, Avg. per-sample expected Loss: 0.13448
# Batch count: 195, Avg. per-sample expected Loss: 0.14674
# Batch count: 196, Avg. per-sample expected Loss: 0.13970
# Batch count: 197, Avg. per-sample expected Loss: 0.13807
# Batch count: 198, Avg. per-sample expected Loss: 0.13675
# Batch count: 199, Avg. per-sample expected Loss: 0.14543
# Batch count: 200, Avg. per-sample expected Loss: 0.13671
# Batch count: 201, Avg. per-sample expected Loss: 0.13286
# Batch count: 202, Avg. per-sample expected Loss: 0.13272
# Batch count: 203, Avg. per-sample expected Loss: 0.13599
# Batch count: 204, Avg. per-sample expected Loss: 0.13216
# Batch count: 205, Avg. per-sample expected Loss: 0.12976
# Batch count: 206, Avg. per-sample expected Loss: 0.12612
# Batch count: 207, Avg. per-sample expected Loss: 0.14694
# Batch count: 208, Avg. per-sample expected Loss: 0.12827
# Batch count: 209, Avg. per-sample expected Loss: 0.12534
# Batch count: 210, Avg. per-sample expected Loss: 0.13683
# Batch count: 211, Avg. per-sample expected Loss: 0.14195
# Batch count: 212, Avg. per-sample expected Loss: 0.13372
# Batch count: 213, Avg. per-sample expected Loss: 0.13656
# Batch count: 214, Avg. per-sample expected Loss: 0.13771
# Batch count: 215, Avg. per-sample expected Loss: 0.15327
# Batch count: 216, Avg. per-sample expected Loss: 0.15038
# Batch count: 217, Avg. per-sample expected Loss: 0.14135
# Batch count: 218, Avg. per-sample expected Loss: 0.14552
# Batch count: 219, Avg. per-sample expected Loss: 0.14675
# Batch count: 220, Avg. per-sample expected Loss: 0.14629
# Batch count: 221, Avg. per-sample expected Loss: 0.14590
# Batch count: 222, Avg. per-sample expected Loss: 0.14679
# Batch count: 223, Avg. per-sample expected Loss: 0.15935
# Batch count: 224, Avg. per-sample expected Loss: 0.15046
# Batch count: 225, Avg. per-sample expected Loss: 0.16027
# Batch count: 226, Avg. per-sample expected Loss: 0.14730
# Batch count: 227, Avg. per-sample expected Loss: 0.15286
# Batch count: 228, Avg. per-sample expected Loss: 0.14472
# Batch count: 229, Avg. per-sample expected Loss: 0.14632
# Batch count: 230, Avg. per-sample expected Loss: 0.14110
# Batch count: 231, Avg. per-sample expected Loss: 0.14615
# Batch count: 232, Avg. per-sample expected Loss: 0.14793
# Batch count: 233, Avg. per-sample expected Loss: 0.13708
# Batch count: 234, Avg. per-sample expected Loss: 0.14315
# Batch count: 235, Avg. per-sample expected Loss: 0.14043
# Batch count: 236, Avg. per-sample expected Loss: 0.15064
# Batch count: 237, Avg. per-sample expected Loss: 0.15014
# Batch count: 238, Avg. per-sample expected Loss: 0.13487
# Batch count: 239, Avg. per-sample expected Loss: 0.14790
# Batch count: 240, Avg. per-sample expected Loss: 0.14846
# Batch count: 241, Avg. per-sample expected Loss: 0.14307
# Batch count: 242, Avg. per-sample expected Loss: 0.13950
# Batch count: 243, Avg. per-sample expected Loss: 0.12982
# Batch count: 244, Avg. per-sample expected Loss: 0.14475
# Batch count: 245, Avg. per-sample expected Loss: 0.13239
# Batch count: 246, Avg. per-sample expected Loss: 0.13138
# Batch count: 247, Avg. per-sample expected Loss: 0.13911
# Batch count: 248, Avg. per-sample expected Loss: 0.15531
# Batch count: 249, Avg. per-sample expected Loss: 0.14297
# Batch count: 250, Avg. per-sample expected Loss: 0.14424
# Batch count: 251, Avg. per-sample expected Loss: 0.14639
# Batch count: 252, Avg. per-sample expected Loss: 0.14114
# Batch count: 253, Avg. per-sample expected Loss: 0.13960
# Batch count: 254, Avg. per-sample expected Loss: 0.13710
# Batch count: 255, Avg. per-sample expected Loss: 0.15092
# Batch count: 256, Avg. per-sample expected Loss: 0.12837
# Batch count: 257, Avg. per-sample expected Loss: 0.14606
# Batch count: 258, Avg. per-sample expected Loss: 0.15670
# Batch count: 259, Avg. per-sample expected Loss: 0.16028
# Batch count: 260, Avg. per-sample expected Loss: 0.14200
# Batch count: 261, Avg. per-sample expected Loss: 0.14041
# Batch count: 262, Avg. per-sample expected Loss: 0.13700
# Batch count: 263, Avg. per-sample expected Loss: 0.14738
# Batch count: 264, Avg. per-sample expected Loss: 0.14167
# Batch count: 265, Avg. per-sample expected Loss: 0.11905
# Batch count: 266, Avg. per-sample expected Loss: 0.14065
# Batch count: 267, Avg. per-sample expected Loss: 0.13048
# Batch count: 268, Avg. per-sample expected Loss: 0.13551
# Batch count: 269, Avg. per-sample expected Loss: 0.13384
# Batch count: 270, Avg. per-sample expected Loss: 0.13168
# Batch count: 271, Avg. per-sample expected Loss: 0.13622
# Batch count: 272, Avg. per-sample expected Loss: 0.13828
# Batch count: 273, Avg. per-sample expected Loss: 0.14717
# Batch count: 274, Avg. per-sample expected Loss: 0.13734
# Batch count: 275, Avg. per-sample expected Loss: 0.14632
# Batch count: 276, Avg. per-sample expected Loss: 0.12708
# Batch count: 277, Avg. per-sample expected Loss: 0.13566
# Batch count: 278, Avg. per-sample expected Loss: 0.14482
# Batch count: 279, Avg. per-sample expected Loss: 0.13492
# Batch count: 280, Avg. per-sample expected Loss: 0.13647
# Batch count: 281, Avg. per-sample expected Loss: 0.13548
# Batch count: 282, Avg. per-sample expected Loss: 0.13871
# Batch count: 283, Avg. per-sample expected Loss: 0.13032
# Batch count: 284, Avg. per-sample expected Loss: 0.12782
# Batch count: 285, Avg. per-sample expected Loss: 0.13230
# Batch count: 286, Avg. per-sample expected Loss: 0.15297
# Batch count: 287, Avg. per-sample expected Loss: 0.13066
# Batch count: 288, Avg. per-sample expected Loss: 0.13668
# Batch count: 289, Avg. per-sample expected Loss: 0.12464
# Batch count: 290, Avg. per-sample expected Loss: 0.12237
# Batch count: 291, Avg. per-sample expected Loss: 0.13908
# Batch count: 292, Avg. per-sample expected Loss: 0.13418
# Batch count: 293, Avg. per-sample expected Loss: 0.14159
# Batch count: 294, Avg. per-sample expected Loss: 0.14137
# Batch count: 295, Avg. per-sample expected Loss: 0.14403
# Batch count: 296, Avg. per-sample expected Loss: 0.14095
# Batch count: 297, Avg. per-sample expected Loss: 0.13352
# Batch count: 298, Avg. per-sample expected Loss: 0.14146
# Batch count: 299, Avg. per-sample expected Loss: 0.12248
# Batch count: 300, Avg. per-sample expected Loss: 0.13511
# Batch count: 301, Avg. per-sample expected Loss: 0.14406
# Batch count: 302, Avg. per-sample expected Loss: 0.13872
# Batch count: 303, Avg. per-sample expected Loss: 0.13429
# Batch count: 304, Avg. per-sample expected Loss: 0.13599
# Batch count: 305, Avg. per-sample expected Loss: 0.12977
# Batch count: 306, Avg. per-sample expected Loss: 0.14231
# Batch count: 307, Avg. per-sample expected Loss: 0.14504
# Batch count: 308, Avg. per-sample expected Loss: 0.13782
# Batch count: 309, Avg. per-sample expected Loss: 0.14586
# Batch count: 310, Avg. per-sample expected Loss: 0.13907
# Batch count: 311, Avg. per-sample expected Loss: 0.12798
# Batch count: 312, Avg. per-sample expected Loss: 0.13510
# Batch count: 313, Avg. per-sample expected Loss: 0.13680
# Batch count: 314, Avg. per-sample expected Loss: 0.12655
# Batch count: 315, Avg. per-sample expected Loss: 0.13516
# Batch count: 316, Avg. per-sample expected Loss: 0.14846
# Batch count: 317, Avg. per-sample expected Loss: 0.15740
# Batch count: 318, Avg. per-sample expected Loss: 0.13721
# Batch count: 319, Avg. per-sample expected Loss: 0.15040
# Batch count: 320, Avg. per-sample expected Loss: 0.15648
# Batch count: 321, Avg. per-sample expected Loss: 0.14014
# Batch count: 322, Avg. per-sample expected Loss: 0.13239
# Batch count: 323, Avg. per-sample expected Loss: 0.13738
# Batch count: 324, Avg. per-sample expected Loss: 0.13153
# Batch count: 325, Avg. per-sample expected Loss: 0.14850
# Batch count: 326, Avg. per-sample expected Loss: 0.12358
# Batch count: 327, Avg. per-sample expected Loss: 0.13042
# Batch count: 328, Avg. per-sample expected Loss: 0.14694
# Batch count: 329, Avg. per-sample expected Loss: 0.13957
# Batch count: 330, Avg. per-sample expected Loss: 0.14610
# Batch count: 331, Avg. per-sample expected Loss: 0.13239
# Batch count: 332, Avg. per-sample expected Loss: 0.12215
# Batch count: 333, Avg. per-sample expected Loss: 0.12891
# Batch count: 334, Avg. per-sample expected Loss: 0.13592
# Batch count: 335, Avg. per-sample expected Loss: 0.13265
# Batch count: 336, Avg. per-sample expected Loss: 0.13521
# Batch count: 337, Avg. per-sample expected Loss: 0.13372
# Batch count: 338, Avg. per-sample expected Loss: 0.15506
# Batch count: 339, Avg. per-sample expected Loss: 0.14634
# Batch count: 340, Avg. per-sample expected Loss: 0.15097
# Batch count: 341, Avg. per-sample expected Loss: 0.14733
# Batch count: 342, Avg. per-sample expected Loss: 0.15081
# Batch count: 343, Avg. per-sample expected Loss: 0.14405
# Batch count: 344, Avg. per-sample expected Loss: 0.13927
# Batch count: 345, Avg. per-sample expected Loss: 0.13765
# Batch count: 346, Avg. per-sample expected Loss: 0.15233
# Batch count: 347, Avg. per-sample expected Loss: 0.13606
# Batch count: 348, Avg. per-sample expected Loss: 0.14351
# Batch count: 349, Avg. per-sample expected Loss: 0.14469

# %% [markdown]
# ## Plots

# %%
plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "b", label="2-QNSCD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.", label="2-QNSCD Empirical Loss")

plt.title("Training using 2-QNSCD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.show()

# %% [markdown]
# ## 6-RQSGD using 600 samples

# %%
SGD6cparams = np.array(init_params)
SGD6c_cost = []
SGD6c_Ecost = []

SGD6c_cost.append(temp_cost)
SGD6c_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 6 coordinates
        idx = sorted(np.random.permutation(nparams)[0:6].tolist())
        
        grad = []
        
        ### Gradient estimation
        for i_grad in range(6):
            y_hat,b = EstGrad(SGD6cparams,phiT[:,itr3+i_grad],idx[i_grad])
            b = (1-b)/2
            grad.append((-1)*((-1)**b)*loss(y_hat,labelT[itr3+i_grad]))

        ### single-parameter update
        SGD6cparams[idx] = SGD6cparams[idx] - np.dot(step_size,grad)
    
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6cparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6c_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6ccount = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6cparams,phiT[:,itr]) != labelT[itr]:
            SGD6ccount += 1
    SGD6c_Ecost.append(SGD6ccount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "3Q 6-RQSGD Expected Loss"
file_name2 = "3Q 6-RQSGD Empirical Loss"

np.save(file_name1,SGD6c_cost)
np.save(file_name2,SGD6c_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.56092
# Batch count:  1, Avg. per-sample expected Loss: 0.56540
# Batch count:  2, Avg. per-sample expected Loss: 0.55718
# Batch count:  3, Avg. per-sample expected Loss: 0.56292
# Batch count:  4, Avg. per-sample expected Loss: 0.55016
# Batch count:  5, Avg. per-sample expected Loss: 0.54493
# Batch count:  6, Avg. per-sample expected Loss: 0.54226
# Batch count:  7, Avg. per-sample expected Loss: 0.53869
# Batch count:  8, Avg. per-sample expected Loss: 0.53897
# Batch count:  9, Avg. per-sample expected Loss: 0.54657
# Batch count: 10, Avg. per-sample expected Loss: 0.54988
# Batch count: 11, Avg. per-sample expected Loss: 0.54743
# Batch count: 12, Avg. per-sample expected Loss: 0.53926
# Batch count: 13, Avg. per-sample expected Loss: 0.52754
# Batch count: 14, Avg. per-sample expected Loss: 0.53675
# Batch count: 15, Avg. per-sample expected Loss: 0.53782
# Batch count: 16, Avg. per-sample expected Loss: 0.53829
# Batch count: 17, Avg. per-sample expected Loss: 0.52190
# Batch count: 18, Avg. per-sample expected Loss: 0.52933
# Batch count: 19, Avg. per-sample expected Loss: 0.53002
# Batch count: 20, Avg. per-sample expected Loss: 0.53240
# Batch count: 21, Avg. per-sample expected Loss: 0.52780
# Batch count: 22, Avg. per-sample expected Loss: 0.52185
# Batch count: 23, Avg. per-sample expected Loss: 0.52648
# Batch count: 24, Avg. per-sample expected Loss: 0.52037
# Batch count: 25, Avg. per-sample expected Loss: 0.52014
# Batch count: 26, Avg. per-sample expected Loss: 0.51439
# Batch count: 27, Avg. per-sample expected Loss: 0.51385
# Batch count: 28, Avg. per-sample expected Loss: 0.50681
# Batch count: 29, Avg. per-sample expected Loss: 0.50196
# Batch count: 30, Avg. per-sample expected Loss: 0.50681
# Batch count: 31, Avg. per-sample expected Loss: 0.49731
# Batch count: 32, Avg. per-sample expected Loss: 0.49962
# Batch count: 33, Avg. per-sample expected Loss: 0.50306
# Batch count: 34, Avg. per-sample expected Loss: 0.50266
# Batch count: 35, Avg. per-sample expected Loss: 0.49795
# Batch count: 36, Avg. per-sample expected Loss: 0.50426
# Batch count: 37, Avg. per-sample expected Loss: 0.49464
# Batch count: 38, Avg. per-sample expected Loss: 0.49284
# Batch count: 39, Avg. per-sample expected Loss: 0.49477
# Batch count: 40, Avg. per-sample expected Loss: 0.48543
# Batch count: 41, Avg. per-sample expected Loss: 0.46702
# Batch count: 42, Avg. per-sample expected Loss: 0.47667
# Batch count: 43, Avg. per-sample expected Loss: 0.47371
# Batch count: 44, Avg. per-sample expected Loss: 0.47337
# Batch count: 45, Avg. per-sample expected Loss: 0.47171
# Batch count: 46, Avg. per-sample expected Loss: 0.47149
# Batch count: 47, Avg. per-sample expected Loss: 0.46552
# Batch count: 48, Avg. per-sample expected Loss: 0.46271
# Batch count: 49, Avg. per-sample expected Loss: 0.46008
# Batch count: 50, Avg. per-sample expected Loss: 0.44973
# Batch count: 51, Avg. per-sample expected Loss: 0.45908
# Batch count: 52, Avg. per-sample expected Loss: 0.45359
# Batch count: 53, Avg. per-sample expected Loss: 0.44853
# Batch count: 54, Avg. per-sample expected Loss: 0.44363
# Batch count: 55, Avg. per-sample expected Loss: 0.44126
# Batch count: 56, Avg. per-sample expected Loss: 0.43073
# Batch count: 57, Avg. per-sample expected Loss: 0.43166
# Batch count: 58, Avg. per-sample expected Loss: 0.44488
# Batch count: 59, Avg. per-sample expected Loss: 0.42970
# Batch count: 60, Avg. per-sample expected Loss: 0.42225
# Batch count: 61, Avg. per-sample expected Loss: 0.42717
# Batch count: 62, Avg. per-sample expected Loss: 0.42065
# Batch count: 63, Avg. per-sample expected Loss: 0.43027
# Batch count: 64, Avg. per-sample expected Loss: 0.41537
# Batch count: 65, Avg. per-sample expected Loss: 0.41654
# Batch count: 66, Avg. per-sample expected Loss: 0.41261
# Batch count: 67, Avg. per-sample expected Loss: 0.41083
# Batch count: 68, Avg. per-sample expected Loss: 0.40108
# Batch count: 69, Avg. per-sample expected Loss: 0.40061
# Batch count: 70, Avg. per-sample expected Loss: 0.39709
# Batch count: 71, Avg. per-sample expected Loss: 0.39611
# Batch count: 72, Avg. per-sample expected Loss: 0.39123
# Batch count: 73, Avg. per-sample expected Loss: 0.38973
# Batch count: 74, Avg. per-sample expected Loss: 0.38106
# Batch count: 75, Avg. per-sample expected Loss: 0.38658
# Batch count: 76, Avg. per-sample expected Loss: 0.38753
# Batch count: 77, Avg. per-sample expected Loss: 0.37794
# Batch count: 78, Avg. per-sample expected Loss: 0.37722
# Batch count: 79, Avg. per-sample expected Loss: 0.37586
# Batch count: 80, Avg. per-sample expected Loss: 0.36926
# Batch count: 81, Avg. per-sample expected Loss: 0.34384
# Batch count: 82, Avg. per-sample expected Loss: 0.34532
# Batch count: 83, Avg. per-sample expected Loss: 0.34435
# Batch count: 84, Avg. per-sample expected Loss: 0.34899
# Batch count: 85, Avg. per-sample expected Loss: 0.35062
# Batch count: 86, Avg. per-sample expected Loss: 0.33454
# Batch count: 87, Avg. per-sample expected Loss: 0.33808
# Batch count: 88, Avg. per-sample expected Loss: 0.33154
# Batch count: 89, Avg. per-sample expected Loss: 0.32443
# Batch count: 90, Avg. per-sample expected Loss: 0.30733
# Batch count: 91, Avg. per-sample expected Loss: 0.32320
# Batch count: 92, Avg. per-sample expected Loss: 0.30765
# Batch count: 93, Avg. per-sample expected Loss: 0.30394
# Batch count: 94, Avg. per-sample expected Loss: 0.31493
# Batch count: 95, Avg. per-sample expected Loss: 0.30600
# Batch count: 96, Avg. per-sample expected Loss: 0.29977
# Batch count: 97, Avg. per-sample expected Loss: 0.29492
# Batch count: 98, Avg. per-sample expected Loss: 0.28779
# Batch count: 99, Avg. per-sample expected Loss: 0.28875
# Batch count: 100, Avg. per-sample expected Loss: 0.28384
# Batch count: 101, Avg. per-sample expected Loss: 0.27936
# Batch count: 102, Avg. per-sample expected Loss: 0.28131
# Batch count: 103, Avg. per-sample expected Loss: 0.27600
# Batch count: 104, Avg. per-sample expected Loss: 0.27992
# Batch count: 105, Avg. per-sample expected Loss: 0.27096
# Batch count: 106, Avg. per-sample expected Loss: 0.27972
# Batch count: 107, Avg. per-sample expected Loss: 0.26308
# Batch count: 108, Avg. per-sample expected Loss: 0.26977
# Batch count: 109, Avg. per-sample expected Loss: 0.26881
# Batch count: 110, Avg. per-sample expected Loss: 0.25984
# Batch count: 111, Avg. per-sample expected Loss: 0.25558
# Batch count: 112, Avg. per-sample expected Loss: 0.24812
# Batch count: 113, Avg. per-sample expected Loss: 0.25134
# Batch count: 114, Avg. per-sample expected Loss: 0.25044
# Batch count: 115, Avg. per-sample expected Loss: 0.25562
# Batch count: 116, Avg. per-sample expected Loss: 0.24487
# Batch count: 117, Avg. per-sample expected Loss: 0.25515
# Batch count: 118, Avg. per-sample expected Loss: 0.24222
# Batch count: 119, Avg. per-sample expected Loss: 0.22728
# Batch count: 120, Avg. per-sample expected Loss: 0.23354
# Batch count: 121, Avg. per-sample expected Loss: 0.23310
# Batch count: 122, Avg. per-sample expected Loss: 0.24071
# Batch count: 123, Avg. per-sample expected Loss: 0.23241
# Batch count: 124, Avg. per-sample expected Loss: 0.22648
# Batch count: 125, Avg. per-sample expected Loss: 0.22111
# Batch count: 126, Avg. per-sample expected Loss: 0.21645
# Batch count: 127, Avg. per-sample expected Loss: 0.22789
# Batch count: 128, Avg. per-sample expected Loss: 0.21923
# Batch count: 129, Avg. per-sample expected Loss: 0.22305
# Batch count: 130, Avg. per-sample expected Loss: 0.21646
# Batch count: 131, Avg. per-sample expected Loss: 0.21144
# Batch count: 132, Avg. per-sample expected Loss: 0.21265
# Batch count: 133, Avg. per-sample expected Loss: 0.20920
# Batch count: 134, Avg. per-sample expected Loss: 0.21538
# Batch count: 135, Avg. per-sample expected Loss: 0.21147
# Batch count: 136, Avg. per-sample expected Loss: 0.20835
# Batch count: 137, Avg. per-sample expected Loss: 0.21022
# Batch count: 138, Avg. per-sample expected Loss: 0.20107
# Batch count: 139, Avg. per-sample expected Loss: 0.21040
# Batch count: 140, Avg. per-sample expected Loss: 0.20209
# Batch count: 141, Avg. per-sample expected Loss: 0.20583
# Batch count: 142, Avg. per-sample expected Loss: 0.20297
# Batch count: 143, Avg. per-sample expected Loss: 0.19742
# Batch count: 144, Avg. per-sample expected Loss: 0.19832
# Batch count: 145, Avg. per-sample expected Loss: 0.19375
# Batch count: 146, Avg. per-sample expected Loss: 0.19848
# Batch count: 147, Avg. per-sample expected Loss: 0.19511
# Batch count: 148, Avg. per-sample expected Loss: 0.19535
# Batch count: 149, Avg. per-sample expected Loss: 0.20116
# Batch count: 150, Avg. per-sample expected Loss: 0.18689
# Batch count: 151, Avg. per-sample expected Loss: 0.18814
# Batch count: 152, Avg. per-sample expected Loss: 0.18672
# Batch count: 153, Avg. per-sample expected Loss: 0.19087
# Batch count: 154, Avg. per-sample expected Loss: 0.19239
# Batch count: 155, Avg. per-sample expected Loss: 0.18220
# Batch count: 156, Avg. per-sample expected Loss: 0.19296
# Batch count: 157, Avg. per-sample expected Loss: 0.18918
# Batch count: 158, Avg. per-sample expected Loss: 0.18446
# Batch count: 159, Avg. per-sample expected Loss: 0.18654
# Batch count: 160, Avg. per-sample expected Loss: 0.17394
# Batch count: 161, Avg. per-sample expected Loss: 0.18461
# Batch count: 162, Avg. per-sample expected Loss: 0.17991
# Batch count: 163, Avg. per-sample expected Loss: 0.17446
# Batch count: 164, Avg. per-sample expected Loss: 0.17399
# Batch count: 165, Avg. per-sample expected Loss: 0.17779
# Batch count: 166, Avg. per-sample expected Loss: 0.18126
# Batch count: 167, Avg. per-sample expected Loss: 0.17470
# Batch count: 168, Avg. per-sample expected Loss: 0.16990
# Batch count: 169, Avg. per-sample expected Loss: 0.17065
# Batch count: 170, Avg. per-sample expected Loss: 0.17759
# Batch count: 171, Avg. per-sample expected Loss: 0.17808
# Batch count: 172, Avg. per-sample expected Loss: 0.16924
# Batch count: 173, Avg. per-sample expected Loss: 0.16646
# Batch count: 174, Avg. per-sample expected Loss: 0.17271
# Batch count: 175, Avg. per-sample expected Loss: 0.16541
# Batch count: 176, Avg. per-sample expected Loss: 0.16624
# Batch count: 177, Avg. per-sample expected Loss: 0.16953
# Batch count: 178, Avg. per-sample expected Loss: 0.16873
# Batch count: 179, Avg. per-sample expected Loss: 0.16045
# Batch count: 180, Avg. per-sample expected Loss: 0.17610
# Batch count: 181, Avg. per-sample expected Loss: 0.16157
# Batch count: 182, Avg. per-sample expected Loss: 0.16516
# Batch count: 183, Avg. per-sample expected Loss: 0.16894
# Batch count: 184, Avg. per-sample expected Loss: 0.16594
# Batch count: 185, Avg. per-sample expected Loss: 0.16736
# Batch count: 186, Avg. per-sample expected Loss: 0.16739
# Batch count: 187, Avg. per-sample expected Loss: 0.17071
# Batch count: 188, Avg. per-sample expected Loss: 0.16609
# Batch count: 189, Avg. per-sample expected Loss: 0.15343
# Batch count: 190, Avg. per-sample expected Loss: 0.15312
# Batch count: 191, Avg. per-sample expected Loss: 0.16269
# Batch count: 192, Avg. per-sample expected Loss: 0.16503
# Batch count: 193, Avg. per-sample expected Loss: 0.15533
# Batch count: 194, Avg. per-sample expected Loss: 0.16083
# Batch count: 195, Avg. per-sample expected Loss: 0.16743
# Batch count: 196, Avg. per-sample expected Loss: 0.16144
# Batch count: 197, Avg. per-sample expected Loss: 0.16079
# Batch count: 198, Avg. per-sample expected Loss: 0.15898
# Batch count: 199, Avg. per-sample expected Loss: 0.16394
# Batch count: 200, Avg. per-sample expected Loss: 0.15821
# Batch count: 201, Avg. per-sample expected Loss: 0.15347
# Batch count: 202, Avg. per-sample expected Loss: 0.15626
# Batch count: 203, Avg. per-sample expected Loss: 0.15468
# Batch count: 204, Avg. per-sample expected Loss: 0.15878
# Batch count: 205, Avg. per-sample expected Loss: 0.15071
# Batch count: 206, Avg. per-sample expected Loss: 0.15396
# Batch count: 207, Avg. per-sample expected Loss: 0.16531
# Batch count: 208, Avg. per-sample expected Loss: 0.14670
# Batch count: 209, Avg. per-sample expected Loss: 0.14550
# Batch count: 210, Avg. per-sample expected Loss: 0.14846
# Batch count: 211, Avg. per-sample expected Loss: 0.15447
# Batch count: 212, Avg. per-sample expected Loss: 0.15112
# Batch count: 213, Avg. per-sample expected Loss: 0.15062
# Batch count: 214, Avg. per-sample expected Loss: 0.15135
# Batch count: 215, Avg. per-sample expected Loss: 0.16431
# Batch count: 216, Avg. per-sample expected Loss: 0.16609
# Batch count: 217, Avg. per-sample expected Loss: 0.15072
# Batch count: 218, Avg. per-sample expected Loss: 0.14970
# Batch count: 219, Avg. per-sample expected Loss: 0.14702
# Batch count: 220, Avg. per-sample expected Loss: 0.14993
# Batch count: 221, Avg. per-sample expected Loss: 0.15102
# Batch count: 222, Avg. per-sample expected Loss: 0.15052
# Batch count: 223, Avg. per-sample expected Loss: 0.15963
# Batch count: 224, Avg. per-sample expected Loss: 0.15628
# Batch count: 225, Avg. per-sample expected Loss: 0.16316
# Batch count: 226, Avg. per-sample expected Loss: 0.15104
# Batch count: 227, Avg. per-sample expected Loss: 0.15634
# Batch count: 228, Avg. per-sample expected Loss: 0.14914
# Batch count: 229, Avg. per-sample expected Loss: 0.15254
# Batch count: 230, Avg. per-sample expected Loss: 0.14612
# Batch count: 231, Avg. per-sample expected Loss: 0.14825
# Batch count: 232, Avg. per-sample expected Loss: 0.15115
# Batch count: 233, Avg. per-sample expected Loss: 0.14516
# Batch count: 234, Avg. per-sample expected Loss: 0.14760
# Batch count: 235, Avg. per-sample expected Loss: 0.14727
# Batch count: 236, Avg. per-sample expected Loss: 0.15662
# Batch count: 237, Avg. per-sample expected Loss: 0.15925
# Batch count: 238, Avg. per-sample expected Loss: 0.14069
# Batch count: 239, Avg. per-sample expected Loss: 0.15325
# Batch count: 240, Avg. per-sample expected Loss: 0.14692
# Batch count: 241, Avg. per-sample expected Loss: 0.14808
# Batch count: 242, Avg. per-sample expected Loss: 0.14972
# Batch count: 243, Avg. per-sample expected Loss: 0.13739
# Batch count: 244, Avg. per-sample expected Loss: 0.15792
# Batch count: 245, Avg. per-sample expected Loss: 0.14408
# Batch count: 246, Avg. per-sample expected Loss: 0.14588
# Batch count: 247, Avg. per-sample expected Loss: 0.15347
# Batch count: 248, Avg. per-sample expected Loss: 0.16394
# Batch count: 249, Avg. per-sample expected Loss: 0.15055
# Batch count: 250, Avg. per-sample expected Loss: 0.15656
# Batch count: 251, Avg. per-sample expected Loss: 0.15399
# Batch count: 252, Avg. per-sample expected Loss: 0.14537
# Batch count: 253, Avg. per-sample expected Loss: 0.14792
# Batch count: 254, Avg. per-sample expected Loss: 0.14708
# Batch count: 255, Avg. per-sample expected Loss: 0.15517
# Batch count: 256, Avg. per-sample expected Loss: 0.13267
# Batch count: 257, Avg. per-sample expected Loss: 0.14745
# Batch count: 258, Avg. per-sample expected Loss: 0.15535
# Batch count: 259, Avg. per-sample expected Loss: 0.15884
# Batch count: 260, Avg. per-sample expected Loss: 0.14725
# Batch count: 261, Avg. per-sample expected Loss: 0.14601
# Batch count: 262, Avg. per-sample expected Loss: 0.14157
# Batch count: 263, Avg. per-sample expected Loss: 0.14935
# Batch count: 264, Avg. per-sample expected Loss: 0.14940
# Batch count: 265, Avg. per-sample expected Loss: 0.12503
# Batch count: 266, Avg. per-sample expected Loss: 0.14395
# Batch count: 267, Avg. per-sample expected Loss: 0.13706
# Batch count: 268, Avg. per-sample expected Loss: 0.14270
# Batch count: 269, Avg. per-sample expected Loss: 0.13729
# Batch count: 270, Avg. per-sample expected Loss: 0.13552
# Batch count: 271, Avg. per-sample expected Loss: 0.13907
# Batch count: 272, Avg. per-sample expected Loss: 0.13656
# Batch count: 273, Avg. per-sample expected Loss: 0.14688
# Batch count: 274, Avg. per-sample expected Loss: 0.13875
# Batch count: 275, Avg. per-sample expected Loss: 0.14457
# Batch count: 276, Avg. per-sample expected Loss: 0.12565
# Batch count: 277, Avg. per-sample expected Loss: 0.13217
# Batch count: 278, Avg. per-sample expected Loss: 0.13951
# Batch count: 279, Avg. per-sample expected Loss: 0.13082
# Batch count: 280, Avg. per-sample expected Loss: 0.13660
# Batch count: 281, Avg. per-sample expected Loss: 0.13550
# Batch count: 282, Avg. per-sample expected Loss: 0.14072
# Batch count: 283, Avg. per-sample expected Loss: 0.13277
# Batch count: 284, Avg. per-sample expected Loss: 0.13069
# Batch count: 285, Avg. per-sample expected Loss: 0.13310
# Batch count: 286, Avg. per-sample expected Loss: 0.15524
# Batch count: 287, Avg. per-sample expected Loss: 0.13728
# Batch count: 288, Avg. per-sample expected Loss: 0.14382
# Batch count: 289, Avg. per-sample expected Loss: 0.13434
# Batch count: 290, Avg. per-sample expected Loss: 0.12809
# Batch count: 291, Avg. per-sample expected Loss: 0.14520
# Batch count: 292, Avg. per-sample expected Loss: 0.14004
# Batch count: 293, Avg. per-sample expected Loss: 0.14478
# Batch count: 294, Avg. per-sample expected Loss: 0.14479
# Batch count: 295, Avg. per-sample expected Loss: 0.14832
# Batch count: 296, Avg. per-sample expected Loss: 0.14515
# Batch count: 297, Avg. per-sample expected Loss: 0.13798
# Batch count: 298, Avg. per-sample expected Loss: 0.14472
# Batch count: 299, Avg. per-sample expected Loss: 0.12813
# Batch count: 300, Avg. per-sample expected Loss: 0.13889
# Batch count: 301, Avg. per-sample expected Loss: 0.14765
# Batch count: 302, Avg. per-sample expected Loss: 0.14331
# Batch count: 303, Avg. per-sample expected Loss: 0.13791
# Batch count: 304, Avg. per-sample expected Loss: 0.13951
# Batch count: 305, Avg. per-sample expected Loss: 0.13256
# Batch count: 306, Avg. per-sample expected Loss: 0.14772
# Batch count: 307, Avg. per-sample expected Loss: 0.14764
# Batch count: 308, Avg. per-sample expected Loss: 0.14061
# Batch count: 309, Avg. per-sample expected Loss: 0.15008
# Batch count: 310, Avg. per-sample expected Loss: 0.14320
# Batch count: 311, Avg. per-sample expected Loss: 0.13081
# Batch count: 312, Avg. per-sample expected Loss: 0.13436
# Batch count: 313, Avg. per-sample expected Loss: 0.13458
# Batch count: 314, Avg. per-sample expected Loss: 0.12370
# Batch count: 315, Avg. per-sample expected Loss: 0.12973
# Batch count: 316, Avg. per-sample expected Loss: 0.13971
# Batch count: 317, Avg. per-sample expected Loss: 0.14548
# Batch count: 318, Avg. per-sample expected Loss: 0.12791
# Batch count: 319, Avg. per-sample expected Loss: 0.13957
# Batch count: 320, Avg. per-sample expected Loss: 0.14734
# Batch count: 321, Avg. per-sample expected Loss: 0.13300
# Batch count: 322, Avg. per-sample expected Loss: 0.12908
# Batch count: 323, Avg. per-sample expected Loss: 0.13660
# Batch count: 324, Avg. per-sample expected Loss: 0.13062
# Batch count: 325, Avg. per-sample expected Loss: 0.14811
# Batch count: 326, Avg. per-sample expected Loss: 0.12348
# Batch count: 327, Avg. per-sample expected Loss: 0.13257
# Batch count: 328, Avg. per-sample expected Loss: 0.14527
# Batch count: 329, Avg. per-sample expected Loss: 0.13950
# Batch count: 330, Avg. per-sample expected Loss: 0.14531
# Batch count: 331, Avg. per-sample expected Loss: 0.13160
# Batch count: 332, Avg. per-sample expected Loss: 0.12205
# Batch count: 333, Avg. per-sample expected Loss: 0.13006
# Batch count: 334, Avg. per-sample expected Loss: 0.13799
# Batch count: 335, Avg. per-sample expected Loss: 0.13345
# Batch count: 336, Avg. per-sample expected Loss: 0.13561
# Batch count: 337, Avg. per-sample expected Loss: 0.13166
# Batch count: 338, Avg. per-sample expected Loss: 0.14977
# Batch count: 339, Avg. per-sample expected Loss: 0.13806
# Batch count: 340, Avg. per-sample expected Loss: 0.14069
# Batch count: 341, Avg. per-sample expected Loss: 0.13568
# Batch count: 342, Avg. per-sample expected Loss: 0.14120
# Batch count: 343, Avg. per-sample expected Loss: 0.13239
# Batch count: 344, Avg. per-sample expected Loss: 0.13180
# Batch count: 345, Avg. per-sample expected Loss: 0.13346
# Batch count: 346, Avg. per-sample expected Loss: 0.14302
# Batch count: 347, Avg. per-sample expected Loss: 0.12868
# Batch count: 348, Avg. per-sample expected Loss: 0.13877
# Batch count: 349, Avg. per-sample expected Loss: 0.13736

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="Training Expected Loss using 2-QNSCD")
plt.plot(SGD6c_cost, "g", label="Training Empirical Loss using 6-QRSGD")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="Training Empirical Loss using 2-QNSCD")
plt.plot(SGD6c_Ecost, "g.",alpha=0.5, label="Training Empirical Loss using 6-QRSGD")


plt.title("Training of QNN using 2-QNSCD, 2-QRSGD, and 4-QRSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()

# plt.savefig('2QNSCD_6-RSGD.png')
# plt.show()

# %% [markdown]
# ## 2-RQSGD using 600 samples per step and 6 samples per itr

# %%
SGD6params = np.array(init_params)
SGD6_cost = []
SGD6_Ecost = []

SGD6_cost.append(temp_cost)
SGD6_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 2 coordinates
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())
        
        grad = []
        
        ### Gradient estimation
        y_hat01,b01 = EstGrad(SGD6params,phiT[:,itr3+0],idx[0])
        b01 = (1-b01)/2
        y_hat02,b02 = EstGrad(SGD6params,phiT[:,itr3+1],idx[0])
        b02 = (1-b02)/2
        y_hat03,b03 = EstGrad(SGD6params,phiT[:,itr3+2],idx[0])
        b03 = (1-b03)/2
        
        temp0 = ((-1)**b01)*loss(y_hat01,labelT[itr3+0]) \
              + ((-1)**b02)*loss(y_hat02,labelT[itr3+1]) \
              + ((-1)**b03)*loss(y_hat03,labelT[itr3+2])

        grad.append((-1)*temp0/3)
        
        y_hat11,b11 = EstGrad(SGD6params,phiT[:,itr3+3],idx[1])
        b11 = (1-b11)/2
        y_hat12,b12 = EstGrad(SGD6params,phiT[:,itr3+4],idx[1])
        b12 = (1-b12)/2
        y_hat13,b13 = EstGrad(SGD6params,phiT[:,itr3+5],idx[1])
        b13 = (1-b13)/2
        
        temp1 = ((-1)**b11)*loss(y_hat11,labelT[itr3+3]) \
              + ((-1)**b12)*loss(y_hat12,labelT[itr3+4]) \
              + ((-1)**b13)*loss(y_hat13,labelT[itr3+5])

        grad.append((-1)*temp1/3)

        ### single-parameter update
        SGD6params[idx] = SGD6params[idx] - np.dot(step_size,grad)
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6params,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6count = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6params,phiT[:,itr]) != labelT[itr]:
            SGD6count += 1
    SGD6_Ecost.append(SGD6count/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "3Q 2-RQSGD_6s Expected Loss"
file_name2 = "3Q 2-RQSGD_6s Empirical Loss"

np.save(file_name1,SGD6_cost)
np.save(file_name2,SGD6_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.56092
# Batch count:  1, Avg. per-sample expected Loss: 0.57107
# Batch count:  2, Avg. per-sample expected Loss: 0.56287
# Batch count:  3, Avg. per-sample expected Loss: 0.57050
# Batch count:  4, Avg. per-sample expected Loss: 0.55855
# Batch count:  5, Avg. per-sample expected Loss: 0.55392
# Batch count:  6, Avg. per-sample expected Loss: 0.55479
# Batch count:  7, Avg. per-sample expected Loss: 0.55409
# Batch count:  8, Avg. per-sample expected Loss: 0.55540
# Batch count:  9, Avg. per-sample expected Loss: 0.56431
# Batch count: 10, Avg. per-sample expected Loss: 0.56762
# Batch count: 11, Avg. per-sample expected Loss: 0.56420
# Batch count: 12, Avg. per-sample expected Loss: 0.55683
# Batch count: 13, Avg. per-sample expected Loss: 0.54402
# Batch count: 14, Avg. per-sample expected Loss: 0.55618
# Batch count: 15, Avg. per-sample expected Loss: 0.56070
# Batch count: 16, Avg. per-sample expected Loss: 0.56238
# Batch count: 17, Avg. per-sample expected Loss: 0.54258
# Batch count: 18, Avg. per-sample expected Loss: 0.54969
# Batch count: 19, Avg. per-sample expected Loss: 0.55080
# Batch count: 20, Avg. per-sample expected Loss: 0.55257
# Batch count: 21, Avg. per-sample expected Loss: 0.54990
# Batch count: 22, Avg. per-sample expected Loss: 0.54533
# Batch count: 23, Avg. per-sample expected Loss: 0.54688
# Batch count: 24, Avg. per-sample expected Loss: 0.54323
# Batch count: 25, Avg. per-sample expected Loss: 0.54447
# Batch count: 26, Avg. per-sample expected Loss: 0.54096
# Batch count: 27, Avg. per-sample expected Loss: 0.54291
# Batch count: 28, Avg. per-sample expected Loss: 0.53626
# Batch count: 29, Avg. per-sample expected Loss: 0.53728
# Batch count: 30, Avg. per-sample expected Loss: 0.53966
# Batch count: 31, Avg. per-sample expected Loss: 0.53080
# Batch count: 32, Avg. per-sample expected Loss: 0.53050
# Batch count: 33, Avg. per-sample expected Loss: 0.53568
# Batch count: 34, Avg. per-sample expected Loss: 0.53620
# Batch count: 35, Avg. per-sample expected Loss: 0.53384
# Batch count: 36, Avg. per-sample expected Loss: 0.54304
# Batch count: 37, Avg. per-sample expected Loss: 0.53659
# Batch count: 38, Avg. per-sample expected Loss: 0.52828
# Batch count: 39, Avg. per-sample expected Loss: 0.53914
# Batch count: 40, Avg. per-sample expected Loss: 0.53375
# Batch count: 41, Avg. per-sample expected Loss: 0.51892
# Batch count: 42, Avg. per-sample expected Loss: 0.52354
# Batch count: 43, Avg. per-sample expected Loss: 0.52958
# Batch count: 44, Avg. per-sample expected Loss: 0.52398
# Batch count: 45, Avg. per-sample expected Loss: 0.52007
# Batch count: 46, Avg. per-sample expected Loss: 0.52548
# Batch count: 47, Avg. per-sample expected Loss: 0.51856
# Batch count: 48, Avg. per-sample expected Loss: 0.51938
# Batch count: 49, Avg. per-sample expected Loss: 0.51524
# Batch count: 50, Avg. per-sample expected Loss: 0.52423
# Batch count: 51, Avg. per-sample expected Loss: 0.51645
# Batch count: 52, Avg. per-sample expected Loss: 0.51895
# Batch count: 53, Avg. per-sample expected Loss: 0.51610
# Batch count: 54, Avg. per-sample expected Loss: 0.51808
# Batch count: 55, Avg. per-sample expected Loss: 0.52008
# Batch count: 56, Avg. per-sample expected Loss: 0.50228
# Batch count: 57, Avg. per-sample expected Loss: 0.51640
# Batch count: 58, Avg. per-sample expected Loss: 0.53205
# Batch count: 59, Avg. per-sample expected Loss: 0.51572
# Batch count: 60, Avg. per-sample expected Loss: 0.51126
# Batch count: 61, Avg. per-sample expected Loss: 0.52035
# Batch count: 62, Avg. per-sample expected Loss: 0.51180
# Batch count: 63, Avg. per-sample expected Loss: 0.51990
# Batch count: 64, Avg. per-sample expected Loss: 0.49761
# Batch count: 65, Avg. per-sample expected Loss: 0.50855
# Batch count: 66, Avg. per-sample expected Loss: 0.50549
# Batch count: 67, Avg. per-sample expected Loss: 0.51341
# Batch count: 68, Avg. per-sample expected Loss: 0.51321
# Batch count: 69, Avg. per-sample expected Loss: 0.49903
# Batch count: 70, Avg. per-sample expected Loss: 0.50833
# Batch count: 71, Avg. per-sample expected Loss: 0.51605
# Batch count: 72, Avg. per-sample expected Loss: 0.50543
# Batch count: 73, Avg. per-sample expected Loss: 0.50256
# Batch count: 74, Avg. per-sample expected Loss: 0.49339
# Batch count: 75, Avg. per-sample expected Loss: 0.50254
# Batch count: 76, Avg. per-sample expected Loss: 0.50039
# Batch count: 77, Avg. per-sample expected Loss: 0.49929
# Batch count: 78, Avg. per-sample expected Loss: 0.50026
# Batch count: 79, Avg. per-sample expected Loss: 0.49840
# Batch count: 80, Avg. per-sample expected Loss: 0.49766
# Batch count: 81, Avg. per-sample expected Loss: 0.49578
# Batch count: 82, Avg. per-sample expected Loss: 0.49467
# Batch count: 83, Avg. per-sample expected Loss: 0.49402
# Batch count: 84, Avg. per-sample expected Loss: 0.49193
# Batch count: 85, Avg. per-sample expected Loss: 0.49002
# Batch count: 86, Avg. per-sample expected Loss: 0.49187
# Batch count: 87, Avg. per-sample expected Loss: 0.50103
# Batch count: 88, Avg. per-sample expected Loss: 0.50100
# Batch count: 89, Avg. per-sample expected Loss: 0.49342
# Batch count: 90, Avg. per-sample expected Loss: 0.49323
# Batch count: 91, Avg. per-sample expected Loss: 0.48926
# Batch count: 92, Avg. per-sample expected Loss: 0.48198
# Batch count: 93, Avg. per-sample expected Loss: 0.48589
# Batch count: 94, Avg. per-sample expected Loss: 0.49105
# Batch count: 95, Avg. per-sample expected Loss: 0.48914
# Batch count: 96, Avg. per-sample expected Loss: 0.48980
# Batch count: 97, Avg. per-sample expected Loss: 0.48159
# Batch count: 98, Avg. per-sample expected Loss: 0.48432
# Batch count: 99, Avg. per-sample expected Loss: 0.48771
# Batch count: 100, Avg. per-sample expected Loss: 0.49356
# Batch count: 101, Avg. per-sample expected Loss: 0.48239
# Batch count: 102, Avg. per-sample expected Loss: 0.48712
# Batch count: 103, Avg. per-sample expected Loss: 0.48688
# Batch count: 104, Avg. per-sample expected Loss: 0.48653
# Batch count: 105, Avg. per-sample expected Loss: 0.49171
# Batch count: 106, Avg. per-sample expected Loss: 0.48443
# Batch count: 107, Avg. per-sample expected Loss: 0.48085
# Batch count: 108, Avg. per-sample expected Loss: 0.47994
# Batch count: 109, Avg. per-sample expected Loss: 0.48880
# Batch count: 110, Avg. per-sample expected Loss: 0.48344
# Batch count: 111, Avg. per-sample expected Loss: 0.47470
# Batch count: 112, Avg. per-sample expected Loss: 0.47989
# Batch count: 113, Avg. per-sample expected Loss: 0.48257
# Batch count: 114, Avg. per-sample expected Loss: 0.47978
# Batch count: 115, Avg. per-sample expected Loss: 0.48354
# Batch count: 116, Avg. per-sample expected Loss: 0.48104
# Batch count: 117, Avg. per-sample expected Loss: 0.47443
# Batch count: 118, Avg. per-sample expected Loss: 0.48113
# Batch count: 119, Avg. per-sample expected Loss: 0.47111
# Batch count: 120, Avg. per-sample expected Loss: 0.48585
# Batch count: 121, Avg. per-sample expected Loss: 0.47683
# Batch count: 122, Avg. per-sample expected Loss: 0.47978
# Batch count: 123, Avg. per-sample expected Loss: 0.47152
# Batch count: 124, Avg. per-sample expected Loss: 0.46729
# Batch count: 125, Avg. per-sample expected Loss: 0.45983
# Batch count: 126, Avg. per-sample expected Loss: 0.45833
# Batch count: 127, Avg. per-sample expected Loss: 0.46416
# Batch count: 128, Avg. per-sample expected Loss: 0.47345
# Batch count: 129, Avg. per-sample expected Loss: 0.47362
# Batch count: 130, Avg. per-sample expected Loss: 0.47357
# Batch count: 131, Avg. per-sample expected Loss: 0.46526
# Batch count: 132, Avg. per-sample expected Loss: 0.45845
# Batch count: 133, Avg. per-sample expected Loss: 0.46582
# Batch count: 134, Avg. per-sample expected Loss: 0.47303
# Batch count: 135, Avg. per-sample expected Loss: 0.46407
# Batch count: 136, Avg. per-sample expected Loss: 0.45803
# Batch count: 137, Avg. per-sample expected Loss: 0.47220
# Batch count: 138, Avg. per-sample expected Loss: 0.45613
# Batch count: 139, Avg. per-sample expected Loss: 0.46865
# Batch count: 140, Avg. per-sample expected Loss: 0.45193
# Batch count: 141, Avg. per-sample expected Loss: 0.45432
# Batch count: 142, Avg. per-sample expected Loss: 0.45825
# Batch count: 143, Avg. per-sample expected Loss: 0.44575
# Batch count: 144, Avg. per-sample expected Loss: 0.45511
# Batch count: 145, Avg. per-sample expected Loss: 0.44833
# Batch count: 146, Avg. per-sample expected Loss: 0.45602
# Batch count: 147, Avg. per-sample expected Loss: 0.43633
# Batch count: 148, Avg. per-sample expected Loss: 0.44335
# Batch count: 149, Avg. per-sample expected Loss: 0.45007
# Batch count: 150, Avg. per-sample expected Loss: 0.44758
# Batch count: 151, Avg. per-sample expected Loss: 0.44245
# Batch count: 152, Avg. per-sample expected Loss: 0.44983
# Batch count: 153, Avg. per-sample expected Loss: 0.43259
# Batch count: 154, Avg. per-sample expected Loss: 0.45009
# Batch count: 155, Avg. per-sample expected Loss: 0.42955
# Batch count: 156, Avg. per-sample expected Loss: 0.44080
# Batch count: 157, Avg. per-sample expected Loss: 0.43923
# Batch count: 158, Avg. per-sample expected Loss: 0.44326
# Batch count: 159, Avg. per-sample expected Loss: 0.43584
# Batch count: 160, Avg. per-sample expected Loss: 0.43347
# Batch count: 161, Avg. per-sample expected Loss: 0.43179
# Batch count: 162, Avg. per-sample expected Loss: 0.43736
# Batch count: 163, Avg. per-sample expected Loss: 0.43394
# Batch count: 164, Avg. per-sample expected Loss: 0.42578
# Batch count: 165, Avg. per-sample expected Loss: 0.43176
# Batch count: 166, Avg. per-sample expected Loss: 0.42507
# Batch count: 167, Avg. per-sample expected Loss: 0.43553
# Batch count: 168, Avg. per-sample expected Loss: 0.42530
# Batch count: 169, Avg. per-sample expected Loss: 0.42927
# Batch count: 170, Avg. per-sample expected Loss: 0.42972
# Batch count: 171, Avg. per-sample expected Loss: 0.41736
# Batch count: 172, Avg. per-sample expected Loss: 0.42356
# Batch count: 173, Avg. per-sample expected Loss: 0.42065
# Batch count: 174, Avg. per-sample expected Loss: 0.40796
# Batch count: 175, Avg. per-sample expected Loss: 0.41096
# Batch count: 176, Avg. per-sample expected Loss: 0.40700
# Batch count: 177, Avg. per-sample expected Loss: 0.42245
# Batch count: 178, Avg. per-sample expected Loss: 0.40561
# Batch count: 179, Avg. per-sample expected Loss: 0.41302
# Batch count: 180, Avg. per-sample expected Loss: 0.40708
# Batch count: 181, Avg. per-sample expected Loss: 0.40848
# Batch count: 182, Avg. per-sample expected Loss: 0.40853
# Batch count: 183, Avg. per-sample expected Loss: 0.40245
# Batch count: 184, Avg. per-sample expected Loss: 0.39055
# Batch count: 185, Avg. per-sample expected Loss: 0.39518
# Batch count: 186, Avg. per-sample expected Loss: 0.39335
# Batch count: 187, Avg. per-sample expected Loss: 0.40078
# Batch count: 188, Avg. per-sample expected Loss: 0.40004
# Batch count: 189, Avg. per-sample expected Loss: 0.39871
# Batch count: 190, Avg. per-sample expected Loss: 0.39348
# Batch count: 191, Avg. per-sample expected Loss: 0.39341
# Batch count: 192, Avg. per-sample expected Loss: 0.40076
# Batch count: 193, Avg. per-sample expected Loss: 0.38875
# Batch count: 194, Avg. per-sample expected Loss: 0.38538
# Batch count: 195, Avg. per-sample expected Loss: 0.38048
# Batch count: 196, Avg. per-sample expected Loss: 0.38880
# Batch count: 197, Avg. per-sample expected Loss: 0.38522
# Batch count: 198, Avg. per-sample expected Loss: 0.38988
# Batch count: 199, Avg. per-sample expected Loss: 0.38336
# Batch count: 200, Avg. per-sample expected Loss: 0.38569
# Batch count: 201, Avg. per-sample expected Loss: 0.38463
# Batch count: 202, Avg. per-sample expected Loss: 0.36896
# Batch count: 203, Avg. per-sample expected Loss: 0.37427
# Batch count: 204, Avg. per-sample expected Loss: 0.37967
# Batch count: 205, Avg. per-sample expected Loss: 0.37606
# Batch count: 206, Avg. per-sample expected Loss: 0.37554
# Batch count: 207, Avg. per-sample expected Loss: 0.37045
# Batch count: 208, Avg. per-sample expected Loss: 0.37279
# Batch count: 209, Avg. per-sample expected Loss: 0.35909
# Batch count: 210, Avg. per-sample expected Loss: 0.36943
# Batch count: 211, Avg. per-sample expected Loss: 0.36606
# Batch count: 212, Avg. per-sample expected Loss: 0.35748
# Batch count: 213, Avg. per-sample expected Loss: 0.36459
# Batch count: 214, Avg. per-sample expected Loss: 0.36191
# Batch count: 215, Avg. per-sample expected Loss: 0.35266
# Batch count: 216, Avg. per-sample expected Loss: 0.35052
# Batch count: 217, Avg. per-sample expected Loss: 0.34370
# Batch count: 218, Avg. per-sample expected Loss: 0.33853
# Batch count: 219, Avg. per-sample expected Loss: 0.34895
# Batch count: 220, Avg. per-sample expected Loss: 0.34043
# Batch count: 221, Avg. per-sample expected Loss: 0.34721
# Batch count: 222, Avg. per-sample expected Loss: 0.33749
# Batch count: 223, Avg. per-sample expected Loss: 0.33890
# Batch count: 224, Avg. per-sample expected Loss: 0.33282
# Batch count: 225, Avg. per-sample expected Loss: 0.32990
# Batch count: 226, Avg. per-sample expected Loss: 0.33390
# Batch count: 227, Avg. per-sample expected Loss: 0.33271
# Batch count: 228, Avg. per-sample expected Loss: 0.32668
# Batch count: 229, Avg. per-sample expected Loss: 0.32759
# Batch count: 230, Avg. per-sample expected Loss: 0.31993
# Batch count: 231, Avg. per-sample expected Loss: 0.32685
# Batch count: 232, Avg. per-sample expected Loss: 0.31093
# Batch count: 233, Avg. per-sample expected Loss: 0.31859
# Batch count: 234, Avg. per-sample expected Loss: 0.31070
# Batch count: 235, Avg. per-sample expected Loss: 0.31198
# Batch count: 236, Avg. per-sample expected Loss: 0.31329
# Batch count: 237, Avg. per-sample expected Loss: 0.30689
# Batch count: 238, Avg. per-sample expected Loss: 0.30301
# Batch count: 239, Avg. per-sample expected Loss: 0.30762
# Batch count: 240, Avg. per-sample expected Loss: 0.30407
# Batch count: 241, Avg. per-sample expected Loss: 0.30376
# Batch count: 242, Avg. per-sample expected Loss: 0.29390
# Batch count: 243, Avg. per-sample expected Loss: 0.30116
# Batch count: 244, Avg. per-sample expected Loss: 0.28635
# Batch count: 245, Avg. per-sample expected Loss: 0.29336
# Batch count: 246, Avg. per-sample expected Loss: 0.28290
# Batch count: 247, Avg. per-sample expected Loss: 0.29487
# Batch count: 248, Avg. per-sample expected Loss: 0.29112
# Batch count: 249, Avg. per-sample expected Loss: 0.29831
# Batch count: 250, Avg. per-sample expected Loss: 0.28148
# Batch count: 251, Avg. per-sample expected Loss: 0.26903
# Batch count: 252, Avg. per-sample expected Loss: 0.28502
# Batch count: 253, Avg. per-sample expected Loss: 0.27006
# Batch count: 254, Avg. per-sample expected Loss: 0.27177
# Batch count: 255, Avg. per-sample expected Loss: 0.29025
# Batch count: 256, Avg. per-sample expected Loss: 0.26121
# Batch count: 257, Avg. per-sample expected Loss: 0.27665
# Batch count: 258, Avg. per-sample expected Loss: 0.27900
# Batch count: 259, Avg. per-sample expected Loss: 0.27583
# Batch count: 260, Avg. per-sample expected Loss: 0.25722
# Batch count: 261, Avg. per-sample expected Loss: 0.25622
# Batch count: 262, Avg. per-sample expected Loss: 0.24879
# Batch count: 263, Avg. per-sample expected Loss: 0.25631
# Batch count: 264, Avg. per-sample expected Loss: 0.25240
# Batch count: 265, Avg. per-sample expected Loss: 0.24151
# Batch count: 266, Avg. per-sample expected Loss: 0.25124
# Batch count: 267, Avg. per-sample expected Loss: 0.24212
# Batch count: 268, Avg. per-sample expected Loss: 0.24345
# Batch count: 269, Avg. per-sample expected Loss: 0.24890
# Batch count: 270, Avg. per-sample expected Loss: 0.23535
# Batch count: 271, Avg. per-sample expected Loss: 0.23864
# Batch count: 272, Avg. per-sample expected Loss: 0.24077
# Batch count: 273, Avg. per-sample expected Loss: 0.23979
# Batch count: 274, Avg. per-sample expected Loss: 0.23180
# Batch count: 275, Avg. per-sample expected Loss: 0.23200
# Batch count: 276, Avg. per-sample expected Loss: 0.21999
# Batch count: 277, Avg. per-sample expected Loss: 0.22288
# Batch count: 278, Avg. per-sample expected Loss: 0.22380
# Batch count: 279, Avg. per-sample expected Loss: 0.21776
# Batch count: 280, Avg. per-sample expected Loss: 0.22608
# Batch count: 281, Avg. per-sample expected Loss: 0.21345
# Batch count: 282, Avg. per-sample expected Loss: 0.21765
# Batch count: 283, Avg. per-sample expected Loss: 0.20867
# Batch count: 284, Avg. per-sample expected Loss: 0.21022
# Batch count: 285, Avg. per-sample expected Loss: 0.20111
# Batch count: 286, Avg. per-sample expected Loss: 0.20812
# Batch count: 287, Avg. per-sample expected Loss: 0.20834
# Batch count: 288, Avg. per-sample expected Loss: 0.20589
# Batch count: 289, Avg. per-sample expected Loss: 0.19648
# Batch count: 290, Avg. per-sample expected Loss: 0.20214
# Batch count: 291, Avg. per-sample expected Loss: 0.20026
# Batch count: 292, Avg. per-sample expected Loss: 0.19292
# Batch count: 293, Avg. per-sample expected Loss: 0.20001
# Batch count: 294, Avg. per-sample expected Loss: 0.19843
# Batch count: 295, Avg. per-sample expected Loss: 0.20094
# Batch count: 296, Avg. per-sample expected Loss: 0.19296
# Batch count: 297, Avg. per-sample expected Loss: 0.18544
# Batch count: 298, Avg. per-sample expected Loss: 0.18950
# Batch count: 299, Avg. per-sample expected Loss: 0.17918
# Batch count: 300, Avg. per-sample expected Loss: 0.18303
# Batch count: 301, Avg. per-sample expected Loss: 0.18952
# Batch count: 302, Avg. per-sample expected Loss: 0.18498
# Batch count: 303, Avg. per-sample expected Loss: 0.17972
# Batch count: 304, Avg. per-sample expected Loss: 0.18014
# Batch count: 305, Avg. per-sample expected Loss: 0.17433
# Batch count: 306, Avg. per-sample expected Loss: 0.17824
# Batch count: 307, Avg. per-sample expected Loss: 0.18442
# Batch count: 308, Avg. per-sample expected Loss: 0.18001
# Batch count: 309, Avg. per-sample expected Loss: 0.18835
# Batch count: 310, Avg. per-sample expected Loss: 0.17756
# Batch count: 311, Avg. per-sample expected Loss: 0.16567
# Batch count: 312, Avg. per-sample expected Loss: 0.17124
# Batch count: 313, Avg. per-sample expected Loss: 0.17335
# Batch count: 314, Avg. per-sample expected Loss: 0.16187
# Batch count: 315, Avg. per-sample expected Loss: 0.16455
# Batch count: 316, Avg. per-sample expected Loss: 0.17220
# Batch count: 317, Avg. per-sample expected Loss: 0.17689
# Batch count: 318, Avg. per-sample expected Loss: 0.15907
# Batch count: 319, Avg. per-sample expected Loss: 0.16324
# Batch count: 320, Avg. per-sample expected Loss: 0.17176
# Batch count: 321, Avg. per-sample expected Loss: 0.15995
# Batch count: 322, Avg. per-sample expected Loss: 0.15544
# Batch count: 323, Avg. per-sample expected Loss: 0.15837
# Batch count: 324, Avg. per-sample expected Loss: 0.15679
# Batch count: 325, Avg. per-sample expected Loss: 0.16694
# Batch count: 326, Avg. per-sample expected Loss: 0.14781
# Batch count: 327, Avg. per-sample expected Loss: 0.15471
# Batch count: 328, Avg. per-sample expected Loss: 0.16416
# Batch count: 329, Avg. per-sample expected Loss: 0.15652
# Batch count: 330, Avg. per-sample expected Loss: 0.16211
# Batch count: 331, Avg. per-sample expected Loss: 0.14779
# Batch count: 332, Avg. per-sample expected Loss: 0.14514
# Batch count: 333, Avg. per-sample expected Loss: 0.14560
# Batch count: 334, Avg. per-sample expected Loss: 0.15267
# Batch count: 335, Avg. per-sample expected Loss: 0.14900
# Batch count: 336, Avg. per-sample expected Loss: 0.15002
# Batch count: 337, Avg. per-sample expected Loss: 0.14870
# Batch count: 338, Avg. per-sample expected Loss: 0.16140
# Batch count: 339, Avg. per-sample expected Loss: 0.15226
# Batch count: 340, Avg. per-sample expected Loss: 0.14860
# Batch count: 341, Avg. per-sample expected Loss: 0.14836
# Batch count: 342, Avg. per-sample expected Loss: 0.14634
# Batch count: 343, Avg. per-sample expected Loss: 0.14357
# Batch count: 344, Avg. per-sample expected Loss: 0.14644
# Batch count: 345, Avg. per-sample expected Loss: 0.13737
# Batch count: 346, Avg. per-sample expected Loss: 0.14757
# Batch count: 347, Avg. per-sample expected Loss: 0.13585
# Batch count: 348, Avg. per-sample expected Loss: 0.14074
# Batch count: 349, Avg. per-sample expected Loss: 0.14280

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")

plt.title("Training using 2-QNSCD and 2-RQSGD (6 samples per itr)")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("2RSGD_6s.png")
plt.show()

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")
plt.plot(SGD6c_cost, "g", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")
plt.plot(SGD6c_Ecost, "g.",alpha=0.5, label="6-RQSGD Empirical Loss")


plt.title("Training 2-QNSCD and 2-RQSGD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
# plt.savefig("RQSGD.png")
# plt.show()

# %% [markdown]
# ## Testing Phase

# %%
### Saving Final Parameters:
file_name1 = "3Q 2-QNSCD params"
file_name2 = "3Q 2-RQSGD_6s params"
file_name3 = "3Q 6-RQSGD params"

np.save(file_name1,NCGDparams)
np.save(file_name2,SGD6params)
np.save(file_name3,SGD6cparams)

# %%
phiTest = np.load('3-qubitsPhiTest_v1.npy')
labelTest = np.load('3-qubitsLabelTest_v1.npy')

phiTest.requires_grad = False
labelTest.requires_grad = False

# %%
nTest = 1000

NCGDparams_opt = NCGDparams 
SGD6params_opt = SGD6params
SGD6cparams_opt = SGD6cparams

# %%
### Optimal Expected Loss
expOperator = 0

for i in range(nTest):
    op = np.matmul(phiTest[:,i].reshape(dim,1),phiTest[:,i].reshape(1,dim))
    expOperator = expOperator + labelTest[i]*op
expOperator = expOperator/(nTest)
opt_value = 0.5*(1+sum(abs(np.linalg.svd(expOperator)[1])))

# %%
NCGD_rslt = []
SGD6_rslt = []
SGD6c_rslt = []

for i in range(int(1e1)):
    NCGDcount = 0
    SGD6count = 0
    SGD6ccount = 0

    for itr in range(nTest):
        if circuit_test(NCGDparams_opt,phiTest[:,itr]) == labelTest[itr]:
            NCGDcount += 1 
        if circuit_test(SGD6params_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6count += 1
        if circuit_test(SGD6cparams_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6ccount += 1
    
    NCGD_rslt.append(NCGDcount/nTest)
    SGD6_rslt.append(SGD6count/nTest)
    SGD6c_rslt.append(SGD6ccount/nTest)
#     print("itr = ",i)

# %%
print("Optimal: {:.3f} \nNCGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n2-RQSGD_6s: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n6-RQSGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f}"\
      .format(opt_value,np.average(NCGD_rslt),np.std(NCGD_rslt),max(NCGD_rslt),min(NCGD_rslt),\
              np.average(SGD6_rslt),np.std(SGD6_rslt),max(SGD6_rslt),min(SGD6_rslt), \
              np.average(SGD6c_rslt),np.std(SGD6c_rslt),max(SGD6c_rslt),min(SGD6c_rslt)))
# Out:
# Optimal: 0.874
# NCGD: 0.859 / 0.011 max: 0.877 min: 0.837
# 2-RQSGD_6s: 0.854 / 0.008 max: 0.865 min: 0.841
# 6-RQSGD: 0.856 / 0.009 max: 0.866 min: 0.832
