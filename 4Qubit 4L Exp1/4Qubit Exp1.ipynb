# %%
import pennylane as qml
from pennylane import numpy as np
import scipy
import matplotlib.pyplot as plt
from globalVars import *
from model_4qubit import *

from GRADest_4Q import EstGrad
from EQFIMest_4Q import Est_EQFIM

# %% [markdown]
# ## Quantum Neural Network

# %%
random_state = np.random.rand(dim)
random_state = random_state /np.linalg.norm(random_state)
qml.draw_mpl(QNN)(np.zeros(nparams),random_state)
# Out:
# (<Figure size 1300x500 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### Model Initialization

# %%
S_pItr = 6  # no. of samples used per-iteration 

nStep = 350
nItr = 100
step_size = 0.0025

Bsize = S_pItr*nItr

# %%
phiTrain = np.load('4-qubitsPhiTrain_v1.npy')
labelTrain = np.load('4-qubitsLabelTrain_v1.npy')

phiTrain.requires_grad = False
labelTrain.requires_grad = False

# %%
'QNSCD Dataset'
phiTrainNCGD = phiTrain
labelTrainNCGD = labelTrain

'SGD Dataset'
phiTrainSGD = phiTrain
labelTrainSGD = labelTrain

# %%
### Optimal Expected Loss
Opt_cost = []
itrBatch = np.linspace(0,Bsize*nStep,nStep,endpoint = False,dtype = 'int').tolist()
for itr1 in itrBatch:
    expOperator = 0
    for itr2 in range(Bsize):
        temp_phi = phiTrain[:,itr1+itr2]
        op = np.matmul(temp_phi.reshape(dim,1),temp_phi.reshape(1,dim))
        expOperator = expOperator + labelTrain[itr1+itr2]*op
    expOperator = expOperator/Bsize
    opt_value = 0.5*(1-sum(abs(np.linalg.svd(expOperator)[1])))
    Opt_cost.append(opt_value)

file_name = "4Q-Minimum Expected Loss"
np.save(file_name,Opt_cost)

# %% [markdown]
# # Optimizers

# %%
'QNN outputs yhat'
dev = qml.device("default.qubit", wires=nqubits, shots=1)

@qml.qnode(dev,interface='autograd')
def circuit_test(params,state):
    QNN(params,state)
    return qml.sample(qml.Hermitian(M,wires=list(range(nqubits))))

# %%
init_params = np.random.uniform(low=0, high=2*np.pi, size=nparams, requires_grad=True)
init_params = np.array([0.43759813, 4.11996975, 1.10477885, 5.57055168, 5.43163314, 3.93864496,
 3.73156917, 1.26885442, 3.65963692, 0.11796649, 4.376764,   1.75271384,
 0.89642774, 4.11107355, 2.76627377, 4.20084436], requires_grad=True)

'cost initialization'
phiTrain0 = phiTrain[:,-1*(Bsize+1):-1]
labelTrain0 = labelTrain[-1*(Bsize+1):-1]
temp_cost = sum([ps_expLoss(init_params,phiTrain0[:,itr],labelTrain0[itr]) for itr in range(Bsize)])/Bsize
print("Initial Average Per-Sample Expected Loss: ",temp_cost)

count = 0
for itr in range(Bsize):
    if circuit_test(init_params,phiTrain0[:,itr]) != labelTrain0[itr]:
        count += 1
temp_Ecost = count/Bsize
print("Initial Average Empirical Loss", temp_Ecost)
# Out:
# Initial Average Per-Sample Expected Loss:  0.4991157050400209
# Initial Average Empirical Loss 0.4716666666666667

# %% [markdown]
# ## Quantum Natural Stochastic Pairwise Coordinate Descent (2-QNSCD)

# %%
NCGDparams = np.array(init_params)
NCGD_cost = []
NCGD_Ecost = []

NCGD_cost.append(temp_cost)
NCGD_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainNCGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainNCGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a pair of coordinate
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())

        ### Gradient estimation
        y1, b1 = EstGrad(NCGDparams,phiT[:,itr3],idx[0])
        y2, b2 = EstGrad(NCGDparams,phiT[:,itr3+1],idx[1])
        b1 = (1-b1)/2
        b2 = (1-b2)/2

        grad = [-1*((-1)**b1)*loss(y1,labelT[itr3]),-1*((-1)**b2)*loss(y2,labelT[itr3+1])]
        
        ### E-QFIM estimation
        metric = Est_EQFIM(NCGDparams,idx,phiT[:,itr3+2:itr3+S_pItr])

        ### double-parameters update
        NCGDparams[idx] = NCGDparams[idx] - (step_size)*np.dot(np.linalg.inv(metric),grad) 
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(NCGDparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    NCGD_cost.append(energy)
    
    ### average empirical loss calculation
    NCGDcount = 0
    for itr in range(Bsize):
        if circuit_test(NCGDparams,phiT[:,itr]) != labelT[itr]:
            NCGDcount += 1
    NCGD_Ecost.append(NCGDcount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))

file_name1 = "4Q 2-QNSCD Expected Loss"
file_name2 = "4Q 2-QNSCD Empirical Loss"

np.save(file_name1,NCGD_cost)
np.save(file_name2,NCGD_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.49912
# Batch count:  1, Avg. per-sample expected Loss: 0.49843
# Batch count:  2, Avg. per-sample expected Loss: 0.49757
# Batch count:  3, Avg. per-sample expected Loss: 0.49874
# Batch count:  4, Avg. per-sample expected Loss: 0.50030
# Batch count:  5, Avg. per-sample expected Loss: 0.50112
# Batch count:  6, Avg. per-sample expected Loss: 0.49536
# Batch count:  7, Avg. per-sample expected Loss: 0.49333
# Batch count:  8, Avg. per-sample expected Loss: 0.48412
# Batch count:  9, Avg. per-sample expected Loss: 0.48397
# Batch count: 10, Avg. per-sample expected Loss: 0.47636
# Batch count: 11, Avg. per-sample expected Loss: 0.47787
# Batch count: 12, Avg. per-sample expected Loss: 0.47712
# Batch count: 13, Avg. per-sample expected Loss: 0.47301
# Batch count: 14, Avg. per-sample expected Loss: 0.47667
# Batch count: 15, Avg. per-sample expected Loss: 0.47514
# Batch count: 16, Avg. per-sample expected Loss: 0.45961
# Batch count: 17, Avg. per-sample expected Loss: 0.45201
# Batch count: 18, Avg. per-sample expected Loss: 0.46076
# Batch count: 19, Avg. per-sample expected Loss: 0.44563
# Batch count: 20, Avg. per-sample expected Loss: 0.43701
# Batch count: 21, Avg. per-sample expected Loss: 0.43395
# Batch count: 22, Avg. per-sample expected Loss: 0.42532
# Batch count: 23, Avg. per-sample expected Loss: 0.41883
# Batch count: 24, Avg. per-sample expected Loss: 0.41255
# Batch count: 25, Avg. per-sample expected Loss: 0.40686
# Batch count: 26, Avg. per-sample expected Loss: 0.40344
# Batch count: 27, Avg. per-sample expected Loss: 0.40746
# Batch count: 28, Avg. per-sample expected Loss: 0.39781
# Batch count: 29, Avg. per-sample expected Loss: 0.38406
# Batch count: 30, Avg. per-sample expected Loss: 0.37772
# Batch count: 31, Avg. per-sample expected Loss: 0.38603
# Batch count: 32, Avg. per-sample expected Loss: 0.39535
# Batch count: 33, Avg. per-sample expected Loss: 0.40113
# Batch count: 34, Avg. per-sample expected Loss: 0.41315
# Batch count: 35, Avg. per-sample expected Loss: 0.40476
# Batch count: 36, Avg. per-sample expected Loss: 0.39806
# Batch count: 37, Avg. per-sample expected Loss: 0.40188
# Batch count: 38, Avg. per-sample expected Loss: 0.39890
# Batch count: 39, Avg. per-sample expected Loss: 0.36263
# Batch count: 40, Avg. per-sample expected Loss: 0.36767
# Batch count: 41, Avg. per-sample expected Loss: 0.35147
# Batch count: 42, Avg. per-sample expected Loss: 0.33881
# Batch count: 43, Avg. per-sample expected Loss: 0.32832
# Batch count: 44, Avg. per-sample expected Loss: 0.33035
# Batch count: 45, Avg. per-sample expected Loss: 0.31943
# Batch count: 46, Avg. per-sample expected Loss: 0.31907
# Batch count: 47, Avg. per-sample expected Loss: 0.31190
# Batch count: 48, Avg. per-sample expected Loss: 0.30537
# Batch count: 49, Avg. per-sample expected Loss: 0.29876
# Batch count: 50, Avg. per-sample expected Loss: 0.28499
# Batch count: 51, Avg. per-sample expected Loss: 0.28921
# Batch count: 52, Avg. per-sample expected Loss: 0.29008
# Batch count: 53, Avg. per-sample expected Loss: 0.29037
# Batch count: 54, Avg. per-sample expected Loss: 0.27844
# Batch count: 55, Avg. per-sample expected Loss: 0.27964
# Batch count: 56, Avg. per-sample expected Loss: 0.27118
# Batch count: 57, Avg. per-sample expected Loss: 0.26466
# Batch count: 58, Avg. per-sample expected Loss: 0.25449
# Batch count: 59, Avg. per-sample expected Loss: 0.26225
# Batch count: 60, Avg. per-sample expected Loss: 0.26203
# Batch count: 61, Avg. per-sample expected Loss: 0.24658
# Batch count: 62, Avg. per-sample expected Loss: 0.24769
# Batch count: 63, Avg. per-sample expected Loss: 0.24876
# Batch count: 64, Avg. per-sample expected Loss: 0.24230
# Batch count: 65, Avg. per-sample expected Loss: 0.24704
# Batch count: 66, Avg. per-sample expected Loss: 0.23629
# Batch count: 67, Avg. per-sample expected Loss: 0.24487
# Batch count: 68, Avg. per-sample expected Loss: 0.23562
# Batch count: 69, Avg. per-sample expected Loss: 0.24256
# Batch count: 70, Avg. per-sample expected Loss: 0.24456
# Batch count: 71, Avg. per-sample expected Loss: 0.24090
# Batch count: 72, Avg. per-sample expected Loss: 0.24055
# Batch count: 73, Avg. per-sample expected Loss: 0.23466
# Batch count: 74, Avg. per-sample expected Loss: 0.22807
# Batch count: 75, Avg. per-sample expected Loss: 0.22762
# Batch count: 76, Avg. per-sample expected Loss: 0.21337
# Batch count: 77, Avg. per-sample expected Loss: 0.20668
# Batch count: 78, Avg. per-sample expected Loss: 0.20616
# Batch count: 79, Avg. per-sample expected Loss: 0.20379
# Batch count: 80, Avg. per-sample expected Loss: 0.19956
# Batch count: 81, Avg. per-sample expected Loss: 0.18364
# Batch count: 82, Avg. per-sample expected Loss: 0.18752
# Batch count: 83, Avg. per-sample expected Loss: 0.17789
# Batch count: 84, Avg. per-sample expected Loss: 0.18455
# Batch count: 85, Avg. per-sample expected Loss: 0.18152
# Batch count: 86, Avg. per-sample expected Loss: 0.17776
# Batch count: 87, Avg. per-sample expected Loss: 0.17081
# Batch count: 88, Avg. per-sample expected Loss: 0.16970
# Batch count: 89, Avg. per-sample expected Loss: 0.17750
# Batch count: 90, Avg. per-sample expected Loss: 0.16364
# Batch count: 91, Avg. per-sample expected Loss: 0.17305
# Batch count: 92, Avg. per-sample expected Loss: 0.16458
# Batch count: 93, Avg. per-sample expected Loss: 0.16312
# Batch count: 94, Avg. per-sample expected Loss: 0.16465
# Batch count: 95, Avg. per-sample expected Loss: 0.15497
# Batch count: 96, Avg. per-sample expected Loss: 0.15994
# Batch count: 97, Avg. per-sample expected Loss: 0.16030
# Batch count: 98, Avg. per-sample expected Loss: 0.16332
# Batch count: 99, Avg. per-sample expected Loss: 0.16648
# Batch count: 100, Avg. per-sample expected Loss: 0.16005
# Batch count: 101, Avg. per-sample expected Loss: 0.15307
# Batch count: 102, Avg. per-sample expected Loss: 0.16016
# Batch count: 103, Avg. per-sample expected Loss: 0.15037
# Batch count: 104, Avg. per-sample expected Loss: 0.14748
# Batch count: 105, Avg. per-sample expected Loss: 0.17518
# Batch count: 106, Avg. per-sample expected Loss: 0.16656
# Batch count: 107, Avg. per-sample expected Loss: 0.16479
# Batch count: 108, Avg. per-sample expected Loss: 0.16910
# Batch count: 109, Avg. per-sample expected Loss: 0.17243
# Batch count: 110, Avg. per-sample expected Loss: 0.15569
# Batch count: 111, Avg. per-sample expected Loss: 0.17228
# Batch count: 112, Avg. per-sample expected Loss: 0.16468
# Batch count: 113, Avg. per-sample expected Loss: 0.16145
# Batch count: 114, Avg. per-sample expected Loss: 0.15314
# Batch count: 115, Avg. per-sample expected Loss: 0.15995
# Batch count: 116, Avg. per-sample expected Loss: 0.16541
# Batch count: 117, Avg. per-sample expected Loss: 0.15604
# Batch count: 118, Avg. per-sample expected Loss: 0.16135
# Batch count: 119, Avg. per-sample expected Loss: 0.14381
# Batch count: 120, Avg. per-sample expected Loss: 0.14861
# Batch count: 121, Avg. per-sample expected Loss: 0.14370
# Batch count: 122, Avg. per-sample expected Loss: 0.15354
# Batch count: 123, Avg. per-sample expected Loss: 0.15401
# Batch count: 124, Avg. per-sample expected Loss: 0.14877
# Batch count: 125, Avg. per-sample expected Loss: 0.15633
# Batch count: 126, Avg. per-sample expected Loss: 0.16921
# Batch count: 127, Avg. per-sample expected Loss: 0.15062
# Batch count: 128, Avg. per-sample expected Loss: 0.15410
# Batch count: 129, Avg. per-sample expected Loss: 0.16469
# Batch count: 130, Avg. per-sample expected Loss: 0.16020
# Batch count: 131, Avg. per-sample expected Loss: 0.14966
# Batch count: 132, Avg. per-sample expected Loss: 0.15685
# Batch count: 133, Avg. per-sample expected Loss: 0.14402
# Batch count: 134, Avg. per-sample expected Loss: 0.14962
# Batch count: 135, Avg. per-sample expected Loss: 0.15969
# Batch count: 136, Avg. per-sample expected Loss: 0.13917
# Batch count: 137, Avg. per-sample expected Loss: 0.15748
# Batch count: 138, Avg. per-sample expected Loss: 0.15543
# Batch count: 139, Avg. per-sample expected Loss: 0.15462
# Batch count: 140, Avg. per-sample expected Loss: 0.16146
# Batch count: 141, Avg. per-sample expected Loss: 0.15970
# Batch count: 142, Avg. per-sample expected Loss: 0.15904
# Batch count: 143, Avg. per-sample expected Loss: 0.15908
# Batch count: 144, Avg. per-sample expected Loss: 0.15193
# Batch count: 145, Avg. per-sample expected Loss: 0.15103
# Batch count: 146, Avg. per-sample expected Loss: 0.16282
# Batch count: 147, Avg. per-sample expected Loss: 0.13769
# Batch count: 148, Avg. per-sample expected Loss: 0.14053
# Batch count: 149, Avg. per-sample expected Loss: 0.14836
# Batch count: 150, Avg. per-sample expected Loss: 0.16016
# Batch count: 151, Avg. per-sample expected Loss: 0.14665
# Batch count: 152, Avg. per-sample expected Loss: 0.15033
# Batch count: 153, Avg. per-sample expected Loss: 0.13731
# Batch count: 154, Avg. per-sample expected Loss: 0.14229
# Batch count: 155, Avg. per-sample expected Loss: 0.16048
# Batch count: 156, Avg. per-sample expected Loss: 0.15582
# Batch count: 157, Avg. per-sample expected Loss: 0.15899
# Batch count: 158, Avg. per-sample expected Loss: 0.16657
# Batch count: 159, Avg. per-sample expected Loss: 0.15384
# Batch count: 160, Avg. per-sample expected Loss: 0.15299
# Batch count: 161, Avg. per-sample expected Loss: 0.15449
# Batch count: 162, Avg. per-sample expected Loss: 0.15848
# Batch count: 163, Avg. per-sample expected Loss: 0.15346
# Batch count: 164, Avg. per-sample expected Loss: 0.15653
# Batch count: 165, Avg. per-sample expected Loss: 0.15568
# Batch count: 166, Avg. per-sample expected Loss: 0.15482
# Batch count: 167, Avg. per-sample expected Loss: 0.16413
# Batch count: 168, Avg. per-sample expected Loss: 0.15430
# Batch count: 169, Avg. per-sample expected Loss: 0.16016
# Batch count: 170, Avg. per-sample expected Loss: 0.15464
# Batch count: 171, Avg. per-sample expected Loss: 0.15660
# Batch count: 172, Avg. per-sample expected Loss: 0.15937
# Batch count: 173, Avg. per-sample expected Loss: 0.16644
# Batch count: 174, Avg. per-sample expected Loss: 0.15608
# Batch count: 175, Avg. per-sample expected Loss: 0.15653
# Batch count: 176, Avg. per-sample expected Loss: 0.16945
# Batch count: 177, Avg. per-sample expected Loss: 0.15922
# Batch count: 178, Avg. per-sample expected Loss: 0.17187
# Batch count: 179, Avg. per-sample expected Loss: 0.16498
# Batch count: 180, Avg. per-sample expected Loss: 0.16301
# Batch count: 181, Avg. per-sample expected Loss: 0.16928
# Batch count: 182, Avg. per-sample expected Loss: 0.15606
# Batch count: 183, Avg. per-sample expected Loss: 0.17047
# Batch count: 184, Avg. per-sample expected Loss: 0.16343
# Batch count: 185, Avg. per-sample expected Loss: 0.14856
# Batch count: 186, Avg. per-sample expected Loss: 0.14875
# Batch count: 187, Avg. per-sample expected Loss: 0.14679
# Batch count: 188, Avg. per-sample expected Loss: 0.14895
# Batch count: 189, Avg. per-sample expected Loss: 0.15925
# Batch count: 190, Avg. per-sample expected Loss: 0.16734
# Batch count: 191, Avg. per-sample expected Loss: 0.16857
# Batch count: 192, Avg. per-sample expected Loss: 0.15837
# Batch count: 193, Avg. per-sample expected Loss: 0.15324
# Batch count: 194, Avg. per-sample expected Loss: 0.15784
# Batch count: 195, Avg. per-sample expected Loss: 0.16013
# Batch count: 196, Avg. per-sample expected Loss: 0.15669
# Batch count: 197, Avg. per-sample expected Loss: 0.15472
# Batch count: 198, Avg. per-sample expected Loss: 0.14883
# Batch count: 199, Avg. per-sample expected Loss: 0.14602
# Batch count: 200, Avg. per-sample expected Loss: 0.16279
# Batch count: 201, Avg. per-sample expected Loss: 0.17099
# Batch count: 202, Avg. per-sample expected Loss: 0.16535
# Batch count: 203, Avg. per-sample expected Loss: 0.15315
# Batch count: 204, Avg. per-sample expected Loss: 0.16087
# Batch count: 205, Avg. per-sample expected Loss: 0.14324
# Batch count: 206, Avg. per-sample expected Loss: 0.14652
# Batch count: 207, Avg. per-sample expected Loss: 0.17536
# Batch count: 208, Avg. per-sample expected Loss: 0.14530
# Batch count: 209, Avg. per-sample expected Loss: 0.15688
# Batch count: 210, Avg. per-sample expected Loss: 0.14826
# Batch count: 211, Avg. per-sample expected Loss: 0.16193
# Batch count: 212, Avg. per-sample expected Loss: 0.15976
# Batch count: 213, Avg. per-sample expected Loss: 0.14718
# Batch count: 214, Avg. per-sample expected Loss: 0.15510
# Batch count: 215, Avg. per-sample expected Loss: 0.15979
# Batch count: 216, Avg. per-sample expected Loss: 0.16194
# Batch count: 217, Avg. per-sample expected Loss: 0.17182
# Batch count: 218, Avg. per-sample expected Loss: 0.15508
# Batch count: 219, Avg. per-sample expected Loss: 0.15856
# Batch count: 220, Avg. per-sample expected Loss: 0.15995
# Batch count: 221, Avg. per-sample expected Loss: 0.16396
# Batch count: 222, Avg. per-sample expected Loss: 0.15826
# Batch count: 223, Avg. per-sample expected Loss: 0.16559
# Batch count: 224, Avg. per-sample expected Loss: 0.15711
# Batch count: 225, Avg. per-sample expected Loss: 0.16262
# Batch count: 226, Avg. per-sample expected Loss: 0.16094
# Batch count: 227, Avg. per-sample expected Loss: 0.15440
# Batch count: 228, Avg. per-sample expected Loss: 0.16244
# Batch count: 229, Avg. per-sample expected Loss: 0.14868
# Batch count: 230, Avg. per-sample expected Loss: 0.16343
# Batch count: 231, Avg. per-sample expected Loss: 0.16874
# Batch count: 232, Avg. per-sample expected Loss: 0.15930
# Batch count: 233, Avg. per-sample expected Loss: 0.16492
# Batch count: 234, Avg. per-sample expected Loss: 0.16725
# Batch count: 235, Avg. per-sample expected Loss: 0.15780
# Batch count: 236, Avg. per-sample expected Loss: 0.16124
# Batch count: 237, Avg. per-sample expected Loss: 0.16224
# Batch count: 238, Avg. per-sample expected Loss: 0.17329
# Batch count: 239, Avg. per-sample expected Loss: 0.16209
# Batch count: 240, Avg. per-sample expected Loss: 0.16094
# Batch count: 241, Avg. per-sample expected Loss: 0.16422
# Batch count: 242, Avg. per-sample expected Loss: 0.16653
# Batch count: 243, Avg. per-sample expected Loss: 0.16881
# Batch count: 244, Avg. per-sample expected Loss: 0.16300
# Batch count: 245, Avg. per-sample expected Loss: 0.17490
# Batch count: 246, Avg. per-sample expected Loss: 0.17418
# Batch count: 247, Avg. per-sample expected Loss: 0.16778
# Batch count: 248, Avg. per-sample expected Loss: 0.15548
# Batch count: 249, Avg. per-sample expected Loss: 0.15702
# Batch count: 250, Avg. per-sample expected Loss: 0.14333
# Batch count: 251, Avg. per-sample expected Loss: 0.16005
# Batch count: 252, Avg. per-sample expected Loss: 0.15666
# Batch count: 253, Avg. per-sample expected Loss: 0.14570
# Batch count: 254, Avg. per-sample expected Loss: 0.16147
# Batch count: 255, Avg. per-sample expected Loss: 0.14642
# Batch count: 256, Avg. per-sample expected Loss: 0.14740
# Batch count: 257, Avg. per-sample expected Loss: 0.15601
# Batch count: 258, Avg. per-sample expected Loss: 0.15044
# Batch count: 259, Avg. per-sample expected Loss: 0.14575
# Batch count: 260, Avg. per-sample expected Loss: 0.15411
# Batch count: 261, Avg. per-sample expected Loss: 0.15231
# Batch count: 262, Avg. per-sample expected Loss: 0.14565
# Batch count: 263, Avg. per-sample expected Loss: 0.15108
# Batch count: 264, Avg. per-sample expected Loss: 0.14522
# Batch count: 265, Avg. per-sample expected Loss: 0.14681
# Batch count: 266, Avg. per-sample expected Loss: 0.14454
# Batch count: 267, Avg. per-sample expected Loss: 0.14946
# Batch count: 268, Avg. per-sample expected Loss: 0.15115
# Batch count: 269, Avg. per-sample expected Loss: 0.14765
# Batch count: 270, Avg. per-sample expected Loss: 0.14435
# Batch count: 271, Avg. per-sample expected Loss: 0.14594
# Batch count: 272, Avg. per-sample expected Loss: 0.14459
# Batch count: 273, Avg. per-sample expected Loss: 0.14633
# Batch count: 274, Avg. per-sample expected Loss: 0.14501
# Batch count: 275, Avg. per-sample expected Loss: 0.14823
# Batch count: 276, Avg. per-sample expected Loss: 0.15076
# Batch count: 277, Avg. per-sample expected Loss: 0.16146
# Batch count: 278, Avg. per-sample expected Loss: 0.15472
# Batch count: 279, Avg. per-sample expected Loss: 0.15822
# Batch count: 280, Avg. per-sample expected Loss: 0.15288
# Batch count: 281, Avg. per-sample expected Loss: 0.14817
# Batch count: 282, Avg. per-sample expected Loss: 0.14747
# Batch count: 283, Avg. per-sample expected Loss: 0.14220
# Batch count: 284, Avg. per-sample expected Loss: 0.14818
# Batch count: 285, Avg. per-sample expected Loss: 0.15586
# Batch count: 286, Avg. per-sample expected Loss: 0.14202
# Batch count: 287, Avg. per-sample expected Loss: 0.15131
# Batch count: 288, Avg. per-sample expected Loss: 0.16230
# Batch count: 289, Avg. per-sample expected Loss: 0.16399
# Batch count: 290, Avg. per-sample expected Loss: 0.16257
# Batch count: 291, Avg. per-sample expected Loss: 0.15908
# Batch count: 292, Avg. per-sample expected Loss: 0.16636
# Batch count: 293, Avg. per-sample expected Loss: 0.15533
# Batch count: 294, Avg. per-sample expected Loss: 0.16416
# Batch count: 295, Avg. per-sample expected Loss: 0.17454
# Batch count: 296, Avg. per-sample expected Loss: 0.17067
# Batch count: 297, Avg. per-sample expected Loss: 0.16653
# Batch count: 298, Avg. per-sample expected Loss: 0.16628
# Batch count: 299, Avg. per-sample expected Loss: 0.16565
# Batch count: 300, Avg. per-sample expected Loss: 0.15876
# Batch count: 301, Avg. per-sample expected Loss: 0.16300
# Batch count: 302, Avg. per-sample expected Loss: 0.16442
# Batch count: 303, Avg. per-sample expected Loss: 0.17355
# Batch count: 304, Avg. per-sample expected Loss: 0.16290
# Batch count: 305, Avg. per-sample expected Loss: 0.16475
# Batch count: 306, Avg. per-sample expected Loss: 0.16708
# Batch count: 307, Avg. per-sample expected Loss: 0.16015
# Batch count: 308, Avg. per-sample expected Loss: 0.16471
# Batch count: 309, Avg. per-sample expected Loss: 0.15596
# Batch count: 310, Avg. per-sample expected Loss: 0.15797
# Batch count: 311, Avg. per-sample expected Loss: 0.17149
# Batch count: 312, Avg. per-sample expected Loss: 0.15525
# Batch count: 313, Avg. per-sample expected Loss: 0.16395
# Batch count: 314, Avg. per-sample expected Loss: 0.16306
# Batch count: 315, Avg. per-sample expected Loss: 0.16111
# Batch count: 316, Avg. per-sample expected Loss: 0.15819
# Batch count: 317, Avg. per-sample expected Loss: 0.16223
# Batch count: 318, Avg. per-sample expected Loss: 0.14225
# Batch count: 319, Avg. per-sample expected Loss: 0.15597
# Batch count: 320, Avg. per-sample expected Loss: 0.15677
# Batch count: 321, Avg. per-sample expected Loss: 0.15609
# Batch count: 322, Avg. per-sample expected Loss: 0.15415
# Batch count: 323, Avg. per-sample expected Loss: 0.14397
# Batch count: 324, Avg. per-sample expected Loss: 0.14661
# Batch count: 325, Avg. per-sample expected Loss: 0.15607
# Batch count: 326, Avg. per-sample expected Loss: 0.13833
# Batch count: 327, Avg. per-sample expected Loss: 0.14429
# Batch count: 328, Avg. per-sample expected Loss: 0.13518
# Batch count: 329, Avg. per-sample expected Loss: 0.15415
# Batch count: 330, Avg. per-sample expected Loss: 0.13808
# Batch count: 331, Avg. per-sample expected Loss: 0.15619
# Batch count: 332, Avg. per-sample expected Loss: 0.14619
# Batch count: 333, Avg. per-sample expected Loss: 0.15534
# Batch count: 334, Avg. per-sample expected Loss: 0.15489
# Batch count: 335, Avg. per-sample expected Loss: 0.15199
# Batch count: 336, Avg. per-sample expected Loss: 0.15823
# Batch count: 337, Avg. per-sample expected Loss: 0.16035
# Batch count: 338, Avg. per-sample expected Loss: 0.14888
# Batch count: 339, Avg. per-sample expected Loss: 0.15609
# Batch count: 340, Avg. per-sample expected Loss: 0.15714
# Batch count: 341, Avg. per-sample expected Loss: 0.15784
# Batch count: 342, Avg. per-sample expected Loss: 0.14569
# Batch count: 343, Avg. per-sample expected Loss: 0.15715
# Batch count: 344, Avg. per-sample expected Loss: 0.13748
# Batch count: 345, Avg. per-sample expected Loss: 0.15655
# Batch count: 346, Avg. per-sample expected Loss: 0.15772
# Batch count: 347, Avg. per-sample expected Loss: 0.16742
# Batch count: 348, Avg. per-sample expected Loss: 0.16877
# Batch count: 349, Avg. per-sample expected Loss: 0.15852

# %% [markdown]
# ## Plots

# %%
plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "b", label="2-QNSCD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.", label="2-QNSCD Empirical Loss")

plt.title("Training using 2-QNSCD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.show()

# %% [markdown]
# ## 6-RQSGD using 600 samples per step

# %%
SGD6cparams = np.array(init_params)
SGD6c_cost = []
SGD6c_Ecost = []

SGD6c_cost.append(temp_cost)
SGD6c_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 6 coordinates
        idx = sorted(np.random.permutation(nparams)[0:6].tolist())
        
        grad = []
        
        ### Gradient estimation
        for i_grad in range(6):
            y_hat,b = EstGrad(SGD6cparams,phiT[:,itr3+i_grad],idx[i_grad])
            b = (1-b)/2
            grad.append((-1)*((-1)**b)*loss(y_hat,labelT[itr3+i_grad]))

        ### single-parameter update
        SGD6cparams[idx] = SGD6cparams[idx] - np.dot(step_size,grad)
    
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6cparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6c_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6ccount = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6cparams,phiT[:,itr]) != labelT[itr]:
            SGD6ccount += 1
    SGD6c_Ecost.append(SGD6ccount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "4Q 6-RQSGD Expected Loss"
file_name2 = "4Q 6-RQSGD Empirical Loss"

np.save(file_name1,SGD6c_cost)
np.save(file_name2,SGD6c_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.49912
# Batch count:  1, Avg. per-sample expected Loss: 0.49810
# Batch count:  2, Avg. per-sample expected Loss: 0.49752
# Batch count:  3, Avg. per-sample expected Loss: 0.49766
# Batch count:  4, Avg. per-sample expected Loss: 0.49605
# Batch count:  5, Avg. per-sample expected Loss: 0.49766
# Batch count:  6, Avg. per-sample expected Loss: 0.49586
# Batch count:  7, Avg. per-sample expected Loss: 0.49442
# Batch count:  8, Avg. per-sample expected Loss: 0.49589
# Batch count:  9, Avg. per-sample expected Loss: 0.49937
# Batch count: 10, Avg. per-sample expected Loss: 0.49726
# Batch count: 11, Avg. per-sample expected Loss: 0.49772
# Batch count: 12, Avg. per-sample expected Loss: 0.49896
# Batch count: 13, Avg. per-sample expected Loss: 0.49521
# Batch count: 14, Avg. per-sample expected Loss: 0.49702
# Batch count: 15, Avg. per-sample expected Loss: 0.49779
# Batch count: 16, Avg. per-sample expected Loss: 0.49467
# Batch count: 17, Avg. per-sample expected Loss: 0.49248
# Batch count: 18, Avg. per-sample expected Loss: 0.49867
# Batch count: 19, Avg. per-sample expected Loss: 0.49511
# Batch count: 20, Avg. per-sample expected Loss: 0.49545
# Batch count: 21, Avg. per-sample expected Loss: 0.49658
# Batch count: 22, Avg. per-sample expected Loss: 0.49716
# Batch count: 23, Avg. per-sample expected Loss: 0.49426
# Batch count: 24, Avg. per-sample expected Loss: 0.49447
# Batch count: 25, Avg. per-sample expected Loss: 0.49441
# Batch count: 26, Avg. per-sample expected Loss: 0.49446
# Batch count: 27, Avg. per-sample expected Loss: 0.49149
# Batch count: 28, Avg. per-sample expected Loss: 0.49262
# Batch count: 29, Avg. per-sample expected Loss: 0.49088
# Batch count: 30, Avg. per-sample expected Loss: 0.49081
# Batch count: 31, Avg. per-sample expected Loss: 0.49293
# Batch count: 32, Avg. per-sample expected Loss: 0.49189
# Batch count: 33, Avg. per-sample expected Loss: 0.49103
# Batch count: 34, Avg. per-sample expected Loss: 0.49006
# Batch count: 35, Avg. per-sample expected Loss: 0.49093
# Batch count: 36, Avg. per-sample expected Loss: 0.49178
# Batch count: 37, Avg. per-sample expected Loss: 0.49250
# Batch count: 38, Avg. per-sample expected Loss: 0.49264
# Batch count: 39, Avg. per-sample expected Loss: 0.49181
# Batch count: 40, Avg. per-sample expected Loss: 0.49467
# Batch count: 41, Avg. per-sample expected Loss: 0.49209
# Batch count: 42, Avg. per-sample expected Loss: 0.49226
# Batch count: 43, Avg. per-sample expected Loss: 0.49216
# Batch count: 44, Avg. per-sample expected Loss: 0.49019
# Batch count: 45, Avg. per-sample expected Loss: 0.49151
# Batch count: 46, Avg. per-sample expected Loss: 0.49242
# Batch count: 47, Avg. per-sample expected Loss: 0.49077
# Batch count: 48, Avg. per-sample expected Loss: 0.49358
# Batch count: 49, Avg. per-sample expected Loss: 0.49373
# Batch count: 50, Avg. per-sample expected Loss: 0.49158
# Batch count: 51, Avg. per-sample expected Loss: 0.49207
# Batch count: 52, Avg. per-sample expected Loss: 0.49214
# Batch count: 53, Avg. per-sample expected Loss: 0.49091
# Batch count: 54, Avg. per-sample expected Loss: 0.49055
# Batch count: 55, Avg. per-sample expected Loss: 0.49114
# Batch count: 56, Avg. per-sample expected Loss: 0.49117
# Batch count: 57, Avg. per-sample expected Loss: 0.48723
# Batch count: 58, Avg. per-sample expected Loss: 0.48878
# Batch count: 59, Avg. per-sample expected Loss: 0.49058
# Batch count: 60, Avg. per-sample expected Loss: 0.48833
# Batch count: 61, Avg. per-sample expected Loss: 0.48800
# Batch count: 62, Avg. per-sample expected Loss: 0.48612
# Batch count: 63, Avg. per-sample expected Loss: 0.48809
# Batch count: 64, Avg. per-sample expected Loss: 0.48901
# Batch count: 65, Avg. per-sample expected Loss: 0.48921
# Batch count: 66, Avg. per-sample expected Loss: 0.48535
# Batch count: 67, Avg. per-sample expected Loss: 0.48794
# Batch count: 68, Avg. per-sample expected Loss: 0.48744
# Batch count: 69, Avg. per-sample expected Loss: 0.49027
# Batch count: 70, Avg. per-sample expected Loss: 0.48939
# Batch count: 71, Avg. per-sample expected Loss: 0.48863
# Batch count: 72, Avg. per-sample expected Loss: 0.49184
# Batch count: 73, Avg. per-sample expected Loss: 0.49041
# Batch count: 74, Avg. per-sample expected Loss: 0.49062
# Batch count: 75, Avg. per-sample expected Loss: 0.48834
# Batch count: 76, Avg. per-sample expected Loss: 0.49018
# Batch count: 77, Avg. per-sample expected Loss: 0.49199
# Batch count: 78, Avg. per-sample expected Loss: 0.49006
# Batch count: 79, Avg. per-sample expected Loss: 0.48933
# Batch count: 80, Avg. per-sample expected Loss: 0.48976
# Batch count: 81, Avg. per-sample expected Loss: 0.49007
# Batch count: 82, Avg. per-sample expected Loss: 0.48968
# Batch count: 83, Avg. per-sample expected Loss: 0.48876
# Batch count: 84, Avg. per-sample expected Loss: 0.48948
# Batch count: 85, Avg. per-sample expected Loss: 0.49030
# Batch count: 86, Avg. per-sample expected Loss: 0.49009
# Batch count: 87, Avg. per-sample expected Loss: 0.48879
# Batch count: 88, Avg. per-sample expected Loss: 0.48746
# Batch count: 89, Avg. per-sample expected Loss: 0.48731
# Batch count: 90, Avg. per-sample expected Loss: 0.48472
# Batch count: 91, Avg. per-sample expected Loss: 0.48296
# Batch count: 92, Avg. per-sample expected Loss: 0.48625
# Batch count: 93, Avg. per-sample expected Loss: 0.48668
# Batch count: 94, Avg. per-sample expected Loss: 0.48644
# Batch count: 95, Avg. per-sample expected Loss: 0.48864
# Batch count: 96, Avg. per-sample expected Loss: 0.48550
# Batch count: 97, Avg. per-sample expected Loss: 0.48812
# Batch count: 98, Avg. per-sample expected Loss: 0.48747
# Batch count: 99, Avg. per-sample expected Loss: 0.48721
# Batch count: 100, Avg. per-sample expected Loss: 0.48760
# Batch count: 101, Avg. per-sample expected Loss: 0.48465
# Batch count: 102, Avg. per-sample expected Loss: 0.48503
# Batch count: 103, Avg. per-sample expected Loss: 0.48315
# Batch count: 104, Avg. per-sample expected Loss: 0.48746
# Batch count: 105, Avg. per-sample expected Loss: 0.48677
# Batch count: 106, Avg. per-sample expected Loss: 0.48260
# Batch count: 107, Avg. per-sample expected Loss: 0.48679
# Batch count: 108, Avg. per-sample expected Loss: 0.48929
# Batch count: 109, Avg. per-sample expected Loss: 0.48615
# Batch count: 110, Avg. per-sample expected Loss: 0.48758
# Batch count: 111, Avg. per-sample expected Loss: 0.48590
# Batch count: 112, Avg. per-sample expected Loss: 0.48577
# Batch count: 113, Avg. per-sample expected Loss: 0.48605
# Batch count: 114, Avg. per-sample expected Loss: 0.48259
# Batch count: 115, Avg. per-sample expected Loss: 0.48138
# Batch count: 116, Avg. per-sample expected Loss: 0.48384
# Batch count: 117, Avg. per-sample expected Loss: 0.48385
# Batch count: 118, Avg. per-sample expected Loss: 0.48691
# Batch count: 119, Avg. per-sample expected Loss: 0.48379
# Batch count: 120, Avg. per-sample expected Loss: 0.48282
# Batch count: 121, Avg. per-sample expected Loss: 0.48285
# Batch count: 122, Avg. per-sample expected Loss: 0.48200
# Batch count: 123, Avg. per-sample expected Loss: 0.48329
# Batch count: 124, Avg. per-sample expected Loss: 0.48287
# Batch count: 125, Avg. per-sample expected Loss: 0.48096
# Batch count: 126, Avg. per-sample expected Loss: 0.48392
# Batch count: 127, Avg. per-sample expected Loss: 0.48073
# Batch count: 128, Avg. per-sample expected Loss: 0.48062
# Batch count: 129, Avg. per-sample expected Loss: 0.48429
# Batch count: 130, Avg. per-sample expected Loss: 0.48164
# Batch count: 131, Avg. per-sample expected Loss: 0.48019
# Batch count: 132, Avg. per-sample expected Loss: 0.48065
# Batch count: 133, Avg. per-sample expected Loss: 0.48062
# Batch count: 134, Avg. per-sample expected Loss: 0.48205
# Batch count: 135, Avg. per-sample expected Loss: 0.48602
# Batch count: 136, Avg. per-sample expected Loss: 0.48146
# Batch count: 137, Avg. per-sample expected Loss: 0.48060
# Batch count: 138, Avg. per-sample expected Loss: 0.47517
# Batch count: 139, Avg. per-sample expected Loss: 0.47745
# Batch count: 140, Avg. per-sample expected Loss: 0.47920
# Batch count: 141, Avg. per-sample expected Loss: 0.47909
# Batch count: 142, Avg. per-sample expected Loss: 0.47819
# Batch count: 143, Avg. per-sample expected Loss: 0.48044
# Batch count: 144, Avg. per-sample expected Loss: 0.47461
# Batch count: 145, Avg. per-sample expected Loss: 0.47821
# Batch count: 146, Avg. per-sample expected Loss: 0.47265
# Batch count: 147, Avg. per-sample expected Loss: 0.47394
# Batch count: 148, Avg. per-sample expected Loss: 0.47198
# Batch count: 149, Avg. per-sample expected Loss: 0.47260
# Batch count: 150, Avg. per-sample expected Loss: 0.47705
# Batch count: 151, Avg. per-sample expected Loss: 0.47462
# Batch count: 152, Avg. per-sample expected Loss: 0.47095
# Batch count: 153, Avg. per-sample expected Loss: 0.47126
# Batch count: 154, Avg. per-sample expected Loss: 0.46114
# Batch count: 155, Avg. per-sample expected Loss: 0.46892
# Batch count: 156, Avg. per-sample expected Loss: 0.47033
# Batch count: 157, Avg. per-sample expected Loss: 0.47150
# Batch count: 158, Avg. per-sample expected Loss: 0.46816
# Batch count: 159, Avg. per-sample expected Loss: 0.46588
# Batch count: 160, Avg. per-sample expected Loss: 0.46081
# Batch count: 161, Avg. per-sample expected Loss: 0.45965
# Batch count: 162, Avg. per-sample expected Loss: 0.46432
# Batch count: 163, Avg. per-sample expected Loss: 0.45923
# Batch count: 164, Avg. per-sample expected Loss: 0.46096
# Batch count: 165, Avg. per-sample expected Loss: 0.45293
# Batch count: 166, Avg. per-sample expected Loss: 0.45330
# Batch count: 167, Avg. per-sample expected Loss: 0.44761
# Batch count: 168, Avg. per-sample expected Loss: 0.44471
# Batch count: 169, Avg. per-sample expected Loss: 0.44782
# Batch count: 170, Avg. per-sample expected Loss: 0.45259
# Batch count: 171, Avg. per-sample expected Loss: 0.44726
# Batch count: 172, Avg. per-sample expected Loss: 0.44521
# Batch count: 173, Avg. per-sample expected Loss: 0.44287
# Batch count: 174, Avg. per-sample expected Loss: 0.43771
# Batch count: 175, Avg. per-sample expected Loss: 0.44376
# Batch count: 176, Avg. per-sample expected Loss: 0.44278
# Batch count: 177, Avg. per-sample expected Loss: 0.43681
# Batch count: 178, Avg. per-sample expected Loss: 0.43715
# Batch count: 179, Avg. per-sample expected Loss: 0.43547
# Batch count: 180, Avg. per-sample expected Loss: 0.42529
# Batch count: 181, Avg. per-sample expected Loss: 0.42980
# Batch count: 182, Avg. per-sample expected Loss: 0.41278
# Batch count: 183, Avg. per-sample expected Loss: 0.42049
# Batch count: 184, Avg. per-sample expected Loss: 0.41674
# Batch count: 185, Avg. per-sample expected Loss: 0.40124
# Batch count: 186, Avg. per-sample expected Loss: 0.40650
# Batch count: 187, Avg. per-sample expected Loss: 0.40844
# Batch count: 188, Avg. per-sample expected Loss: 0.38750
# Batch count: 189, Avg. per-sample expected Loss: 0.39262
# Batch count: 190, Avg. per-sample expected Loss: 0.39802
# Batch count: 191, Avg. per-sample expected Loss: 0.39627
# Batch count: 192, Avg. per-sample expected Loss: 0.38551
# Batch count: 193, Avg. per-sample expected Loss: 0.38216
# Batch count: 194, Avg. per-sample expected Loss: 0.38097
# Batch count: 195, Avg. per-sample expected Loss: 0.37976
# Batch count: 196, Avg. per-sample expected Loss: 0.37974
# Batch count: 197, Avg. per-sample expected Loss: 0.37697
# Batch count: 198, Avg. per-sample expected Loss: 0.35829
# Batch count: 199, Avg. per-sample expected Loss: 0.36418
# Batch count: 200, Avg. per-sample expected Loss: 0.37109
# Batch count: 201, Avg. per-sample expected Loss: 0.37038
# Batch count: 202, Avg. per-sample expected Loss: 0.35709
# Batch count: 203, Avg. per-sample expected Loss: 0.34498
# Batch count: 204, Avg. per-sample expected Loss: 0.34931
# Batch count: 205, Avg. per-sample expected Loss: 0.32479
# Batch count: 206, Avg. per-sample expected Loss: 0.31391
# Batch count: 207, Avg. per-sample expected Loss: 0.33596
# Batch count: 208, Avg. per-sample expected Loss: 0.30254
# Batch count: 209, Avg. per-sample expected Loss: 0.31340
# Batch count: 210, Avg. per-sample expected Loss: 0.29726
# Batch count: 211, Avg. per-sample expected Loss: 0.30739
# Batch count: 212, Avg. per-sample expected Loss: 0.30352
# Batch count: 213, Avg. per-sample expected Loss: 0.27890
# Batch count: 214, Avg. per-sample expected Loss: 0.27580
# Batch count: 215, Avg. per-sample expected Loss: 0.27703
# Batch count: 216, Avg. per-sample expected Loss: 0.27825
# Batch count: 217, Avg. per-sample expected Loss: 0.28293
# Batch count: 218, Avg. per-sample expected Loss: 0.26262
# Batch count: 219, Avg. per-sample expected Loss: 0.26323
# Batch count: 220, Avg. per-sample expected Loss: 0.26108
# Batch count: 221, Avg. per-sample expected Loss: 0.25878
# Batch count: 222, Avg. per-sample expected Loss: 0.25079
# Batch count: 223, Avg. per-sample expected Loss: 0.26394
# Batch count: 224, Avg. per-sample expected Loss: 0.25240
# Batch count: 225, Avg. per-sample expected Loss: 0.25816
# Batch count: 226, Avg. per-sample expected Loss: 0.23907
# Batch count: 227, Avg. per-sample expected Loss: 0.22655
# Batch count: 228, Avg. per-sample expected Loss: 0.22796
# Batch count: 229, Avg. per-sample expected Loss: 0.21174
# Batch count: 230, Avg. per-sample expected Loss: 0.22478
# Batch count: 231, Avg. per-sample expected Loss: 0.23294
# Batch count: 232, Avg. per-sample expected Loss: 0.21190
# Batch count: 233, Avg. per-sample expected Loss: 0.21931
# Batch count: 234, Avg. per-sample expected Loss: 0.21833
# Batch count: 235, Avg. per-sample expected Loss: 0.19513
# Batch count: 236, Avg. per-sample expected Loss: 0.19820
# Batch count: 237, Avg. per-sample expected Loss: 0.18976
# Batch count: 238, Avg. per-sample expected Loss: 0.19855
# Batch count: 239, Avg. per-sample expected Loss: 0.18564
# Batch count: 240, Avg. per-sample expected Loss: 0.17464
# Batch count: 241, Avg. per-sample expected Loss: 0.18170
# Batch count: 242, Avg. per-sample expected Loss: 0.16943
# Batch count: 243, Avg. per-sample expected Loss: 0.17477
# Batch count: 244, Avg. per-sample expected Loss: 0.17374
# Batch count: 245, Avg. per-sample expected Loss: 0.19129
# Batch count: 246, Avg. per-sample expected Loss: 0.17891
# Batch count: 247, Avg. per-sample expected Loss: 0.17225
# Batch count: 248, Avg. per-sample expected Loss: 0.16683
# Batch count: 249, Avg. per-sample expected Loss: 0.17111
# Batch count: 250, Avg. per-sample expected Loss: 0.15532
# Batch count: 251, Avg. per-sample expected Loss: 0.18126
# Batch count: 252, Avg. per-sample expected Loss: 0.17702
# Batch count: 253, Avg. per-sample expected Loss: 0.15833
# Batch count: 254, Avg. per-sample expected Loss: 0.17901
# Batch count: 255, Avg. per-sample expected Loss: 0.15441
# Batch count: 256, Avg. per-sample expected Loss: 0.16119
# Batch count: 257, Avg. per-sample expected Loss: 0.16885
# Batch count: 258, Avg. per-sample expected Loss: 0.16545
# Batch count: 259, Avg. per-sample expected Loss: 0.15585
# Batch count: 260, Avg. per-sample expected Loss: 0.16358
# Batch count: 261, Avg. per-sample expected Loss: 0.16286
# Batch count: 262, Avg. per-sample expected Loss: 0.15109
# Batch count: 263, Avg. per-sample expected Loss: 0.16004
# Batch count: 264, Avg. per-sample expected Loss: 0.14911
# Batch count: 265, Avg. per-sample expected Loss: 0.15479
# Batch count: 266, Avg. per-sample expected Loss: 0.15260
# Batch count: 267, Avg. per-sample expected Loss: 0.15691
# Batch count: 268, Avg. per-sample expected Loss: 0.15852
# Batch count: 269, Avg. per-sample expected Loss: 0.15489
# Batch count: 270, Avg. per-sample expected Loss: 0.15262
# Batch count: 271, Avg. per-sample expected Loss: 0.15313
# Batch count: 272, Avg. per-sample expected Loss: 0.15285
# Batch count: 273, Avg. per-sample expected Loss: 0.15203
# Batch count: 274, Avg. per-sample expected Loss: 0.15024
# Batch count: 275, Avg. per-sample expected Loss: 0.15097
# Batch count: 276, Avg. per-sample expected Loss: 0.14425
# Batch count: 277, Avg. per-sample expected Loss: 0.16117
# Batch count: 278, Avg. per-sample expected Loss: 0.15884
# Batch count: 279, Avg. per-sample expected Loss: 0.16342
# Batch count: 280, Avg. per-sample expected Loss: 0.15549
# Batch count: 281, Avg. per-sample expected Loss: 0.14701
# Batch count: 282, Avg. per-sample expected Loss: 0.14649
# Batch count: 283, Avg. per-sample expected Loss: 0.13658
# Batch count: 284, Avg. per-sample expected Loss: 0.14534
# Batch count: 285, Avg. per-sample expected Loss: 0.15112
# Batch count: 286, Avg. per-sample expected Loss: 0.12824
# Batch count: 287, Avg. per-sample expected Loss: 0.13932
# Batch count: 288, Avg. per-sample expected Loss: 0.15932
# Batch count: 289, Avg. per-sample expected Loss: 0.16029
# Batch count: 290, Avg. per-sample expected Loss: 0.15681
# Batch count: 291, Avg. per-sample expected Loss: 0.14913
# Batch count: 292, Avg. per-sample expected Loss: 0.15554
# Batch count: 293, Avg. per-sample expected Loss: 0.14895
# Batch count: 294, Avg. per-sample expected Loss: 0.15493
# Batch count: 295, Avg. per-sample expected Loss: 0.15773
# Batch count: 296, Avg. per-sample expected Loss: 0.14202
# Batch count: 297, Avg. per-sample expected Loss: 0.14096
# Batch count: 298, Avg. per-sample expected Loss: 0.15426
# Batch count: 299, Avg. per-sample expected Loss: 0.15031
# Batch count: 300, Avg. per-sample expected Loss: 0.13568
# Batch count: 301, Avg. per-sample expected Loss: 0.14031
# Batch count: 302, Avg. per-sample expected Loss: 0.14777
# Batch count: 303, Avg. per-sample expected Loss: 0.15144
# Batch count: 304, Avg. per-sample expected Loss: 0.14714
# Batch count: 305, Avg. per-sample expected Loss: 0.14864
# Batch count: 306, Avg. per-sample expected Loss: 0.15040
# Batch count: 307, Avg. per-sample expected Loss: 0.14284
# Batch count: 308, Avg. per-sample expected Loss: 0.14222
# Batch count: 309, Avg. per-sample expected Loss: 0.13312
# Batch count: 310, Avg. per-sample expected Loss: 0.13842
# Batch count: 311, Avg. per-sample expected Loss: 0.15775
# Batch count: 312, Avg. per-sample expected Loss: 0.14285
# Batch count: 313, Avg. per-sample expected Loss: 0.15176
# Batch count: 314, Avg. per-sample expected Loss: 0.15023
# Batch count: 315, Avg. per-sample expected Loss: 0.14996
# Batch count: 316, Avg. per-sample expected Loss: 0.14921
# Batch count: 317, Avg. per-sample expected Loss: 0.15416
# Batch count: 318, Avg. per-sample expected Loss: 0.13436
# Batch count: 319, Avg. per-sample expected Loss: 0.14886
# Batch count: 320, Avg. per-sample expected Loss: 0.14876
# Batch count: 321, Avg. per-sample expected Loss: 0.15502
# Batch count: 322, Avg. per-sample expected Loss: 0.15300
# Batch count: 323, Avg. per-sample expected Loss: 0.14188
# Batch count: 324, Avg. per-sample expected Loss: 0.14103
# Batch count: 325, Avg. per-sample expected Loss: 0.15135
# Batch count: 326, Avg. per-sample expected Loss: 0.13088
# Batch count: 327, Avg. per-sample expected Loss: 0.13982
# Batch count: 328, Avg. per-sample expected Loss: 0.12929
# Batch count: 329, Avg. per-sample expected Loss: 0.14788
# Batch count: 330, Avg. per-sample expected Loss: 0.13020
# Batch count: 331, Avg. per-sample expected Loss: 0.14751
# Batch count: 332, Avg. per-sample expected Loss: 0.13926
# Batch count: 333, Avg. per-sample expected Loss: 0.14538
# Batch count: 334, Avg. per-sample expected Loss: 0.14563
# Batch count: 335, Avg. per-sample expected Loss: 0.14058
# Batch count: 336, Avg. per-sample expected Loss: 0.14210
# Batch count: 337, Avg. per-sample expected Loss: 0.15184
# Batch count: 338, Avg. per-sample expected Loss: 0.14175
# Batch count: 339, Avg. per-sample expected Loss: 0.15025
# Batch count: 340, Avg. per-sample expected Loss: 0.15051
# Batch count: 341, Avg. per-sample expected Loss: 0.15033
# Batch count: 342, Avg. per-sample expected Loss: 0.13800
# Batch count: 343, Avg. per-sample expected Loss: 0.14908
# Batch count: 344, Avg. per-sample expected Loss: 0.12762
# Batch count: 345, Avg. per-sample expected Loss: 0.14653
# Batch count: 346, Avg. per-sample expected Loss: 0.14778
# Batch count: 347, Avg. per-sample expected Loss: 0.15597
# Batch count: 348, Avg. per-sample expected Loss: 0.15805
# Batch count: 349, Avg. per-sample expected Loss: 0.14973

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6c_cost, "b", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6c_Ecost, "c.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training using 2-QNSCD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("6-RQSGD.png")
plt.show()

# %% [markdown]
# ## 2-RQSGD using 600 samples per step and 6 samples per itr

# %%
SGD6params = np.array(init_params)
SGD6_cost = []
SGD6_Ecost = []

SGD6_cost.append(temp_cost)
SGD6_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 2 coordinates
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())
        
        grad = []
        
        ### Gradient estimation
        y_hat01,b01 = EstGrad(SGD6params,phiT[:,itr3+0],idx[0])
        b01 = (1-b01)/2
        y_hat02,b02 = EstGrad(SGD6params,phiT[:,itr3+1],idx[0])
        b02 = (1-b02)/2
        y_hat03,b03 = EstGrad(SGD6params,phiT[:,itr3+2],idx[0])
        b03 = (1-b03)/2
        
        temp0 = ((-1)**b01)*loss(y_hat01,labelT[itr3+0]) \
              + ((-1)**b02)*loss(y_hat02,labelT[itr3+1]) \
              + ((-1)**b03)*loss(y_hat03,labelT[itr3+2])

        grad.append((-1)*temp0/3)
        
        y_hat11,b11 = EstGrad(SGD6params,phiT[:,itr3+3],idx[1])
        b11 = (1-b11)/2
        y_hat12,b12 = EstGrad(SGD6params,phiT[:,itr3+4],idx[1])
        b12 = (1-b12)/2
        y_hat13,b13 = EstGrad(SGD6params,phiT[:,itr3+5],idx[1])
        b13 = (1-b13)/2
        
        temp1 = ((-1)**b11)*loss(y_hat11,labelT[itr3+3]) \
              + ((-1)**b12)*loss(y_hat12,labelT[itr3+4]) \
              + ((-1)**b13)*loss(y_hat13,labelT[itr3+5])

        grad.append((-1)*temp1/3)

        ### single-parameter update
        SGD6params[idx] = SGD6params[idx] - np.dot(step_size,grad)
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6params,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6count = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6params,phiT[:,itr]) != labelT[itr]:
            SGD6count += 1
    SGD6_Ecost.append(SGD6count/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "4Q 2-RQSGD_6s Expected Loss"
file_name2 = "4Q 2-RQSGD_6s Empirical Loss"

np.save(file_name1,SGD6_cost)
np.save(file_name2,SGD6_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.49912
# Batch count:  1, Avg. per-sample expected Loss: 0.49818
# Batch count:  2, Avg. per-sample expected Loss: 0.49813
# Batch count:  3, Avg. per-sample expected Loss: 0.49851
# Batch count:  4, Avg. per-sample expected Loss: 0.49812
# Batch count:  5, Avg. per-sample expected Loss: 0.50020
# Batch count:  6, Avg. per-sample expected Loss: 0.49667
# Batch count:  7, Avg. per-sample expected Loss: 0.49540
# Batch count:  8, Avg. per-sample expected Loss: 0.49779
# Batch count:  9, Avg. per-sample expected Loss: 0.50075
# Batch count: 10, Avg. per-sample expected Loss: 0.49752
# Batch count: 11, Avg. per-sample expected Loss: 0.49864
# Batch count: 12, Avg. per-sample expected Loss: 0.50075
# Batch count: 13, Avg. per-sample expected Loss: 0.49708
# Batch count: 14, Avg. per-sample expected Loss: 0.49933
# Batch count: 15, Avg. per-sample expected Loss: 0.50018
# Batch count: 16, Avg. per-sample expected Loss: 0.49546
# Batch count: 17, Avg. per-sample expected Loss: 0.49317
# Batch count: 18, Avg. per-sample expected Loss: 0.50184
# Batch count: 19, Avg. per-sample expected Loss: 0.49580
# Batch count: 20, Avg. per-sample expected Loss: 0.49556
# Batch count: 21, Avg. per-sample expected Loss: 0.49794
# Batch count: 22, Avg. per-sample expected Loss: 0.49891
# Batch count: 23, Avg. per-sample expected Loss: 0.49537
# Batch count: 24, Avg. per-sample expected Loss: 0.49689
# Batch count: 25, Avg. per-sample expected Loss: 0.49626
# Batch count: 26, Avg. per-sample expected Loss: 0.49512
# Batch count: 27, Avg. per-sample expected Loss: 0.49646
# Batch count: 28, Avg. per-sample expected Loss: 0.49673
# Batch count: 29, Avg. per-sample expected Loss: 0.49604
# Batch count: 30, Avg. per-sample expected Loss: 0.49556
# Batch count: 31, Avg. per-sample expected Loss: 0.49567
# Batch count: 32, Avg. per-sample expected Loss: 0.49776
# Batch count: 33, Avg. per-sample expected Loss: 0.49443
# Batch count: 34, Avg. per-sample expected Loss: 0.49814
# Batch count: 35, Avg. per-sample expected Loss: 0.49584
# Batch count: 36, Avg. per-sample expected Loss: 0.49725
# Batch count: 37, Avg. per-sample expected Loss: 0.49920
# Batch count: 38, Avg. per-sample expected Loss: 0.49733
# Batch count: 39, Avg. per-sample expected Loss: 0.49261
# Batch count: 40, Avg. per-sample expected Loss: 0.49703
# Batch count: 41, Avg. per-sample expected Loss: 0.49328
# Batch count: 42, Avg. per-sample expected Loss: 0.49425
# Batch count: 43, Avg. per-sample expected Loss: 0.49320
# Batch count: 44, Avg. per-sample expected Loss: 0.49332
# Batch count: 45, Avg. per-sample expected Loss: 0.49209
# Batch count: 46, Avg. per-sample expected Loss: 0.49635
# Batch count: 47, Avg. per-sample expected Loss: 0.49278
# Batch count: 48, Avg. per-sample expected Loss: 0.49720
# Batch count: 49, Avg. per-sample expected Loss: 0.49801
# Batch count: 50, Avg. per-sample expected Loss: 0.49481
# Batch count: 51, Avg. per-sample expected Loss: 0.49303
# Batch count: 52, Avg. per-sample expected Loss: 0.49493
# Batch count: 53, Avg. per-sample expected Loss: 0.49220
# Batch count: 54, Avg. per-sample expected Loss: 0.49200
# Batch count: 55, Avg. per-sample expected Loss: 0.49401
# Batch count: 56, Avg. per-sample expected Loss: 0.49496
# Batch count: 57, Avg. per-sample expected Loss: 0.49304
# Batch count: 58, Avg. per-sample expected Loss: 0.49169
# Batch count: 59, Avg. per-sample expected Loss: 0.49593
# Batch count: 60, Avg. per-sample expected Loss: 0.49097
# Batch count: 61, Avg. per-sample expected Loss: 0.49170
# Batch count: 62, Avg. per-sample expected Loss: 0.49333
# Batch count: 63, Avg. per-sample expected Loss: 0.49175
# Batch count: 64, Avg. per-sample expected Loss: 0.49029
# Batch count: 65, Avg. per-sample expected Loss: 0.49524
# Batch count: 66, Avg. per-sample expected Loss: 0.49391
# Batch count: 67, Avg. per-sample expected Loss: 0.49200
# Batch count: 68, Avg. per-sample expected Loss: 0.48984
# Batch count: 69, Avg. per-sample expected Loss: 0.49329
# Batch count: 70, Avg. per-sample expected Loss: 0.49316
# Batch count: 71, Avg. per-sample expected Loss: 0.49260
# Batch count: 72, Avg. per-sample expected Loss: 0.49082
# Batch count: 73, Avg. per-sample expected Loss: 0.49098
# Batch count: 74, Avg. per-sample expected Loss: 0.49021
# Batch count: 75, Avg. per-sample expected Loss: 0.49239
# Batch count: 76, Avg. per-sample expected Loss: 0.49198
# Batch count: 77, Avg. per-sample expected Loss: 0.49683
# Batch count: 78, Avg. per-sample expected Loss: 0.49066
# Batch count: 79, Avg. per-sample expected Loss: 0.48817
# Batch count: 80, Avg. per-sample expected Loss: 0.49148
# Batch count: 81, Avg. per-sample expected Loss: 0.49065
# Batch count: 82, Avg. per-sample expected Loss: 0.49349
# Batch count: 83, Avg. per-sample expected Loss: 0.48984
# Batch count: 84, Avg. per-sample expected Loss: 0.48972
# Batch count: 85, Avg. per-sample expected Loss: 0.49047
# Batch count: 86, Avg. per-sample expected Loss: 0.49226
# Batch count: 87, Avg. per-sample expected Loss: 0.49259
# Batch count: 88, Avg. per-sample expected Loss: 0.49032
# Batch count: 89, Avg. per-sample expected Loss: 0.48623
# Batch count: 90, Avg. per-sample expected Loss: 0.48807
# Batch count: 91, Avg. per-sample expected Loss: 0.48789
# Batch count: 92, Avg. per-sample expected Loss: 0.49084
# Batch count: 93, Avg. per-sample expected Loss: 0.49017
# Batch count: 94, Avg. per-sample expected Loss: 0.48817
# Batch count: 95, Avg. per-sample expected Loss: 0.49056
# Batch count: 96, Avg. per-sample expected Loss: 0.48823
# Batch count: 97, Avg. per-sample expected Loss: 0.48784
# Batch count: 98, Avg. per-sample expected Loss: 0.49260
# Batch count: 99, Avg. per-sample expected Loss: 0.49142
# Batch count: 100, Avg. per-sample expected Loss: 0.49062
# Batch count: 101, Avg. per-sample expected Loss: 0.49091
# Batch count: 102, Avg. per-sample expected Loss: 0.49002
# Batch count: 103, Avg. per-sample expected Loss: 0.48646
# Batch count: 104, Avg. per-sample expected Loss: 0.48817
# Batch count: 105, Avg. per-sample expected Loss: 0.48581
# Batch count: 106, Avg. per-sample expected Loss: 0.48619
# Batch count: 107, Avg. per-sample expected Loss: 0.49115
# Batch count: 108, Avg. per-sample expected Loss: 0.48846
# Batch count: 109, Avg. per-sample expected Loss: 0.48640
# Batch count: 110, Avg. per-sample expected Loss: 0.49143
# Batch count: 111, Avg. per-sample expected Loss: 0.48895
# Batch count: 112, Avg. per-sample expected Loss: 0.49011
# Batch count: 113, Avg. per-sample expected Loss: 0.48275
# Batch count: 114, Avg. per-sample expected Loss: 0.48706
# Batch count: 115, Avg. per-sample expected Loss: 0.48507
# Batch count: 116, Avg. per-sample expected Loss: 0.48672
# Batch count: 117, Avg. per-sample expected Loss: 0.48431
# Batch count: 118, Avg. per-sample expected Loss: 0.48460
# Batch count: 119, Avg. per-sample expected Loss: 0.48996
# Batch count: 120, Avg. per-sample expected Loss: 0.48356
# Batch count: 121, Avg. per-sample expected Loss: 0.48546
# Batch count: 122, Avg. per-sample expected Loss: 0.48738
# Batch count: 123, Avg. per-sample expected Loss: 0.48766
# Batch count: 124, Avg. per-sample expected Loss: 0.48729
# Batch count: 125, Avg. per-sample expected Loss: 0.48818
# Batch count: 126, Avg. per-sample expected Loss: 0.48286
# Batch count: 127, Avg. per-sample expected Loss: 0.48443
# Batch count: 128, Avg. per-sample expected Loss: 0.48619
# Batch count: 129, Avg. per-sample expected Loss: 0.48035
# Batch count: 130, Avg. per-sample expected Loss: 0.48885
# Batch count: 131, Avg. per-sample expected Loss: 0.48728
# Batch count: 132, Avg. per-sample expected Loss: 0.48622
# Batch count: 133, Avg. per-sample expected Loss: 0.48625
# Batch count: 134, Avg. per-sample expected Loss: 0.48524
# Batch count: 135, Avg. per-sample expected Loss: 0.48280
# Batch count: 136, Avg. per-sample expected Loss: 0.48643
# Batch count: 137, Avg. per-sample expected Loss: 0.48202
# Batch count: 138, Avg. per-sample expected Loss: 0.49208
# Batch count: 139, Avg. per-sample expected Loss: 0.48363
# Batch count: 140, Avg. per-sample expected Loss: 0.48403
# Batch count: 141, Avg. per-sample expected Loss: 0.48897
# Batch count: 142, Avg. per-sample expected Loss: 0.48315
# Batch count: 143, Avg. per-sample expected Loss: 0.47744
# Batch count: 144, Avg. per-sample expected Loss: 0.48756
# Batch count: 145, Avg. per-sample expected Loss: 0.48247
# Batch count: 146, Avg. per-sample expected Loss: 0.48080
# Batch count: 147, Avg. per-sample expected Loss: 0.48949
# Batch count: 148, Avg. per-sample expected Loss: 0.49004
# Batch count: 149, Avg. per-sample expected Loss: 0.48462
# Batch count: 150, Avg. per-sample expected Loss: 0.47739
# Batch count: 151, Avg. per-sample expected Loss: 0.48488
# Batch count: 152, Avg. per-sample expected Loss: 0.48396
# Batch count: 153, Avg. per-sample expected Loss: 0.48599
# Batch count: 154, Avg. per-sample expected Loss: 0.48797
# Batch count: 155, Avg. per-sample expected Loss: 0.47978
# Batch count: 156, Avg. per-sample expected Loss: 0.48535
# Batch count: 157, Avg. per-sample expected Loss: 0.47617
# Batch count: 158, Avg. per-sample expected Loss: 0.47854
# Batch count: 159, Avg. per-sample expected Loss: 0.48472
# Batch count: 160, Avg. per-sample expected Loss: 0.48505
# Batch count: 161, Avg. per-sample expected Loss: 0.48674
# Batch count: 162, Avg. per-sample expected Loss: 0.48620
# Batch count: 163, Avg. per-sample expected Loss: 0.48681
# Batch count: 164, Avg. per-sample expected Loss: 0.48770
# Batch count: 165, Avg. per-sample expected Loss: 0.48654
# Batch count: 166, Avg. per-sample expected Loss: 0.48361
# Batch count: 167, Avg. per-sample expected Loss: 0.48601
# Batch count: 168, Avg. per-sample expected Loss: 0.48647
# Batch count: 169, Avg. per-sample expected Loss: 0.48211
# Batch count: 170, Avg. per-sample expected Loss: 0.48215
# Batch count: 171, Avg. per-sample expected Loss: 0.48013
# Batch count: 172, Avg. per-sample expected Loss: 0.48292
# Batch count: 173, Avg. per-sample expected Loss: 0.47916
# Batch count: 174, Avg. per-sample expected Loss: 0.48536
# Batch count: 175, Avg. per-sample expected Loss: 0.47924
# Batch count: 176, Avg. per-sample expected Loss: 0.47919
# Batch count: 177, Avg. per-sample expected Loss: 0.48151
# Batch count: 178, Avg. per-sample expected Loss: 0.48139
# Batch count: 179, Avg. per-sample expected Loss: 0.48056
# Batch count: 180, Avg. per-sample expected Loss: 0.48394
# Batch count: 181, Avg. per-sample expected Loss: 0.48058
# Batch count: 182, Avg. per-sample expected Loss: 0.48461
# Batch count: 183, Avg. per-sample expected Loss: 0.48160
# Batch count: 184, Avg. per-sample expected Loss: 0.48247
# Batch count: 185, Avg. per-sample expected Loss: 0.48725
# Batch count: 186, Avg. per-sample expected Loss: 0.48074
# Batch count: 187, Avg. per-sample expected Loss: 0.48178
# Batch count: 188, Avg. per-sample expected Loss: 0.48637
# Batch count: 189, Avg. per-sample expected Loss: 0.48074
# Batch count: 190, Avg. per-sample expected Loss: 0.48198
# Batch count: 191, Avg. per-sample expected Loss: 0.47733
# Batch count: 192, Avg. per-sample expected Loss: 0.48115
# Batch count: 193, Avg. per-sample expected Loss: 0.48154
# Batch count: 194, Avg. per-sample expected Loss: 0.47904
# Batch count: 195, Avg. per-sample expected Loss: 0.47846
# Batch count: 196, Avg. per-sample expected Loss: 0.48152
# Batch count: 197, Avg. per-sample expected Loss: 0.47656
# Batch count: 198, Avg. per-sample expected Loss: 0.48479
# Batch count: 199, Avg. per-sample expected Loss: 0.47951
# Batch count: 200, Avg. per-sample expected Loss: 0.47831
# Batch count: 201, Avg. per-sample expected Loss: 0.48081
# Batch count: 202, Avg. per-sample expected Loss: 0.48193
# Batch count: 203, Avg. per-sample expected Loss: 0.48542
# Batch count: 204, Avg. per-sample expected Loss: 0.47920
# Batch count: 205, Avg. per-sample expected Loss: 0.48432
# Batch count: 206, Avg. per-sample expected Loss: 0.48141
# Batch count: 207, Avg. per-sample expected Loss: 0.47507
# Batch count: 208, Avg. per-sample expected Loss: 0.48453
# Batch count: 209, Avg. per-sample expected Loss: 0.47753
# Batch count: 210, Avg. per-sample expected Loss: 0.47640
# Batch count: 211, Avg. per-sample expected Loss: 0.47993
# Batch count: 212, Avg. per-sample expected Loss: 0.47489
# Batch count: 213, Avg. per-sample expected Loss: 0.47805
# Batch count: 214, Avg. per-sample expected Loss: 0.47657
# Batch count: 215, Avg. per-sample expected Loss: 0.48301
# Batch count: 216, Avg. per-sample expected Loss: 0.47963
# Batch count: 217, Avg. per-sample expected Loss: 0.47883
# Batch count: 218, Avg. per-sample expected Loss: 0.48083
# Batch count: 219, Avg. per-sample expected Loss: 0.48249
# Batch count: 220, Avg. per-sample expected Loss: 0.47807
# Batch count: 221, Avg. per-sample expected Loss: 0.47940
# Batch count: 222, Avg. per-sample expected Loss: 0.48105
# Batch count: 223, Avg. per-sample expected Loss: 0.47547
# Batch count: 224, Avg. per-sample expected Loss: 0.47871
# Batch count: 225, Avg. per-sample expected Loss: 0.47072
# Batch count: 226, Avg. per-sample expected Loss: 0.47754
# Batch count: 227, Avg. per-sample expected Loss: 0.48079
# Batch count: 228, Avg. per-sample expected Loss: 0.47884
# Batch count: 229, Avg. per-sample expected Loss: 0.48209
# Batch count: 230, Avg. per-sample expected Loss: 0.48299
# Batch count: 231, Avg. per-sample expected Loss: 0.47301
# Batch count: 232, Avg. per-sample expected Loss: 0.47592
# Batch count: 233, Avg. per-sample expected Loss: 0.47321
# Batch count: 234, Avg. per-sample expected Loss: 0.47151
# Batch count: 235, Avg. per-sample expected Loss: 0.47912
# Batch count: 236, Avg. per-sample expected Loss: 0.47221
# Batch count: 237, Avg. per-sample expected Loss: 0.47434
# Batch count: 238, Avg. per-sample expected Loss: 0.47751
# Batch count: 239, Avg. per-sample expected Loss: 0.47820
# Batch count: 240, Avg. per-sample expected Loss: 0.48122
# Batch count: 241, Avg. per-sample expected Loss: 0.47484
# Batch count: 242, Avg. per-sample expected Loss: 0.47456
# Batch count: 243, Avg. per-sample expected Loss: 0.47400
# Batch count: 244, Avg. per-sample expected Loss: 0.47664
# Batch count: 245, Avg. per-sample expected Loss: 0.47186
# Batch count: 246, Avg. per-sample expected Loss: 0.47784
# Batch count: 247, Avg. per-sample expected Loss: 0.47433
# Batch count: 248, Avg. per-sample expected Loss: 0.48014
# Batch count: 249, Avg. per-sample expected Loss: 0.47181
# Batch count: 250, Avg. per-sample expected Loss: 0.47444
# Batch count: 251, Avg. per-sample expected Loss: 0.46571
# Batch count: 252, Avg. per-sample expected Loss: 0.47265
# Batch count: 253, Avg. per-sample expected Loss: 0.46985
# Batch count: 254, Avg. per-sample expected Loss: 0.46605
# Batch count: 255, Avg. per-sample expected Loss: 0.47216
# Batch count: 256, Avg. per-sample expected Loss: 0.46795
# Batch count: 257, Avg. per-sample expected Loss: 0.47074
# Batch count: 258, Avg. per-sample expected Loss: 0.47053
# Batch count: 259, Avg. per-sample expected Loss: 0.46783
# Batch count: 260, Avg. per-sample expected Loss: 0.47146
# Batch count: 261, Avg. per-sample expected Loss: 0.47368
# Batch count: 262, Avg. per-sample expected Loss: 0.47101
# Batch count: 263, Avg. per-sample expected Loss: 0.46657
# Batch count: 264, Avg. per-sample expected Loss: 0.47644
# Batch count: 265, Avg. per-sample expected Loss: 0.47414
# Batch count: 266, Avg. per-sample expected Loss: 0.47248
# Batch count: 267, Avg. per-sample expected Loss: 0.47350
# Batch count: 268, Avg. per-sample expected Loss: 0.46938
# Batch count: 269, Avg. per-sample expected Loss: 0.46909
# Batch count: 270, Avg. per-sample expected Loss: 0.46881
# Batch count: 271, Avg. per-sample expected Loss: 0.46708
# Batch count: 272, Avg. per-sample expected Loss: 0.46534
# Batch count: 273, Avg. per-sample expected Loss: 0.47113
# Batch count: 274, Avg. per-sample expected Loss: 0.47213
# Batch count: 275, Avg. per-sample expected Loss: 0.47252
# Batch count: 276, Avg. per-sample expected Loss: 0.47298
# Batch count: 277, Avg. per-sample expected Loss: 0.46654
# Batch count: 278, Avg. per-sample expected Loss: 0.46565
# Batch count: 279, Avg. per-sample expected Loss: 0.46893
# Batch count: 280, Avg. per-sample expected Loss: 0.46554
# Batch count: 281, Avg. per-sample expected Loss: 0.46303
# Batch count: 282, Avg. per-sample expected Loss: 0.46537
# Batch count: 283, Avg. per-sample expected Loss: 0.47593
# Batch count: 284, Avg. per-sample expected Loss: 0.46702
# Batch count: 285, Avg. per-sample expected Loss: 0.46722
# Batch count: 286, Avg. per-sample expected Loss: 0.47422
# Batch count: 287, Avg. per-sample expected Loss: 0.47112
# Batch count: 288, Avg. per-sample expected Loss: 0.47224
# Batch count: 289, Avg. per-sample expected Loss: 0.46808
# Batch count: 290, Avg. per-sample expected Loss: 0.47046
# Batch count: 291, Avg. per-sample expected Loss: 0.46403
# Batch count: 292, Avg. per-sample expected Loss: 0.46340
# Batch count: 293, Avg. per-sample expected Loss: 0.46231
# Batch count: 294, Avg. per-sample expected Loss: 0.46810
# Batch count: 295, Avg. per-sample expected Loss: 0.46465
# Batch count: 296, Avg. per-sample expected Loss: 0.47057
# Batch count: 297, Avg. per-sample expected Loss: 0.46908
# Batch count: 298, Avg. per-sample expected Loss: 0.46131
# Batch count: 299, Avg. per-sample expected Loss: 0.46676
# Batch count: 300, Avg. per-sample expected Loss: 0.46687
# Batch count: 301, Avg. per-sample expected Loss: 0.47120
# Batch count: 302, Avg. per-sample expected Loss: 0.45861
# Batch count: 303, Avg. per-sample expected Loss: 0.46788
# Batch count: 304, Avg. per-sample expected Loss: 0.46354
# Batch count: 305, Avg. per-sample expected Loss: 0.46241
# Batch count: 306, Avg. per-sample expected Loss: 0.46258
# Batch count: 307, Avg. per-sample expected Loss: 0.45885
# Batch count: 308, Avg. per-sample expected Loss: 0.46631
# Batch count: 309, Avg. per-sample expected Loss: 0.47253
# Batch count: 310, Avg. per-sample expected Loss: 0.46940
# Batch count: 311, Avg. per-sample expected Loss: 0.46370
# Batch count: 312, Avg. per-sample expected Loss: 0.46808
# Batch count: 313, Avg. per-sample expected Loss: 0.46376
# Batch count: 314, Avg. per-sample expected Loss: 0.46479
# Batch count: 315, Avg. per-sample expected Loss: 0.46040
# Batch count: 316, Avg. per-sample expected Loss: 0.46132
# Batch count: 317, Avg. per-sample expected Loss: 0.45599
# Batch count: 318, Avg. per-sample expected Loss: 0.46723
# Batch count: 319, Avg. per-sample expected Loss: 0.45928
# Batch count: 320, Avg. per-sample expected Loss: 0.46188
# Batch count: 321, Avg. per-sample expected Loss: 0.45500
# Batch count: 322, Avg. per-sample expected Loss: 0.45793
# Batch count: 323, Avg. per-sample expected Loss: 0.46581
# Batch count: 324, Avg. per-sample expected Loss: 0.46329
# Batch count: 325, Avg. per-sample expected Loss: 0.46292
# Batch count: 326, Avg. per-sample expected Loss: 0.46676
# Batch count: 327, Avg. per-sample expected Loss: 0.46323
# Batch count: 328, Avg. per-sample expected Loss: 0.47217
# Batch count: 329, Avg. per-sample expected Loss: 0.46400
# Batch count: 330, Avg. per-sample expected Loss: 0.46667
# Batch count: 331, Avg. per-sample expected Loss: 0.45512
# Batch count: 332, Avg. per-sample expected Loss: 0.46396
# Batch count: 333, Avg. per-sample expected Loss: 0.46266
# Batch count: 334, Avg. per-sample expected Loss: 0.46419
# Batch count: 335, Avg. per-sample expected Loss: 0.46005
# Batch count: 336, Avg. per-sample expected Loss: 0.45881
# Batch count: 337, Avg. per-sample expected Loss: 0.45013
# Batch count: 338, Avg. per-sample expected Loss: 0.46460
# Batch count: 339, Avg. per-sample expected Loss: 0.46438
# Batch count: 340, Avg. per-sample expected Loss: 0.44778
# Batch count: 341, Avg. per-sample expected Loss: 0.45747
# Batch count: 342, Avg. per-sample expected Loss: 0.45306
# Batch count: 343, Avg. per-sample expected Loss: 0.45796
# Batch count: 344, Avg. per-sample expected Loss: 0.46559
# Batch count: 345, Avg. per-sample expected Loss: 0.45471
# Batch count: 346, Avg. per-sample expected Loss: 0.46128
# Batch count: 347, Avg. per-sample expected Loss: 0.45540
# Batch count: 348, Avg. per-sample expected Loss: 0.46063
# Batch count: 349, Avg. per-sample expected Loss: 0.44412

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")

plt.title("Training using 2-QNSCD and 2-RQSGD (6 samples per itr)")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("2RSGD_6s.png")
plt.show()

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")
plt.plot(SGD6c_cost, "g", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")
plt.plot(SGD6c_Ecost, "g.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training 2-QNSCD and 2-RQSGD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("RQSGD.png")
plt.show()

# %% [markdown]
# ## Testing Phase

# %%
### Saving Final Parameters:
file_name1 = "4Q 2-QNSCD params"
file_name2 = "4Q 2-RQSGD_6s params"
file_name3 = "4Q 6-RQSGD params"

np.save(file_name1,NCGDparams)
np.save(file_name2,SGD6params)
np.save(file_name3,SGD6cparams)

# %%
phiTest = np.load('4-qubitsPhiTest_v1.npy')
labelTest = np.load('4-qubitsLabelTest_v1.npy')

phiTest.requires_grad = False
labelTest.requires_grad = False

# %%
nTest = 1000

NCGDparams_opt = NCGDparams 
SGD6params_opt = SGD6params
SGD6cparams_opt = SGD6cparams

# %%
### Optimal Expected Loss
expOperator = 0

for i in range(nTest):
    op = np.matmul(phiTest[:,i].reshape(dim,1),phiTest[:,i].reshape(1,dim))
    expOperator = expOperator + labelTest[i]*op
expOperator = expOperator/(nTest)
opt_value = 0.5*(1+sum(abs(np.linalg.svd(expOperator)[1])))

# %%
NCGD_rslt = []
SGD6_rslt = []
SGD6c_rslt = []

for i in range(int(1e1)):
    NCGDcount = 0
    SGD6count = 0
    SGD6ccount = 0

    for itr in range(nTest):
        if circuit_test(NCGDparams_opt,phiTest[:,itr]) == labelTest[itr]:
            NCGDcount += 1 
        if circuit_test(SGD6params_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6count += 1
        if circuit_test(SGD6cparams_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6ccount += 1
    
    NCGD_rslt.append(NCGDcount/nTest)
    SGD6_rslt.append(SGD6count/nTest)
    SGD6c_rslt.append(SGD6ccount/nTest)
#     print("itr = ",i)

# %%
print("Optimal: {:.3f} \nNCGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n2-RQSGD_6s: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n6-RQSGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f}"\
      .format(opt_value,np.average(NCGD_rslt),np.std(NCGD_rslt),max(NCGD_rslt),min(NCGD_rslt),\
              np.average(SGD6_rslt),np.std(SGD6_rslt),max(SGD6_rslt),min(SGD6_rslt), \
              np.average(SGD6c_rslt),np.std(SGD6c_rslt),max(SGD6c_rslt),min(SGD6c_rslt)))
# Out:
# Optimal: 0.876
# NCGD: 0.846 / 0.012 max: 0.864 min: 0.821
# 2-RQSGD_6s: 0.547 / 0.007 max: 0.565 min: 0.538
# 6-RQSGD: 0.851 / 0.007 max: 0.864 min: 0.839
