# %%
import pennylane as qml
from pennylane import numpy as np
import scipy
import matplotlib.pyplot as plt
from globalVars import *
from model_4qubit import *

from GRADest_4Q import EstGrad
from EQFIMest_4Q import Est_EQFIM

# %% [markdown]
# ## Quantum Neural Network

# %%
random_state = np.random.rand(dim)
random_state = random_state /np.linalg.norm(random_state)
qml.draw_mpl(QNN)(np.zeros(nparams),random_state)
# Out:
# (<Figure size 1300x500 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### Model Initialization

# %%
S_pItr = 6  # no. of samples used per-iteration 

nStep = 350
nItr = 100
step_size = 0.0025

Bsize = S_pItr*nItr

# %%
phiTrain = np.load('4-qubitsPhiTrain_v1.npy')
labelTrain = np.load('4-qubitsLabelTrain_v1.npy')

phiTrain.requires_grad = False
labelTrain.requires_grad = False

# %%
'QNSCD Dataset'
phiTrainNCGD = phiTrain
labelTrainNCGD = labelTrain

'SGD Dataset'
phiTrainSGD = phiTrain
labelTrainSGD = labelTrain

# %%
### Optimal Expected Loss
Opt_cost = []
itrBatch = np.linspace(0,Bsize*nStep,nStep,endpoint = False,dtype = 'int').tolist()
for itr1 in itrBatch:
    expOperator = 0
    for itr2 in range(Bsize):
        temp_phi = phiTrain[:,itr1+itr2]
        op = np.matmul(temp_phi.reshape(dim,1),temp_phi.reshape(1,dim))
        expOperator = expOperator + labelTrain[itr1+itr2]*op
    expOperator = expOperator/Bsize
    opt_value = 0.5*(1-sum(abs(np.linalg.svd(expOperator)[1])))
    Opt_cost.append(opt_value)

file_name = "4Q-Minimum Expected Loss"
np.save(file_name,Opt_cost)

# %% [markdown]
# # Optimizers

# %%
'QNN outputs yhat'
dev = qml.device("default.qubit", wires=nqubits, shots=1)

@qml.qnode(dev,interface='autograd')
def circuit_test(params,state):
    QNN(params,state)
    return qml.sample(qml.Hermitian(M,wires=list(range(nqubits))))

# %%
init_params = np.random.uniform(low=0, high=2*np.pi, size=nparams, requires_grad=True)
init_params = np.array([3.65963692, 0.11796649, 4.376764,   1.75271384,
 0.89642774, 4.11107355, 2.76627377, 0.43759813, 4.11996975, 1.10477885, 5.57055168, 5.43163314, 3.93864496,
 3.73156917, 1.26885442, 4.20084436], requires_grad=True)

'cost initialization'
phiTrain0 = phiTrain[:,-1*(Bsize+1):-1]
labelTrain0 = labelTrain[-1*(Bsize+1):-1]
temp_cost = sum([ps_expLoss(init_params,phiTrain0[:,itr],labelTrain0[itr]) for itr in range(Bsize)])/Bsize
print("Initial Average Per-Sample Expected Loss: ",temp_cost)

count = 0
for itr in range(Bsize):
    if circuit_test(init_params,phiTrain0[:,itr]) != labelTrain0[itr]:
        count += 1
temp_Ecost = count/Bsize
print("Initial Average Empirical Loss", temp_Ecost)
# Out:
# Initial Average Per-Sample Expected Loss:  0.45991617049182415
# Initial Average Empirical Loss 0.4866666666666667

# %% [markdown]
# ## Quantum Natural Stochastic Pairwise Coordinate Descent (2-QNSCD)

# %%
NCGDparams = np.array(init_params)
NCGD_cost = []
NCGD_Ecost = []

NCGD_cost.append(temp_cost)
NCGD_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainNCGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainNCGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a pair of coordinate
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())

        ### Gradient estimation
        y1, b1 = EstGrad(NCGDparams,phiT[:,itr3],idx[0])
        y2, b2 = EstGrad(NCGDparams,phiT[:,itr3+1],idx[1])
        b1 = (1-b1)/2
        b2 = (1-b2)/2

        grad = [-1*((-1)**b1)*loss(y1,labelT[itr3]),-1*((-1)**b2)*loss(y2,labelT[itr3+1])]
        
        ### E-QFIM estimation
        metric = Est_EQFIM(NCGDparams,idx,phiT[:,itr3+2:itr3+S_pItr])

        ### double-parameters update
        NCGDparams[idx] = NCGDparams[idx] - (step_size)*np.dot(np.linalg.inv(metric),grad) 
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(NCGDparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    NCGD_cost.append(energy)
    
    ### average empirical loss calculation
    NCGDcount = 0
    for itr in range(Bsize):
        if circuit_test(NCGDparams,phiT[:,itr]) != labelT[itr]:
            NCGDcount += 1
    NCGD_Ecost.append(NCGDcount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))

file_name1 = "4Q 2-QNSCD Expected Loss"
file_name2 = "4Q 2-QNSCD Empirical Loss"

np.save(file_name1,NCGD_cost)
np.save(file_name2,NCGD_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.45992
# Batch count:  1, Avg. per-sample expected Loss: 0.47899
# Batch count:  2, Avg. per-sample expected Loss: 0.48185
# Batch count:  3, Avg. per-sample expected Loss: 0.48158
# Batch count:  4, Avg. per-sample expected Loss: 0.48039
# Batch count:  5, Avg. per-sample expected Loss: 0.47040
# Batch count:  6, Avg. per-sample expected Loss: 0.45828
# Batch count:  7, Avg. per-sample expected Loss: 0.47625
# Batch count:  8, Avg. per-sample expected Loss: 0.46560
# Batch count:  9, Avg. per-sample expected Loss: 0.46352
# Batch count: 10, Avg. per-sample expected Loss: 0.47294
# Batch count: 11, Avg. per-sample expected Loss: 0.46092
# Batch count: 12, Avg. per-sample expected Loss: 0.45770
# Batch count: 13, Avg. per-sample expected Loss: 0.46719
# Batch count: 14, Avg. per-sample expected Loss: 0.46004
# Batch count: 15, Avg. per-sample expected Loss: 0.47232
# Batch count: 16, Avg. per-sample expected Loss: 0.45467
# Batch count: 17, Avg. per-sample expected Loss: 0.44770
# Batch count: 18, Avg. per-sample expected Loss: 0.46666
# Batch count: 19, Avg. per-sample expected Loss: 0.44994
# Batch count: 20, Avg. per-sample expected Loss: 0.44747
# Batch count: 21, Avg. per-sample expected Loss: 0.43893
# Batch count: 22, Avg. per-sample expected Loss: 0.45150
# Batch count: 23, Avg. per-sample expected Loss: 0.46280
# Batch count: 24, Avg. per-sample expected Loss: 0.45528
# Batch count: 25, Avg. per-sample expected Loss: 0.47416
# Batch count: 26, Avg. per-sample expected Loss: 0.46004
# Batch count: 27, Avg. per-sample expected Loss: 0.45885
# Batch count: 28, Avg. per-sample expected Loss: 0.46121
# Batch count: 29, Avg. per-sample expected Loss: 0.46121
# Batch count: 30, Avg. per-sample expected Loss: 0.45674
# Batch count: 31, Avg. per-sample expected Loss: 0.46389
# Batch count: 32, Avg. per-sample expected Loss: 0.45496
# Batch count: 33, Avg. per-sample expected Loss: 0.45855
# Batch count: 34, Avg. per-sample expected Loss: 0.44035
# Batch count: 35, Avg. per-sample expected Loss: 0.44486
# Batch count: 36, Avg. per-sample expected Loss: 0.46091
# Batch count: 37, Avg. per-sample expected Loss: 0.44694
# Batch count: 38, Avg. per-sample expected Loss: 0.45149
# Batch count: 39, Avg. per-sample expected Loss: 0.44185
# Batch count: 40, Avg. per-sample expected Loss: 0.45600
# Batch count: 41, Avg. per-sample expected Loss: 0.44459
# Batch count: 42, Avg. per-sample expected Loss: 0.43633
# Batch count: 43, Avg. per-sample expected Loss: 0.45765
# Batch count: 44, Avg. per-sample expected Loss: 0.44519
# Batch count: 45, Avg. per-sample expected Loss: 0.45193
# Batch count: 46, Avg. per-sample expected Loss: 0.44242
# Batch count: 47, Avg. per-sample expected Loss: 0.44703
# Batch count: 48, Avg. per-sample expected Loss: 0.43851
# Batch count: 49, Avg. per-sample expected Loss: 0.43820
# Batch count: 50, Avg. per-sample expected Loss: 0.44443
# Batch count: 51, Avg. per-sample expected Loss: 0.45350
# Batch count: 52, Avg. per-sample expected Loss: 0.45048
# Batch count: 53, Avg. per-sample expected Loss: 0.45311
# Batch count: 54, Avg. per-sample expected Loss: 0.46685
# Batch count: 55, Avg. per-sample expected Loss: 0.44933
# Batch count: 56, Avg. per-sample expected Loss: 0.44250
# Batch count: 57, Avg. per-sample expected Loss: 0.44941
# Batch count: 58, Avg. per-sample expected Loss: 0.44889
# Batch count: 59, Avg. per-sample expected Loss: 0.45146
# Batch count: 60, Avg. per-sample expected Loss: 0.46757
# Batch count: 61, Avg. per-sample expected Loss: 0.45416
# Batch count: 62, Avg. per-sample expected Loss: 0.45542
# Batch count: 63, Avg. per-sample expected Loss: 0.45685
# Batch count: 64, Avg. per-sample expected Loss: 0.47644
# Batch count: 65, Avg. per-sample expected Loss: 0.47458
# Batch count: 66, Avg. per-sample expected Loss: 0.46110
# Batch count: 67, Avg. per-sample expected Loss: 0.47159
# Batch count: 68, Avg. per-sample expected Loss: 0.46981
# Batch count: 69, Avg. per-sample expected Loss: 0.46710
# Batch count: 70, Avg. per-sample expected Loss: 0.47221
# Batch count: 71, Avg. per-sample expected Loss: 0.46508
# Batch count: 72, Avg. per-sample expected Loss: 0.47602
# Batch count: 73, Avg. per-sample expected Loss: 0.45303
# Batch count: 74, Avg. per-sample expected Loss: 0.47496
# Batch count: 75, Avg. per-sample expected Loss: 0.46172
# Batch count: 76, Avg. per-sample expected Loss: 0.46554
# Batch count: 77, Avg. per-sample expected Loss: 0.46158
# Batch count: 78, Avg. per-sample expected Loss: 0.46188
# Batch count: 79, Avg. per-sample expected Loss: 0.47009
# Batch count: 80, Avg. per-sample expected Loss: 0.45205
# Batch count: 81, Avg. per-sample expected Loss: 0.46536
# Batch count: 82, Avg. per-sample expected Loss: 0.44947
# Batch count: 83, Avg. per-sample expected Loss: 0.45463
# Batch count: 84, Avg. per-sample expected Loss: 0.44988
# Batch count: 85, Avg. per-sample expected Loss: 0.45883
# Batch count: 86, Avg. per-sample expected Loss: 0.45029
# Batch count: 87, Avg. per-sample expected Loss: 0.46642
# Batch count: 88, Avg. per-sample expected Loss: 0.45468
# Batch count: 89, Avg. per-sample expected Loss: 0.46323
# Batch count: 90, Avg. per-sample expected Loss: 0.47115
# Batch count: 91, Avg. per-sample expected Loss: 0.44906
# Batch count: 92, Avg. per-sample expected Loss: 0.47995
# Batch count: 93, Avg. per-sample expected Loss: 0.47622
# Batch count: 94, Avg. per-sample expected Loss: 0.47252
# Batch count: 95, Avg. per-sample expected Loss: 0.46738
# Batch count: 96, Avg. per-sample expected Loss: 0.47694
# Batch count: 97, Avg. per-sample expected Loss: 0.47357
# Batch count: 98, Avg. per-sample expected Loss: 0.44999
# Batch count: 99, Avg. per-sample expected Loss: 0.43849
# Batch count: 100, Avg. per-sample expected Loss: 0.44920
# Batch count: 101, Avg. per-sample expected Loss: 0.44826
# Batch count: 102, Avg. per-sample expected Loss: 0.44550
# Batch count: 103, Avg. per-sample expected Loss: 0.46174
# Batch count: 104, Avg. per-sample expected Loss: 0.46787
# Batch count: 105, Avg. per-sample expected Loss: 0.44047
# Batch count: 106, Avg. per-sample expected Loss: 0.42905
# Batch count: 107, Avg. per-sample expected Loss: 0.43969
# Batch count: 108, Avg. per-sample expected Loss: 0.44740
# Batch count: 109, Avg. per-sample expected Loss: 0.43650
# Batch count: 110, Avg. per-sample expected Loss: 0.45944
# Batch count: 111, Avg. per-sample expected Loss: 0.42854
# Batch count: 112, Avg. per-sample expected Loss: 0.43254
# Batch count: 113, Avg. per-sample expected Loss: 0.46367
# Batch count: 114, Avg. per-sample expected Loss: 0.45707
# Batch count: 115, Avg. per-sample expected Loss: 0.44027
# Batch count: 116, Avg. per-sample expected Loss: 0.44911
# Batch count: 117, Avg. per-sample expected Loss: 0.45356
# Batch count: 118, Avg. per-sample expected Loss: 0.46091
# Batch count: 119, Avg. per-sample expected Loss: 0.44234
# Batch count: 120, Avg. per-sample expected Loss: 0.44838
# Batch count: 121, Avg. per-sample expected Loss: 0.44337
# Batch count: 122, Avg. per-sample expected Loss: 0.41419
# Batch count: 123, Avg. per-sample expected Loss: 0.41838
# Batch count: 124, Avg. per-sample expected Loss: 0.43372
# Batch count: 125, Avg. per-sample expected Loss: 0.40632
# Batch count: 126, Avg. per-sample expected Loss: 0.42164
# Batch count: 127, Avg. per-sample expected Loss: 0.43401
# Batch count: 128, Avg. per-sample expected Loss: 0.40762
# Batch count: 129, Avg. per-sample expected Loss: 0.41283
# Batch count: 130, Avg. per-sample expected Loss: 0.38899
# Batch count: 131, Avg. per-sample expected Loss: 0.41109
# Batch count: 132, Avg. per-sample expected Loss: 0.39437
# Batch count: 133, Avg. per-sample expected Loss: 0.41265
# Batch count: 134, Avg. per-sample expected Loss: 0.40405
# Batch count: 135, Avg. per-sample expected Loss: 0.41989
# Batch count: 136, Avg. per-sample expected Loss: 0.41814
# Batch count: 137, Avg. per-sample expected Loss: 0.39842
# Batch count: 138, Avg. per-sample expected Loss: 0.39216
# Batch count: 139, Avg. per-sample expected Loss: 0.39616
# Batch count: 140, Avg. per-sample expected Loss: 0.38685
# Batch count: 141, Avg. per-sample expected Loss: 0.38269
# Batch count: 142, Avg. per-sample expected Loss: 0.38679
# Batch count: 143, Avg. per-sample expected Loss: 0.39493
# Batch count: 144, Avg. per-sample expected Loss: 0.40155
# Batch count: 145, Avg. per-sample expected Loss: 0.38964
# Batch count: 146, Avg. per-sample expected Loss: 0.35661
# Batch count: 147, Avg. per-sample expected Loss: 0.37792
# Batch count: 148, Avg. per-sample expected Loss: 0.36159
# Batch count: 149, Avg. per-sample expected Loss: 0.36725
# Batch count: 150, Avg. per-sample expected Loss: 0.35157
# Batch count: 151, Avg. per-sample expected Loss: 0.37503
# Batch count: 152, Avg. per-sample expected Loss: 0.35338
# Batch count: 153, Avg. per-sample expected Loss: 0.36791
# Batch count: 154, Avg. per-sample expected Loss: 0.35159
# Batch count: 155, Avg. per-sample expected Loss: 0.34744
# Batch count: 156, Avg. per-sample expected Loss: 0.36507
# Batch count: 157, Avg. per-sample expected Loss: 0.35367
# Batch count: 158, Avg. per-sample expected Loss: 0.35841
# Batch count: 159, Avg. per-sample expected Loss: 0.36482
# Batch count: 160, Avg. per-sample expected Loss: 0.35677
# Batch count: 161, Avg. per-sample expected Loss: 0.36439
# Batch count: 162, Avg. per-sample expected Loss: 0.35635
# Batch count: 163, Avg. per-sample expected Loss: 0.34653
# Batch count: 164, Avg. per-sample expected Loss: 0.34550
# Batch count: 165, Avg. per-sample expected Loss: 0.33348
# Batch count: 166, Avg. per-sample expected Loss: 0.32747
# Batch count: 167, Avg. per-sample expected Loss: 0.31603
# Batch count: 168, Avg. per-sample expected Loss: 0.30504
# Batch count: 169, Avg. per-sample expected Loss: 0.32651
# Batch count: 170, Avg. per-sample expected Loss: 0.32091
# Batch count: 171, Avg. per-sample expected Loss: 0.32272
# Batch count: 172, Avg. per-sample expected Loss: 0.29707
# Batch count: 173, Avg. per-sample expected Loss: 0.29920
# Batch count: 174, Avg. per-sample expected Loss: 0.30522
# Batch count: 175, Avg. per-sample expected Loss: 0.30177
# Batch count: 176, Avg. per-sample expected Loss: 0.30903
# Batch count: 177, Avg. per-sample expected Loss: 0.28366
# Batch count: 178, Avg. per-sample expected Loss: 0.28322
# Batch count: 179, Avg. per-sample expected Loss: 0.26333
# Batch count: 180, Avg. per-sample expected Loss: 0.25724
# Batch count: 181, Avg. per-sample expected Loss: 0.26805
# Batch count: 182, Avg. per-sample expected Loss: 0.24961
# Batch count: 183, Avg. per-sample expected Loss: 0.25404
# Batch count: 184, Avg. per-sample expected Loss: 0.24627
# Batch count: 185, Avg. per-sample expected Loss: 0.22788
# Batch count: 186, Avg. per-sample expected Loss: 0.22270
# Batch count: 187, Avg. per-sample expected Loss: 0.23186
# Batch count: 188, Avg. per-sample expected Loss: 0.21851
# Batch count: 189, Avg. per-sample expected Loss: 0.22395
# Batch count: 190, Avg. per-sample expected Loss: 0.23252
# Batch count: 191, Avg. per-sample expected Loss: 0.21024
# Batch count: 192, Avg. per-sample expected Loss: 0.20823
# Batch count: 193, Avg. per-sample expected Loss: 0.21111
# Batch count: 194, Avg. per-sample expected Loss: 0.21218
# Batch count: 195, Avg. per-sample expected Loss: 0.23010
# Batch count: 196, Avg. per-sample expected Loss: 0.21425
# Batch count: 197, Avg. per-sample expected Loss: 0.23050
# Batch count: 198, Avg. per-sample expected Loss: 0.20448
# Batch count: 199, Avg. per-sample expected Loss: 0.20918
# Batch count: 200, Avg. per-sample expected Loss: 0.21383
# Batch count: 201, Avg. per-sample expected Loss: 0.21689
# Batch count: 202, Avg. per-sample expected Loss: 0.20866
# Batch count: 203, Avg. per-sample expected Loss: 0.20100
# Batch count: 204, Avg. per-sample expected Loss: 0.19974
# Batch count: 205, Avg. per-sample expected Loss: 0.17258
# Batch count: 206, Avg. per-sample expected Loss: 0.17671
# Batch count: 207, Avg. per-sample expected Loss: 0.19777
# Batch count: 208, Avg. per-sample expected Loss: 0.17365
# Batch count: 209, Avg. per-sample expected Loss: 0.18177
# Batch count: 210, Avg. per-sample expected Loss: 0.17107
# Batch count: 211, Avg. per-sample expected Loss: 0.17443
# Batch count: 212, Avg. per-sample expected Loss: 0.17299
# Batch count: 213, Avg. per-sample expected Loss: 0.15471
# Batch count: 214, Avg. per-sample expected Loss: 0.15769
# Batch count: 215, Avg. per-sample expected Loss: 0.15799
# Batch count: 216, Avg. per-sample expected Loss: 0.16126
# Batch count: 217, Avg. per-sample expected Loss: 0.16579
# Batch count: 218, Avg. per-sample expected Loss: 0.15420
# Batch count: 219, Avg. per-sample expected Loss: 0.15613
# Batch count: 220, Avg. per-sample expected Loss: 0.16061
# Batch count: 221, Avg. per-sample expected Loss: 0.16183
# Batch count: 222, Avg. per-sample expected Loss: 0.15883
# Batch count: 223, Avg. per-sample expected Loss: 0.17506
# Batch count: 224, Avg. per-sample expected Loss: 0.16473
# Batch count: 225, Avg. per-sample expected Loss: 0.16842
# Batch count: 226, Avg. per-sample expected Loss: 0.17088
# Batch count: 227, Avg. per-sample expected Loss: 0.15320
# Batch count: 228, Avg. per-sample expected Loss: 0.16100
# Batch count: 229, Avg. per-sample expected Loss: 0.14472
# Batch count: 230, Avg. per-sample expected Loss: 0.15531
# Batch count: 231, Avg. per-sample expected Loss: 0.16810
# Batch count: 232, Avg. per-sample expected Loss: 0.15678
# Batch count: 233, Avg. per-sample expected Loss: 0.16164
# Batch count: 234, Avg. per-sample expected Loss: 0.16879
# Batch count: 235, Avg. per-sample expected Loss: 0.14805
# Batch count: 236, Avg. per-sample expected Loss: 0.15419
# Batch count: 237, Avg. per-sample expected Loss: 0.14916
# Batch count: 238, Avg. per-sample expected Loss: 0.16038
# Batch count: 239, Avg. per-sample expected Loss: 0.14930
# Batch count: 240, Avg. per-sample expected Loss: 0.13978
# Batch count: 241, Avg. per-sample expected Loss: 0.15191
# Batch count: 242, Avg. per-sample expected Loss: 0.14287
# Batch count: 243, Avg. per-sample expected Loss: 0.15215
# Batch count: 244, Avg. per-sample expected Loss: 0.15292
# Batch count: 245, Avg. per-sample expected Loss: 0.17119
# Batch count: 246, Avg. per-sample expected Loss: 0.16089
# Batch count: 247, Avg. per-sample expected Loss: 0.15481
# Batch count: 248, Avg. per-sample expected Loss: 0.15320
# Batch count: 249, Avg. per-sample expected Loss: 0.15766
# Batch count: 250, Avg. per-sample expected Loss: 0.14402
# Batch count: 251, Avg. per-sample expected Loss: 0.16619
# Batch count: 252, Avg. per-sample expected Loss: 0.16210
# Batch count: 253, Avg. per-sample expected Loss: 0.14611
# Batch count: 254, Avg. per-sample expected Loss: 0.17018
# Batch count: 255, Avg. per-sample expected Loss: 0.15088
# Batch count: 256, Avg. per-sample expected Loss: 0.15592
# Batch count: 257, Avg. per-sample expected Loss: 0.15904
# Batch count: 258, Avg. per-sample expected Loss: 0.15564
# Batch count: 259, Avg. per-sample expected Loss: 0.14827
# Batch count: 260, Avg. per-sample expected Loss: 0.15656
# Batch count: 261, Avg. per-sample expected Loss: 0.15783
# Batch count: 262, Avg. per-sample expected Loss: 0.15820
# Batch count: 263, Avg. per-sample expected Loss: 0.16355
# Batch count: 264, Avg. per-sample expected Loss: 0.15943
# Batch count: 265, Avg. per-sample expected Loss: 0.16231
# Batch count: 266, Avg. per-sample expected Loss: 0.16277
# Batch count: 267, Avg. per-sample expected Loss: 0.16249
# Batch count: 268, Avg. per-sample expected Loss: 0.16466
# Batch count: 269, Avg. per-sample expected Loss: 0.15549
# Batch count: 270, Avg. per-sample expected Loss: 0.15331
# Batch count: 271, Avg. per-sample expected Loss: 0.15071
# Batch count: 272, Avg. per-sample expected Loss: 0.15367
# Batch count: 273, Avg. per-sample expected Loss: 0.15253
# Batch count: 274, Avg. per-sample expected Loss: 0.15548
# Batch count: 275, Avg. per-sample expected Loss: 0.15604
# Batch count: 276, Avg. per-sample expected Loss: 0.14952
# Batch count: 277, Avg. per-sample expected Loss: 0.15960
# Batch count: 278, Avg. per-sample expected Loss: 0.16283
# Batch count: 279, Avg. per-sample expected Loss: 0.16646
# Batch count: 280, Avg. per-sample expected Loss: 0.16197
# Batch count: 281, Avg. per-sample expected Loss: 0.15596
# Batch count: 282, Avg. per-sample expected Loss: 0.15710
# Batch count: 283, Avg. per-sample expected Loss: 0.14176
# Batch count: 284, Avg. per-sample expected Loss: 0.15052
# Batch count: 285, Avg. per-sample expected Loss: 0.15309
# Batch count: 286, Avg. per-sample expected Loss: 0.13208
# Batch count: 287, Avg. per-sample expected Loss: 0.14238
# Batch count: 288, Avg. per-sample expected Loss: 0.15843
# Batch count: 289, Avg. per-sample expected Loss: 0.16078
# Batch count: 290, Avg. per-sample expected Loss: 0.15382
# Batch count: 291, Avg. per-sample expected Loss: 0.15122
# Batch count: 292, Avg. per-sample expected Loss: 0.15864
# Batch count: 293, Avg. per-sample expected Loss: 0.15354
# Batch count: 294, Avg. per-sample expected Loss: 0.15780
# Batch count: 295, Avg. per-sample expected Loss: 0.15977
# Batch count: 296, Avg. per-sample expected Loss: 0.14751
# Batch count: 297, Avg. per-sample expected Loss: 0.14739
# Batch count: 298, Avg. per-sample expected Loss: 0.15850
# Batch count: 299, Avg. per-sample expected Loss: 0.15586
# Batch count: 300, Avg. per-sample expected Loss: 0.14669
# Batch count: 301, Avg. per-sample expected Loss: 0.14497
# Batch count: 302, Avg. per-sample expected Loss: 0.15333
# Batch count: 303, Avg. per-sample expected Loss: 0.15430
# Batch count: 304, Avg. per-sample expected Loss: 0.15226
# Batch count: 305, Avg. per-sample expected Loss: 0.15032
# Batch count: 306, Avg. per-sample expected Loss: 0.15164
# Batch count: 307, Avg. per-sample expected Loss: 0.14588
# Batch count: 308, Avg. per-sample expected Loss: 0.14318
# Batch count: 309, Avg. per-sample expected Loss: 0.13688
# Batch count: 310, Avg. per-sample expected Loss: 0.14286
# Batch count: 311, Avg. per-sample expected Loss: 0.15858
# Batch count: 312, Avg. per-sample expected Loss: 0.14527
# Batch count: 313, Avg. per-sample expected Loss: 0.15486
# Batch count: 314, Avg. per-sample expected Loss: 0.15526
# Batch count: 315, Avg. per-sample expected Loss: 0.15395
# Batch count: 316, Avg. per-sample expected Loss: 0.15196
# Batch count: 317, Avg. per-sample expected Loss: 0.15852
# Batch count: 318, Avg. per-sample expected Loss: 0.13846
# Batch count: 319, Avg. per-sample expected Loss: 0.15262
# Batch count: 320, Avg. per-sample expected Loss: 0.15155
# Batch count: 321, Avg. per-sample expected Loss: 0.15471
# Batch count: 322, Avg. per-sample expected Loss: 0.15489
# Batch count: 323, Avg. per-sample expected Loss: 0.14438
# Batch count: 324, Avg. per-sample expected Loss: 0.14264
# Batch count: 325, Avg. per-sample expected Loss: 0.15221
# Batch count: 326, Avg. per-sample expected Loss: 0.13521
# Batch count: 327, Avg. per-sample expected Loss: 0.14362
# Batch count: 328, Avg. per-sample expected Loss: 0.13177
# Batch count: 329, Avg. per-sample expected Loss: 0.14837
# Batch count: 330, Avg. per-sample expected Loss: 0.13144
# Batch count: 331, Avg. per-sample expected Loss: 0.14874
# Batch count: 332, Avg. per-sample expected Loss: 0.14189
# Batch count: 333, Avg. per-sample expected Loss: 0.14701
# Batch count: 334, Avg. per-sample expected Loss: 0.14753
# Batch count: 335, Avg. per-sample expected Loss: 0.14193
# Batch count: 336, Avg. per-sample expected Loss: 0.14259
# Batch count: 337, Avg. per-sample expected Loss: 0.15115
# Batch count: 338, Avg. per-sample expected Loss: 0.14206
# Batch count: 339, Avg. per-sample expected Loss: 0.15047
# Batch count: 340, Avg. per-sample expected Loss: 0.15077
# Batch count: 341, Avg. per-sample expected Loss: 0.15208
# Batch count: 342, Avg. per-sample expected Loss: 0.13959
# Batch count: 343, Avg. per-sample expected Loss: 0.15175
# Batch count: 344, Avg. per-sample expected Loss: 0.13013
# Batch count: 345, Avg. per-sample expected Loss: 0.15102
# Batch count: 346, Avg. per-sample expected Loss: 0.15113
# Batch count: 347, Avg. per-sample expected Loss: 0.16018
# Batch count: 348, Avg. per-sample expected Loss: 0.16309
# Batch count: 349, Avg. per-sample expected Loss: 0.15424

# %% [markdown]
# ## Plots

# %%
plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "b", label="2-QNSCD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.", label="2-QNSCD Empirical Loss")

plt.title("Training using 2-QNSCD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.show()

# %% [markdown]
# ## 6-RQSGD using 600 samples per step

# %%
SGD6cparams = np.array(init_params)
SGD6c_cost = []
SGD6c_Ecost = []

SGD6c_cost.append(temp_cost)
SGD6c_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 6 coordinates
        idx = sorted(np.random.permutation(nparams)[0:6].tolist())
        
        grad = []
        
        ### Gradient estimation
        for i_grad in range(6):
            y_hat,b = EstGrad(SGD6cparams,phiT[:,itr3+i_grad],idx[i_grad])
            b = (1-b)/2
            grad.append((-1)*((-1)**b)*loss(y_hat,labelT[itr3+i_grad]))

        ### single-parameter update
        SGD6cparams[idx] = SGD6cparams[idx] - np.dot(step_size,grad)
    
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6cparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6c_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6ccount = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6cparams,phiT[:,itr]) != labelT[itr]:
            SGD6ccount += 1
    SGD6c_Ecost.append(SGD6ccount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "4Q 6-RQSGD Expected Loss"
file_name2 = "4Q 6-RQSGD Empirical Loss"

np.save(file_name1,SGD6c_cost)
np.save(file_name2,SGD6c_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.45992
# Batch count:  1, Avg. per-sample expected Loss: 0.47627
# Batch count:  2, Avg. per-sample expected Loss: 0.47904
# Batch count:  3, Avg. per-sample expected Loss: 0.47913
# Batch count:  4, Avg. per-sample expected Loss: 0.47932
# Batch count:  5, Avg. per-sample expected Loss: 0.47295
# Batch count:  6, Avg. per-sample expected Loss: 0.46373
# Batch count:  7, Avg. per-sample expected Loss: 0.47808
# Batch count:  8, Avg. per-sample expected Loss: 0.46375
# Batch count:  9, Avg. per-sample expected Loss: 0.46635
# Batch count: 10, Avg. per-sample expected Loss: 0.47063
# Batch count: 11, Avg. per-sample expected Loss: 0.46083
# Batch count: 12, Avg. per-sample expected Loss: 0.45724
# Batch count: 13, Avg. per-sample expected Loss: 0.46323
# Batch count: 14, Avg. per-sample expected Loss: 0.45627
# Batch count: 15, Avg. per-sample expected Loss: 0.46814
# Batch count: 16, Avg. per-sample expected Loss: 0.45343
# Batch count: 17, Avg. per-sample expected Loss: 0.45390
# Batch count: 18, Avg. per-sample expected Loss: 0.47364
# Batch count: 19, Avg. per-sample expected Loss: 0.45862
# Batch count: 20, Avg. per-sample expected Loss: 0.45791
# Batch count: 21, Avg. per-sample expected Loss: 0.44794
# Batch count: 22, Avg. per-sample expected Loss: 0.46011
# Batch count: 23, Avg. per-sample expected Loss: 0.47053
# Batch count: 24, Avg. per-sample expected Loss: 0.46216
# Batch count: 25, Avg. per-sample expected Loss: 0.47892
# Batch count: 26, Avg. per-sample expected Loss: 0.46616
# Batch count: 27, Avg. per-sample expected Loss: 0.46911
# Batch count: 28, Avg. per-sample expected Loss: 0.46979
# Batch count: 29, Avg. per-sample expected Loss: 0.47115
# Batch count: 30, Avg. per-sample expected Loss: 0.46917
# Batch count: 31, Avg. per-sample expected Loss: 0.47196
# Batch count: 32, Avg. per-sample expected Loss: 0.46543
# Batch count: 33, Avg. per-sample expected Loss: 0.47116
# Batch count: 34, Avg. per-sample expected Loss: 0.44812
# Batch count: 35, Avg. per-sample expected Loss: 0.45805
# Batch count: 36, Avg. per-sample expected Loss: 0.46745
# Batch count: 37, Avg. per-sample expected Loss: 0.45089
# Batch count: 38, Avg. per-sample expected Loss: 0.46032
# Batch count: 39, Avg. per-sample expected Loss: 0.45460
# Batch count: 40, Avg. per-sample expected Loss: 0.46482
# Batch count: 41, Avg. per-sample expected Loss: 0.45759
# Batch count: 42, Avg. per-sample expected Loss: 0.44982
# Batch count: 43, Avg. per-sample expected Loss: 0.46677
# Batch count: 44, Avg. per-sample expected Loss: 0.45447
# Batch count: 45, Avg. per-sample expected Loss: 0.46150
# Batch count: 46, Avg. per-sample expected Loss: 0.45058
# Batch count: 47, Avg. per-sample expected Loss: 0.45594
# Batch count: 48, Avg. per-sample expected Loss: 0.44177
# Batch count: 49, Avg. per-sample expected Loss: 0.44168
# Batch count: 50, Avg. per-sample expected Loss: 0.44608
# Batch count: 51, Avg. per-sample expected Loss: 0.45272
# Batch count: 52, Avg. per-sample expected Loss: 0.45190
# Batch count: 53, Avg. per-sample expected Loss: 0.45497
# Batch count: 54, Avg. per-sample expected Loss: 0.46452
# Batch count: 55, Avg. per-sample expected Loss: 0.44839
# Batch count: 56, Avg. per-sample expected Loss: 0.43914
# Batch count: 57, Avg. per-sample expected Loss: 0.44328
# Batch count: 58, Avg. per-sample expected Loss: 0.44185
# Batch count: 59, Avg. per-sample expected Loss: 0.44483
# Batch count: 60, Avg. per-sample expected Loss: 0.45426
# Batch count: 61, Avg. per-sample expected Loss: 0.43899
# Batch count: 62, Avg. per-sample expected Loss: 0.44444
# Batch count: 63, Avg. per-sample expected Loss: 0.44536
# Batch count: 64, Avg. per-sample expected Loss: 0.45469
# Batch count: 65, Avg. per-sample expected Loss: 0.45627
# Batch count: 66, Avg. per-sample expected Loss: 0.44146
# Batch count: 67, Avg. per-sample expected Loss: 0.44554
# Batch count: 68, Avg. per-sample expected Loss: 0.43585
# Batch count: 69, Avg. per-sample expected Loss: 0.43784
# Batch count: 70, Avg. per-sample expected Loss: 0.44675
# Batch count: 71, Avg. per-sample expected Loss: 0.44110
# Batch count: 72, Avg. per-sample expected Loss: 0.45000
# Batch count: 73, Avg. per-sample expected Loss: 0.42812
# Batch count: 74, Avg. per-sample expected Loss: 0.44609
# Batch count: 75, Avg. per-sample expected Loss: 0.43728
# Batch count: 76, Avg. per-sample expected Loss: 0.43686
# Batch count: 77, Avg. per-sample expected Loss: 0.44125
# Batch count: 78, Avg. per-sample expected Loss: 0.43658
# Batch count: 79, Avg. per-sample expected Loss: 0.44031
# Batch count: 80, Avg. per-sample expected Loss: 0.43199
# Batch count: 81, Avg. per-sample expected Loss: 0.43861
# Batch count: 82, Avg. per-sample expected Loss: 0.43258
# Batch count: 83, Avg. per-sample expected Loss: 0.43397
# Batch count: 84, Avg. per-sample expected Loss: 0.42456
# Batch count: 85, Avg. per-sample expected Loss: 0.43265
# Batch count: 86, Avg. per-sample expected Loss: 0.42688
# Batch count: 87, Avg. per-sample expected Loss: 0.44010
# Batch count: 88, Avg. per-sample expected Loss: 0.42224
# Batch count: 89, Avg. per-sample expected Loss: 0.42397
# Batch count: 90, Avg. per-sample expected Loss: 0.43587
# Batch count: 91, Avg. per-sample expected Loss: 0.41267
# Batch count: 92, Avg. per-sample expected Loss: 0.44367
# Batch count: 93, Avg. per-sample expected Loss: 0.44043
# Batch count: 94, Avg. per-sample expected Loss: 0.43200
# Batch count: 95, Avg. per-sample expected Loss: 0.43066
# Batch count: 96, Avg. per-sample expected Loss: 0.43568
# Batch count: 97, Avg. per-sample expected Loss: 0.42949
# Batch count: 98, Avg. per-sample expected Loss: 0.42910
# Batch count: 99, Avg. per-sample expected Loss: 0.41141
# Batch count: 100, Avg. per-sample expected Loss: 0.41724
# Batch count: 101, Avg. per-sample expected Loss: 0.42193
# Batch count: 102, Avg. per-sample expected Loss: 0.41678
# Batch count: 103, Avg. per-sample expected Loss: 0.42164
# Batch count: 104, Avg. per-sample expected Loss: 0.42687
# Batch count: 105, Avg. per-sample expected Loss: 0.40483
# Batch count: 106, Avg. per-sample expected Loss: 0.41006
# Batch count: 107, Avg. per-sample expected Loss: 0.41359
# Batch count: 108, Avg. per-sample expected Loss: 0.42115
# Batch count: 109, Avg. per-sample expected Loss: 0.40401
# Batch count: 110, Avg. per-sample expected Loss: 0.43353
# Batch count: 111, Avg. per-sample expected Loss: 0.40630
# Batch count: 112, Avg. per-sample expected Loss: 0.41086
# Batch count: 113, Avg. per-sample expected Loss: 0.41373
# Batch count: 114, Avg. per-sample expected Loss: 0.42345
# Batch count: 115, Avg. per-sample expected Loss: 0.41006
# Batch count: 116, Avg. per-sample expected Loss: 0.42524
# Batch count: 117, Avg. per-sample expected Loss: 0.41743
# Batch count: 118, Avg. per-sample expected Loss: 0.41634
# Batch count: 119, Avg. per-sample expected Loss: 0.41484
# Batch count: 120, Avg. per-sample expected Loss: 0.41745
# Batch count: 121, Avg. per-sample expected Loss: 0.41964
# Batch count: 122, Avg. per-sample expected Loss: 0.40652
# Batch count: 123, Avg. per-sample expected Loss: 0.40551
# Batch count: 124, Avg. per-sample expected Loss: 0.41280
# Batch count: 125, Avg. per-sample expected Loss: 0.40010
# Batch count: 126, Avg. per-sample expected Loss: 0.41000
# Batch count: 127, Avg. per-sample expected Loss: 0.41516
# Batch count: 128, Avg. per-sample expected Loss: 0.40147
# Batch count: 129, Avg. per-sample expected Loss: 0.40079
# Batch count: 130, Avg. per-sample expected Loss: 0.39301
# Batch count: 131, Avg. per-sample expected Loss: 0.41216
# Batch count: 132, Avg. per-sample expected Loss: 0.40054
# Batch count: 133, Avg. per-sample expected Loss: 0.41114
# Batch count: 134, Avg. per-sample expected Loss: 0.40449
# Batch count: 135, Avg. per-sample expected Loss: 0.41186
# Batch count: 136, Avg. per-sample expected Loss: 0.41067
# Batch count: 137, Avg. per-sample expected Loss: 0.40104
# Batch count: 138, Avg. per-sample expected Loss: 0.40897
# Batch count: 139, Avg. per-sample expected Loss: 0.40561
# Batch count: 140, Avg. per-sample expected Loss: 0.39642
# Batch count: 141, Avg. per-sample expected Loss: 0.40726
# Batch count: 142, Avg. per-sample expected Loss: 0.40361
# Batch count: 143, Avg. per-sample expected Loss: 0.40185
# Batch count: 144, Avg. per-sample expected Loss: 0.41378
# Batch count: 145, Avg. per-sample expected Loss: 0.40969
# Batch count: 146, Avg. per-sample expected Loss: 0.38669
# Batch count: 147, Avg. per-sample expected Loss: 0.41633
# Batch count: 148, Avg. per-sample expected Loss: 0.40140
# Batch count: 149, Avg. per-sample expected Loss: 0.40224
# Batch count: 150, Avg. per-sample expected Loss: 0.38420
# Batch count: 151, Avg. per-sample expected Loss: 0.41204
# Batch count: 152, Avg. per-sample expected Loss: 0.38739
# Batch count: 153, Avg. per-sample expected Loss: 0.40206
# Batch count: 154, Avg. per-sample expected Loss: 0.40669
# Batch count: 155, Avg. per-sample expected Loss: 0.38808
# Batch count: 156, Avg. per-sample expected Loss: 0.40136
# Batch count: 157, Avg. per-sample expected Loss: 0.38206
# Batch count: 158, Avg. per-sample expected Loss: 0.38709
# Batch count: 159, Avg. per-sample expected Loss: 0.39447
# Batch count: 160, Avg. per-sample expected Loss: 0.38947
# Batch count: 161, Avg. per-sample expected Loss: 0.39763
# Batch count: 162, Avg. per-sample expected Loss: 0.40086
# Batch count: 163, Avg. per-sample expected Loss: 0.40218
# Batch count: 164, Avg. per-sample expected Loss: 0.41036
# Batch count: 165, Avg. per-sample expected Loss: 0.39656
# Batch count: 166, Avg. per-sample expected Loss: 0.40774
# Batch count: 167, Avg. per-sample expected Loss: 0.39940
# Batch count: 168, Avg. per-sample expected Loss: 0.38984
# Batch count: 169, Avg. per-sample expected Loss: 0.39380
# Batch count: 170, Avg. per-sample expected Loss: 0.39669
# Batch count: 171, Avg. per-sample expected Loss: 0.39717
# Batch count: 172, Avg. per-sample expected Loss: 0.39062
# Batch count: 173, Avg. per-sample expected Loss: 0.37759
# Batch count: 174, Avg. per-sample expected Loss: 0.40271
# Batch count: 175, Avg. per-sample expected Loss: 0.39539
# Batch count: 176, Avg. per-sample expected Loss: 0.39948
# Batch count: 177, Avg. per-sample expected Loss: 0.39730
# Batch count: 178, Avg. per-sample expected Loss: 0.38411
# Batch count: 179, Avg. per-sample expected Loss: 0.37986
# Batch count: 180, Avg. per-sample expected Loss: 0.38171
# Batch count: 181, Avg. per-sample expected Loss: 0.39877
# Batch count: 182, Avg. per-sample expected Loss: 0.39679
# Batch count: 183, Avg. per-sample expected Loss: 0.39151
# Batch count: 184, Avg. per-sample expected Loss: 0.38996
# Batch count: 185, Avg. per-sample expected Loss: 0.39807
# Batch count: 186, Avg. per-sample expected Loss: 0.38317
# Batch count: 187, Avg. per-sample expected Loss: 0.39074
# Batch count: 188, Avg. per-sample expected Loss: 0.39606
# Batch count: 189, Avg. per-sample expected Loss: 0.38364
# Batch count: 190, Avg. per-sample expected Loss: 0.39318
# Batch count: 191, Avg. per-sample expected Loss: 0.37315
# Batch count: 192, Avg. per-sample expected Loss: 0.37945
# Batch count: 193, Avg. per-sample expected Loss: 0.38710
# Batch count: 194, Avg. per-sample expected Loss: 0.38859
# Batch count: 195, Avg. per-sample expected Loss: 0.38740
# Batch count: 196, Avg. per-sample expected Loss: 0.38444
# Batch count: 197, Avg. per-sample expected Loss: 0.39306
# Batch count: 198, Avg. per-sample expected Loss: 0.38937
# Batch count: 199, Avg. per-sample expected Loss: 0.38914
# Batch count: 200, Avg. per-sample expected Loss: 0.37720
# Batch count: 201, Avg. per-sample expected Loss: 0.37622
# Batch count: 202, Avg. per-sample expected Loss: 0.37816
# Batch count: 203, Avg. per-sample expected Loss: 0.39193
# Batch count: 204, Avg. per-sample expected Loss: 0.39070
# Batch count: 205, Avg. per-sample expected Loss: 0.39058
# Batch count: 206, Avg. per-sample expected Loss: 0.39022
# Batch count: 207, Avg. per-sample expected Loss: 0.37274
# Batch count: 208, Avg. per-sample expected Loss: 0.39537
# Batch count: 209, Avg. per-sample expected Loss: 0.38135
# Batch count: 210, Avg. per-sample expected Loss: 0.37444
# Batch count: 211, Avg. per-sample expected Loss: 0.38089
# Batch count: 212, Avg. per-sample expected Loss: 0.37840
# Batch count: 213, Avg. per-sample expected Loss: 0.39916
# Batch count: 214, Avg. per-sample expected Loss: 0.38488
# Batch count: 215, Avg. per-sample expected Loss: 0.38067
# Batch count: 216, Avg. per-sample expected Loss: 0.37941
# Batch count: 217, Avg. per-sample expected Loss: 0.37500
# Batch count: 218, Avg. per-sample expected Loss: 0.38771
# Batch count: 219, Avg. per-sample expected Loss: 0.39272
# Batch count: 220, Avg. per-sample expected Loss: 0.37683
# Batch count: 221, Avg. per-sample expected Loss: 0.38699
# Batch count: 222, Avg. per-sample expected Loss: 0.38747
# Batch count: 223, Avg. per-sample expected Loss: 0.37372
# Batch count: 224, Avg. per-sample expected Loss: 0.38118
# Batch count: 225, Avg. per-sample expected Loss: 0.37206
# Batch count: 226, Avg. per-sample expected Loss: 0.39245
# Batch count: 227, Avg. per-sample expected Loss: 0.38536
# Batch count: 228, Avg. per-sample expected Loss: 0.38313
# Batch count: 229, Avg. per-sample expected Loss: 0.38137
# Batch count: 230, Avg. per-sample expected Loss: 0.38279
# Batch count: 231, Avg. per-sample expected Loss: 0.37707
# Batch count: 232, Avg. per-sample expected Loss: 0.38268
# Batch count: 233, Avg. per-sample expected Loss: 0.37412
# Batch count: 234, Avg. per-sample expected Loss: 0.37202
# Batch count: 235, Avg. per-sample expected Loss: 0.38269
# Batch count: 236, Avg. per-sample expected Loss: 0.37630
# Batch count: 237, Avg. per-sample expected Loss: 0.38698
# Batch count: 238, Avg. per-sample expected Loss: 0.38114
# Batch count: 239, Avg. per-sample expected Loss: 0.36867
# Batch count: 240, Avg. per-sample expected Loss: 0.38329
# Batch count: 241, Avg. per-sample expected Loss: 0.37868
# Batch count: 242, Avg. per-sample expected Loss: 0.38673
# Batch count: 243, Avg. per-sample expected Loss: 0.37819
# Batch count: 244, Avg. per-sample expected Loss: 0.37577
# Batch count: 245, Avg. per-sample expected Loss: 0.37363
# Batch count: 246, Avg. per-sample expected Loss: 0.38337
# Batch count: 247, Avg. per-sample expected Loss: 0.39217
# Batch count: 248, Avg. per-sample expected Loss: 0.39046
# Batch count: 249, Avg. per-sample expected Loss: 0.38766
# Batch count: 250, Avg. per-sample expected Loss: 0.37654
# Batch count: 251, Avg. per-sample expected Loss: 0.36848
# Batch count: 252, Avg. per-sample expected Loss: 0.37147
# Batch count: 253, Avg. per-sample expected Loss: 0.38476
# Batch count: 254, Avg. per-sample expected Loss: 0.36605
# Batch count: 255, Avg. per-sample expected Loss: 0.38171
# Batch count: 256, Avg. per-sample expected Loss: 0.38353
# Batch count: 257, Avg. per-sample expected Loss: 0.37429
# Batch count: 258, Avg. per-sample expected Loss: 0.36476
# Batch count: 259, Avg. per-sample expected Loss: 0.38102
# Batch count: 260, Avg. per-sample expected Loss: 0.37873
# Batch count: 261, Avg. per-sample expected Loss: 0.38100
# Batch count: 262, Avg. per-sample expected Loss: 0.39135
# Batch count: 263, Avg. per-sample expected Loss: 0.38134
# Batch count: 264, Avg. per-sample expected Loss: 0.39047
# Batch count: 265, Avg. per-sample expected Loss: 0.38632
# Batch count: 266, Avg. per-sample expected Loss: 0.38697
# Batch count: 267, Avg. per-sample expected Loss: 0.38672
# Batch count: 268, Avg. per-sample expected Loss: 0.38905
# Batch count: 269, Avg. per-sample expected Loss: 0.38517
# Batch count: 270, Avg. per-sample expected Loss: 0.37432
# Batch count: 271, Avg. per-sample expected Loss: 0.38820
# Batch count: 272, Avg. per-sample expected Loss: 0.35943
# Batch count: 273, Avg. per-sample expected Loss: 0.38585
# Batch count: 274, Avg. per-sample expected Loss: 0.37517
# Batch count: 275, Avg. per-sample expected Loss: 0.38702
# Batch count: 276, Avg. per-sample expected Loss: 0.38088
# Batch count: 277, Avg. per-sample expected Loss: 0.36753
# Batch count: 278, Avg. per-sample expected Loss: 0.37657
# Batch count: 279, Avg. per-sample expected Loss: 0.38110
# Batch count: 280, Avg. per-sample expected Loss: 0.37830
# Batch count: 281, Avg. per-sample expected Loss: 0.37421
# Batch count: 282, Avg. per-sample expected Loss: 0.37719
# Batch count: 283, Avg. per-sample expected Loss: 0.38371
# Batch count: 284, Avg. per-sample expected Loss: 0.38616
# Batch count: 285, Avg. per-sample expected Loss: 0.38742
# Batch count: 286, Avg. per-sample expected Loss: 0.39923
# Batch count: 287, Avg. per-sample expected Loss: 0.38698
# Batch count: 288, Avg. per-sample expected Loss: 0.37788
# Batch count: 289, Avg. per-sample expected Loss: 0.37332
# Batch count: 290, Avg. per-sample expected Loss: 0.37005
# Batch count: 291, Avg. per-sample expected Loss: 0.36636
# Batch count: 292, Avg. per-sample expected Loss: 0.36086
# Batch count: 293, Avg. per-sample expected Loss: 0.36401
# Batch count: 294, Avg. per-sample expected Loss: 0.35790
# Batch count: 295, Avg. per-sample expected Loss: 0.35703
# Batch count: 296, Avg. per-sample expected Loss: 0.38052
# Batch count: 297, Avg. per-sample expected Loss: 0.38517
# Batch count: 298, Avg. per-sample expected Loss: 0.37146
# Batch count: 299, Avg. per-sample expected Loss: 0.37459
# Batch count: 300, Avg. per-sample expected Loss: 0.39170
# Batch count: 301, Avg. per-sample expected Loss: 0.38449
# Batch count: 302, Avg. per-sample expected Loss: 0.37481
# Batch count: 303, Avg. per-sample expected Loss: 0.37460
# Batch count: 304, Avg. per-sample expected Loss: 0.37525
# Batch count: 305, Avg. per-sample expected Loss: 0.38339
# Batch count: 306, Avg. per-sample expected Loss: 0.36603
# Batch count: 307, Avg. per-sample expected Loss: 0.38124
# Batch count: 308, Avg. per-sample expected Loss: 0.37596
# Batch count: 309, Avg. per-sample expected Loss: 0.39820
# Batch count: 310, Avg. per-sample expected Loss: 0.39160
# Batch count: 311, Avg. per-sample expected Loss: 0.37559
# Batch count: 312, Avg. per-sample expected Loss: 0.39270
# Batch count: 313, Avg. per-sample expected Loss: 0.37574
# Batch count: 314, Avg. per-sample expected Loss: 0.38425
# Batch count: 315, Avg. per-sample expected Loss: 0.37712
# Batch count: 316, Avg. per-sample expected Loss: 0.37519
# Batch count: 317, Avg. per-sample expected Loss: 0.38018
# Batch count: 318, Avg. per-sample expected Loss: 0.37686
# Batch count: 319, Avg. per-sample expected Loss: 0.37881
# Batch count: 320, Avg. per-sample expected Loss: 0.37297
# Batch count: 321, Avg. per-sample expected Loss: 0.37415
# Batch count: 322, Avg. per-sample expected Loss: 0.36520
# Batch count: 323, Avg. per-sample expected Loss: 0.39233
# Batch count: 324, Avg. per-sample expected Loss: 0.37077
# Batch count: 325, Avg. per-sample expected Loss: 0.37955
# Batch count: 326, Avg. per-sample expected Loss: 0.39407
# Batch count: 327, Avg. per-sample expected Loss: 0.38985
# Batch count: 328, Avg. per-sample expected Loss: 0.39954
# Batch count: 329, Avg. per-sample expected Loss: 0.37729
# Batch count: 330, Avg. per-sample expected Loss: 0.38576
# Batch count: 331, Avg. per-sample expected Loss: 0.37670
# Batch count: 332, Avg. per-sample expected Loss: 0.37223
# Batch count: 333, Avg. per-sample expected Loss: 0.38002
# Batch count: 334, Avg. per-sample expected Loss: 0.38006
# Batch count: 335, Avg. per-sample expected Loss: 0.37807
# Batch count: 336, Avg. per-sample expected Loss: 0.37807
# Batch count: 337, Avg. per-sample expected Loss: 0.37377
# Batch count: 338, Avg. per-sample expected Loss: 0.39216
# Batch count: 339, Avg. per-sample expected Loss: 0.38475
# Batch count: 340, Avg. per-sample expected Loss: 0.37969
# Batch count: 341, Avg. per-sample expected Loss: 0.37645
# Batch count: 342, Avg. per-sample expected Loss: 0.38120
# Batch count: 343, Avg. per-sample expected Loss: 0.37590
# Batch count: 344, Avg. per-sample expected Loss: 0.39826
# Batch count: 345, Avg. per-sample expected Loss: 0.37838
# Batch count: 346, Avg. per-sample expected Loss: 0.38113
# Batch count: 347, Avg. per-sample expected Loss: 0.37490
# Batch count: 348, Avg. per-sample expected Loss: 0.36653
# Batch count: 349, Avg. per-sample expected Loss: 0.36955

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6c_cost, "b", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6c_Ecost, "c.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training using 2-QNSCD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("6-RQSGD.png")
plt.show()

# %% [markdown]
# ## 2-RQSGD using 600 samples per step and 6 samples per itr

# %%
SGD6params = np.array(init_params)
SGD6_cost = []
SGD6_Ecost = []

SGD6_cost.append(temp_cost)
SGD6_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 2 coordinates
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())
        
        grad = []
        
        ### Gradient estimation
        y_hat01,b01 = EstGrad(SGD6params,phiT[:,itr3+0],idx[0])
        b01 = (1-b01)/2
        y_hat02,b02 = EstGrad(SGD6params,phiT[:,itr3+1],idx[0])
        b02 = (1-b02)/2
        y_hat03,b03 = EstGrad(SGD6params,phiT[:,itr3+2],idx[0])
        b03 = (1-b03)/2
        
        temp0 = ((-1)**b01)*loss(y_hat01,labelT[itr3+0]) \
              + ((-1)**b02)*loss(y_hat02,labelT[itr3+1]) \
              + ((-1)**b03)*loss(y_hat03,labelT[itr3+2])

        grad.append((-1)*temp0/3)
        
        y_hat11,b11 = EstGrad(SGD6params,phiT[:,itr3+3],idx[1])
        b11 = (1-b11)/2
        y_hat12,b12 = EstGrad(SGD6params,phiT[:,itr3+4],idx[1])
        b12 = (1-b12)/2
        y_hat13,b13 = EstGrad(SGD6params,phiT[:,itr3+5],idx[1])
        b13 = (1-b13)/2
        
        temp1 = ((-1)**b11)*loss(y_hat11,labelT[itr3+3]) \
              + ((-1)**b12)*loss(y_hat12,labelT[itr3+4]) \
              + ((-1)**b13)*loss(y_hat13,labelT[itr3+5])

        grad.append((-1)*temp1/3)

        ### single-parameter update
        SGD6params[idx] = SGD6params[idx] - np.dot(step_size,grad)
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6params,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6count = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6params,phiT[:,itr]) != labelT[itr]:
            SGD6count += 1
    SGD6_Ecost.append(SGD6count/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "4Q 2-RQSGD_6s Expected Loss"
file_name2 = "4Q 2-RQSGD_6s Empirical Loss"

np.save(file_name1,SGD6_cost)
np.save(file_name2,SGD6_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.45992
# Batch count:  1, Avg. per-sample expected Loss: 0.47627
# Batch count:  2, Avg. per-sample expected Loss: 0.48001
# Batch count:  3, Avg. per-sample expected Loss: 0.48126
# Batch count:  4, Avg. per-sample expected Loss: 0.48219
# Batch count:  5, Avg. per-sample expected Loss: 0.47666
# Batch count:  6, Avg. per-sample expected Loss: 0.46929
# Batch count:  7, Avg. per-sample expected Loss: 0.48638
# Batch count:  8, Avg. per-sample expected Loss: 0.47153
# Batch count:  9, Avg. per-sample expected Loss: 0.47198
# Batch count: 10, Avg. per-sample expected Loss: 0.47661
# Batch count: 11, Avg. per-sample expected Loss: 0.46704
# Batch count: 12, Avg. per-sample expected Loss: 0.46417
# Batch count: 13, Avg. per-sample expected Loss: 0.47297
# Batch count: 14, Avg. per-sample expected Loss: 0.46509
# Batch count: 15, Avg. per-sample expected Loss: 0.47686
# Batch count: 16, Avg. per-sample expected Loss: 0.46423
# Batch count: 17, Avg. per-sample expected Loss: 0.46661
# Batch count: 18, Avg. per-sample expected Loss: 0.48008
# Batch count: 19, Avg. per-sample expected Loss: 0.47050
# Batch count: 20, Avg. per-sample expected Loss: 0.46985
# Batch count: 21, Avg. per-sample expected Loss: 0.45842
# Batch count: 22, Avg. per-sample expected Loss: 0.46868
# Batch count: 23, Avg. per-sample expected Loss: 0.47995
# Batch count: 24, Avg. per-sample expected Loss: 0.47140
# Batch count: 25, Avg. per-sample expected Loss: 0.48855
# Batch count: 26, Avg. per-sample expected Loss: 0.47745
# Batch count: 27, Avg. per-sample expected Loss: 0.47739
# Batch count: 28, Avg. per-sample expected Loss: 0.47878
# Batch count: 29, Avg. per-sample expected Loss: 0.47900
# Batch count: 30, Avg. per-sample expected Loss: 0.47783
# Batch count: 31, Avg. per-sample expected Loss: 0.48173
# Batch count: 32, Avg. per-sample expected Loss: 0.47168
# Batch count: 33, Avg. per-sample expected Loss: 0.47943
# Batch count: 34, Avg. per-sample expected Loss: 0.45570
# Batch count: 35, Avg. per-sample expected Loss: 0.46665
# Batch count: 36, Avg. per-sample expected Loss: 0.47392
# Batch count: 37, Avg. per-sample expected Loss: 0.45686
# Batch count: 38, Avg. per-sample expected Loss: 0.46704
# Batch count: 39, Avg. per-sample expected Loss: 0.46702
# Batch count: 40, Avg. per-sample expected Loss: 0.47088
# Batch count: 41, Avg. per-sample expected Loss: 0.46974
# Batch count: 42, Avg. per-sample expected Loss: 0.46122
# Batch count: 43, Avg. per-sample expected Loss: 0.47550
# Batch count: 44, Avg. per-sample expected Loss: 0.46448
# Batch count: 45, Avg. per-sample expected Loss: 0.47457
# Batch count: 46, Avg. per-sample expected Loss: 0.45937
# Batch count: 47, Avg. per-sample expected Loss: 0.46717
# Batch count: 48, Avg. per-sample expected Loss: 0.45112
# Batch count: 49, Avg. per-sample expected Loss: 0.45208
# Batch count: 50, Avg. per-sample expected Loss: 0.46054
# Batch count: 51, Avg. per-sample expected Loss: 0.47024
# Batch count: 52, Avg. per-sample expected Loss: 0.46746
# Batch count: 53, Avg. per-sample expected Loss: 0.47418
# Batch count: 54, Avg. per-sample expected Loss: 0.48237
# Batch count: 55, Avg. per-sample expected Loss: 0.46719
# Batch count: 56, Avg. per-sample expected Loss: 0.45622
# Batch count: 57, Avg. per-sample expected Loss: 0.46189
# Batch count: 58, Avg. per-sample expected Loss: 0.46515
# Batch count: 59, Avg. per-sample expected Loss: 0.46122
# Batch count: 60, Avg. per-sample expected Loss: 0.47768
# Batch count: 61, Avg. per-sample expected Loss: 0.46275
# Batch count: 62, Avg. per-sample expected Loss: 0.46083
# Batch count: 63, Avg. per-sample expected Loss: 0.46414
# Batch count: 64, Avg. per-sample expected Loss: 0.47770
# Batch count: 65, Avg. per-sample expected Loss: 0.47049
# Batch count: 66, Avg. per-sample expected Loss: 0.45739
# Batch count: 67, Avg. per-sample expected Loss: 0.46723
# Batch count: 68, Avg. per-sample expected Loss: 0.46289
# Batch count: 69, Avg. per-sample expected Loss: 0.45911
# Batch count: 70, Avg. per-sample expected Loss: 0.46574
# Batch count: 71, Avg. per-sample expected Loss: 0.46114
# Batch count: 72, Avg. per-sample expected Loss: 0.47573
# Batch count: 73, Avg. per-sample expected Loss: 0.45531
# Batch count: 74, Avg. per-sample expected Loss: 0.47465
# Batch count: 75, Avg. per-sample expected Loss: 0.45835
# Batch count: 76, Avg. per-sample expected Loss: 0.46324
# Batch count: 77, Avg. per-sample expected Loss: 0.45927
# Batch count: 78, Avg. per-sample expected Loss: 0.46536
# Batch count: 79, Avg. per-sample expected Loss: 0.47402
# Batch count: 80, Avg. per-sample expected Loss: 0.45886
# Batch count: 81, Avg. per-sample expected Loss: 0.46712
# Batch count: 82, Avg. per-sample expected Loss: 0.45547
# Batch count: 83, Avg. per-sample expected Loss: 0.46341
# Batch count: 84, Avg. per-sample expected Loss: 0.45732
# Batch count: 85, Avg. per-sample expected Loss: 0.46328
# Batch count: 86, Avg. per-sample expected Loss: 0.45513
# Batch count: 87, Avg. per-sample expected Loss: 0.46675
# Batch count: 88, Avg. per-sample expected Loss: 0.45393
# Batch count: 89, Avg. per-sample expected Loss: 0.46391
# Batch count: 90, Avg. per-sample expected Loss: 0.46747
# Batch count: 91, Avg. per-sample expected Loss: 0.44786
# Batch count: 92, Avg. per-sample expected Loss: 0.47179
# Batch count: 93, Avg. per-sample expected Loss: 0.46930
# Batch count: 94, Avg. per-sample expected Loss: 0.46914
# Batch count: 95, Avg. per-sample expected Loss: 0.46421
# Batch count: 96, Avg. per-sample expected Loss: 0.47118
# Batch count: 97, Avg. per-sample expected Loss: 0.46763
# Batch count: 98, Avg. per-sample expected Loss: 0.45382
# Batch count: 99, Avg. per-sample expected Loss: 0.44413
# Batch count: 100, Avg. per-sample expected Loss: 0.45091
# Batch count: 101, Avg. per-sample expected Loss: 0.45339
# Batch count: 102, Avg. per-sample expected Loss: 0.45198
# Batch count: 103, Avg. per-sample expected Loss: 0.46457
# Batch count: 104, Avg. per-sample expected Loss: 0.46781
# Batch count: 105, Avg. per-sample expected Loss: 0.45300
# Batch count: 106, Avg. per-sample expected Loss: 0.45297
# Batch count: 107, Avg. per-sample expected Loss: 0.45341
# Batch count: 108, Avg. per-sample expected Loss: 0.46442
# Batch count: 109, Avg. per-sample expected Loss: 0.45922
# Batch count: 110, Avg. per-sample expected Loss: 0.46816
# Batch count: 111, Avg. per-sample expected Loss: 0.44944
# Batch count: 112, Avg. per-sample expected Loss: 0.44896
# Batch count: 113, Avg. per-sample expected Loss: 0.47150
# Batch count: 114, Avg. per-sample expected Loss: 0.46895
# Batch count: 115, Avg. per-sample expected Loss: 0.45850
# Batch count: 116, Avg. per-sample expected Loss: 0.46936
# Batch count: 117, Avg. per-sample expected Loss: 0.47090
# Batch count: 118, Avg. per-sample expected Loss: 0.47118
# Batch count: 119, Avg. per-sample expected Loss: 0.45709
# Batch count: 120, Avg. per-sample expected Loss: 0.47098
# Batch count: 121, Avg. per-sample expected Loss: 0.46708
# Batch count: 122, Avg. per-sample expected Loss: 0.45152
# Batch count: 123, Avg. per-sample expected Loss: 0.45373
# Batch count: 124, Avg. per-sample expected Loss: 0.46207
# Batch count: 125, Avg. per-sample expected Loss: 0.44856
# Batch count: 126, Avg. per-sample expected Loss: 0.46343
# Batch count: 127, Avg. per-sample expected Loss: 0.46899
# Batch count: 128, Avg. per-sample expected Loss: 0.45366
# Batch count: 129, Avg. per-sample expected Loss: 0.46156
# Batch count: 130, Avg. per-sample expected Loss: 0.44146
# Batch count: 131, Avg. per-sample expected Loss: 0.45474
# Batch count: 132, Avg. per-sample expected Loss: 0.44991
# Batch count: 133, Avg. per-sample expected Loss: 0.45768
# Batch count: 134, Avg. per-sample expected Loss: 0.45661
# Batch count: 135, Avg. per-sample expected Loss: 0.46345
# Batch count: 136, Avg. per-sample expected Loss: 0.45736
# Batch count: 137, Avg. per-sample expected Loss: 0.45836
# Batch count: 138, Avg. per-sample expected Loss: 0.44911
# Batch count: 139, Avg. per-sample expected Loss: 0.45762
# Batch count: 140, Avg. per-sample expected Loss: 0.45295
# Batch count: 141, Avg. per-sample expected Loss: 0.44627
# Batch count: 142, Avg. per-sample expected Loss: 0.45652
# Batch count: 143, Avg. per-sample expected Loss: 0.46616
# Batch count: 144, Avg. per-sample expected Loss: 0.45893
# Batch count: 145, Avg. per-sample expected Loss: 0.46323
# Batch count: 146, Avg. per-sample expected Loss: 0.44587
# Batch count: 147, Avg. per-sample expected Loss: 0.45415
# Batch count: 148, Avg. per-sample expected Loss: 0.44681
# Batch count: 149, Avg. per-sample expected Loss: 0.45301
# Batch count: 150, Avg. per-sample expected Loss: 0.45675
# Batch count: 151, Avg. per-sample expected Loss: 0.46172
# Batch count: 152, Avg. per-sample expected Loss: 0.44872
# Batch count: 153, Avg. per-sample expected Loss: 0.45386
# Batch count: 154, Avg. per-sample expected Loss: 0.44974
# Batch count: 155, Avg. per-sample expected Loss: 0.45352
# Batch count: 156, Avg. per-sample expected Loss: 0.45454
# Batch count: 157, Avg. per-sample expected Loss: 0.45758
# Batch count: 158, Avg. per-sample expected Loss: 0.45193
# Batch count: 159, Avg. per-sample expected Loss: 0.45541
# Batch count: 160, Avg. per-sample expected Loss: 0.44673
# Batch count: 161, Avg. per-sample expected Loss: 0.44472
# Batch count: 162, Avg. per-sample expected Loss: 0.44981
# Batch count: 163, Avg. per-sample expected Loss: 0.44780
# Batch count: 164, Avg. per-sample expected Loss: 0.45420
# Batch count: 165, Avg. per-sample expected Loss: 0.44236
# Batch count: 166, Avg. per-sample expected Loss: 0.45569
# Batch count: 167, Avg. per-sample expected Loss: 0.44539
# Batch count: 168, Avg. per-sample expected Loss: 0.43274
# Batch count: 169, Avg. per-sample expected Loss: 0.45229
# Batch count: 170, Avg. per-sample expected Loss: 0.44917
# Batch count: 171, Avg. per-sample expected Loss: 0.45575
# Batch count: 172, Avg. per-sample expected Loss: 0.44103
# Batch count: 173, Avg. per-sample expected Loss: 0.44393
# Batch count: 174, Avg. per-sample expected Loss: 0.44830
# Batch count: 175, Avg. per-sample expected Loss: 0.45834
# Batch count: 176, Avg. per-sample expected Loss: 0.46101
# Batch count: 177, Avg. per-sample expected Loss: 0.45349
# Batch count: 178, Avg. per-sample expected Loss: 0.44557
# Batch count: 179, Avg. per-sample expected Loss: 0.44604
# Batch count: 180, Avg. per-sample expected Loss: 0.44057
# Batch count: 181, Avg. per-sample expected Loss: 0.45496
# Batch count: 182, Avg. per-sample expected Loss: 0.44755
# Batch count: 183, Avg. per-sample expected Loss: 0.44998
# Batch count: 184, Avg. per-sample expected Loss: 0.44521
# Batch count: 185, Avg. per-sample expected Loss: 0.44113
# Batch count: 186, Avg. per-sample expected Loss: 0.44417
# Batch count: 187, Avg. per-sample expected Loss: 0.45256
# Batch count: 188, Avg. per-sample expected Loss: 0.44000
# Batch count: 189, Avg. per-sample expected Loss: 0.44082
# Batch count: 190, Avg. per-sample expected Loss: 0.44850
# Batch count: 191, Avg. per-sample expected Loss: 0.43835
# Batch count: 192, Avg. per-sample expected Loss: 0.43834
# Batch count: 193, Avg. per-sample expected Loss: 0.44060
# Batch count: 194, Avg. per-sample expected Loss: 0.44965
# Batch count: 195, Avg. per-sample expected Loss: 0.45319
# Batch count: 196, Avg. per-sample expected Loss: 0.44682
# Batch count: 197, Avg. per-sample expected Loss: 0.45589
# Batch count: 198, Avg. per-sample expected Loss: 0.43379
# Batch count: 199, Avg. per-sample expected Loss: 0.45563
# Batch count: 200, Avg. per-sample expected Loss: 0.44363
# Batch count: 201, Avg. per-sample expected Loss: 0.44179
# Batch count: 202, Avg. per-sample expected Loss: 0.43487
# Batch count: 203, Avg. per-sample expected Loss: 0.44272
# Batch count: 204, Avg. per-sample expected Loss: 0.45062
# Batch count: 205, Avg. per-sample expected Loss: 0.43554
# Batch count: 206, Avg. per-sample expected Loss: 0.44202
# Batch count: 207, Avg. per-sample expected Loss: 0.44045
# Batch count: 208, Avg. per-sample expected Loss: 0.44706
# Batch count: 209, Avg. per-sample expected Loss: 0.44442
# Batch count: 210, Avg. per-sample expected Loss: 0.44991
# Batch count: 211, Avg. per-sample expected Loss: 0.43936
# Batch count: 212, Avg. per-sample expected Loss: 0.44793
# Batch count: 213, Avg. per-sample expected Loss: 0.46117
# Batch count: 214, Avg. per-sample expected Loss: 0.44470
# Batch count: 215, Avg. per-sample expected Loss: 0.42873
# Batch count: 216, Avg. per-sample expected Loss: 0.43604
# Batch count: 217, Avg. per-sample expected Loss: 0.43182
# Batch count: 218, Avg. per-sample expected Loss: 0.43776
# Batch count: 219, Avg. per-sample expected Loss: 0.44002
# Batch count: 220, Avg. per-sample expected Loss: 0.44120
# Batch count: 221, Avg. per-sample expected Loss: 0.43659
# Batch count: 222, Avg. per-sample expected Loss: 0.43281
# Batch count: 223, Avg. per-sample expected Loss: 0.43857
# Batch count: 224, Avg. per-sample expected Loss: 0.43615
# Batch count: 225, Avg. per-sample expected Loss: 0.44341
# Batch count: 226, Avg. per-sample expected Loss: 0.44249
# Batch count: 227, Avg. per-sample expected Loss: 0.43507
# Batch count: 228, Avg. per-sample expected Loss: 0.44060
# Batch count: 229, Avg. per-sample expected Loss: 0.43073
# Batch count: 230, Avg. per-sample expected Loss: 0.42735
# Batch count: 231, Avg. per-sample expected Loss: 0.43873
# Batch count: 232, Avg. per-sample expected Loss: 0.43118
# Batch count: 233, Avg. per-sample expected Loss: 0.44014
# Batch count: 234, Avg. per-sample expected Loss: 0.43721
# Batch count: 235, Avg. per-sample expected Loss: 0.43119
# Batch count: 236, Avg. per-sample expected Loss: 0.43830
# Batch count: 237, Avg. per-sample expected Loss: 0.43951
# Batch count: 238, Avg. per-sample expected Loss: 0.42963
# Batch count: 239, Avg. per-sample expected Loss: 0.41834
# Batch count: 240, Avg. per-sample expected Loss: 0.42489
# Batch count: 241, Avg. per-sample expected Loss: 0.43324
# Batch count: 242, Avg. per-sample expected Loss: 0.43354
# Batch count: 243, Avg. per-sample expected Loss: 0.43076
# Batch count: 244, Avg. per-sample expected Loss: 0.41948
# Batch count: 245, Avg. per-sample expected Loss: 0.42934
# Batch count: 246, Avg. per-sample expected Loss: 0.42803
# Batch count: 247, Avg. per-sample expected Loss: 0.43255
# Batch count: 248, Avg. per-sample expected Loss: 0.42057
# Batch count: 249, Avg. per-sample expected Loss: 0.43135
# Batch count: 250, Avg. per-sample expected Loss: 0.42302
# Batch count: 251, Avg. per-sample expected Loss: 0.43017
# Batch count: 252, Avg. per-sample expected Loss: 0.42469
# Batch count: 253, Avg. per-sample expected Loss: 0.43624
# Batch count: 254, Avg. per-sample expected Loss: 0.43077
# Batch count: 255, Avg. per-sample expected Loss: 0.42777
# Batch count: 256, Avg. per-sample expected Loss: 0.43504
# Batch count: 257, Avg. per-sample expected Loss: 0.42554
# Batch count: 258, Avg. per-sample expected Loss: 0.41865
# Batch count: 259, Avg. per-sample expected Loss: 0.42789
# Batch count: 260, Avg. per-sample expected Loss: 0.42245
# Batch count: 261, Avg. per-sample expected Loss: 0.42181
# Batch count: 262, Avg. per-sample expected Loss: 0.43216
# Batch count: 263, Avg. per-sample expected Loss: 0.42380
# Batch count: 264, Avg. per-sample expected Loss: 0.42136
# Batch count: 265, Avg. per-sample expected Loss: 0.42134
# Batch count: 266, Avg. per-sample expected Loss: 0.42458
# Batch count: 267, Avg. per-sample expected Loss: 0.42630
# Batch count: 268, Avg. per-sample expected Loss: 0.42880
# Batch count: 269, Avg. per-sample expected Loss: 0.42684
# Batch count: 270, Avg. per-sample expected Loss: 0.42459
# Batch count: 271, Avg. per-sample expected Loss: 0.42514
# Batch count: 272, Avg. per-sample expected Loss: 0.41858
# Batch count: 273, Avg. per-sample expected Loss: 0.42634
# Batch count: 274, Avg. per-sample expected Loss: 0.41416
# Batch count: 275, Avg. per-sample expected Loss: 0.42154
# Batch count: 276, Avg. per-sample expected Loss: 0.41605
# Batch count: 277, Avg. per-sample expected Loss: 0.41659
# Batch count: 278, Avg. per-sample expected Loss: 0.41952
# Batch count: 279, Avg. per-sample expected Loss: 0.42015
# Batch count: 280, Avg. per-sample expected Loss: 0.41842
# Batch count: 281, Avg. per-sample expected Loss: 0.42062
# Batch count: 282, Avg. per-sample expected Loss: 0.42543
# Batch count: 283, Avg. per-sample expected Loss: 0.40596
# Batch count: 284, Avg. per-sample expected Loss: 0.42374
# Batch count: 285, Avg. per-sample expected Loss: 0.42498
# Batch count: 286, Avg. per-sample expected Loss: 0.41965
# Batch count: 287, Avg. per-sample expected Loss: 0.41892
# Batch count: 288, Avg. per-sample expected Loss: 0.41001
# Batch count: 289, Avg. per-sample expected Loss: 0.41303
# Batch count: 290, Avg. per-sample expected Loss: 0.40444
# Batch count: 291, Avg. per-sample expected Loss: 0.41337
# Batch count: 292, Avg. per-sample expected Loss: 0.41521
# Batch count: 293, Avg. per-sample expected Loss: 0.40935
# Batch count: 294, Avg. per-sample expected Loss: 0.40098
# Batch count: 295, Avg. per-sample expected Loss: 0.40150
# Batch count: 296, Avg. per-sample expected Loss: 0.41112
# Batch count: 297, Avg. per-sample expected Loss: 0.41610
# Batch count: 298, Avg. per-sample expected Loss: 0.41442
# Batch count: 299, Avg. per-sample expected Loss: 0.40888
# Batch count: 300, Avg. per-sample expected Loss: 0.42084
# Batch count: 301, Avg. per-sample expected Loss: 0.40743
# Batch count: 302, Avg. per-sample expected Loss: 0.41953
# Batch count: 303, Avg. per-sample expected Loss: 0.40719
# Batch count: 304, Avg. per-sample expected Loss: 0.41516
# Batch count: 305, Avg. per-sample expected Loss: 0.41568
# Batch count: 306, Avg. per-sample expected Loss: 0.40615
# Batch count: 307, Avg. per-sample expected Loss: 0.41550
# Batch count: 308, Avg. per-sample expected Loss: 0.40531
# Batch count: 309, Avg. per-sample expected Loss: 0.41319
# Batch count: 310, Avg. per-sample expected Loss: 0.41201
# Batch count: 311, Avg. per-sample expected Loss: 0.40982
# Batch count: 312, Avg. per-sample expected Loss: 0.41906
# Batch count: 313, Avg. per-sample expected Loss: 0.40504
# Batch count: 314, Avg. per-sample expected Loss: 0.40665
# Batch count: 315, Avg. per-sample expected Loss: 0.41221
# Batch count: 316, Avg. per-sample expected Loss: 0.40927
# Batch count: 317, Avg. per-sample expected Loss: 0.41601
# Batch count: 318, Avg. per-sample expected Loss: 0.39594
# Batch count: 319, Avg. per-sample expected Loss: 0.40985
# Batch count: 320, Avg. per-sample expected Loss: 0.40252
# Batch count: 321, Avg. per-sample expected Loss: 0.40807
# Batch count: 322, Avg. per-sample expected Loss: 0.40088
# Batch count: 323, Avg. per-sample expected Loss: 0.40431
# Batch count: 324, Avg. per-sample expected Loss: 0.39574
# Batch count: 325, Avg. per-sample expected Loss: 0.40207
# Batch count: 326, Avg. per-sample expected Loss: 0.40522
# Batch count: 327, Avg. per-sample expected Loss: 0.40999
# Batch count: 328, Avg. per-sample expected Loss: 0.39795
# Batch count: 329, Avg. per-sample expected Loss: 0.39659
# Batch count: 330, Avg. per-sample expected Loss: 0.39732
# Batch count: 331, Avg. per-sample expected Loss: 0.39902
# Batch count: 332, Avg. per-sample expected Loss: 0.39072
# Batch count: 333, Avg. per-sample expected Loss: 0.39606
# Batch count: 334, Avg. per-sample expected Loss: 0.39267
# Batch count: 335, Avg. per-sample expected Loss: 0.39223
# Batch count: 336, Avg. per-sample expected Loss: 0.39613
# Batch count: 337, Avg. per-sample expected Loss: 0.40255
# Batch count: 338, Avg. per-sample expected Loss: 0.40126
# Batch count: 339, Avg. per-sample expected Loss: 0.39180
# Batch count: 340, Avg. per-sample expected Loss: 0.39965
# Batch count: 341, Avg. per-sample expected Loss: 0.39454
# Batch count: 342, Avg. per-sample expected Loss: 0.39764
# Batch count: 343, Avg. per-sample expected Loss: 0.38766
# Batch count: 344, Avg. per-sample expected Loss: 0.38784
# Batch count: 345, Avg. per-sample expected Loss: 0.39374
# Batch count: 346, Avg. per-sample expected Loss: 0.38592
# Batch count: 347, Avg. per-sample expected Loss: 0.39013
# Batch count: 348, Avg. per-sample expected Loss: 0.37950
# Batch count: 349, Avg. per-sample expected Loss: 0.39370

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")

plt.title("Training using 2-QNSCD and 2-RQSGD (6 samples per itr)")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("2RSGD_6s.png")
plt.show()

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")
plt.plot(SGD6c_cost, "g", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")
plt.plot(SGD6c_Ecost, "g.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training 2-QNSCD and 2-RQSGD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("RQSGD.png")
plt.show()

# %% [markdown]
# ## Testing Phase

# %%
### Saving Final Parameters:
file_name1 = "4Q 2-QNSCD params"
file_name2 = "4Q 2-RQSGD_6s params"
file_name3 = "4Q 6-RQSGD params"

np.save(file_name1,NCGDparams)
np.save(file_name2,SGD6params)
np.save(file_name3,SGD6cparams)

# %%
phiTest = np.load('4-qubitsPhiTest_v1.npy')
labelTest = np.load('4-qubitsLabelTest_v1.npy')

phiTest.requires_grad = False
labelTest.requires_grad = False

# %%
nTest = 1000

NCGDparams_opt = NCGDparams 
SGD6params_opt = SGD6params
SGD6cparams_opt = SGD6cparams

# %%
### Optimal Expected Loss
expOperator = 0

for i in range(nTest):
    op = np.matmul(phiTest[:,i].reshape(dim,1),phiTest[:,i].reshape(1,dim))
    expOperator = expOperator + labelTest[i]*op
expOperator = expOperator/(nTest)
opt_value = 0.5*(1+sum(abs(np.linalg.svd(expOperator)[1])))

# %%
NCGD_rslt = []
SGD6_rslt = []
SGD6c_rslt = []

for i in range(int(1e1)):
    NCGDcount = 0
    SGD6count = 0
    SGD6ccount = 0

    for itr in range(nTest):
        if circuit_test(NCGDparams_opt,phiTest[:,itr]) == labelTest[itr]:
            NCGDcount += 1 
        if circuit_test(SGD6params_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6count += 1
        if circuit_test(SGD6cparams_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6ccount += 1
    
    NCGD_rslt.append(NCGDcount/nTest)
    SGD6_rslt.append(SGD6count/nTest)
    SGD6c_rslt.append(SGD6ccount/nTest)
#     print("itr = ",i)

# %%
print("Optimal: {:.3f} \nNCGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n2-RQSGD_6s: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n6-RQSGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f}"\
      .format(opt_value,np.average(NCGD_rslt),np.std(NCGD_rslt),max(NCGD_rslt),min(NCGD_rslt),\
              np.average(SGD6_rslt),np.std(SGD6_rslt),max(SGD6_rslt),min(SGD6_rslt), \
              np.average(SGD6c_rslt),np.std(SGD6c_rslt),max(SGD6c_rslt),min(SGD6c_rslt)))
# Out:
# Optimal: 0.876
# NCGD: 0.848 / 0.006 max: 0.856 min: 0.841
# 2-RQSGD_6s: 0.608 / 0.015 max: 0.629 min: 0.582
# 6-RQSGD: 0.617 / 0.013 max: 0.643 min: 0.599
