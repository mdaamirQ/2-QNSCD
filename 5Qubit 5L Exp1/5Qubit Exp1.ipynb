# %%
import pennylane as qml
from pennylane import numpy as np
import scipy
import matplotlib.pyplot as plt
from globalVars import *
from model_5qubit import *

from GRADest_5Q import EstGrad
from EQFIMest_5Q import Est_EQFIM

# %% [markdown]
# ## Quantum Neural Network

# %%
random_state = np.random.rand(dim)
random_state = random_state /np.linalg.norm(random_state)
qml.draw_mpl(QNN)(np.zeros(nparams),random_state)
# Out:
# (<Figure size 1400x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### Model Initialization

# %%
S_pItr = 6  # no. of samples used per-iteration 

nStep = 350
nItr = 100
step_size = 0.0025

Bsize = S_pItr*nItr

# %%
phiTrain = np.load('5-qubitsPhiTrain_v1.npy')
labelTrain = np.load('5-qubitsLabelTrain_v1.npy')

phiTrain.requires_grad = False
labelTrain.requires_grad = False

# %%
'QNSCD Dataset'
phiTrainNCGD = phiTrain
labelTrainNCGD = labelTrain

'SGD Dataset'
phiTrainSGD = phiTrain
labelTrainSGD = labelTrain

# %%
### Optimal Expected Loss
Opt_cost = []
itrBatch = np.linspace(0,Bsize*nStep,nStep,endpoint = False,dtype = 'int').tolist()
for itr1 in itrBatch:
    expOperator = 0
    for itr2 in range(Bsize):
        temp_phi = phiTrain[:,itr1+itr2]
        op = np.matmul(temp_phi.reshape(dim,1),temp_phi.reshape(1,dim))
        expOperator = expOperator + labelTrain[itr1+itr2]*op
    expOperator = expOperator/Bsize
    opt_value = 0.5*(1-sum(abs(np.linalg.svd(expOperator)[1])))
    Opt_cost.append(opt_value)

file_name = "5Q-Minimum Expected Loss"
np.save(file_name,Opt_cost)

# %% [markdown]
# # Optimizers

# %%
'QNN outputs yhat'
dev = qml.device("default.qubit", wires=nqubits, shots=1)

@qml.qnode(dev,interface='autograd')
def circuit_test(params,state):
    QNN(params,state)
    return qml.sample(qml.Hermitian(M,wires=list(range(nqubits))))

# %%
init_params = np.random.uniform(low=0, high=2*np.pi, size=nparams, requires_grad=True)
init_params = np.array([0.17597592, 2.80026145, 4.75800683, 1.61872755, 0.62161711, 1.50741365,
 0.90493351, 3.77732589, 1.0929669,  5.09549716, 4.34126859, 1.12753162,
 1.23926837, 0.16649768, 2.93976278, 5.60148565, 5.39291707, 3.7437218,
 2.558476,   0.46036657, 5.4685636,  0.66669079, 3.61680781, 5.75147581,
 1.90553183, 0.64069775, 4.76989237, 6.04365707, 5.92116225, 2.2141628],requires_grad=True)

'cost initialization'
phiTrain0 = phiTrain[:,-1*(Bsize+1):-1]
labelTrain0 = labelTrain[-1*(Bsize+1):-1]
temp_cost = sum([ps_expLoss(init_params,phiTrain0[:,itr],labelTrain0[itr]) for itr in range(Bsize)])/Bsize
print("Initial Average Per-Sample Expected Loss: ",temp_cost)

count = 0
for itr in range(Bsize):
    if circuit_test(init_params,phiTrain0[:,itr]) != labelTrain0[itr]:
        count += 1
temp_Ecost = count/Bsize
print("Initial Average Empirical Loss", temp_Ecost)
# Out:
# Initial Average Per-Sample Expected Loss:  0.5628347171106669
# Initial Average Empirical Loss 0.535

# %% [markdown]
# ## Quantum Natural Stochastic Pairwise Coordinate Descent (2-QNSCD)

# %%
NCGDparams = np.array(init_params)
NCGD_cost = []
NCGD_Ecost = []

NCGD_cost.append(temp_cost)
NCGD_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainNCGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainNCGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a pair of coordinate
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())

        ### Gradient estimation
        y1, b1 = EstGrad(NCGDparams,phiT[:,itr3],idx[0])
        y2, b2 = EstGrad(NCGDparams,phiT[:,itr3+1],idx[1])
        b1 = (1-b1)/2
        b2 = (1-b2)/2

        grad = [-1*((-1)**b1)*loss(y1,labelT[itr3]),-1*((-1)**b2)*loss(y2,labelT[itr3+1])]
        
        ### E-QFIM estimation
        metric = Est_EQFIM(NCGDparams,idx,phiT[:,itr3+2:itr3+S_pItr])

        ### double-parameters update
        NCGDparams[idx] = NCGDparams[idx] - (step_size)*np.dot(np.linalg.inv(metric),grad) 
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(NCGDparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    NCGD_cost.append(energy)
    
    ### average empirical loss calculation
    NCGDcount = 0
    for itr in range(Bsize):
        if circuit_test(NCGDparams,phiT[:,itr]) != labelT[itr]:
            NCGDcount += 1
    NCGD_Ecost.append(NCGDcount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))

file_name1 = "5Q 2-QNSCD Expected Loss"
file_name2 = "5Q 2-QNSCD Empirical Loss"

np.save(file_name1,NCGD_cost)
np.save(file_name2,NCGD_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.56283
# Batch count:  1, Avg. per-sample expected Loss: 0.56169
# Batch count:  2, Avg. per-sample expected Loss: 0.56127
# Batch count:  3, Avg. per-sample expected Loss: 0.56574
# Batch count:  4, Avg. per-sample expected Loss: 0.57097
# Batch count:  5, Avg. per-sample expected Loss: 0.57083
# Batch count:  6, Avg. per-sample expected Loss: 0.57164
# Batch count:  7, Avg. per-sample expected Loss: 0.56942
# Batch count:  8, Avg. per-sample expected Loss: 0.57649
# Batch count:  9, Avg. per-sample expected Loss: 0.57074
# Batch count: 10, Avg. per-sample expected Loss: 0.56816
# Batch count: 11, Avg. per-sample expected Loss: 0.57039
# Batch count: 12, Avg. per-sample expected Loss: 0.57119
# Batch count: 13, Avg. per-sample expected Loss: 0.57061
# Batch count: 14, Avg. per-sample expected Loss: 0.56718
# Batch count: 15, Avg. per-sample expected Loss: 0.57425
# Batch count: 16, Avg. per-sample expected Loss: 0.57465
# Batch count: 17, Avg. per-sample expected Loss: 0.56575
# Batch count: 18, Avg. per-sample expected Loss: 0.56602
# Batch count: 19, Avg. per-sample expected Loss: 0.56567
# Batch count: 20, Avg. per-sample expected Loss: 0.56808
# Batch count: 21, Avg. per-sample expected Loss: 0.56849
# Batch count: 22, Avg. per-sample expected Loss: 0.55585
# Batch count: 23, Avg. per-sample expected Loss: 0.55416
# Batch count: 24, Avg. per-sample expected Loss: 0.55985
# Batch count: 25, Avg. per-sample expected Loss: 0.54595
# Batch count: 26, Avg. per-sample expected Loss: 0.55463
# Batch count: 27, Avg. per-sample expected Loss: 0.54368
# Batch count: 28, Avg. per-sample expected Loss: 0.54673
# Batch count: 29, Avg. per-sample expected Loss: 0.55133
# Batch count: 30, Avg. per-sample expected Loss: 0.55420
# Batch count: 31, Avg. per-sample expected Loss: 0.53997
# Batch count: 32, Avg. per-sample expected Loss: 0.54542
# Batch count: 33, Avg. per-sample expected Loss: 0.54083
# Batch count: 34, Avg. per-sample expected Loss: 0.53664
# Batch count: 35, Avg. per-sample expected Loss: 0.53964
# Batch count: 36, Avg. per-sample expected Loss: 0.54100
# Batch count: 37, Avg. per-sample expected Loss: 0.53996
# Batch count: 38, Avg. per-sample expected Loss: 0.54135
# Batch count: 39, Avg. per-sample expected Loss: 0.53514
# Batch count: 40, Avg. per-sample expected Loss: 0.54652
# Batch count: 41, Avg. per-sample expected Loss: 0.52960
# Batch count: 42, Avg. per-sample expected Loss: 0.53982
# Batch count: 43, Avg. per-sample expected Loss: 0.53326
# Batch count: 44, Avg. per-sample expected Loss: 0.53524
# Batch count: 45, Avg. per-sample expected Loss: 0.53624
# Batch count: 46, Avg. per-sample expected Loss: 0.53452
# Batch count: 47, Avg. per-sample expected Loss: 0.52502
# Batch count: 48, Avg. per-sample expected Loss: 0.52203
# Batch count: 49, Avg. per-sample expected Loss: 0.51955
# Batch count: 50, Avg. per-sample expected Loss: 0.52285
# Batch count: 51, Avg. per-sample expected Loss: 0.51648
# Batch count: 52, Avg. per-sample expected Loss: 0.52689
# Batch count: 53, Avg. per-sample expected Loss: 0.52622
# Batch count: 54, Avg. per-sample expected Loss: 0.52165
# Batch count: 55, Avg. per-sample expected Loss: 0.52112
# Batch count: 56, Avg. per-sample expected Loss: 0.52733
# Batch count: 57, Avg. per-sample expected Loss: 0.52520
# Batch count: 58, Avg. per-sample expected Loss: 0.51417
# Batch count: 59, Avg. per-sample expected Loss: 0.51177
# Batch count: 60, Avg. per-sample expected Loss: 0.50934
# Batch count: 61, Avg. per-sample expected Loss: 0.51682
# Batch count: 62, Avg. per-sample expected Loss: 0.51953
# Batch count: 63, Avg. per-sample expected Loss: 0.51267
# Batch count: 64, Avg. per-sample expected Loss: 0.51363
# Batch count: 65, Avg. per-sample expected Loss: 0.51480
# Batch count: 66, Avg. per-sample expected Loss: 0.51600
# Batch count: 67, Avg. per-sample expected Loss: 0.50819
# Batch count: 68, Avg. per-sample expected Loss: 0.51474
# Batch count: 69, Avg. per-sample expected Loss: 0.51488
# Batch count: 70, Avg. per-sample expected Loss: 0.51191
# Batch count: 71, Avg. per-sample expected Loss: 0.52220
# Batch count: 72, Avg. per-sample expected Loss: 0.51145
# Batch count: 73, Avg. per-sample expected Loss: 0.51395
# Batch count: 74, Avg. per-sample expected Loss: 0.51212
# Batch count: 75, Avg. per-sample expected Loss: 0.50289
# Batch count: 76, Avg. per-sample expected Loss: 0.50566
# Batch count: 77, Avg. per-sample expected Loss: 0.50507
# Batch count: 78, Avg. per-sample expected Loss: 0.50463
# Batch count: 79, Avg. per-sample expected Loss: 0.50323
# Batch count: 80, Avg. per-sample expected Loss: 0.50288
# Batch count: 81, Avg. per-sample expected Loss: 0.50411
# Batch count: 82, Avg. per-sample expected Loss: 0.50458
# Batch count: 83, Avg. per-sample expected Loss: 0.50806
# Batch count: 84, Avg. per-sample expected Loss: 0.50335
# Batch count: 85, Avg. per-sample expected Loss: 0.50384
# Batch count: 86, Avg. per-sample expected Loss: 0.50716
# Batch count: 87, Avg. per-sample expected Loss: 0.50050
# Batch count: 88, Avg. per-sample expected Loss: 0.49630
# Batch count: 89, Avg. per-sample expected Loss: 0.49266
# Batch count: 90, Avg. per-sample expected Loss: 0.50309
# Batch count: 91, Avg. per-sample expected Loss: 0.50698
# Batch count: 92, Avg. per-sample expected Loss: 0.50148
# Batch count: 93, Avg. per-sample expected Loss: 0.50479
# Batch count: 94, Avg. per-sample expected Loss: 0.49821
# Batch count: 95, Avg. per-sample expected Loss: 0.50546
# Batch count: 96, Avg. per-sample expected Loss: 0.50654
# Batch count: 97, Avg. per-sample expected Loss: 0.49737
# Batch count: 98, Avg. per-sample expected Loss: 0.49871
# Batch count: 99, Avg. per-sample expected Loss: 0.50381
# Batch count: 100, Avg. per-sample expected Loss: 0.49924
# Batch count: 101, Avg. per-sample expected Loss: 0.49076
# Batch count: 102, Avg. per-sample expected Loss: 0.49272
# Batch count: 103, Avg. per-sample expected Loss: 0.49452
# Batch count: 104, Avg. per-sample expected Loss: 0.49206
# Batch count: 105, Avg. per-sample expected Loss: 0.49657
# Batch count: 106, Avg. per-sample expected Loss: 0.49220
# Batch count: 107, Avg. per-sample expected Loss: 0.50113
# Batch count: 108, Avg. per-sample expected Loss: 0.50127
# Batch count: 109, Avg. per-sample expected Loss: 0.48921
# Batch count: 110, Avg. per-sample expected Loss: 0.48737
# Batch count: 111, Avg. per-sample expected Loss: 0.49049
# Batch count: 112, Avg. per-sample expected Loss: 0.48332
# Batch count: 113, Avg. per-sample expected Loss: 0.48704
# Batch count: 114, Avg. per-sample expected Loss: 0.48470
# Batch count: 115, Avg. per-sample expected Loss: 0.48017
# Batch count: 116, Avg. per-sample expected Loss: 0.47978
# Batch count: 117, Avg. per-sample expected Loss: 0.47495
# Batch count: 118, Avg. per-sample expected Loss: 0.47563
# Batch count: 119, Avg. per-sample expected Loss: 0.46810
# Batch count: 120, Avg. per-sample expected Loss: 0.46872
# Batch count: 121, Avg. per-sample expected Loss: 0.46977
# Batch count: 122, Avg. per-sample expected Loss: 0.45851
# Batch count: 123, Avg. per-sample expected Loss: 0.47366
# Batch count: 124, Avg. per-sample expected Loss: 0.47414
# Batch count: 125, Avg. per-sample expected Loss: 0.46877
# Batch count: 126, Avg. per-sample expected Loss: 0.46909
# Batch count: 127, Avg. per-sample expected Loss: 0.47349
# Batch count: 128, Avg. per-sample expected Loss: 0.46729
# Batch count: 129, Avg. per-sample expected Loss: 0.46617
# Batch count: 130, Avg. per-sample expected Loss: 0.46173
# Batch count: 131, Avg. per-sample expected Loss: 0.45959
# Batch count: 132, Avg. per-sample expected Loss: 0.46494
# Batch count: 133, Avg. per-sample expected Loss: 0.44814
# Batch count: 134, Avg. per-sample expected Loss: 0.44421
# Batch count: 135, Avg. per-sample expected Loss: 0.44097
# Batch count: 136, Avg. per-sample expected Loss: 0.43564
# Batch count: 137, Avg. per-sample expected Loss: 0.43210
# Batch count: 138, Avg. per-sample expected Loss: 0.43833
# Batch count: 139, Avg. per-sample expected Loss: 0.42896
# Batch count: 140, Avg. per-sample expected Loss: 0.42548
# Batch count: 141, Avg. per-sample expected Loss: 0.42720
# Batch count: 142, Avg. per-sample expected Loss: 0.42841
# Batch count: 143, Avg. per-sample expected Loss: 0.43108
# Batch count: 144, Avg. per-sample expected Loss: 0.41925
# Batch count: 145, Avg. per-sample expected Loss: 0.41228
# Batch count: 146, Avg. per-sample expected Loss: 0.40884
# Batch count: 147, Avg. per-sample expected Loss: 0.40524
# Batch count: 148, Avg. per-sample expected Loss: 0.40125
# Batch count: 149, Avg. per-sample expected Loss: 0.40610
# Batch count: 150, Avg. per-sample expected Loss: 0.39893
# Batch count: 151, Avg. per-sample expected Loss: 0.41661
# Batch count: 152, Avg. per-sample expected Loss: 0.38935
# Batch count: 153, Avg. per-sample expected Loss: 0.38349
# Batch count: 154, Avg. per-sample expected Loss: 0.38088
# Batch count: 155, Avg. per-sample expected Loss: 0.37292
# Batch count: 156, Avg. per-sample expected Loss: 0.36669
# Batch count: 157, Avg. per-sample expected Loss: 0.37051
# Batch count: 158, Avg. per-sample expected Loss: 0.37944
# Batch count: 159, Avg. per-sample expected Loss: 0.37024
# Batch count: 160, Avg. per-sample expected Loss: 0.36395
# Batch count: 161, Avg. per-sample expected Loss: 0.36880
# Batch count: 162, Avg. per-sample expected Loss: 0.36344
# Batch count: 163, Avg. per-sample expected Loss: 0.34979
# Batch count: 164, Avg. per-sample expected Loss: 0.34909
# Batch count: 165, Avg. per-sample expected Loss: 0.32758
# Batch count: 166, Avg. per-sample expected Loss: 0.33242
# Batch count: 167, Avg. per-sample expected Loss: 0.32228
# Batch count: 168, Avg. per-sample expected Loss: 0.31622
# Batch count: 169, Avg. per-sample expected Loss: 0.32067
# Batch count: 170, Avg. per-sample expected Loss: 0.31888
# Batch count: 171, Avg. per-sample expected Loss: 0.32297
# Batch count: 172, Avg. per-sample expected Loss: 0.32033
# Batch count: 173, Avg. per-sample expected Loss: 0.29940
# Batch count: 174, Avg. per-sample expected Loss: 0.30240
# Batch count: 175, Avg. per-sample expected Loss: 0.31033
# Batch count: 176, Avg. per-sample expected Loss: 0.29915
# Batch count: 177, Avg. per-sample expected Loss: 0.29733
# Batch count: 178, Avg. per-sample expected Loss: 0.29802
# Batch count: 179, Avg. per-sample expected Loss: 0.29924
# Batch count: 180, Avg. per-sample expected Loss: 0.28588
# Batch count: 181, Avg. per-sample expected Loss: 0.30271
# Batch count: 182, Avg. per-sample expected Loss: 0.28866
# Batch count: 183, Avg. per-sample expected Loss: 0.29756
# Batch count: 184, Avg. per-sample expected Loss: 0.29988
# Batch count: 185, Avg. per-sample expected Loss: 0.30099
# Batch count: 186, Avg. per-sample expected Loss: 0.30320
# Batch count: 187, Avg. per-sample expected Loss: 0.30392
# Batch count: 188, Avg. per-sample expected Loss: 0.28233
# Batch count: 189, Avg. per-sample expected Loss: 0.27902
# Batch count: 190, Avg. per-sample expected Loss: 0.28059
# Batch count: 191, Avg. per-sample expected Loss: 0.27851
# Batch count: 192, Avg. per-sample expected Loss: 0.28958
# Batch count: 193, Avg. per-sample expected Loss: 0.27389
# Batch count: 194, Avg. per-sample expected Loss: 0.27712
# Batch count: 195, Avg. per-sample expected Loss: 0.28169
# Batch count: 196, Avg. per-sample expected Loss: 0.28334
# Batch count: 197, Avg. per-sample expected Loss: 0.27428
# Batch count: 198, Avg. per-sample expected Loss: 0.24705
# Batch count: 199, Avg. per-sample expected Loss: 0.25985
# Batch count: 200, Avg. per-sample expected Loss: 0.23998
# Batch count: 201, Avg. per-sample expected Loss: 0.25064
# Batch count: 202, Avg. per-sample expected Loss: 0.23349
# Batch count: 203, Avg. per-sample expected Loss: 0.24203
# Batch count: 204, Avg. per-sample expected Loss: 0.24114
# Batch count: 205, Avg. per-sample expected Loss: 0.24482
# Batch count: 206, Avg. per-sample expected Loss: 0.26595
# Batch count: 207, Avg. per-sample expected Loss: 0.26476
# Batch count: 208, Avg. per-sample expected Loss: 0.25574
# Batch count: 209, Avg. per-sample expected Loss: 0.24534
# Batch count: 210, Avg. per-sample expected Loss: 0.24427
# Batch count: 211, Avg. per-sample expected Loss: 0.23593
# Batch count: 212, Avg. per-sample expected Loss: 0.24460
# Batch count: 213, Avg. per-sample expected Loss: 0.21134
# Batch count: 214, Avg. per-sample expected Loss: 0.20365
# Batch count: 215, Avg. per-sample expected Loss: 0.21180
# Batch count: 216, Avg. per-sample expected Loss: 0.21549
# Batch count: 217, Avg. per-sample expected Loss: 0.21907
# Batch count: 218, Avg. per-sample expected Loss: 0.22659
# Batch count: 219, Avg. per-sample expected Loss: 0.22562
# Batch count: 220, Avg. per-sample expected Loss: 0.22368
# Batch count: 221, Avg. per-sample expected Loss: 0.21333
# Batch count: 222, Avg. per-sample expected Loss: 0.20266
# Batch count: 223, Avg. per-sample expected Loss: 0.21811
# Batch count: 224, Avg. per-sample expected Loss: 0.20441
# Batch count: 225, Avg. per-sample expected Loss: 0.20650
# Batch count: 226, Avg. per-sample expected Loss: 0.20810
# Batch count: 227, Avg. per-sample expected Loss: 0.20433
# Batch count: 228, Avg. per-sample expected Loss: 0.21582
# Batch count: 229, Avg. per-sample expected Loss: 0.20301
# Batch count: 230, Avg. per-sample expected Loss: 0.17967
# Batch count: 231, Avg. per-sample expected Loss: 0.19666
# Batch count: 232, Avg. per-sample expected Loss: 0.18588
# Batch count: 233, Avg. per-sample expected Loss: 0.20755
# Batch count: 234, Avg. per-sample expected Loss: 0.21134
# Batch count: 235, Avg. per-sample expected Loss: 0.21643
# Batch count: 236, Avg. per-sample expected Loss: 0.22337
# Batch count: 237, Avg. per-sample expected Loss: 0.21079
# Batch count: 238, Avg. per-sample expected Loss: 0.19349
# Batch count: 239, Avg. per-sample expected Loss: 0.21083
# Batch count: 240, Avg. per-sample expected Loss: 0.19887
# Batch count: 241, Avg. per-sample expected Loss: 0.19870
# Batch count: 242, Avg. per-sample expected Loss: 0.20353
# Batch count: 243, Avg. per-sample expected Loss: 0.20961
# Batch count: 244, Avg. per-sample expected Loss: 0.19647
# Batch count: 245, Avg. per-sample expected Loss: 0.18360
# Batch count: 246, Avg. per-sample expected Loss: 0.19330
# Batch count: 247, Avg. per-sample expected Loss: 0.19010
# Batch count: 248, Avg. per-sample expected Loss: 0.18254
# Batch count: 249, Avg. per-sample expected Loss: 0.21608
# Batch count: 250, Avg. per-sample expected Loss: 0.20374
# Batch count: 251, Avg. per-sample expected Loss: 0.19642
# Batch count: 252, Avg. per-sample expected Loss: 0.20238
# Batch count: 253, Avg. per-sample expected Loss: 0.19044
# Batch count: 254, Avg. per-sample expected Loss: 0.20364
# Batch count: 255, Avg. per-sample expected Loss: 0.19171
# Batch count: 256, Avg. per-sample expected Loss: 0.20018
# Batch count: 257, Avg. per-sample expected Loss: 0.19565
# Batch count: 258, Avg. per-sample expected Loss: 0.19504
# Batch count: 259, Avg. per-sample expected Loss: 0.17694
# Batch count: 260, Avg. per-sample expected Loss: 0.18087
# Batch count: 261, Avg. per-sample expected Loss: 0.16283
# Batch count: 262, Avg. per-sample expected Loss: 0.16851
# Batch count: 263, Avg. per-sample expected Loss: 0.17182
# Batch count: 264, Avg. per-sample expected Loss: 0.16862
# Batch count: 265, Avg. per-sample expected Loss: 0.17157
# Batch count: 266, Avg. per-sample expected Loss: 0.17167
# Batch count: 267, Avg. per-sample expected Loss: 0.18096
# Batch count: 268, Avg. per-sample expected Loss: 0.17754
# Batch count: 269, Avg. per-sample expected Loss: 0.17777
# Batch count: 270, Avg. per-sample expected Loss: 0.18173
# Batch count: 271, Avg. per-sample expected Loss: 0.17816
# Batch count: 272, Avg. per-sample expected Loss: 0.16767
# Batch count: 273, Avg. per-sample expected Loss: 0.17482
# Batch count: 274, Avg. per-sample expected Loss: 0.16375
# Batch count: 275, Avg. per-sample expected Loss: 0.17515
# Batch count: 276, Avg. per-sample expected Loss: 0.17830
# Batch count: 277, Avg. per-sample expected Loss: 0.17568
# Batch count: 278, Avg. per-sample expected Loss: 0.17622
# Batch count: 279, Avg. per-sample expected Loss: 0.16376
# Batch count: 280, Avg. per-sample expected Loss: 0.16568
# Batch count: 281, Avg. per-sample expected Loss: 0.17896
# Batch count: 282, Avg. per-sample expected Loss: 0.16069
# Batch count: 283, Avg. per-sample expected Loss: 0.15599
# Batch count: 284, Avg. per-sample expected Loss: 0.16647
# Batch count: 285, Avg. per-sample expected Loss: 0.15774
# Batch count: 286, Avg. per-sample expected Loss: 0.15877
# Batch count: 287, Avg. per-sample expected Loss: 0.15737
# Batch count: 288, Avg. per-sample expected Loss: 0.15815
# Batch count: 289, Avg. per-sample expected Loss: 0.15721
# Batch count: 290, Avg. per-sample expected Loss: 0.15166
# Batch count: 291, Avg. per-sample expected Loss: 0.16431
# Batch count: 292, Avg. per-sample expected Loss: 0.16092
# Batch count: 293, Avg. per-sample expected Loss: 0.15837
# Batch count: 294, Avg. per-sample expected Loss: 0.17949
# Batch count: 295, Avg. per-sample expected Loss: 0.17018
# Batch count: 296, Avg. per-sample expected Loss: 0.15848
# Batch count: 297, Avg. per-sample expected Loss: 0.16289
# Batch count: 298, Avg. per-sample expected Loss: 0.15023
# Batch count: 299, Avg. per-sample expected Loss: 0.15943
# Batch count: 300, Avg. per-sample expected Loss: 0.15421
# Batch count: 301, Avg. per-sample expected Loss: 0.16606
# Batch count: 302, Avg. per-sample expected Loss: 0.16213
# Batch count: 303, Avg. per-sample expected Loss: 0.15553
# Batch count: 304, Avg. per-sample expected Loss: 0.17386
# Batch count: 305, Avg. per-sample expected Loss: 0.15274
# Batch count: 306, Avg. per-sample expected Loss: 0.16959
# Batch count: 307, Avg. per-sample expected Loss: 0.16273
# Batch count: 308, Avg. per-sample expected Loss: 0.16250
# Batch count: 309, Avg. per-sample expected Loss: 0.14959
# Batch count: 310, Avg. per-sample expected Loss: 0.16539
# Batch count: 311, Avg. per-sample expected Loss: 0.15428
# Batch count: 312, Avg. per-sample expected Loss: 0.16242
# Batch count: 313, Avg. per-sample expected Loss: 0.18096
# Batch count: 314, Avg. per-sample expected Loss: 0.16164
# Batch count: 315, Avg. per-sample expected Loss: 0.15630
# Batch count: 316, Avg. per-sample expected Loss: 0.16746
# Batch count: 317, Avg. per-sample expected Loss: 0.16864
# Batch count: 318, Avg. per-sample expected Loss: 0.15458
# Batch count: 319, Avg. per-sample expected Loss: 0.16267
# Batch count: 320, Avg. per-sample expected Loss: 0.16375
# Batch count: 321, Avg. per-sample expected Loss: 0.15521
# Batch count: 322, Avg. per-sample expected Loss: 0.15164
# Batch count: 323, Avg. per-sample expected Loss: 0.16037
# Batch count: 324, Avg. per-sample expected Loss: 0.17543
# Batch count: 325, Avg. per-sample expected Loss: 0.17654
# Batch count: 326, Avg. per-sample expected Loss: 0.16772
# Batch count: 327, Avg. per-sample expected Loss: 0.16028
# Batch count: 328, Avg. per-sample expected Loss: 0.17669
# Batch count: 329, Avg. per-sample expected Loss: 0.17123
# Batch count: 330, Avg. per-sample expected Loss: 0.16915
# Batch count: 331, Avg. per-sample expected Loss: 0.16565
# Batch count: 332, Avg. per-sample expected Loss: 0.16125
# Batch count: 333, Avg. per-sample expected Loss: 0.16579
# Batch count: 334, Avg. per-sample expected Loss: 0.18622
# Batch count: 335, Avg. per-sample expected Loss: 0.18524
# Batch count: 336, Avg. per-sample expected Loss: 0.16681
# Batch count: 337, Avg. per-sample expected Loss: 0.15653
# Batch count: 338, Avg. per-sample expected Loss: 0.15674
# Batch count: 339, Avg. per-sample expected Loss: 0.16680
# Batch count: 340, Avg. per-sample expected Loss: 0.17404
# Batch count: 341, Avg. per-sample expected Loss: 0.14856
# Batch count: 342, Avg. per-sample expected Loss: 0.16406
# Batch count: 343, Avg. per-sample expected Loss: 0.16411
# Batch count: 344, Avg. per-sample expected Loss: 0.15852
# Batch count: 345, Avg. per-sample expected Loss: 0.16069
# Batch count: 346, Avg. per-sample expected Loss: 0.16288
# Batch count: 347, Avg. per-sample expected Loss: 0.16613
# Batch count: 348, Avg. per-sample expected Loss: 0.16348
# Batch count: 349, Avg. per-sample expected Loss: 0.15192

# %% [markdown]
# ## Plots

# %%
plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "b", label="2-QNSCD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.", label="2-QNSCD Empirical Loss")

plt.title("Training using 2-QNSCD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.show()

# %% [markdown]
# ## 6-RQSGD using 600 samples per step

# %%
SGD6cparams = np.array(init_params)
SGD6c_cost = []
SGD6c_Ecost = []

SGD6c_cost.append(temp_cost)
SGD6c_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 6 coordinates
        idx = sorted(np.random.permutation(nparams)[0:6].tolist())
        
        grad = []
        
        ### Gradient estimation
        for i_grad in range(6):
            y_hat,b = EstGrad(SGD6cparams,phiT[:,itr3+i_grad],idx[i_grad])
            b = (1-b)/2
            grad.append((-1)*((-1)**b)*loss(y_hat,labelT[itr3+i_grad]))

        ### single-parameter update
        SGD6cparams[idx] = SGD6cparams[idx] - np.dot(step_size,grad)
    
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6cparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6c_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6ccount = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6cparams,phiT[:,itr]) != labelT[itr]:
            SGD6ccount += 1
    SGD6c_Ecost.append(SGD6ccount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "5Q 6-RQSGD Expected Loss"
file_name2 = "5Q 6-RQSGD Empirical Loss"

np.save(file_name1,SGD6c_cost)
np.save(file_name2,SGD6c_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.56283
# Batch count:  1, Avg. per-sample expected Loss: 0.55864
# Batch count:  2, Avg. per-sample expected Loss: 0.55750
# Batch count:  3, Avg. per-sample expected Loss: 0.55882
# Batch count:  4, Avg. per-sample expected Loss: 0.55940
# Batch count:  5, Avg. per-sample expected Loss: 0.55459
# Batch count:  6, Avg. per-sample expected Loss: 0.55484
# Batch count:  7, Avg. per-sample expected Loss: 0.55229
# Batch count:  8, Avg. per-sample expected Loss: 0.55681
# Batch count:  9, Avg. per-sample expected Loss: 0.55725
# Batch count: 10, Avg. per-sample expected Loss: 0.55095
# Batch count: 11, Avg. per-sample expected Loss: 0.54936
# Batch count: 12, Avg. per-sample expected Loss: 0.54900
# Batch count: 13, Avg. per-sample expected Loss: 0.54867
# Batch count: 14, Avg. per-sample expected Loss: 0.54147
# Batch count: 15, Avg. per-sample expected Loss: 0.54567
# Batch count: 16, Avg. per-sample expected Loss: 0.54812
# Batch count: 17, Avg. per-sample expected Loss: 0.54210
# Batch count: 18, Avg. per-sample expected Loss: 0.54270
# Batch count: 19, Avg. per-sample expected Loss: 0.54057
# Batch count: 20, Avg. per-sample expected Loss: 0.54504
# Batch count: 21, Avg. per-sample expected Loss: 0.53999
# Batch count: 22, Avg. per-sample expected Loss: 0.54031
# Batch count: 23, Avg. per-sample expected Loss: 0.53933
# Batch count: 24, Avg. per-sample expected Loss: 0.54818
# Batch count: 25, Avg. per-sample expected Loss: 0.53617
# Batch count: 26, Avg. per-sample expected Loss: 0.54393
# Batch count: 27, Avg. per-sample expected Loss: 0.53489
# Batch count: 28, Avg. per-sample expected Loss: 0.53976
# Batch count: 29, Avg. per-sample expected Loss: 0.54317
# Batch count: 30, Avg. per-sample expected Loss: 0.54013
# Batch count: 31, Avg. per-sample expected Loss: 0.53169
# Batch count: 32, Avg. per-sample expected Loss: 0.53740
# Batch count: 33, Avg. per-sample expected Loss: 0.53436
# Batch count: 34, Avg. per-sample expected Loss: 0.53629
# Batch count: 35, Avg. per-sample expected Loss: 0.53164
# Batch count: 36, Avg. per-sample expected Loss: 0.53952
# Batch count: 37, Avg. per-sample expected Loss: 0.53271
# Batch count: 38, Avg. per-sample expected Loss: 0.53115
# Batch count: 39, Avg. per-sample expected Loss: 0.53196
# Batch count: 40, Avg. per-sample expected Loss: 0.53719
# Batch count: 41, Avg. per-sample expected Loss: 0.52448
# Batch count: 42, Avg. per-sample expected Loss: 0.52552
# Batch count: 43, Avg. per-sample expected Loss: 0.52225
# Batch count: 44, Avg. per-sample expected Loss: 0.52684
# Batch count: 45, Avg. per-sample expected Loss: 0.52210
# Batch count: 46, Avg. per-sample expected Loss: 0.52983
# Batch count: 47, Avg. per-sample expected Loss: 0.52615
# Batch count: 48, Avg. per-sample expected Loss: 0.51981
# Batch count: 49, Avg. per-sample expected Loss: 0.52289
# Batch count: 50, Avg. per-sample expected Loss: 0.52293
# Batch count: 51, Avg. per-sample expected Loss: 0.52180
# Batch count: 52, Avg. per-sample expected Loss: 0.52634
# Batch count: 53, Avg. per-sample expected Loss: 0.52753
# Batch count: 54, Avg. per-sample expected Loss: 0.52112
# Batch count: 55, Avg. per-sample expected Loss: 0.52340
# Batch count: 56, Avg. per-sample expected Loss: 0.52258
# Batch count: 57, Avg. per-sample expected Loss: 0.52241
# Batch count: 58, Avg. per-sample expected Loss: 0.51770
# Batch count: 59, Avg. per-sample expected Loss: 0.51947
# Batch count: 60, Avg. per-sample expected Loss: 0.51981
# Batch count: 61, Avg. per-sample expected Loss: 0.51971
# Batch count: 62, Avg. per-sample expected Loss: 0.52267
# Batch count: 63, Avg. per-sample expected Loss: 0.52146
# Batch count: 64, Avg. per-sample expected Loss: 0.51485
# Batch count: 65, Avg. per-sample expected Loss: 0.51682
# Batch count: 66, Avg. per-sample expected Loss: 0.52130
# Batch count: 67, Avg. per-sample expected Loss: 0.51657
# Batch count: 68, Avg. per-sample expected Loss: 0.52188
# Batch count: 69, Avg. per-sample expected Loss: 0.51785
# Batch count: 70, Avg. per-sample expected Loss: 0.52699
# Batch count: 71, Avg. per-sample expected Loss: 0.53296
# Batch count: 72, Avg. per-sample expected Loss: 0.52271
# Batch count: 73, Avg. per-sample expected Loss: 0.52389
# Batch count: 74, Avg. per-sample expected Loss: 0.52127
# Batch count: 75, Avg. per-sample expected Loss: 0.52011
# Batch count: 76, Avg. per-sample expected Loss: 0.51908
# Batch count: 77, Avg. per-sample expected Loss: 0.51384
# Batch count: 78, Avg. per-sample expected Loss: 0.51848
# Batch count: 79, Avg. per-sample expected Loss: 0.51219
# Batch count: 80, Avg. per-sample expected Loss: 0.51630
# Batch count: 81, Avg. per-sample expected Loss: 0.52057
# Batch count: 82, Avg. per-sample expected Loss: 0.52214
# Batch count: 83, Avg. per-sample expected Loss: 0.52309
# Batch count: 84, Avg. per-sample expected Loss: 0.51206
# Batch count: 85, Avg. per-sample expected Loss: 0.51705
# Batch count: 86, Avg. per-sample expected Loss: 0.51760
# Batch count: 87, Avg. per-sample expected Loss: 0.51929
# Batch count: 88, Avg. per-sample expected Loss: 0.51294
# Batch count: 89, Avg. per-sample expected Loss: 0.51448
# Batch count: 90, Avg. per-sample expected Loss: 0.51603
# Batch count: 91, Avg. per-sample expected Loss: 0.52118
# Batch count: 92, Avg. per-sample expected Loss: 0.51593
# Batch count: 93, Avg. per-sample expected Loss: 0.51650
# Batch count: 94, Avg. per-sample expected Loss: 0.50845
# Batch count: 95, Avg. per-sample expected Loss: 0.51790
# Batch count: 96, Avg. per-sample expected Loss: 0.51495
# Batch count: 97, Avg. per-sample expected Loss: 0.51213
# Batch count: 98, Avg. per-sample expected Loss: 0.51391
# Batch count: 99, Avg. per-sample expected Loss: 0.51700
# Batch count: 100, Avg. per-sample expected Loss: 0.51301
# Batch count: 101, Avg. per-sample expected Loss: 0.51178
# Batch count: 102, Avg. per-sample expected Loss: 0.51383
# Batch count: 103, Avg. per-sample expected Loss: 0.51328
# Batch count: 104, Avg. per-sample expected Loss: 0.50995
# Batch count: 105, Avg. per-sample expected Loss: 0.51044
# Batch count: 106, Avg. per-sample expected Loss: 0.51195
# Batch count: 107, Avg. per-sample expected Loss: 0.51765
# Batch count: 108, Avg. per-sample expected Loss: 0.51054
# Batch count: 109, Avg. per-sample expected Loss: 0.51029
# Batch count: 110, Avg. per-sample expected Loss: 0.51199
# Batch count: 111, Avg. per-sample expected Loss: 0.51619
# Batch count: 112, Avg. per-sample expected Loss: 0.51036
# Batch count: 113, Avg. per-sample expected Loss: 0.50971
# Batch count: 114, Avg. per-sample expected Loss: 0.51252
# Batch count: 115, Avg. per-sample expected Loss: 0.50811
# Batch count: 116, Avg. per-sample expected Loss: 0.50967
# Batch count: 117, Avg. per-sample expected Loss: 0.51890
# Batch count: 118, Avg. per-sample expected Loss: 0.51943
# Batch count: 119, Avg. per-sample expected Loss: 0.50810
# Batch count: 120, Avg. per-sample expected Loss: 0.51053
# Batch count: 121, Avg. per-sample expected Loss: 0.50602
# Batch count: 122, Avg. per-sample expected Loss: 0.51257
# Batch count: 123, Avg. per-sample expected Loss: 0.51137
# Batch count: 124, Avg. per-sample expected Loss: 0.51031
# Batch count: 125, Avg. per-sample expected Loss: 0.50571
# Batch count: 126, Avg. per-sample expected Loss: 0.50738
# Batch count: 127, Avg. per-sample expected Loss: 0.51489
# Batch count: 128, Avg. per-sample expected Loss: 0.50653
# Batch count: 129, Avg. per-sample expected Loss: 0.50936
# Batch count: 130, Avg. per-sample expected Loss: 0.51072
# Batch count: 131, Avg. per-sample expected Loss: 0.50124
# Batch count: 132, Avg. per-sample expected Loss: 0.50667
# Batch count: 133, Avg. per-sample expected Loss: 0.50262
# Batch count: 134, Avg. per-sample expected Loss: 0.50211
# Batch count: 135, Avg. per-sample expected Loss: 0.50900
# Batch count: 136, Avg. per-sample expected Loss: 0.50584
# Batch count: 137, Avg. per-sample expected Loss: 0.50173
# Batch count: 138, Avg. per-sample expected Loss: 0.50875
# Batch count: 139, Avg. per-sample expected Loss: 0.50227
# Batch count: 140, Avg. per-sample expected Loss: 0.50032
# Batch count: 141, Avg. per-sample expected Loss: 0.49460
# Batch count: 142, Avg. per-sample expected Loss: 0.50547
# Batch count: 143, Avg. per-sample expected Loss: 0.50912
# Batch count: 144, Avg. per-sample expected Loss: 0.50224
# Batch count: 145, Avg. per-sample expected Loss: 0.50291
# Batch count: 146, Avg. per-sample expected Loss: 0.50234
# Batch count: 147, Avg. per-sample expected Loss: 0.49767
# Batch count: 148, Avg. per-sample expected Loss: 0.50154
# Batch count: 149, Avg. per-sample expected Loss: 0.49886
# Batch count: 150, Avg. per-sample expected Loss: 0.50013
# Batch count: 151, Avg. per-sample expected Loss: 0.50306
# Batch count: 152, Avg. per-sample expected Loss: 0.49928
# Batch count: 153, Avg. per-sample expected Loss: 0.49905
# Batch count: 154, Avg. per-sample expected Loss: 0.49861
# Batch count: 155, Avg. per-sample expected Loss: 0.50310
# Batch count: 156, Avg. per-sample expected Loss: 0.49999
# Batch count: 157, Avg. per-sample expected Loss: 0.49864
# Batch count: 158, Avg. per-sample expected Loss: 0.49697
# Batch count: 159, Avg. per-sample expected Loss: 0.49317
# Batch count: 160, Avg. per-sample expected Loss: 0.49603
# Batch count: 161, Avg. per-sample expected Loss: 0.49561
# Batch count: 162, Avg. per-sample expected Loss: 0.49774
# Batch count: 163, Avg. per-sample expected Loss: 0.49559
# Batch count: 164, Avg. per-sample expected Loss: 0.49779
# Batch count: 165, Avg. per-sample expected Loss: 0.49037
# Batch count: 166, Avg. per-sample expected Loss: 0.49391
# Batch count: 167, Avg. per-sample expected Loss: 0.49388
# Batch count: 168, Avg. per-sample expected Loss: 0.49947
# Batch count: 169, Avg. per-sample expected Loss: 0.49422
# Batch count: 170, Avg. per-sample expected Loss: 0.49037
# Batch count: 171, Avg. per-sample expected Loss: 0.49594
# Batch count: 172, Avg. per-sample expected Loss: 0.49171
# Batch count: 173, Avg. per-sample expected Loss: 0.48897
# Batch count: 174, Avg. per-sample expected Loss: 0.49403
# Batch count: 175, Avg. per-sample expected Loss: 0.49090
# Batch count: 176, Avg. per-sample expected Loss: 0.48998
# Batch count: 177, Avg. per-sample expected Loss: 0.49473
# Batch count: 178, Avg. per-sample expected Loss: 0.49589
# Batch count: 179, Avg. per-sample expected Loss: 0.49243
# Batch count: 180, Avg. per-sample expected Loss: 0.49338
# Batch count: 181, Avg. per-sample expected Loss: 0.49064
# Batch count: 182, Avg. per-sample expected Loss: 0.49081
# Batch count: 183, Avg. per-sample expected Loss: 0.49460
# Batch count: 184, Avg. per-sample expected Loss: 0.48688
# Batch count: 185, Avg. per-sample expected Loss: 0.49430
# Batch count: 186, Avg. per-sample expected Loss: 0.48589
# Batch count: 187, Avg. per-sample expected Loss: 0.49022
# Batch count: 188, Avg. per-sample expected Loss: 0.48408
# Batch count: 189, Avg. per-sample expected Loss: 0.48980
# Batch count: 190, Avg. per-sample expected Loss: 0.49070
# Batch count: 191, Avg. per-sample expected Loss: 0.49064
# Batch count: 192, Avg. per-sample expected Loss: 0.49199
# Batch count: 193, Avg. per-sample expected Loss: 0.49106
# Batch count: 194, Avg. per-sample expected Loss: 0.48887
# Batch count: 195, Avg. per-sample expected Loss: 0.48670
# Batch count: 196, Avg. per-sample expected Loss: 0.48993
# Batch count: 197, Avg. per-sample expected Loss: 0.49210
# Batch count: 198, Avg. per-sample expected Loss: 0.48551
# Batch count: 199, Avg. per-sample expected Loss: 0.49041
# Batch count: 200, Avg. per-sample expected Loss: 0.48773
# Batch count: 201, Avg. per-sample expected Loss: 0.48588
# Batch count: 202, Avg. per-sample expected Loss: 0.48772
# Batch count: 203, Avg. per-sample expected Loss: 0.48258
# Batch count: 204, Avg. per-sample expected Loss: 0.48135
# Batch count: 205, Avg. per-sample expected Loss: 0.48099
# Batch count: 206, Avg. per-sample expected Loss: 0.47972
# Batch count: 207, Avg. per-sample expected Loss: 0.48403
# Batch count: 208, Avg. per-sample expected Loss: 0.48278
# Batch count: 209, Avg. per-sample expected Loss: 0.48481
# Batch count: 210, Avg. per-sample expected Loss: 0.48450
# Batch count: 211, Avg. per-sample expected Loss: 0.48113
# Batch count: 212, Avg. per-sample expected Loss: 0.48481
# Batch count: 213, Avg. per-sample expected Loss: 0.47840
# Batch count: 214, Avg. per-sample expected Loss: 0.47919
# Batch count: 215, Avg. per-sample expected Loss: 0.48134
# Batch count: 216, Avg. per-sample expected Loss: 0.47825
# Batch count: 217, Avg. per-sample expected Loss: 0.48035
# Batch count: 218, Avg. per-sample expected Loss: 0.48094
# Batch count: 219, Avg. per-sample expected Loss: 0.48497
# Batch count: 220, Avg. per-sample expected Loss: 0.48216
# Batch count: 221, Avg. per-sample expected Loss: 0.47927
# Batch count: 222, Avg. per-sample expected Loss: 0.48401
# Batch count: 223, Avg. per-sample expected Loss: 0.47569
# Batch count: 224, Avg. per-sample expected Loss: 0.48182
# Batch count: 225, Avg. per-sample expected Loss: 0.48277
# Batch count: 226, Avg. per-sample expected Loss: 0.47763
# Batch count: 227, Avg. per-sample expected Loss: 0.47602
# Batch count: 228, Avg. per-sample expected Loss: 0.48062
# Batch count: 229, Avg. per-sample expected Loss: 0.47879
# Batch count: 230, Avg. per-sample expected Loss: 0.47799
# Batch count: 231, Avg. per-sample expected Loss: 0.47588
# Batch count: 232, Avg. per-sample expected Loss: 0.47859
# Batch count: 233, Avg. per-sample expected Loss: 0.47832
# Batch count: 234, Avg. per-sample expected Loss: 0.47573
# Batch count: 235, Avg. per-sample expected Loss: 0.47744
# Batch count: 236, Avg. per-sample expected Loss: 0.47423
# Batch count: 237, Avg. per-sample expected Loss: 0.47034
# Batch count: 238, Avg. per-sample expected Loss: 0.47695
# Batch count: 239, Avg. per-sample expected Loss: 0.47707
# Batch count: 240, Avg. per-sample expected Loss: 0.47271
# Batch count: 241, Avg. per-sample expected Loss: 0.47113
# Batch count: 242, Avg. per-sample expected Loss: 0.46564
# Batch count: 243, Avg. per-sample expected Loss: 0.46928
# Batch count: 244, Avg. per-sample expected Loss: 0.47134
# Batch count: 245, Avg. per-sample expected Loss: 0.47420
# Batch count: 246, Avg. per-sample expected Loss: 0.47000
# Batch count: 247, Avg. per-sample expected Loss: 0.46460
# Batch count: 248, Avg. per-sample expected Loss: 0.46949
# Batch count: 249, Avg. per-sample expected Loss: 0.46704
# Batch count: 250, Avg. per-sample expected Loss: 0.46171
# Batch count: 251, Avg. per-sample expected Loss: 0.46409
# Batch count: 252, Avg. per-sample expected Loss: 0.46514
# Batch count: 253, Avg. per-sample expected Loss: 0.46658
# Batch count: 254, Avg. per-sample expected Loss: 0.46449
# Batch count: 255, Avg. per-sample expected Loss: 0.46921
# Batch count: 256, Avg. per-sample expected Loss: 0.46564
# Batch count: 257, Avg. per-sample expected Loss: 0.46561
# Batch count: 258, Avg. per-sample expected Loss: 0.46300
# Batch count: 259, Avg. per-sample expected Loss: 0.46357
# Batch count: 260, Avg. per-sample expected Loss: 0.46702
# Batch count: 261, Avg. per-sample expected Loss: 0.46586
# Batch count: 262, Avg. per-sample expected Loss: 0.46231
# Batch count: 263, Avg. per-sample expected Loss: 0.46556
# Batch count: 264, Avg. per-sample expected Loss: 0.46149
# Batch count: 265, Avg. per-sample expected Loss: 0.46352
# Batch count: 266, Avg. per-sample expected Loss: 0.46136
# Batch count: 267, Avg. per-sample expected Loss: 0.46015
# Batch count: 268, Avg. per-sample expected Loss: 0.46199
# Batch count: 269, Avg. per-sample expected Loss: 0.46247
# Batch count: 270, Avg. per-sample expected Loss: 0.46138
# Batch count: 271, Avg. per-sample expected Loss: 0.45924
# Batch count: 272, Avg. per-sample expected Loss: 0.46115
# Batch count: 273, Avg. per-sample expected Loss: 0.45436
# Batch count: 274, Avg. per-sample expected Loss: 0.46081
# Batch count: 275, Avg. per-sample expected Loss: 0.45558
# Batch count: 276, Avg. per-sample expected Loss: 0.44974
# Batch count: 277, Avg. per-sample expected Loss: 0.45764
# Batch count: 278, Avg. per-sample expected Loss: 0.45175
# Batch count: 279, Avg. per-sample expected Loss: 0.45532
# Batch count: 280, Avg. per-sample expected Loss: 0.45593
# Batch count: 281, Avg. per-sample expected Loss: 0.45604
# Batch count: 282, Avg. per-sample expected Loss: 0.45123
# Batch count: 283, Avg. per-sample expected Loss: 0.45304
# Batch count: 284, Avg. per-sample expected Loss: 0.44821
# Batch count: 285, Avg. per-sample expected Loss: 0.45450
# Batch count: 286, Avg. per-sample expected Loss: 0.44785
# Batch count: 287, Avg. per-sample expected Loss: 0.44626
# Batch count: 288, Avg. per-sample expected Loss: 0.44492
# Batch count: 289, Avg. per-sample expected Loss: 0.44227
# Batch count: 290, Avg. per-sample expected Loss: 0.44590
# Batch count: 291, Avg. per-sample expected Loss: 0.44172
# Batch count: 292, Avg. per-sample expected Loss: 0.43854
# Batch count: 293, Avg. per-sample expected Loss: 0.44337
# Batch count: 294, Avg. per-sample expected Loss: 0.43897
# Batch count: 295, Avg. per-sample expected Loss: 0.44015
# Batch count: 296, Avg. per-sample expected Loss: 0.43682
# Batch count: 297, Avg. per-sample expected Loss: 0.43565
# Batch count: 298, Avg. per-sample expected Loss: 0.43760
# Batch count: 299, Avg. per-sample expected Loss: 0.43668
# Batch count: 300, Avg. per-sample expected Loss: 0.43922
# Batch count: 301, Avg. per-sample expected Loss: 0.42747
# Batch count: 302, Avg. per-sample expected Loss: 0.42915
# Batch count: 303, Avg. per-sample expected Loss: 0.43358
# Batch count: 304, Avg. per-sample expected Loss: 0.42798
# Batch count: 305, Avg. per-sample expected Loss: 0.43138
# Batch count: 306, Avg. per-sample expected Loss: 0.42783
# Batch count: 307, Avg. per-sample expected Loss: 0.42611
# Batch count: 308, Avg. per-sample expected Loss: 0.43070
# Batch count: 309, Avg. per-sample expected Loss: 0.43177
# Batch count: 310, Avg. per-sample expected Loss: 0.43045
# Batch count: 311, Avg. per-sample expected Loss: 0.42626
# Batch count: 312, Avg. per-sample expected Loss: 0.42790
# Batch count: 313, Avg. per-sample expected Loss: 0.42565
# Batch count: 314, Avg. per-sample expected Loss: 0.43033
# Batch count: 315, Avg. per-sample expected Loss: 0.43283
# Batch count: 316, Avg. per-sample expected Loss: 0.42889
# Batch count: 317, Avg. per-sample expected Loss: 0.42508
# Batch count: 318, Avg. per-sample expected Loss: 0.42959
# Batch count: 319, Avg. per-sample expected Loss: 0.41922
# Batch count: 320, Avg. per-sample expected Loss: 0.42197
# Batch count: 321, Avg. per-sample expected Loss: 0.42324
# Batch count: 322, Avg. per-sample expected Loss: 0.42684
# Batch count: 323, Avg. per-sample expected Loss: 0.41558
# Batch count: 324, Avg. per-sample expected Loss: 0.42050
# Batch count: 325, Avg. per-sample expected Loss: 0.41936
# Batch count: 326, Avg. per-sample expected Loss: 0.41666
# Batch count: 327, Avg. per-sample expected Loss: 0.41478
# Batch count: 328, Avg. per-sample expected Loss: 0.41662
# Batch count: 329, Avg. per-sample expected Loss: 0.41479
# Batch count: 330, Avg. per-sample expected Loss: 0.41306
# Batch count: 331, Avg. per-sample expected Loss: 0.41608
# Batch count: 332, Avg. per-sample expected Loss: 0.41135
# Batch count: 333, Avg. per-sample expected Loss: 0.41383
# Batch count: 334, Avg. per-sample expected Loss: 0.41000
# Batch count: 335, Avg. per-sample expected Loss: 0.41298
# Batch count: 336, Avg. per-sample expected Loss: 0.41039
# Batch count: 337, Avg. per-sample expected Loss: 0.41676
# Batch count: 338, Avg. per-sample expected Loss: 0.41535
# Batch count: 339, Avg. per-sample expected Loss: 0.41180
# Batch count: 340, Avg. per-sample expected Loss: 0.41014
# Batch count: 341, Avg. per-sample expected Loss: 0.41567
# Batch count: 342, Avg. per-sample expected Loss: 0.40989
# Batch count: 343, Avg. per-sample expected Loss: 0.40997
# Batch count: 344, Avg. per-sample expected Loss: 0.40710
# Batch count: 345, Avg. per-sample expected Loss: 0.40970
# Batch count: 346, Avg. per-sample expected Loss: 0.40476
# Batch count: 347, Avg. per-sample expected Loss: 0.40218
# Batch count: 348, Avg. per-sample expected Loss: 0.40882
# Batch count: 349, Avg. per-sample expected Loss: 0.40870

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6c_cost, "b", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6c_Ecost, "c.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training using 2-QNSCD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("6-RQSGD.png")
plt.show()

# %% [markdown]
# ## 2-RQSGD using 600 samples per step and 6 samples per itr

# %%
SGD6params = np.array(init_params)
SGD6_cost = []
SGD6_Ecost = []

SGD6_cost.append(temp_cost)
SGD6_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 2 coordinates
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())
        
        grad = []
        
        ### Gradient estimation
        y_hat01,b01 = EstGrad(SGD6params,phiT[:,itr3+0],idx[0])
        b01 = (1-b01)/2
        y_hat02,b02 = EstGrad(SGD6params,phiT[:,itr3+1],idx[0])
        b02 = (1-b02)/2
        y_hat03,b03 = EstGrad(SGD6params,phiT[:,itr3+2],idx[0])
        b03 = (1-b03)/2
        
        temp0 = ((-1)**b01)*loss(y_hat01,labelT[itr3+0]) \
              + ((-1)**b02)*loss(y_hat02,labelT[itr3+1]) \
              + ((-1)**b03)*loss(y_hat03,labelT[itr3+2])

        grad.append((-1)*temp0/3)
        
        y_hat11,b11 = EstGrad(SGD6params,phiT[:,itr3+3],idx[1])
        b11 = (1-b11)/2
        y_hat12,b12 = EstGrad(SGD6params,phiT[:,itr3+4],idx[1])
        b12 = (1-b12)/2
        y_hat13,b13 = EstGrad(SGD6params,phiT[:,itr3+5],idx[1])
        b13 = (1-b13)/2
        
        temp1 = ((-1)**b11)*loss(y_hat11,labelT[itr3+3]) \
              + ((-1)**b12)*loss(y_hat12,labelT[itr3+4]) \
              + ((-1)**b13)*loss(y_hat13,labelT[itr3+5])

        grad.append((-1)*temp1/3)

        ### single-parameter update
        SGD6params[idx] = SGD6params[idx] - np.dot(step_size,grad)
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6params,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6count = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6params,phiT[:,itr]) != labelT[itr]:
            SGD6count += 1
    SGD6_Ecost.append(SGD6count/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "5Q 2-RQSGD_6s Expected Loss"
file_name2 = "5Q 2-RQSGD_6s Empirical Loss"

np.save(file_name1,SGD6_cost)
np.save(file_name2,SGD6_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.56283
# Batch count:  1, Avg. per-sample expected Loss: 0.55845
# Batch count:  2, Avg. per-sample expected Loss: 0.55854
# Batch count:  3, Avg. per-sample expected Loss: 0.55976
# Batch count:  4, Avg. per-sample expected Loss: 0.56133
# Batch count:  5, Avg. per-sample expected Loss: 0.55827
# Batch count:  6, Avg. per-sample expected Loss: 0.55986
# Batch count:  7, Avg. per-sample expected Loss: 0.55580
# Batch count:  8, Avg. per-sample expected Loss: 0.56052
# Batch count:  9, Avg. per-sample expected Loss: 0.56122
# Batch count: 10, Avg. per-sample expected Loss: 0.55680
# Batch count: 11, Avg. per-sample expected Loss: 0.55848
# Batch count: 12, Avg. per-sample expected Loss: 0.55820
# Batch count: 13, Avg. per-sample expected Loss: 0.55883
# Batch count: 14, Avg. per-sample expected Loss: 0.55297
# Batch count: 15, Avg. per-sample expected Loss: 0.55881
# Batch count: 16, Avg. per-sample expected Loss: 0.56013
# Batch count: 17, Avg. per-sample expected Loss: 0.55378
# Batch count: 18, Avg. per-sample expected Loss: 0.55386
# Batch count: 19, Avg. per-sample expected Loss: 0.55134
# Batch count: 20, Avg. per-sample expected Loss: 0.55674
# Batch count: 21, Avg. per-sample expected Loss: 0.55274
# Batch count: 22, Avg. per-sample expected Loss: 0.55432
# Batch count: 23, Avg. per-sample expected Loss: 0.55439
# Batch count: 24, Avg. per-sample expected Loss: 0.56244
# Batch count: 25, Avg. per-sample expected Loss: 0.55201
# Batch count: 26, Avg. per-sample expected Loss: 0.56040
# Batch count: 27, Avg. per-sample expected Loss: 0.54808
# Batch count: 28, Avg. per-sample expected Loss: 0.55337
# Batch count: 29, Avg. per-sample expected Loss: 0.56048
# Batch count: 30, Avg. per-sample expected Loss: 0.55854
# Batch count: 31, Avg. per-sample expected Loss: 0.54855
# Batch count: 32, Avg. per-sample expected Loss: 0.55745
# Batch count: 33, Avg. per-sample expected Loss: 0.55424
# Batch count: 34, Avg. per-sample expected Loss: 0.55472
# Batch count: 35, Avg. per-sample expected Loss: 0.55179
# Batch count: 36, Avg. per-sample expected Loss: 0.56144
# Batch count: 37, Avg. per-sample expected Loss: 0.55593
# Batch count: 38, Avg. per-sample expected Loss: 0.55513
# Batch count: 39, Avg. per-sample expected Loss: 0.55342
# Batch count: 40, Avg. per-sample expected Loss: 0.56042
# Batch count: 41, Avg. per-sample expected Loss: 0.54783
# Batch count: 42, Avg. per-sample expected Loss: 0.55096
# Batch count: 43, Avg. per-sample expected Loss: 0.54672
# Batch count: 44, Avg. per-sample expected Loss: 0.55321
# Batch count: 45, Avg. per-sample expected Loss: 0.55056
# Batch count: 46, Avg. per-sample expected Loss: 0.55585
# Batch count: 47, Avg. per-sample expected Loss: 0.54972
# Batch count: 48, Avg. per-sample expected Loss: 0.54580
# Batch count: 49, Avg. per-sample expected Loss: 0.55025
# Batch count: 50, Avg. per-sample expected Loss: 0.54896
# Batch count: 51, Avg. per-sample expected Loss: 0.54756
# Batch count: 52, Avg. per-sample expected Loss: 0.55296
# Batch count: 53, Avg. per-sample expected Loss: 0.55392
# Batch count: 54, Avg. per-sample expected Loss: 0.54564
# Batch count: 55, Avg. per-sample expected Loss: 0.55119
# Batch count: 56, Avg. per-sample expected Loss: 0.55176
# Batch count: 57, Avg. per-sample expected Loss: 0.55250
# Batch count: 58, Avg. per-sample expected Loss: 0.54617
# Batch count: 59, Avg. per-sample expected Loss: 0.54789
# Batch count: 60, Avg. per-sample expected Loss: 0.54625
# Batch count: 61, Avg. per-sample expected Loss: 0.54789
# Batch count: 62, Avg. per-sample expected Loss: 0.55206
# Batch count: 63, Avg. per-sample expected Loss: 0.54911
# Batch count: 64, Avg. per-sample expected Loss: 0.54408
# Batch count: 65, Avg. per-sample expected Loss: 0.54642
# Batch count: 66, Avg. per-sample expected Loss: 0.55067
# Batch count: 67, Avg. per-sample expected Loss: 0.54598
# Batch count: 68, Avg. per-sample expected Loss: 0.54835
# Batch count: 69, Avg. per-sample expected Loss: 0.54317
# Batch count: 70, Avg. per-sample expected Loss: 0.55066
# Batch count: 71, Avg. per-sample expected Loss: 0.55568
# Batch count: 72, Avg. per-sample expected Loss: 0.54884
# Batch count: 73, Avg. per-sample expected Loss: 0.54641
# Batch count: 74, Avg. per-sample expected Loss: 0.54545
# Batch count: 75, Avg. per-sample expected Loss: 0.54379
# Batch count: 76, Avg. per-sample expected Loss: 0.54583
# Batch count: 77, Avg. per-sample expected Loss: 0.53946
# Batch count: 78, Avg. per-sample expected Loss: 0.54298
# Batch count: 79, Avg. per-sample expected Loss: 0.53736
# Batch count: 80, Avg. per-sample expected Loss: 0.54207
# Batch count: 81, Avg. per-sample expected Loss: 0.54610
# Batch count: 82, Avg. per-sample expected Loss: 0.54565
# Batch count: 83, Avg. per-sample expected Loss: 0.54786
# Batch count: 84, Avg. per-sample expected Loss: 0.53712
# Batch count: 85, Avg. per-sample expected Loss: 0.54394
# Batch count: 86, Avg. per-sample expected Loss: 0.54572
# Batch count: 87, Avg. per-sample expected Loss: 0.54590
# Batch count: 88, Avg. per-sample expected Loss: 0.53979
# Batch count: 89, Avg. per-sample expected Loss: 0.54045
# Batch count: 90, Avg. per-sample expected Loss: 0.54116
# Batch count: 91, Avg. per-sample expected Loss: 0.54833
# Batch count: 92, Avg. per-sample expected Loss: 0.54298
# Batch count: 93, Avg. per-sample expected Loss: 0.54341
# Batch count: 94, Avg. per-sample expected Loss: 0.53515
# Batch count: 95, Avg. per-sample expected Loss: 0.54634
# Batch count: 96, Avg. per-sample expected Loss: 0.54255
# Batch count: 97, Avg. per-sample expected Loss: 0.54078
# Batch count: 98, Avg. per-sample expected Loss: 0.54240
# Batch count: 99, Avg. per-sample expected Loss: 0.54540
# Batch count: 100, Avg. per-sample expected Loss: 0.54185
# Batch count: 101, Avg. per-sample expected Loss: 0.53989
# Batch count: 102, Avg. per-sample expected Loss: 0.53961
# Batch count: 103, Avg. per-sample expected Loss: 0.54112
# Batch count: 104, Avg. per-sample expected Loss: 0.53731
# Batch count: 105, Avg. per-sample expected Loss: 0.53990
# Batch count: 106, Avg. per-sample expected Loss: 0.53680
# Batch count: 107, Avg. per-sample expected Loss: 0.54470
# Batch count: 108, Avg. per-sample expected Loss: 0.53966
# Batch count: 109, Avg. per-sample expected Loss: 0.53588
# Batch count: 110, Avg. per-sample expected Loss: 0.53889
# Batch count: 111, Avg. per-sample expected Loss: 0.54471
# Batch count: 112, Avg. per-sample expected Loss: 0.53557
# Batch count: 113, Avg. per-sample expected Loss: 0.53611
# Batch count: 114, Avg. per-sample expected Loss: 0.54041
# Batch count: 115, Avg. per-sample expected Loss: 0.53643
# Batch count: 116, Avg. per-sample expected Loss: 0.53869
# Batch count: 117, Avg. per-sample expected Loss: 0.54271
# Batch count: 118, Avg. per-sample expected Loss: 0.54188
# Batch count: 119, Avg. per-sample expected Loss: 0.53405
# Batch count: 120, Avg. per-sample expected Loss: 0.53229
# Batch count: 121, Avg. per-sample expected Loss: 0.53613
# Batch count: 122, Avg. per-sample expected Loss: 0.54001
# Batch count: 123, Avg. per-sample expected Loss: 0.54147
# Batch count: 124, Avg. per-sample expected Loss: 0.53644
# Batch count: 125, Avg. per-sample expected Loss: 0.53236
# Batch count: 126, Avg. per-sample expected Loss: 0.53399
# Batch count: 127, Avg. per-sample expected Loss: 0.54146
# Batch count: 128, Avg. per-sample expected Loss: 0.53493
# Batch count: 129, Avg. per-sample expected Loss: 0.53373
# Batch count: 130, Avg. per-sample expected Loss: 0.53783
# Batch count: 131, Avg. per-sample expected Loss: 0.53308
# Batch count: 132, Avg. per-sample expected Loss: 0.53699
# Batch count: 133, Avg. per-sample expected Loss: 0.53072
# Batch count: 134, Avg. per-sample expected Loss: 0.52888
# Batch count: 135, Avg. per-sample expected Loss: 0.54266
# Batch count: 136, Avg. per-sample expected Loss: 0.53677
# Batch count: 137, Avg. per-sample expected Loss: 0.53533
# Batch count: 138, Avg. per-sample expected Loss: 0.54025
# Batch count: 139, Avg. per-sample expected Loss: 0.53426
# Batch count: 140, Avg. per-sample expected Loss: 0.52873
# Batch count: 141, Avg. per-sample expected Loss: 0.52796
# Batch count: 142, Avg. per-sample expected Loss: 0.53415
# Batch count: 143, Avg. per-sample expected Loss: 0.53863
# Batch count: 144, Avg. per-sample expected Loss: 0.52705
# Batch count: 145, Avg. per-sample expected Loss: 0.53230
# Batch count: 146, Avg. per-sample expected Loss: 0.52901
# Batch count: 147, Avg. per-sample expected Loss: 0.52948
# Batch count: 148, Avg. per-sample expected Loss: 0.53231
# Batch count: 149, Avg. per-sample expected Loss: 0.52946
# Batch count: 150, Avg. per-sample expected Loss: 0.53172
# Batch count: 151, Avg. per-sample expected Loss: 0.53754
# Batch count: 152, Avg. per-sample expected Loss: 0.53148
# Batch count: 153, Avg. per-sample expected Loss: 0.53342
# Batch count: 154, Avg. per-sample expected Loss: 0.53434
# Batch count: 155, Avg. per-sample expected Loss: 0.53423
# Batch count: 156, Avg. per-sample expected Loss: 0.52924
# Batch count: 157, Avg. per-sample expected Loss: 0.52761
# Batch count: 158, Avg. per-sample expected Loss: 0.53044
# Batch count: 159, Avg. per-sample expected Loss: 0.53109
# Batch count: 160, Avg. per-sample expected Loss: 0.52769
# Batch count: 161, Avg. per-sample expected Loss: 0.53126
# Batch count: 162, Avg. per-sample expected Loss: 0.53259
# Batch count: 163, Avg. per-sample expected Loss: 0.52532
# Batch count: 164, Avg. per-sample expected Loss: 0.53005
# Batch count: 165, Avg. per-sample expected Loss: 0.52186
# Batch count: 166, Avg. per-sample expected Loss: 0.52507
# Batch count: 167, Avg. per-sample expected Loss: 0.52620
# Batch count: 168, Avg. per-sample expected Loss: 0.52882
# Batch count: 169, Avg. per-sample expected Loss: 0.52614
# Batch count: 170, Avg. per-sample expected Loss: 0.52836
# Batch count: 171, Avg. per-sample expected Loss: 0.53067
# Batch count: 172, Avg. per-sample expected Loss: 0.52710
# Batch count: 173, Avg. per-sample expected Loss: 0.52486
# Batch count: 174, Avg. per-sample expected Loss: 0.52741
# Batch count: 175, Avg. per-sample expected Loss: 0.53008
# Batch count: 176, Avg. per-sample expected Loss: 0.52531
# Batch count: 177, Avg. per-sample expected Loss: 0.52828
# Batch count: 178, Avg. per-sample expected Loss: 0.52752
# Batch count: 179, Avg. per-sample expected Loss: 0.52954
# Batch count: 180, Avg. per-sample expected Loss: 0.52650
# Batch count: 181, Avg. per-sample expected Loss: 0.52660
# Batch count: 182, Avg. per-sample expected Loss: 0.52502
# Batch count: 183, Avg. per-sample expected Loss: 0.52854
# Batch count: 184, Avg. per-sample expected Loss: 0.52469
# Batch count: 185, Avg. per-sample expected Loss: 0.52532
# Batch count: 186, Avg. per-sample expected Loss: 0.52287
# Batch count: 187, Avg. per-sample expected Loss: 0.52943
# Batch count: 188, Avg. per-sample expected Loss: 0.52021
# Batch count: 189, Avg. per-sample expected Loss: 0.52695
# Batch count: 190, Avg. per-sample expected Loss: 0.52900
# Batch count: 191, Avg. per-sample expected Loss: 0.52400
# Batch count: 192, Avg. per-sample expected Loss: 0.52794
# Batch count: 193, Avg. per-sample expected Loss: 0.52408
# Batch count: 194, Avg. per-sample expected Loss: 0.52691
# Batch count: 195, Avg. per-sample expected Loss: 0.52321
# Batch count: 196, Avg. per-sample expected Loss: 0.52718
# Batch count: 197, Avg. per-sample expected Loss: 0.52600
# Batch count: 198, Avg. per-sample expected Loss: 0.51999
# Batch count: 199, Avg. per-sample expected Loss: 0.52924
# Batch count: 200, Avg. per-sample expected Loss: 0.52550
# Batch count: 201, Avg. per-sample expected Loss: 0.52576
# Batch count: 202, Avg. per-sample expected Loss: 0.52065
# Batch count: 203, Avg. per-sample expected Loss: 0.51936
# Batch count: 204, Avg. per-sample expected Loss: 0.52094
# Batch count: 205, Avg. per-sample expected Loss: 0.51681
# Batch count: 206, Avg. per-sample expected Loss: 0.52445
# Batch count: 207, Avg. per-sample expected Loss: 0.52979
# Batch count: 208, Avg. per-sample expected Loss: 0.52589
# Batch count: 209, Avg. per-sample expected Loss: 0.52231
# Batch count: 210, Avg. per-sample expected Loss: 0.52536
# Batch count: 211, Avg. per-sample expected Loss: 0.51947
# Batch count: 212, Avg. per-sample expected Loss: 0.52996
# Batch count: 213, Avg. per-sample expected Loss: 0.51708
# Batch count: 214, Avg. per-sample expected Loss: 0.52421
# Batch count: 215, Avg. per-sample expected Loss: 0.52207
# Batch count: 216, Avg. per-sample expected Loss: 0.52034
# Batch count: 217, Avg. per-sample expected Loss: 0.52090
# Batch count: 218, Avg. per-sample expected Loss: 0.51988
# Batch count: 219, Avg. per-sample expected Loss: 0.52080
# Batch count: 220, Avg. per-sample expected Loss: 0.52254
# Batch count: 221, Avg. per-sample expected Loss: 0.51957
# Batch count: 222, Avg. per-sample expected Loss: 0.52064
# Batch count: 223, Avg. per-sample expected Loss: 0.51387
# Batch count: 224, Avg. per-sample expected Loss: 0.51819
# Batch count: 225, Avg. per-sample expected Loss: 0.51932
# Batch count: 226, Avg. per-sample expected Loss: 0.51737
# Batch count: 227, Avg. per-sample expected Loss: 0.51267
# Batch count: 228, Avg. per-sample expected Loss: 0.51833
# Batch count: 229, Avg. per-sample expected Loss: 0.52077
# Batch count: 230, Avg. per-sample expected Loss: 0.51551
# Batch count: 231, Avg. per-sample expected Loss: 0.51944
# Batch count: 232, Avg. per-sample expected Loss: 0.51798
# Batch count: 233, Avg. per-sample expected Loss: 0.52147
# Batch count: 234, Avg. per-sample expected Loss: 0.51908
# Batch count: 235, Avg. per-sample expected Loss: 0.52150
# Batch count: 236, Avg. per-sample expected Loss: 0.51738
# Batch count: 237, Avg. per-sample expected Loss: 0.51392
# Batch count: 238, Avg. per-sample expected Loss: 0.51883
# Batch count: 239, Avg. per-sample expected Loss: 0.52314
# Batch count: 240, Avg. per-sample expected Loss: 0.51568
# Batch count: 241, Avg. per-sample expected Loss: 0.52010
# Batch count: 242, Avg. per-sample expected Loss: 0.51103
# Batch count: 243, Avg. per-sample expected Loss: 0.51985
# Batch count: 244, Avg. per-sample expected Loss: 0.51572
# Batch count: 245, Avg. per-sample expected Loss: 0.51752
# Batch count: 246, Avg. per-sample expected Loss: 0.51556
# Batch count: 247, Avg. per-sample expected Loss: 0.51516
# Batch count: 248, Avg. per-sample expected Loss: 0.51934
# Batch count: 249, Avg. per-sample expected Loss: 0.52146
# Batch count: 250, Avg. per-sample expected Loss: 0.51544
# Batch count: 251, Avg. per-sample expected Loss: 0.51265
# Batch count: 252, Avg. per-sample expected Loss: 0.51728
# Batch count: 253, Avg. per-sample expected Loss: 0.51847
# Batch count: 254, Avg. per-sample expected Loss: 0.51964
# Batch count: 255, Avg. per-sample expected Loss: 0.51376
# Batch count: 256, Avg. per-sample expected Loss: 0.51273
# Batch count: 257, Avg. per-sample expected Loss: 0.51398
# Batch count: 258, Avg. per-sample expected Loss: 0.51903
# Batch count: 259, Avg. per-sample expected Loss: 0.51529
# Batch count: 260, Avg. per-sample expected Loss: 0.51867
# Batch count: 261, Avg. per-sample expected Loss: 0.51290
# Batch count: 262, Avg. per-sample expected Loss: 0.51255
# Batch count: 263, Avg. per-sample expected Loss: 0.51409
# Batch count: 264, Avg. per-sample expected Loss: 0.51362
# Batch count: 265, Avg. per-sample expected Loss: 0.51563
# Batch count: 266, Avg. per-sample expected Loss: 0.50973
# Batch count: 267, Avg. per-sample expected Loss: 0.51594
# Batch count: 268, Avg. per-sample expected Loss: 0.51543
# Batch count: 269, Avg. per-sample expected Loss: 0.51704
# Batch count: 270, Avg. per-sample expected Loss: 0.51675
# Batch count: 271, Avg. per-sample expected Loss: 0.51590
# Batch count: 272, Avg. per-sample expected Loss: 0.51888
# Batch count: 273, Avg. per-sample expected Loss: 0.51182
# Batch count: 274, Avg. per-sample expected Loss: 0.51348
# Batch count: 275, Avg. per-sample expected Loss: 0.51216
# Batch count: 276, Avg. per-sample expected Loss: 0.50762
# Batch count: 277, Avg. per-sample expected Loss: 0.51947
# Batch count: 278, Avg. per-sample expected Loss: 0.50808
# Batch count: 279, Avg. per-sample expected Loss: 0.51628
# Batch count: 280, Avg. per-sample expected Loss: 0.51496
# Batch count: 281, Avg. per-sample expected Loss: 0.51847
# Batch count: 282, Avg. per-sample expected Loss: 0.51271
# Batch count: 283, Avg. per-sample expected Loss: 0.51228
# Batch count: 284, Avg. per-sample expected Loss: 0.51135
# Batch count: 285, Avg. per-sample expected Loss: 0.51311
# Batch count: 286, Avg. per-sample expected Loss: 0.51426
# Batch count: 287, Avg. per-sample expected Loss: 0.50757
# Batch count: 288, Avg. per-sample expected Loss: 0.51420
# Batch count: 289, Avg. per-sample expected Loss: 0.51103
# Batch count: 290, Avg. per-sample expected Loss: 0.51444
# Batch count: 291, Avg. per-sample expected Loss: 0.51439
# Batch count: 292, Avg. per-sample expected Loss: 0.51382
# Batch count: 293, Avg. per-sample expected Loss: 0.51464
# Batch count: 294, Avg. per-sample expected Loss: 0.51785
# Batch count: 295, Avg. per-sample expected Loss: 0.51391
# Batch count: 296, Avg. per-sample expected Loss: 0.51466
# Batch count: 297, Avg. per-sample expected Loss: 0.51449
# Batch count: 298, Avg. per-sample expected Loss: 0.51064
# Batch count: 299, Avg. per-sample expected Loss: 0.51148
# Batch count: 300, Avg. per-sample expected Loss: 0.51426
# Batch count: 301, Avg. per-sample expected Loss: 0.51027
# Batch count: 302, Avg. per-sample expected Loss: 0.51064
# Batch count: 303, Avg. per-sample expected Loss: 0.51018
# Batch count: 304, Avg. per-sample expected Loss: 0.50837
# Batch count: 305, Avg. per-sample expected Loss: 0.50835
# Batch count: 306, Avg. per-sample expected Loss: 0.50894
# Batch count: 307, Avg. per-sample expected Loss: 0.50729
# Batch count: 308, Avg. per-sample expected Loss: 0.50877
# Batch count: 309, Avg. per-sample expected Loss: 0.50749
# Batch count: 310, Avg. per-sample expected Loss: 0.51231
# Batch count: 311, Avg. per-sample expected Loss: 0.51028
# Batch count: 312, Avg. per-sample expected Loss: 0.50890
# Batch count: 313, Avg. per-sample expected Loss: 0.51710
# Batch count: 314, Avg. per-sample expected Loss: 0.51185
# Batch count: 315, Avg. per-sample expected Loss: 0.51034
# Batch count: 316, Avg. per-sample expected Loss: 0.51332
# Batch count: 317, Avg. per-sample expected Loss: 0.51027
# Batch count: 318, Avg. per-sample expected Loss: 0.51169
# Batch count: 319, Avg. per-sample expected Loss: 0.50746
# Batch count: 320, Avg. per-sample expected Loss: 0.51348
# Batch count: 321, Avg. per-sample expected Loss: 0.51013
# Batch count: 322, Avg. per-sample expected Loss: 0.51170
# Batch count: 323, Avg. per-sample expected Loss: 0.50551
# Batch count: 324, Avg. per-sample expected Loss: 0.51148
# Batch count: 325, Avg. per-sample expected Loss: 0.51491
# Batch count: 326, Avg. per-sample expected Loss: 0.50886
# Batch count: 327, Avg. per-sample expected Loss: 0.51131
# Batch count: 328, Avg. per-sample expected Loss: 0.51104
# Batch count: 329, Avg. per-sample expected Loss: 0.50961
# Batch count: 330, Avg. per-sample expected Loss: 0.50698
# Batch count: 331, Avg. per-sample expected Loss: 0.51123
# Batch count: 332, Avg. per-sample expected Loss: 0.50167
# Batch count: 333, Avg. per-sample expected Loss: 0.50918
# Batch count: 334, Avg. per-sample expected Loss: 0.50853
# Batch count: 335, Avg. per-sample expected Loss: 0.50871
# Batch count: 336, Avg. per-sample expected Loss: 0.50595
# Batch count: 337, Avg. per-sample expected Loss: 0.51117
# Batch count: 338, Avg. per-sample expected Loss: 0.51205
# Batch count: 339, Avg. per-sample expected Loss: 0.50928
# Batch count: 340, Avg. per-sample expected Loss: 0.50574
# Batch count: 341, Avg. per-sample expected Loss: 0.51094
# Batch count: 342, Avg. per-sample expected Loss: 0.50655
# Batch count: 343, Avg. per-sample expected Loss: 0.50635
# Batch count: 344, Avg. per-sample expected Loss: 0.50793
# Batch count: 345, Avg. per-sample expected Loss: 0.50678
# Batch count: 346, Avg. per-sample expected Loss: 0.50547
# Batch count: 347, Avg. per-sample expected Loss: 0.50710
# Batch count: 348, Avg. per-sample expected Loss: 0.50896
# Batch count: 349, Avg. per-sample expected Loss: 0.51319

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")

plt.title("Training using 2-QNSCD and 2-RQSGD (6 samples per itr)")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("2RSGD_6s.png")
plt.show()

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")
plt.plot(SGD6c_cost, "g", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")
plt.plot(SGD6c_Ecost, "g.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training 2-QNSCD and 2-RQSGD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("RQSGD.png")
plt.show()

# %% [markdown]
# ## Testing Phase

# %%
## Saving Final Parameters:
file_name1 = "5Q 2-QNSCD params"
file_name2 = "5Q 2-RQSGD_6s params"
file_name3 = "5Q 6-RQSGD params"

np.save(file_name1,NCGDparams)
np.save(file_name2,SGD6params)
np.save(file_name3,SGD6cparams)

# %%
phiTest = np.load('5-qubitsPhiTest_v1.npy')
labelTest = np.load('5-qubitsLabelTest_v1.npy')

phiTest.requires_grad = False
labelTest.requires_grad = False

# %%
nTest = 1000

NCGDparams_opt = NCGDparams 
SGD6params_opt = SGD6params
SGD6cparams_opt = SGD6cparams

# %%
### Optimal Expected Loss
expOperator = 0

for i in range(nTest):
    op = np.matmul(phiTest[:,i].reshape(dim,1),phiTest[:,i].reshape(1,dim))
    expOperator = expOperator + labelTest[i]*op
expOperator = expOperator/(nTest)
opt_value = 0.5*(1+sum(abs(np.linalg.svd(expOperator)[1])))

# %%
NCGD_rslt = []
SGD6_rslt = []
SGD6c_rslt = []

for i in range(int(1e1)):
    NCGDcount = 0
    SGD6count = 0
    SGD6ccount = 0

    for itr in range(nTest):
        if circuit_test(NCGDparams_opt,phiTest[:,itr]) == labelTest[itr]:
            NCGDcount += 1 
        if circuit_test(SGD6params_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6count += 1
        if circuit_test(SGD6cparams_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6ccount += 1
    
    NCGD_rslt.append(NCGDcount/nTest)
    SGD6_rslt.append(SGD6count/nTest)
    SGD6c_rslt.append(SGD6ccount/nTest)
#     print("itr = ",i)

# %%
print("Optimal: {:.3f} \nNCGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n2-RQSGD_6s: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n6-RQSGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f}"\
      .format(opt_value,np.average(NCGD_rslt),np.std(NCGD_rslt),max(NCGD_rslt),min(NCGD_rslt),\
              np.average(SGD6_rslt),np.std(SGD6_rslt),max(SGD6_rslt),min(SGD6_rslt), \
              np.average(SGD6c_rslt),np.std(SGD6c_rslt),max(SGD6c_rslt),min(SGD6c_rslt)))
# Out:
# Optimal: 0.877
# NCGD: 0.818 / 0.008 max: 0.833 min: 0.810
# 2-RQSGD_6s: 0.499 / 0.013 max: 0.527 min: 0.480
# 6-RQSGD: 0.587 / 0.017 max: 0.610 min: 0.563
