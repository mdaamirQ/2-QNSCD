# %%
import pennylane as qml
from pennylane import numpy as np
import scipy
import matplotlib.pyplot as plt
from globalVars import *
from model_5qubit import *

from GRADest_5Q import EstGrad
from EQFIMest_5Q import Est_EQFIM

# %% [markdown]
# ## Quantum Neural Network

# %%
random_state = np.random.rand(dim)
random_state = random_state /np.linalg.norm(random_state)
qml.draw_mpl(QNN)(np.zeros(nparams),random_state)
# Out:
# (<Figure size 1300x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### Model Initialization

# %%
S_pItr = 6  # no. of samples used per-iteration 

nStep = 350
nItr = 100
step_size = 0.0025

Bsize = S_pItr*nItr

# %%
phiTrain = np.load('5-qubitsPhiTrain_v1.npy')
labelTrain = np.load('5-qubitsLabelTrain_v1.npy')

phiTrain.requires_grad = False
labelTrain.requires_grad = False

# %%
'QNSCD Dataset'
phiTrainNCGD = phiTrain
labelTrainNCGD = labelTrain

'SGD Dataset'
phiTrainSGD = phiTrain
labelTrainSGD = labelTrain

# %%
### Optimal Expected Loss
Opt_cost = []
itrBatch = np.linspace(0,Bsize*nStep,nStep,endpoint = False,dtype = 'int').tolist()
for itr1 in itrBatch:
    expOperator = 0
    for itr2 in range(Bsize):
        temp_phi = phiTrain[:,itr1+itr2]
        op = np.matmul(temp_phi.reshape(dim,1),temp_phi.reshape(1,dim))
        expOperator = expOperator + labelTrain[itr1+itr2]*op
    expOperator = expOperator/Bsize
    opt_value = 0.5*(1-sum(abs(np.linalg.svd(expOperator)[1])))
    Opt_cost.append(opt_value)

file_name = "5Q-Minimum Expected Loss"
np.save(file_name,Opt_cost)

# %% [markdown]
# # Optimizers

# %%
'QNN outputs yhat'
dev = qml.device("default.qubit", wires=nqubits, shots=1)

@qml.qnode(dev,interface='autograd')
def circuit_test(params,state):
    QNN(params,state)
    return qml.sample(qml.Hermitian(M,wires=list(range(nqubits))))

# %%
init_params = np.random.uniform(low=0, high=2*np.pi, size=nparams, requires_grad=True)
init_params = np.array([1.07778161, 1.17221996, 0.03126925, 1.3969618,  0.86026335, 4.23214898,
 1.41900884, 2.86522527, 6.17074357, 5.52038075, 3.20151994, 5.64510468,
 1.85502938, 6.219193,   5.49104428, 5.85866569, 3.81676312, 0.19135027,
 6.11144218, 1.19130994, 4.47822972, 5.72307605, 2.12844511, 5.27052664,
 0.38634499, 6.09500648, 2.41434857, 4.70487298, 4.00955356, 0.06615989],requires_grad=True)

'cost initialization'
phiTrain0 = phiTrain[:,-1*(Bsize+1):-1]
labelTrain0 = labelTrain[-1*(Bsize+1):-1]
temp_cost = sum([ps_expLoss(init_params,phiTrain0[:,itr],labelTrain0[itr]) for itr in range(Bsize)])/Bsize
print("Initial Average Per-Sample Expected Loss: ",temp_cost)

count = 0
for itr in range(Bsize):
    if circuit_test(init_params,phiTrain0[:,itr]) != labelTrain0[itr]:
        count += 1
temp_Ecost = count/Bsize
print("Initial Average Empirical Loss", temp_Ecost)
# Out:
# Initial Average Per-Sample Expected Loss:  0.532456739521506
# Initial Average Empirical Loss 0.545

# %% [markdown]
# ## Quantum Natural Stochastic Pairwise Coordinate Descent (2-QNSCD)

# %%
NCGDparams = np.array(init_params)
NCGD_cost = []
NCGD_Ecost = []

NCGD_cost.append(temp_cost)
NCGD_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainNCGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainNCGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a pair of coordinate
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())

        ### Gradient estimation
        y1, b1 = EstGrad(NCGDparams,phiT[:,itr3],idx[0])
        y2, b2 = EstGrad(NCGDparams,phiT[:,itr3+1],idx[1])
        b1 = (1-b1)/2
        b2 = (1-b2)/2

        grad = [-1*((-1)**b1)*loss(y1,labelT[itr3]),-1*((-1)**b2)*loss(y2,labelT[itr3+1])]
        
        ### E-QFIM estimation
        metric = Est_EQFIM(NCGDparams,idx,phiT[:,itr3+2:itr3+S_pItr])

        ### double-parameters update
        NCGDparams[idx] = NCGDparams[idx] - (step_size)*np.dot(np.linalg.inv(metric),grad) 
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(NCGDparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    NCGD_cost.append(energy)
    
    ### average empirical loss calculation
    NCGDcount = 0
    for itr in range(Bsize):
        if circuit_test(NCGDparams,phiT[:,itr]) != labelT[itr]:
            NCGDcount += 1
    NCGD_Ecost.append(NCGDcount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))

file_name1 = "5Q 2-QNSCD Expected Loss"
file_name2 = "5Q 2-QNSCD Empirical Loss"

np.save(file_name1,NCGD_cost)
np.save(file_name2,NCGD_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.53246
# Batch count:  1, Avg. per-sample expected Loss: 0.50687
# Batch count:  2, Avg. per-sample expected Loss: 0.48448
# Batch count:  3, Avg. per-sample expected Loss: 0.47573
# Batch count:  4, Avg. per-sample expected Loss: 0.48492
# Batch count:  5, Avg. per-sample expected Loss: 0.49011
# Batch count:  6, Avg. per-sample expected Loss: 0.47399
# Batch count:  7, Avg. per-sample expected Loss: 0.47936
# Batch count:  8, Avg. per-sample expected Loss: 0.47830
# Batch count:  9, Avg. per-sample expected Loss: 0.45052
# Batch count: 10, Avg. per-sample expected Loss: 0.44722
# Batch count: 11, Avg. per-sample expected Loss: 0.44961
# Batch count: 12, Avg. per-sample expected Loss: 0.42407
# Batch count: 13, Avg. per-sample expected Loss: 0.42123
# Batch count: 14, Avg. per-sample expected Loss: 0.39894
# Batch count: 15, Avg. per-sample expected Loss: 0.43288
# Batch count: 16, Avg. per-sample expected Loss: 0.42050
# Batch count: 17, Avg. per-sample expected Loss: 0.40297
# Batch count: 18, Avg. per-sample expected Loss: 0.37224
# Batch count: 19, Avg. per-sample expected Loss: 0.34692
# Batch count: 20, Avg. per-sample expected Loss: 0.36988
# Batch count: 21, Avg. per-sample expected Loss: 0.37960
# Batch count: 22, Avg. per-sample expected Loss: 0.36791
# Batch count: 23, Avg. per-sample expected Loss: 0.37140
# Batch count: 24, Avg. per-sample expected Loss: 0.37263
# Batch count: 25, Avg. per-sample expected Loss: 0.36663
# Batch count: 26, Avg. per-sample expected Loss: 0.36668
# Batch count: 27, Avg. per-sample expected Loss: 0.33339
# Batch count: 28, Avg. per-sample expected Loss: 0.33542
# Batch count: 29, Avg. per-sample expected Loss: 0.37038
# Batch count: 30, Avg. per-sample expected Loss: 0.35647
# Batch count: 31, Avg. per-sample expected Loss: 0.32644
# Batch count: 32, Avg. per-sample expected Loss: 0.34532
# Batch count: 33, Avg. per-sample expected Loss: 0.32418
# Batch count: 34, Avg. per-sample expected Loss: 0.30641
# Batch count: 35, Avg. per-sample expected Loss: 0.30851
# Batch count: 36, Avg. per-sample expected Loss: 0.27449
# Batch count: 37, Avg. per-sample expected Loss: 0.27500
# Batch count: 38, Avg. per-sample expected Loss: 0.28188
# Batch count: 39, Avg. per-sample expected Loss: 0.25572
# Batch count: 40, Avg. per-sample expected Loss: 0.26505
# Batch count: 41, Avg. per-sample expected Loss: 0.26111
# Batch count: 42, Avg. per-sample expected Loss: 0.26502
# Batch count: 43, Avg. per-sample expected Loss: 0.26133
# Batch count: 44, Avg. per-sample expected Loss: 0.27851
# Batch count: 45, Avg. per-sample expected Loss: 0.26066
# Batch count: 46, Avg. per-sample expected Loss: 0.23863
# Batch count: 47, Avg. per-sample expected Loss: 0.24230
# Batch count: 48, Avg. per-sample expected Loss: 0.23216
# Batch count: 49, Avg. per-sample expected Loss: 0.25723
# Batch count: 50, Avg. per-sample expected Loss: 0.24302
# Batch count: 51, Avg. per-sample expected Loss: 0.23276
# Batch count: 52, Avg. per-sample expected Loss: 0.24750
# Batch count: 53, Avg. per-sample expected Loss: 0.24606
# Batch count: 54, Avg. per-sample expected Loss: 0.22891
# Batch count: 55, Avg. per-sample expected Loss: 0.23003
# Batch count: 56, Avg. per-sample expected Loss: 0.22114
# Batch count: 57, Avg. per-sample expected Loss: 0.22712
# Batch count: 58, Avg. per-sample expected Loss: 0.18867
# Batch count: 59, Avg. per-sample expected Loss: 0.20535
# Batch count: 60, Avg. per-sample expected Loss: 0.18717
# Batch count: 61, Avg. per-sample expected Loss: 0.18557
# Batch count: 62, Avg. per-sample expected Loss: 0.19157
# Batch count: 63, Avg. per-sample expected Loss: 0.18545
# Batch count: 64, Avg. per-sample expected Loss: 0.18083
# Batch count: 65, Avg. per-sample expected Loss: 0.20037
# Batch count: 66, Avg. per-sample expected Loss: 0.18677
# Batch count: 67, Avg. per-sample expected Loss: 0.17649
# Batch count: 68, Avg. per-sample expected Loss: 0.19136
# Batch count: 69, Avg. per-sample expected Loss: 0.19043
# Batch count: 70, Avg. per-sample expected Loss: 0.18062
# Batch count: 71, Avg. per-sample expected Loss: 0.18301
# Batch count: 72, Avg. per-sample expected Loss: 0.17627
# Batch count: 73, Avg. per-sample expected Loss: 0.17971
# Batch count: 74, Avg. per-sample expected Loss: 0.16850
# Batch count: 75, Avg. per-sample expected Loss: 0.18058
# Batch count: 76, Avg. per-sample expected Loss: 0.18522
# Batch count: 77, Avg. per-sample expected Loss: 0.16127
# Batch count: 78, Avg. per-sample expected Loss: 0.17337
# Batch count: 79, Avg. per-sample expected Loss: 0.16013
# Batch count: 80, Avg. per-sample expected Loss: 0.17159
# Batch count: 81, Avg. per-sample expected Loss: 0.17745
# Batch count: 82, Avg. per-sample expected Loss: 0.18346
# Batch count: 83, Avg. per-sample expected Loss: 0.17781
# Batch count: 84, Avg. per-sample expected Loss: 0.18173
# Batch count: 85, Avg. per-sample expected Loss: 0.18390
# Batch count: 86, Avg. per-sample expected Loss: 0.18688
# Batch count: 87, Avg. per-sample expected Loss: 0.19762
# Batch count: 88, Avg. per-sample expected Loss: 0.17717
# Batch count: 89, Avg. per-sample expected Loss: 0.18095
# Batch count: 90, Avg. per-sample expected Loss: 0.18513
# Batch count: 91, Avg. per-sample expected Loss: 0.17874
# Batch count: 92, Avg. per-sample expected Loss: 0.17207
# Batch count: 93, Avg. per-sample expected Loss: 0.17607
# Batch count: 94, Avg. per-sample expected Loss: 0.15832
# Batch count: 95, Avg. per-sample expected Loss: 0.16705
# Batch count: 96, Avg. per-sample expected Loss: 0.18265
# Batch count: 97, Avg. per-sample expected Loss: 0.16558
# Batch count: 98, Avg. per-sample expected Loss: 0.15890
# Batch count: 99, Avg. per-sample expected Loss: 0.17297
# Batch count: 100, Avg. per-sample expected Loss: 0.15775
# Batch count: 101, Avg. per-sample expected Loss: 0.16264
# Batch count: 102, Avg. per-sample expected Loss: 0.16486
# Batch count: 103, Avg. per-sample expected Loss: 0.17423
# Batch count: 104, Avg. per-sample expected Loss: 0.16342
# Batch count: 105, Avg. per-sample expected Loss: 0.18173
# Batch count: 106, Avg. per-sample expected Loss: 0.16615
# Batch count: 107, Avg. per-sample expected Loss: 0.17116
# Batch count: 108, Avg. per-sample expected Loss: 0.18670
# Batch count: 109, Avg. per-sample expected Loss: 0.16402
# Batch count: 110, Avg. per-sample expected Loss: 0.16574
# Batch count: 111, Avg. per-sample expected Loss: 0.17474
# Batch count: 112, Avg. per-sample expected Loss: 0.16129
# Batch count: 113, Avg. per-sample expected Loss: 0.16332
# Batch count: 114, Avg. per-sample expected Loss: 0.16372
# Batch count: 115, Avg. per-sample expected Loss: 0.17208
# Batch count: 116, Avg. per-sample expected Loss: 0.17181
# Batch count: 117, Avg. per-sample expected Loss: 0.16846
# Batch count: 118, Avg. per-sample expected Loss: 0.16167
# Batch count: 119, Avg. per-sample expected Loss: 0.16437
# Batch count: 120, Avg. per-sample expected Loss: 0.15762
# Batch count: 121, Avg. per-sample expected Loss: 0.16007
# Batch count: 122, Avg. per-sample expected Loss: 0.15931
# Batch count: 123, Avg. per-sample expected Loss: 0.16463
# Batch count: 124, Avg. per-sample expected Loss: 0.15750
# Batch count: 125, Avg. per-sample expected Loss: 0.15519
# Batch count: 126, Avg. per-sample expected Loss: 0.14888
# Batch count: 127, Avg. per-sample expected Loss: 0.14835
# Batch count: 128, Avg. per-sample expected Loss: 0.15722
# Batch count: 129, Avg. per-sample expected Loss: 0.15571
# Batch count: 130, Avg. per-sample expected Loss: 0.15043
# Batch count: 131, Avg. per-sample expected Loss: 0.16552
# Batch count: 132, Avg. per-sample expected Loss: 0.16516
# Batch count: 133, Avg. per-sample expected Loss: 0.15980
# Batch count: 134, Avg. per-sample expected Loss: 0.15011
# Batch count: 135, Avg. per-sample expected Loss: 0.16259
# Batch count: 136, Avg. per-sample expected Loss: 0.15490
# Batch count: 137, Avg. per-sample expected Loss: 0.15576
# Batch count: 138, Avg. per-sample expected Loss: 0.17494
# Batch count: 139, Avg. per-sample expected Loss: 0.16384
# Batch count: 140, Avg. per-sample expected Loss: 0.16355
# Batch count: 141, Avg. per-sample expected Loss: 0.17441
# Batch count: 142, Avg. per-sample expected Loss: 0.15073
# Batch count: 143, Avg. per-sample expected Loss: 0.15552
# Batch count: 144, Avg. per-sample expected Loss: 0.15417
# Batch count: 145, Avg. per-sample expected Loss: 0.16669
# Batch count: 146, Avg. per-sample expected Loss: 0.15580
# Batch count: 147, Avg. per-sample expected Loss: 0.16291
# Batch count: 148, Avg. per-sample expected Loss: 0.16884
# Batch count: 149, Avg. per-sample expected Loss: 0.16587
# Batch count: 150, Avg. per-sample expected Loss: 0.16303
# Batch count: 151, Avg. per-sample expected Loss: 0.17090
# Batch count: 152, Avg. per-sample expected Loss: 0.17013
# Batch count: 153, Avg. per-sample expected Loss: 0.16935
# Batch count: 154, Avg. per-sample expected Loss: 0.16947
# Batch count: 155, Avg. per-sample expected Loss: 0.17533
# Batch count: 156, Avg. per-sample expected Loss: 0.15998
# Batch count: 157, Avg. per-sample expected Loss: 0.16305
# Batch count: 158, Avg. per-sample expected Loss: 0.16724
# Batch count: 159, Avg. per-sample expected Loss: 0.17072
# Batch count: 160, Avg. per-sample expected Loss: 0.15731
# Batch count: 161, Avg. per-sample expected Loss: 0.16885
# Batch count: 162, Avg. per-sample expected Loss: 0.16489
# Batch count: 163, Avg. per-sample expected Loss: 0.15264
# Batch count: 164, Avg. per-sample expected Loss: 0.15188
# Batch count: 165, Avg. per-sample expected Loss: 0.13551
# Batch count: 166, Avg. per-sample expected Loss: 0.15084
# Batch count: 167, Avg. per-sample expected Loss: 0.15134
# Batch count: 168, Avg. per-sample expected Loss: 0.13851
# Batch count: 169, Avg. per-sample expected Loss: 0.14198
# Batch count: 170, Avg. per-sample expected Loss: 0.15372
# Batch count: 171, Avg. per-sample expected Loss: 0.15462
# Batch count: 172, Avg. per-sample expected Loss: 0.16322
# Batch count: 173, Avg. per-sample expected Loss: 0.14907
# Batch count: 174, Avg. per-sample expected Loss: 0.15125
# Batch count: 175, Avg. per-sample expected Loss: 0.16834
# Batch count: 176, Avg. per-sample expected Loss: 0.15755
# Batch count: 177, Avg. per-sample expected Loss: 0.15774
# Batch count: 178, Avg. per-sample expected Loss: 0.16248
# Batch count: 179, Avg. per-sample expected Loss: 0.17131
# Batch count: 180, Avg. per-sample expected Loss: 0.15816
# Batch count: 181, Avg. per-sample expected Loss: 0.16846
# Batch count: 182, Avg. per-sample expected Loss: 0.15629
# Batch count: 183, Avg. per-sample expected Loss: 0.15972
# Batch count: 184, Avg. per-sample expected Loss: 0.14822
# Batch count: 185, Avg. per-sample expected Loss: 0.13996
# Batch count: 186, Avg. per-sample expected Loss: 0.15283
# Batch count: 187, Avg. per-sample expected Loss: 0.15727
# Batch count: 188, Avg. per-sample expected Loss: 0.14055
# Batch count: 189, Avg. per-sample expected Loss: 0.13590
# Batch count: 190, Avg. per-sample expected Loss: 0.15033
# Batch count: 191, Avg. per-sample expected Loss: 0.14421
# Batch count: 192, Avg. per-sample expected Loss: 0.15857
# Batch count: 193, Avg. per-sample expected Loss: 0.15061
# Batch count: 194, Avg. per-sample expected Loss: 0.15875
# Batch count: 195, Avg. per-sample expected Loss: 0.15280
# Batch count: 196, Avg. per-sample expected Loss: 0.15739
# Batch count: 197, Avg. per-sample expected Loss: 0.15411
# Batch count: 198, Avg. per-sample expected Loss: 0.15171
# Batch count: 199, Avg. per-sample expected Loss: 0.16565
# Batch count: 200, Avg. per-sample expected Loss: 0.15574
# Batch count: 201, Avg. per-sample expected Loss: 0.16824
# Batch count: 202, Avg. per-sample expected Loss: 0.15560
# Batch count: 203, Avg. per-sample expected Loss: 0.16559
# Batch count: 204, Avg. per-sample expected Loss: 0.17065
# Batch count: 205, Avg. per-sample expected Loss: 0.16161
# Batch count: 206, Avg. per-sample expected Loss: 0.17234
# Batch count: 207, Avg. per-sample expected Loss: 0.18121
# Batch count: 208, Avg. per-sample expected Loss: 0.16752
# Batch count: 209, Avg. per-sample expected Loss: 0.15827
# Batch count: 210, Avg. per-sample expected Loss: 0.16282
# Batch count: 211, Avg. per-sample expected Loss: 0.15979
# Batch count: 212, Avg. per-sample expected Loss: 0.17504
# Batch count: 213, Avg. per-sample expected Loss: 0.14690
# Batch count: 214, Avg. per-sample expected Loss: 0.14382
# Batch count: 215, Avg. per-sample expected Loss: 0.14913
# Batch count: 216, Avg. per-sample expected Loss: 0.15065
# Batch count: 217, Avg. per-sample expected Loss: 0.15147
# Batch count: 218, Avg. per-sample expected Loss: 0.15894
# Batch count: 219, Avg. per-sample expected Loss: 0.15084
# Batch count: 220, Avg. per-sample expected Loss: 0.14954
# Batch count: 221, Avg. per-sample expected Loss: 0.14767
# Batch count: 222, Avg. per-sample expected Loss: 0.14384
# Batch count: 223, Avg. per-sample expected Loss: 0.15251
# Batch count: 224, Avg. per-sample expected Loss: 0.14265
# Batch count: 225, Avg. per-sample expected Loss: 0.14500
# Batch count: 226, Avg. per-sample expected Loss: 0.15266
# Batch count: 227, Avg. per-sample expected Loss: 0.14842
# Batch count: 228, Avg. per-sample expected Loss: 0.16371
# Batch count: 229, Avg. per-sample expected Loss: 0.15849
# Batch count: 230, Avg. per-sample expected Loss: 0.13999
# Batch count: 231, Avg. per-sample expected Loss: 0.15267
# Batch count: 232, Avg. per-sample expected Loss: 0.14450
# Batch count: 233, Avg. per-sample expected Loss: 0.15768
# Batch count: 234, Avg. per-sample expected Loss: 0.15955
# Batch count: 235, Avg. per-sample expected Loss: 0.15149
# Batch count: 236, Avg. per-sample expected Loss: 0.15515
# Batch count: 237, Avg. per-sample expected Loss: 0.15540
# Batch count: 238, Avg. per-sample expected Loss: 0.14156
# Batch count: 239, Avg. per-sample expected Loss: 0.15507
# Batch count: 240, Avg. per-sample expected Loss: 0.15395
# Batch count: 241, Avg. per-sample expected Loss: 0.14864
# Batch count: 242, Avg. per-sample expected Loss: 0.15270
# Batch count: 243, Avg. per-sample expected Loss: 0.15410
# Batch count: 244, Avg. per-sample expected Loss: 0.14550
# Batch count: 245, Avg. per-sample expected Loss: 0.13129
# Batch count: 246, Avg. per-sample expected Loss: 0.14581
# Batch count: 247, Avg. per-sample expected Loss: 0.14602
# Batch count: 248, Avg. per-sample expected Loss: 0.14025
# Batch count: 249, Avg. per-sample expected Loss: 0.16187
# Batch count: 250, Avg. per-sample expected Loss: 0.15194
# Batch count: 251, Avg. per-sample expected Loss: 0.14873
# Batch count: 252, Avg. per-sample expected Loss: 0.15414
# Batch count: 253, Avg. per-sample expected Loss: 0.14032
# Batch count: 254, Avg. per-sample expected Loss: 0.15679
# Batch count: 255, Avg. per-sample expected Loss: 0.14330
# Batch count: 256, Avg. per-sample expected Loss: 0.15321
# Batch count: 257, Avg. per-sample expected Loss: 0.15249
# Batch count: 258, Avg. per-sample expected Loss: 0.15806
# Batch count: 259, Avg. per-sample expected Loss: 0.14712
# Batch count: 260, Avg. per-sample expected Loss: 0.15376
# Batch count: 261, Avg. per-sample expected Loss: 0.14265
# Batch count: 262, Avg. per-sample expected Loss: 0.14968
# Batch count: 263, Avg. per-sample expected Loss: 0.15065
# Batch count: 264, Avg. per-sample expected Loss: 0.14493
# Batch count: 265, Avg. per-sample expected Loss: 0.15383
# Batch count: 266, Avg. per-sample expected Loss: 0.15078
# Batch count: 267, Avg. per-sample expected Loss: 0.16227
# Batch count: 268, Avg. per-sample expected Loss: 0.15858
# Batch count: 269, Avg. per-sample expected Loss: 0.15468
# Batch count: 270, Avg. per-sample expected Loss: 0.15855
# Batch count: 271, Avg. per-sample expected Loss: 0.15929
# Batch count: 272, Avg. per-sample expected Loss: 0.15017
# Batch count: 273, Avg. per-sample expected Loss: 0.15764
# Batch count: 274, Avg. per-sample expected Loss: 0.14653
# Batch count: 275, Avg. per-sample expected Loss: 0.15914
# Batch count: 276, Avg. per-sample expected Loss: 0.15807
# Batch count: 277, Avg. per-sample expected Loss: 0.15696
# Batch count: 278, Avg. per-sample expected Loss: 0.15483
# Batch count: 279, Avg. per-sample expected Loss: 0.14730
# Batch count: 280, Avg. per-sample expected Loss: 0.15157
# Batch count: 281, Avg. per-sample expected Loss: 0.16435
# Batch count: 282, Avg. per-sample expected Loss: 0.15177
# Batch count: 283, Avg. per-sample expected Loss: 0.15172
# Batch count: 284, Avg. per-sample expected Loss: 0.15708
# Batch count: 285, Avg. per-sample expected Loss: 0.15149
# Batch count: 286, Avg. per-sample expected Loss: 0.15101
# Batch count: 287, Avg. per-sample expected Loss: 0.14807
# Batch count: 288, Avg. per-sample expected Loss: 0.14470
# Batch count: 289, Avg. per-sample expected Loss: 0.14378
# Batch count: 290, Avg. per-sample expected Loss: 0.14057
# Batch count: 291, Avg. per-sample expected Loss: 0.15363
# Batch count: 292, Avg. per-sample expected Loss: 0.14945
# Batch count: 293, Avg. per-sample expected Loss: 0.14484
# Batch count: 294, Avg. per-sample expected Loss: 0.16719
# Batch count: 295, Avg. per-sample expected Loss: 0.15661
# Batch count: 296, Avg. per-sample expected Loss: 0.15116
# Batch count: 297, Avg. per-sample expected Loss: 0.15517
# Batch count: 298, Avg. per-sample expected Loss: 0.14648
# Batch count: 299, Avg. per-sample expected Loss: 0.15850
# Batch count: 300, Avg. per-sample expected Loss: 0.15124
# Batch count: 301, Avg. per-sample expected Loss: 0.15638
# Batch count: 302, Avg. per-sample expected Loss: 0.15137
# Batch count: 303, Avg. per-sample expected Loss: 0.14040
# Batch count: 304, Avg. per-sample expected Loss: 0.15635
# Batch count: 305, Avg. per-sample expected Loss: 0.13390
# Batch count: 306, Avg. per-sample expected Loss: 0.15285
# Batch count: 307, Avg. per-sample expected Loss: 0.14855
# Batch count: 308, Avg. per-sample expected Loss: 0.15203
# Batch count: 309, Avg. per-sample expected Loss: 0.13849
# Batch count: 310, Avg. per-sample expected Loss: 0.14934
# Batch count: 311, Avg. per-sample expected Loss: 0.13807
# Batch count: 312, Avg. per-sample expected Loss: 0.14322
# Batch count: 313, Avg. per-sample expected Loss: 0.16513
# Batch count: 314, Avg. per-sample expected Loss: 0.14395
# Batch count: 315, Avg. per-sample expected Loss: 0.14164
# Batch count: 316, Avg. per-sample expected Loss: 0.14940
# Batch count: 317, Avg. per-sample expected Loss: 0.15272
# Batch count: 318, Avg. per-sample expected Loss: 0.14161
# Batch count: 319, Avg. per-sample expected Loss: 0.14995
# Batch count: 320, Avg. per-sample expected Loss: 0.15056
# Batch count: 321, Avg. per-sample expected Loss: 0.14816
# Batch count: 322, Avg. per-sample expected Loss: 0.14469
# Batch count: 323, Avg. per-sample expected Loss: 0.14995
# Batch count: 324, Avg. per-sample expected Loss: 0.15481
# Batch count: 325, Avg. per-sample expected Loss: 0.15767
# Batch count: 326, Avg. per-sample expected Loss: 0.14795
# Batch count: 327, Avg. per-sample expected Loss: 0.14253
# Batch count: 328, Avg. per-sample expected Loss: 0.15484
# Batch count: 329, Avg. per-sample expected Loss: 0.15161
# Batch count: 330, Avg. per-sample expected Loss: 0.14689
# Batch count: 331, Avg. per-sample expected Loss: 0.14653
# Batch count: 332, Avg. per-sample expected Loss: 0.14538
# Batch count: 333, Avg. per-sample expected Loss: 0.14796
# Batch count: 334, Avg. per-sample expected Loss: 0.16002
# Batch count: 335, Avg. per-sample expected Loss: 0.16384
# Batch count: 336, Avg. per-sample expected Loss: 0.14932
# Batch count: 337, Avg. per-sample expected Loss: 0.14554
# Batch count: 338, Avg. per-sample expected Loss: 0.14366
# Batch count: 339, Avg. per-sample expected Loss: 0.15163
# Batch count: 340, Avg. per-sample expected Loss: 0.15696
# Batch count: 341, Avg. per-sample expected Loss: 0.13743
# Batch count: 342, Avg. per-sample expected Loss: 0.15040
# Batch count: 343, Avg. per-sample expected Loss: 0.15084
# Batch count: 344, Avg. per-sample expected Loss: 0.14761
# Batch count: 345, Avg. per-sample expected Loss: 0.15094
# Batch count: 346, Avg. per-sample expected Loss: 0.15661
# Batch count: 347, Avg. per-sample expected Loss: 0.15819
# Batch count: 348, Avg. per-sample expected Loss: 0.15583
# Batch count: 349, Avg. per-sample expected Loss: 0.14692

# %% [markdown]
# ## Plots

# %%
plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "b", label="2-QNSCD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.", label="2-QNSCD Empirical Loss")

plt.title("Training using 2-QNSCD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.show()

# %% [markdown]
# ## 6-RQSGD using 600 samples per step

# %%
SGD6cparams = np.array(init_params)
SGD6c_cost = []
SGD6c_Ecost = []

SGD6c_cost.append(temp_cost)
SGD6c_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 6 coordinates
        idx = sorted(np.random.permutation(nparams)[0:6].tolist())
        
        grad = []
        
        ### Gradient estimation
        for i_grad in range(6):
            y_hat,b = EstGrad(SGD6cparams,phiT[:,itr3+i_grad],idx[i_grad])
            b = (1-b)/2
            grad.append((-1)*((-1)**b)*loss(y_hat,labelT[itr3+i_grad]))

        ### single-parameter update
        SGD6cparams[idx] = SGD6cparams[idx] - np.dot(step_size,grad)
    
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6cparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6c_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6ccount = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6cparams,phiT[:,itr]) != labelT[itr]:
            SGD6ccount += 1
    SGD6c_Ecost.append(SGD6ccount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "5Q 6-RQSGD Expected Loss"
file_name2 = "5Q 6-RQSGD Empirical Loss"

np.save(file_name1,SGD6c_cost)
np.save(file_name2,SGD6c_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.53246
# Batch count:  1, Avg. per-sample expected Loss: 0.51286
# Batch count:  2, Avg. per-sample expected Loss: 0.52131
# Batch count:  3, Avg. per-sample expected Loss: 0.51416
# Batch count:  4, Avg. per-sample expected Loss: 0.51788
# Batch count:  5, Avg. per-sample expected Loss: 0.50132
# Batch count:  6, Avg. per-sample expected Loss: 0.48894
# Batch count:  7, Avg. per-sample expected Loss: 0.49332
# Batch count:  8, Avg. per-sample expected Loss: 0.49432
# Batch count:  9, Avg. per-sample expected Loss: 0.47761
# Batch count: 10, Avg. per-sample expected Loss: 0.47278
# Batch count: 11, Avg. per-sample expected Loss: 0.45672
# Batch count: 12, Avg. per-sample expected Loss: 0.43179
# Batch count: 13, Avg. per-sample expected Loss: 0.43950
# Batch count: 14, Avg. per-sample expected Loss: 0.41792
# Batch count: 15, Avg. per-sample expected Loss: 0.43265
# Batch count: 16, Avg. per-sample expected Loss: 0.42353
# Batch count: 17, Avg. per-sample expected Loss: 0.40369
# Batch count: 18, Avg. per-sample expected Loss: 0.38960
# Batch count: 19, Avg. per-sample expected Loss: 0.37176
# Batch count: 20, Avg. per-sample expected Loss: 0.39185
# Batch count: 21, Avg. per-sample expected Loss: 0.40191
# Batch count: 22, Avg. per-sample expected Loss: 0.38128
# Batch count: 23, Avg. per-sample expected Loss: 0.37865
# Batch count: 24, Avg. per-sample expected Loss: 0.37708
# Batch count: 25, Avg. per-sample expected Loss: 0.37443
# Batch count: 26, Avg. per-sample expected Loss: 0.37044
# Batch count: 27, Avg. per-sample expected Loss: 0.33314
# Batch count: 28, Avg. per-sample expected Loss: 0.32689
# Batch count: 29, Avg. per-sample expected Loss: 0.36206
# Batch count: 30, Avg. per-sample expected Loss: 0.34431
# Batch count: 31, Avg. per-sample expected Loss: 0.32285
# Batch count: 32, Avg. per-sample expected Loss: 0.34182
# Batch count: 33, Avg. per-sample expected Loss: 0.32995
# Batch count: 34, Avg. per-sample expected Loss: 0.31009
# Batch count: 35, Avg. per-sample expected Loss: 0.30397
# Batch count: 36, Avg. per-sample expected Loss: 0.30563
# Batch count: 37, Avg. per-sample expected Loss: 0.29116
# Batch count: 38, Avg. per-sample expected Loss: 0.29380
# Batch count: 39, Avg. per-sample expected Loss: 0.26492
# Batch count: 40, Avg. per-sample expected Loss: 0.27359
# Batch count: 41, Avg. per-sample expected Loss: 0.26933
# Batch count: 42, Avg. per-sample expected Loss: 0.27295
# Batch count: 43, Avg. per-sample expected Loss: 0.26477
# Batch count: 44, Avg. per-sample expected Loss: 0.27662
# Batch count: 45, Avg. per-sample expected Loss: 0.26258
# Batch count: 46, Avg. per-sample expected Loss: 0.24113
# Batch count: 47, Avg. per-sample expected Loss: 0.23850
# Batch count: 48, Avg. per-sample expected Loss: 0.22915
# Batch count: 49, Avg. per-sample expected Loss: 0.24522
# Batch count: 50, Avg. per-sample expected Loss: 0.22944
# Batch count: 51, Avg. per-sample expected Loss: 0.21798
# Batch count: 52, Avg. per-sample expected Loss: 0.23136
# Batch count: 53, Avg. per-sample expected Loss: 0.23389
# Batch count: 54, Avg. per-sample expected Loss: 0.21574
# Batch count: 55, Avg. per-sample expected Loss: 0.22804
# Batch count: 56, Avg. per-sample expected Loss: 0.22414
# Batch count: 57, Avg. per-sample expected Loss: 0.22400
# Batch count: 58, Avg. per-sample expected Loss: 0.19803
# Batch count: 59, Avg. per-sample expected Loss: 0.21766
# Batch count: 60, Avg. per-sample expected Loss: 0.19963
# Batch count: 61, Avg. per-sample expected Loss: 0.19853
# Batch count: 62, Avg. per-sample expected Loss: 0.20359
# Batch count: 63, Avg. per-sample expected Loss: 0.20248
# Batch count: 64, Avg. per-sample expected Loss: 0.19978
# Batch count: 65, Avg. per-sample expected Loss: 0.21593
# Batch count: 66, Avg. per-sample expected Loss: 0.20647
# Batch count: 67, Avg. per-sample expected Loss: 0.19415
# Batch count: 68, Avg. per-sample expected Loss: 0.19422
# Batch count: 69, Avg. per-sample expected Loss: 0.19396
# Batch count: 70, Avg. per-sample expected Loss: 0.18946
# Batch count: 71, Avg. per-sample expected Loss: 0.19715
# Batch count: 72, Avg. per-sample expected Loss: 0.18880
# Batch count: 73, Avg. per-sample expected Loss: 0.19279
# Batch count: 74, Avg. per-sample expected Loss: 0.18199
# Batch count: 75, Avg. per-sample expected Loss: 0.18945
# Batch count: 76, Avg. per-sample expected Loss: 0.19329
# Batch count: 77, Avg. per-sample expected Loss: 0.17497
# Batch count: 78, Avg. per-sample expected Loss: 0.18958
# Batch count: 79, Avg. per-sample expected Loss: 0.17073
# Batch count: 80, Avg. per-sample expected Loss: 0.17795
# Batch count: 81, Avg. per-sample expected Loss: 0.18079
# Batch count: 82, Avg. per-sample expected Loss: 0.18331
# Batch count: 83, Avg. per-sample expected Loss: 0.17812
# Batch count: 84, Avg. per-sample expected Loss: 0.17877
# Batch count: 85, Avg. per-sample expected Loss: 0.17859
# Batch count: 86, Avg. per-sample expected Loss: 0.17798
# Batch count: 87, Avg. per-sample expected Loss: 0.19185
# Batch count: 88, Avg. per-sample expected Loss: 0.17669
# Batch count: 89, Avg. per-sample expected Loss: 0.17823
# Batch count: 90, Avg. per-sample expected Loss: 0.18107
# Batch count: 91, Avg. per-sample expected Loss: 0.17243
# Batch count: 92, Avg. per-sample expected Loss: 0.16869
# Batch count: 93, Avg. per-sample expected Loss: 0.17403
# Batch count: 94, Avg. per-sample expected Loss: 0.15366
# Batch count: 95, Avg. per-sample expected Loss: 0.16742
# Batch count: 96, Avg. per-sample expected Loss: 0.17950
# Batch count: 97, Avg. per-sample expected Loss: 0.16726
# Batch count: 98, Avg. per-sample expected Loss: 0.16456
# Batch count: 99, Avg. per-sample expected Loss: 0.17789
# Batch count: 100, Avg. per-sample expected Loss: 0.16259
# Batch count: 101, Avg. per-sample expected Loss: 0.16938
# Batch count: 102, Avg. per-sample expected Loss: 0.16439
# Batch count: 103, Avg. per-sample expected Loss: 0.17187
# Batch count: 104, Avg. per-sample expected Loss: 0.16282
# Batch count: 105, Avg. per-sample expected Loss: 0.17591
# Batch count: 106, Avg. per-sample expected Loss: 0.16348
# Batch count: 107, Avg. per-sample expected Loss: 0.16889
# Batch count: 108, Avg. per-sample expected Loss: 0.18274
# Batch count: 109, Avg. per-sample expected Loss: 0.16159
# Batch count: 110, Avg. per-sample expected Loss: 0.16307
# Batch count: 111, Avg. per-sample expected Loss: 0.17128
# Batch count: 112, Avg. per-sample expected Loss: 0.15989
# Batch count: 113, Avg. per-sample expected Loss: 0.16210
# Batch count: 114, Avg. per-sample expected Loss: 0.15766
# Batch count: 115, Avg. per-sample expected Loss: 0.16780
# Batch count: 116, Avg. per-sample expected Loss: 0.16594
# Batch count: 117, Avg. per-sample expected Loss: 0.16543
# Batch count: 118, Avg. per-sample expected Loss: 0.16075
# Batch count: 119, Avg. per-sample expected Loss: 0.16249
# Batch count: 120, Avg. per-sample expected Loss: 0.15369
# Batch count: 121, Avg. per-sample expected Loss: 0.16287
# Batch count: 122, Avg. per-sample expected Loss: 0.16268
# Batch count: 123, Avg. per-sample expected Loss: 0.16974
# Batch count: 124, Avg. per-sample expected Loss: 0.15710
# Batch count: 125, Avg. per-sample expected Loss: 0.15705
# Batch count: 126, Avg. per-sample expected Loss: 0.14915
# Batch count: 127, Avg. per-sample expected Loss: 0.15072
# Batch count: 128, Avg. per-sample expected Loss: 0.16240
# Batch count: 129, Avg. per-sample expected Loss: 0.15797
# Batch count: 130, Avg. per-sample expected Loss: 0.15284
# Batch count: 131, Avg. per-sample expected Loss: 0.16757
# Batch count: 132, Avg. per-sample expected Loss: 0.16405
# Batch count: 133, Avg. per-sample expected Loss: 0.15843
# Batch count: 134, Avg. per-sample expected Loss: 0.14793
# Batch count: 135, Avg. per-sample expected Loss: 0.16320
# Batch count: 136, Avg. per-sample expected Loss: 0.15353
# Batch count: 137, Avg. per-sample expected Loss: 0.15479
# Batch count: 138, Avg. per-sample expected Loss: 0.17800
# Batch count: 139, Avg. per-sample expected Loss: 0.15292
# Batch count: 140, Avg. per-sample expected Loss: 0.15400
# Batch count: 141, Avg. per-sample expected Loss: 0.16654
# Batch count: 142, Avg. per-sample expected Loss: 0.14750
# Batch count: 143, Avg. per-sample expected Loss: 0.15320
# Batch count: 144, Avg. per-sample expected Loss: 0.14686
# Batch count: 145, Avg. per-sample expected Loss: 0.16014
# Batch count: 146, Avg. per-sample expected Loss: 0.15028
# Batch count: 147, Avg. per-sample expected Loss: 0.16092
# Batch count: 148, Avg. per-sample expected Loss: 0.16898
# Batch count: 149, Avg. per-sample expected Loss: 0.16666
# Batch count: 150, Avg. per-sample expected Loss: 0.16274
# Batch count: 151, Avg. per-sample expected Loss: 0.16991
# Batch count: 152, Avg. per-sample expected Loss: 0.16703
# Batch count: 153, Avg. per-sample expected Loss: 0.16466
# Batch count: 154, Avg. per-sample expected Loss: 0.16404
# Batch count: 155, Avg. per-sample expected Loss: 0.16137
# Batch count: 156, Avg. per-sample expected Loss: 0.14457
# Batch count: 157, Avg. per-sample expected Loss: 0.15248
# Batch count: 158, Avg. per-sample expected Loss: 0.16146
# Batch count: 159, Avg. per-sample expected Loss: 0.16699
# Batch count: 160, Avg. per-sample expected Loss: 0.15872
# Batch count: 161, Avg. per-sample expected Loss: 0.17082
# Batch count: 162, Avg. per-sample expected Loss: 0.16726
# Batch count: 163, Avg. per-sample expected Loss: 0.15212
# Batch count: 164, Avg. per-sample expected Loss: 0.15127
# Batch count: 165, Avg. per-sample expected Loss: 0.13239
# Batch count: 166, Avg. per-sample expected Loss: 0.15105
# Batch count: 167, Avg. per-sample expected Loss: 0.14990
# Batch count: 168, Avg. per-sample expected Loss: 0.14119
# Batch count: 169, Avg. per-sample expected Loss: 0.14582
# Batch count: 170, Avg. per-sample expected Loss: 0.15592
# Batch count: 171, Avg. per-sample expected Loss: 0.15792
# Batch count: 172, Avg. per-sample expected Loss: 0.16315
# Batch count: 173, Avg. per-sample expected Loss: 0.14980
# Batch count: 174, Avg. per-sample expected Loss: 0.15081
# Batch count: 175, Avg. per-sample expected Loss: 0.16878
# Batch count: 176, Avg. per-sample expected Loss: 0.15751
# Batch count: 177, Avg. per-sample expected Loss: 0.15558
# Batch count: 178, Avg. per-sample expected Loss: 0.16097
# Batch count: 179, Avg. per-sample expected Loss: 0.16345
# Batch count: 180, Avg. per-sample expected Loss: 0.15604
# Batch count: 181, Avg. per-sample expected Loss: 0.16609
# Batch count: 182, Avg. per-sample expected Loss: 0.15365
# Batch count: 183, Avg. per-sample expected Loss: 0.15927
# Batch count: 184, Avg. per-sample expected Loss: 0.15217
# Batch count: 185, Avg. per-sample expected Loss: 0.14550
# Batch count: 186, Avg. per-sample expected Loss: 0.15171
# Batch count: 187, Avg. per-sample expected Loss: 0.15905
# Batch count: 188, Avg. per-sample expected Loss: 0.14413
# Batch count: 189, Avg. per-sample expected Loss: 0.14292
# Batch count: 190, Avg. per-sample expected Loss: 0.15252
# Batch count: 191, Avg. per-sample expected Loss: 0.14258
# Batch count: 192, Avg. per-sample expected Loss: 0.16070
# Batch count: 193, Avg. per-sample expected Loss: 0.14993
# Batch count: 194, Avg. per-sample expected Loss: 0.15660
# Batch count: 195, Avg. per-sample expected Loss: 0.15295
# Batch count: 196, Avg. per-sample expected Loss: 0.15601
# Batch count: 197, Avg. per-sample expected Loss: 0.15044
# Batch count: 198, Avg. per-sample expected Loss: 0.14860
# Batch count: 199, Avg. per-sample expected Loss: 0.16039
# Batch count: 200, Avg. per-sample expected Loss: 0.14394
# Batch count: 201, Avg. per-sample expected Loss: 0.15643
# Batch count: 202, Avg. per-sample expected Loss: 0.14273
# Batch count: 203, Avg. per-sample expected Loss: 0.15310
# Batch count: 204, Avg. per-sample expected Loss: 0.15618
# Batch count: 205, Avg. per-sample expected Loss: 0.14870
# Batch count: 206, Avg. per-sample expected Loss: 0.16103
# Batch count: 207, Avg. per-sample expected Loss: 0.16997
# Batch count: 208, Avg. per-sample expected Loss: 0.15797
# Batch count: 209, Avg. per-sample expected Loss: 0.15258
# Batch count: 210, Avg. per-sample expected Loss: 0.15776
# Batch count: 211, Avg. per-sample expected Loss: 0.15217
# Batch count: 212, Avg. per-sample expected Loss: 0.16517
# Batch count: 213, Avg. per-sample expected Loss: 0.14808
# Batch count: 214, Avg. per-sample expected Loss: 0.14512
# Batch count: 215, Avg. per-sample expected Loss: 0.15082
# Batch count: 216, Avg. per-sample expected Loss: 0.15108
# Batch count: 217, Avg. per-sample expected Loss: 0.15318
# Batch count: 218, Avg. per-sample expected Loss: 0.15927
# Batch count: 219, Avg. per-sample expected Loss: 0.15197
# Batch count: 220, Avg. per-sample expected Loss: 0.15180
# Batch count: 221, Avg. per-sample expected Loss: 0.14896
# Batch count: 222, Avg. per-sample expected Loss: 0.14588
# Batch count: 223, Avg. per-sample expected Loss: 0.15679
# Batch count: 224, Avg. per-sample expected Loss: 0.14645
# Batch count: 225, Avg. per-sample expected Loss: 0.14693
# Batch count: 226, Avg. per-sample expected Loss: 0.15491
# Batch count: 227, Avg. per-sample expected Loss: 0.14726
# Batch count: 228, Avg. per-sample expected Loss: 0.16183
# Batch count: 229, Avg. per-sample expected Loss: 0.15529
# Batch count: 230, Avg. per-sample expected Loss: 0.13507
# Batch count: 231, Avg. per-sample expected Loss: 0.15373
# Batch count: 232, Avg. per-sample expected Loss: 0.14345
# Batch count: 233, Avg. per-sample expected Loss: 0.15674
# Batch count: 234, Avg. per-sample expected Loss: 0.16008
# Batch count: 235, Avg. per-sample expected Loss: 0.15362
# Batch count: 236, Avg. per-sample expected Loss: 0.15756
# Batch count: 237, Avg. per-sample expected Loss: 0.15756
# Batch count: 238, Avg. per-sample expected Loss: 0.14476
# Batch count: 239, Avg. per-sample expected Loss: 0.15717
# Batch count: 240, Avg. per-sample expected Loss: 0.15474
# Batch count: 241, Avg. per-sample expected Loss: 0.14958
# Batch count: 242, Avg. per-sample expected Loss: 0.15442
# Batch count: 243, Avg. per-sample expected Loss: 0.15763
# Batch count: 244, Avg. per-sample expected Loss: 0.14938
# Batch count: 245, Avg. per-sample expected Loss: 0.13430
# Batch count: 246, Avg. per-sample expected Loss: 0.14871
# Batch count: 247, Avg. per-sample expected Loss: 0.14988
# Batch count: 248, Avg. per-sample expected Loss: 0.14265
# Batch count: 249, Avg. per-sample expected Loss: 0.16746
# Batch count: 250, Avg. per-sample expected Loss: 0.15623
# Batch count: 251, Avg. per-sample expected Loss: 0.15235
# Batch count: 252, Avg. per-sample expected Loss: 0.15727
# Batch count: 253, Avg. per-sample expected Loss: 0.14225
# Batch count: 254, Avg. per-sample expected Loss: 0.15911
# Batch count: 255, Avg. per-sample expected Loss: 0.14493
# Batch count: 256, Avg. per-sample expected Loss: 0.15482
# Batch count: 257, Avg. per-sample expected Loss: 0.15357
# Batch count: 258, Avg. per-sample expected Loss: 0.15970
# Batch count: 259, Avg. per-sample expected Loss: 0.14766
# Batch count: 260, Avg. per-sample expected Loss: 0.15512
# Batch count: 261, Avg. per-sample expected Loss: 0.14404
# Batch count: 262, Avg. per-sample expected Loss: 0.14976
# Batch count: 263, Avg. per-sample expected Loss: 0.14997
# Batch count: 264, Avg. per-sample expected Loss: 0.14501
# Batch count: 265, Avg. per-sample expected Loss: 0.15083
# Batch count: 266, Avg. per-sample expected Loss: 0.14844
# Batch count: 267, Avg. per-sample expected Loss: 0.16084
# Batch count: 268, Avg. per-sample expected Loss: 0.15679
# Batch count: 269, Avg. per-sample expected Loss: 0.15335
# Batch count: 270, Avg. per-sample expected Loss: 0.15809
# Batch count: 271, Avg. per-sample expected Loss: 0.15578
# Batch count: 272, Avg. per-sample expected Loss: 0.14675
# Batch count: 273, Avg. per-sample expected Loss: 0.15248
# Batch count: 274, Avg. per-sample expected Loss: 0.14421
# Batch count: 275, Avg. per-sample expected Loss: 0.15547
# Batch count: 276, Avg. per-sample expected Loss: 0.15367
# Batch count: 277, Avg. per-sample expected Loss: 0.15316
# Batch count: 278, Avg. per-sample expected Loss: 0.15461
# Batch count: 279, Avg. per-sample expected Loss: 0.14645
# Batch count: 280, Avg. per-sample expected Loss: 0.15108
# Batch count: 281, Avg. per-sample expected Loss: 0.16337
# Batch count: 282, Avg. per-sample expected Loss: 0.14746
# Batch count: 283, Avg. per-sample expected Loss: 0.14411
# Batch count: 284, Avg. per-sample expected Loss: 0.15285
# Batch count: 285, Avg. per-sample expected Loss: 0.14432
# Batch count: 286, Avg. per-sample expected Loss: 0.14358
# Batch count: 287, Avg. per-sample expected Loss: 0.14138
# Batch count: 288, Avg. per-sample expected Loss: 0.14380
# Batch count: 289, Avg. per-sample expected Loss: 0.14406
# Batch count: 290, Avg. per-sample expected Loss: 0.13900
# Batch count: 291, Avg. per-sample expected Loss: 0.15301
# Batch count: 292, Avg. per-sample expected Loss: 0.14926
# Batch count: 293, Avg. per-sample expected Loss: 0.14408
# Batch count: 294, Avg. per-sample expected Loss: 0.16587
# Batch count: 295, Avg. per-sample expected Loss: 0.15507
# Batch count: 296, Avg. per-sample expected Loss: 0.14601
# Batch count: 297, Avg. per-sample expected Loss: 0.15225
# Batch count: 298, Avg. per-sample expected Loss: 0.14057
# Batch count: 299, Avg. per-sample expected Loss: 0.15269
# Batch count: 300, Avg. per-sample expected Loss: 0.14614
# Batch count: 301, Avg. per-sample expected Loss: 0.15618
# Batch count: 302, Avg. per-sample expected Loss: 0.14900
# Batch count: 303, Avg. per-sample expected Loss: 0.13842
# Batch count: 304, Avg. per-sample expected Loss: 0.15395
# Batch count: 305, Avg. per-sample expected Loss: 0.13357
# Batch count: 306, Avg. per-sample expected Loss: 0.15024
# Batch count: 307, Avg. per-sample expected Loss: 0.14506
# Batch count: 308, Avg. per-sample expected Loss: 0.14991
# Batch count: 309, Avg. per-sample expected Loss: 0.13818
# Batch count: 310, Avg. per-sample expected Loss: 0.14903
# Batch count: 311, Avg. per-sample expected Loss: 0.13786
# Batch count: 312, Avg. per-sample expected Loss: 0.14434
# Batch count: 313, Avg. per-sample expected Loss: 0.16429
# Batch count: 314, Avg. per-sample expected Loss: 0.14312
# Batch count: 315, Avg. per-sample expected Loss: 0.14160
# Batch count: 316, Avg. per-sample expected Loss: 0.14869
# Batch count: 317, Avg. per-sample expected Loss: 0.15327
# Batch count: 318, Avg. per-sample expected Loss: 0.14209
# Batch count: 319, Avg. per-sample expected Loss: 0.14969
# Batch count: 320, Avg. per-sample expected Loss: 0.15094
# Batch count: 321, Avg. per-sample expected Loss: 0.14649
# Batch count: 322, Avg. per-sample expected Loss: 0.14464
# Batch count: 323, Avg. per-sample expected Loss: 0.14772
# Batch count: 324, Avg. per-sample expected Loss: 0.15365
# Batch count: 325, Avg. per-sample expected Loss: 0.15591
# Batch count: 326, Avg. per-sample expected Loss: 0.14661
# Batch count: 327, Avg. per-sample expected Loss: 0.14432
# Batch count: 328, Avg. per-sample expected Loss: 0.15451
# Batch count: 329, Avg. per-sample expected Loss: 0.15219
# Batch count: 330, Avg. per-sample expected Loss: 0.14651
# Batch count: 331, Avg. per-sample expected Loss: 0.14522
# Batch count: 332, Avg. per-sample expected Loss: 0.14319
# Batch count: 333, Avg. per-sample expected Loss: 0.14544
# Batch count: 334, Avg. per-sample expected Loss: 0.15546
# Batch count: 335, Avg. per-sample expected Loss: 0.15636
# Batch count: 336, Avg. per-sample expected Loss: 0.14480
# Batch count: 337, Avg. per-sample expected Loss: 0.14341
# Batch count: 338, Avg. per-sample expected Loss: 0.14230
# Batch count: 339, Avg. per-sample expected Loss: 0.15070
# Batch count: 340, Avg. per-sample expected Loss: 0.15520
# Batch count: 341, Avg. per-sample expected Loss: 0.13694
# Batch count: 342, Avg. per-sample expected Loss: 0.14886
# Batch count: 343, Avg. per-sample expected Loss: 0.14672
# Batch count: 344, Avg. per-sample expected Loss: 0.14242
# Batch count: 345, Avg. per-sample expected Loss: 0.14457
# Batch count: 346, Avg. per-sample expected Loss: 0.15096
# Batch count: 347, Avg. per-sample expected Loss: 0.14986
# Batch count: 348, Avg. per-sample expected Loss: 0.14824
# Batch count: 349, Avg. per-sample expected Loss: 0.14191

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6c_cost, "b", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6c_Ecost, "c.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training using 2-QNSCD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("6-RQSGD.png")
plt.show()

# %% [markdown]
# ## 2-RQSGD using 600 samples per step and 6 samples per itr

# %%
SGD6params = np.array(init_params)
SGD6_cost = []
SGD6_Ecost = []

SGD6_cost.append(temp_cost)
SGD6_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 2 coordinates
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())
        
        grad = []
        
        ### Gradient estimation
        y_hat01,b01 = EstGrad(SGD6params,phiT[:,itr3+0],idx[0])
        b01 = (1-b01)/2
        y_hat02,b02 = EstGrad(SGD6params,phiT[:,itr3+1],idx[0])
        b02 = (1-b02)/2
        y_hat03,b03 = EstGrad(SGD6params,phiT[:,itr3+2],idx[0])
        b03 = (1-b03)/2
        
        temp0 = ((-1)**b01)*loss(y_hat01,labelT[itr3+0]) \
              + ((-1)**b02)*loss(y_hat02,labelT[itr3+1]) \
              + ((-1)**b03)*loss(y_hat03,labelT[itr3+2])

        grad.append((-1)*temp0/3)
        
        y_hat11,b11 = EstGrad(SGD6params,phiT[:,itr3+3],idx[1])
        b11 = (1-b11)/2
        y_hat12,b12 = EstGrad(SGD6params,phiT[:,itr3+4],idx[1])
        b12 = (1-b12)/2
        y_hat13,b13 = EstGrad(SGD6params,phiT[:,itr3+5],idx[1])
        b13 = (1-b13)/2
        
        temp1 = ((-1)**b11)*loss(y_hat11,labelT[itr3+3]) \
              + ((-1)**b12)*loss(y_hat12,labelT[itr3+4]) \
              + ((-1)**b13)*loss(y_hat13,labelT[itr3+5])

        grad.append((-1)*temp1/3)

        ### single-parameter update
        SGD6params[idx] = SGD6params[idx] - np.dot(step_size,grad)
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6params,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6count = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6params,phiT[:,itr]) != labelT[itr]:
            SGD6count += 1
    SGD6_Ecost.append(SGD6count/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "5Q 2-RQSGD_6s Expected Loss"
file_name2 = "5Q 2-RQSGD_6s Empirical Loss"

np.save(file_name1,SGD6_cost)
np.save(file_name2,SGD6_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.53246
# Batch count:  1, Avg. per-sample expected Loss: 0.51639
# Batch count:  2, Avg. per-sample expected Loss: 0.52930
# Batch count:  3, Avg. per-sample expected Loss: 0.52244
# Batch count:  4, Avg. per-sample expected Loss: 0.52779
# Batch count:  5, Avg. per-sample expected Loss: 0.51745
# Batch count:  6, Avg. per-sample expected Loss: 0.50683
# Batch count:  7, Avg. per-sample expected Loss: 0.51623
# Batch count:  8, Avg. per-sample expected Loss: 0.52295
# Batch count:  9, Avg. per-sample expected Loss: 0.50791
# Batch count: 10, Avg. per-sample expected Loss: 0.51201
# Batch count: 11, Avg. per-sample expected Loss: 0.50408
# Batch count: 12, Avg. per-sample expected Loss: 0.48429
# Batch count: 13, Avg. per-sample expected Loss: 0.49840
# Batch count: 14, Avg. per-sample expected Loss: 0.48512
# Batch count: 15, Avg. per-sample expected Loss: 0.50928
# Batch count: 16, Avg. per-sample expected Loss: 0.50405
# Batch count: 17, Avg. per-sample expected Loss: 0.49014
# Batch count: 18, Avg. per-sample expected Loss: 0.48284
# Batch count: 19, Avg. per-sample expected Loss: 0.46612
# Batch count: 20, Avg. per-sample expected Loss: 0.48292
# Batch count: 21, Avg. per-sample expected Loss: 0.49295
# Batch count: 22, Avg. per-sample expected Loss: 0.47493
# Batch count: 23, Avg. per-sample expected Loss: 0.48008
# Batch count: 24, Avg. per-sample expected Loss: 0.48005
# Batch count: 25, Avg. per-sample expected Loss: 0.48191
# Batch count: 26, Avg. per-sample expected Loss: 0.47980
# Batch count: 27, Avg. per-sample expected Loss: 0.45729
# Batch count: 28, Avg. per-sample expected Loss: 0.45216
# Batch count: 29, Avg. per-sample expected Loss: 0.48167
# Batch count: 30, Avg. per-sample expected Loss: 0.46756
# Batch count: 31, Avg. per-sample expected Loss: 0.45406
# Batch count: 32, Avg. per-sample expected Loss: 0.47407
# Batch count: 33, Avg. per-sample expected Loss: 0.46815
# Batch count: 34, Avg. per-sample expected Loss: 0.45146
# Batch count: 35, Avg. per-sample expected Loss: 0.45104
# Batch count: 36, Avg. per-sample expected Loss: 0.44598
# Batch count: 37, Avg. per-sample expected Loss: 0.43931
# Batch count: 38, Avg. per-sample expected Loss: 0.44848
# Batch count: 39, Avg. per-sample expected Loss: 0.42102
# Batch count: 40, Avg. per-sample expected Loss: 0.43561
# Batch count: 41, Avg. per-sample expected Loss: 0.42784
# Batch count: 42, Avg. per-sample expected Loss: 0.43360
# Batch count: 43, Avg. per-sample expected Loss: 0.42715
# Batch count: 44, Avg. per-sample expected Loss: 0.44129
# Batch count: 45, Avg. per-sample expected Loss: 0.43589
# Batch count: 46, Avg. per-sample expected Loss: 0.40924
# Batch count: 47, Avg. per-sample expected Loss: 0.40635
# Batch count: 48, Avg. per-sample expected Loss: 0.40199
# Batch count: 49, Avg. per-sample expected Loss: 0.41900
# Batch count: 50, Avg. per-sample expected Loss: 0.40331
# Batch count: 51, Avg. per-sample expected Loss: 0.39294
# Batch count: 52, Avg. per-sample expected Loss: 0.41499
# Batch count: 53, Avg. per-sample expected Loss: 0.40792
# Batch count: 54, Avg. per-sample expected Loss: 0.39441
# Batch count: 55, Avg. per-sample expected Loss: 0.40979
# Batch count: 56, Avg. per-sample expected Loss: 0.40523
# Batch count: 57, Avg. per-sample expected Loss: 0.40350
# Batch count: 58, Avg. per-sample expected Loss: 0.37734
# Batch count: 59, Avg. per-sample expected Loss: 0.39612
# Batch count: 60, Avg. per-sample expected Loss: 0.37908
# Batch count: 61, Avg. per-sample expected Loss: 0.37218
# Batch count: 62, Avg. per-sample expected Loss: 0.37957
# Batch count: 63, Avg. per-sample expected Loss: 0.37846
# Batch count: 64, Avg. per-sample expected Loss: 0.37673
# Batch count: 65, Avg. per-sample expected Loss: 0.39409
# Batch count: 66, Avg. per-sample expected Loss: 0.38479
# Batch count: 67, Avg. per-sample expected Loss: 0.37133
# Batch count: 68, Avg. per-sample expected Loss: 0.36814
# Batch count: 69, Avg. per-sample expected Loss: 0.36857
# Batch count: 70, Avg. per-sample expected Loss: 0.36155
# Batch count: 71, Avg. per-sample expected Loss: 0.36939
# Batch count: 72, Avg. per-sample expected Loss: 0.35684
# Batch count: 73, Avg. per-sample expected Loss: 0.35923
# Batch count: 74, Avg. per-sample expected Loss: 0.34457
# Batch count: 75, Avg. per-sample expected Loss: 0.35314
# Batch count: 76, Avg. per-sample expected Loss: 0.36435
# Batch count: 77, Avg. per-sample expected Loss: 0.33544
# Batch count: 78, Avg. per-sample expected Loss: 0.34994
# Batch count: 79, Avg. per-sample expected Loss: 0.33149
# Batch count: 80, Avg. per-sample expected Loss: 0.33700
# Batch count: 81, Avg. per-sample expected Loss: 0.34167
# Batch count: 82, Avg. per-sample expected Loss: 0.33826
# Batch count: 83, Avg. per-sample expected Loss: 0.33500
# Batch count: 84, Avg. per-sample expected Loss: 0.33082
# Batch count: 85, Avg. per-sample expected Loss: 0.32773
# Batch count: 86, Avg. per-sample expected Loss: 0.32889
# Batch count: 87, Avg. per-sample expected Loss: 0.34498
# Batch count: 88, Avg. per-sample expected Loss: 0.32720
# Batch count: 89, Avg. per-sample expected Loss: 0.32794
# Batch count: 90, Avg. per-sample expected Loss: 0.33301
# Batch count: 91, Avg. per-sample expected Loss: 0.31871
# Batch count: 92, Avg. per-sample expected Loss: 0.31323
# Batch count: 93, Avg. per-sample expected Loss: 0.31796
# Batch count: 94, Avg. per-sample expected Loss: 0.29742
# Batch count: 95, Avg. per-sample expected Loss: 0.31150
# Batch count: 96, Avg. per-sample expected Loss: 0.32836
# Batch count: 97, Avg. per-sample expected Loss: 0.31353
# Batch count: 98, Avg. per-sample expected Loss: 0.30749
# Batch count: 99, Avg. per-sample expected Loss: 0.32458
# Batch count: 100, Avg. per-sample expected Loss: 0.30297
# Batch count: 101, Avg. per-sample expected Loss: 0.31421
# Batch count: 102, Avg. per-sample expected Loss: 0.30768
# Batch count: 103, Avg. per-sample expected Loss: 0.31703
# Batch count: 104, Avg. per-sample expected Loss: 0.29818
# Batch count: 105, Avg. per-sample expected Loss: 0.31462
# Batch count: 106, Avg. per-sample expected Loss: 0.29372
# Batch count: 107, Avg. per-sample expected Loss: 0.30023
# Batch count: 108, Avg. per-sample expected Loss: 0.32398
# Batch count: 109, Avg. per-sample expected Loss: 0.28670
# Batch count: 110, Avg. per-sample expected Loss: 0.28827
# Batch count: 111, Avg. per-sample expected Loss: 0.30132
# Batch count: 112, Avg. per-sample expected Loss: 0.27698
# Batch count: 113, Avg. per-sample expected Loss: 0.28708
# Batch count: 114, Avg. per-sample expected Loss: 0.28092
# Batch count: 115, Avg. per-sample expected Loss: 0.28784
# Batch count: 116, Avg. per-sample expected Loss: 0.28904
# Batch count: 117, Avg. per-sample expected Loss: 0.28060
# Batch count: 118, Avg. per-sample expected Loss: 0.27963
# Batch count: 119, Avg. per-sample expected Loss: 0.27767
# Batch count: 120, Avg. per-sample expected Loss: 0.26218
# Batch count: 121, Avg. per-sample expected Loss: 0.27580
# Batch count: 122, Avg. per-sample expected Loss: 0.27011
# Batch count: 123, Avg. per-sample expected Loss: 0.27940
# Batch count: 124, Avg. per-sample expected Loss: 0.26408
# Batch count: 125, Avg. per-sample expected Loss: 0.25961
# Batch count: 126, Avg. per-sample expected Loss: 0.24783
# Batch count: 127, Avg. per-sample expected Loss: 0.25006
# Batch count: 128, Avg. per-sample expected Loss: 0.26571
# Batch count: 129, Avg. per-sample expected Loss: 0.25390
# Batch count: 130, Avg. per-sample expected Loss: 0.24644
# Batch count: 131, Avg. per-sample expected Loss: 0.26888
# Batch count: 132, Avg. per-sample expected Loss: 0.26108
# Batch count: 133, Avg. per-sample expected Loss: 0.24837
# Batch count: 134, Avg. per-sample expected Loss: 0.23628
# Batch count: 135, Avg. per-sample expected Loss: 0.25539
# Batch count: 136, Avg. per-sample expected Loss: 0.24068
# Batch count: 137, Avg. per-sample expected Loss: 0.24377
# Batch count: 138, Avg. per-sample expected Loss: 0.26853
# Batch count: 139, Avg. per-sample expected Loss: 0.23520
# Batch count: 140, Avg. per-sample expected Loss: 0.23494
# Batch count: 141, Avg. per-sample expected Loss: 0.24996
# Batch count: 142, Avg. per-sample expected Loss: 0.22304
# Batch count: 143, Avg. per-sample expected Loss: 0.22767
# Batch count: 144, Avg. per-sample expected Loss: 0.21900
# Batch count: 145, Avg. per-sample expected Loss: 0.23852
# Batch count: 146, Avg. per-sample expected Loss: 0.22607
# Batch count: 147, Avg. per-sample expected Loss: 0.24178
# Batch count: 148, Avg. per-sample expected Loss: 0.24942
# Batch count: 149, Avg. per-sample expected Loss: 0.24381
# Batch count: 150, Avg. per-sample expected Loss: 0.23522
# Batch count: 151, Avg. per-sample expected Loss: 0.24723
# Batch count: 152, Avg. per-sample expected Loss: 0.24153
# Batch count: 153, Avg. per-sample expected Loss: 0.23719
# Batch count: 154, Avg. per-sample expected Loss: 0.23245
# Batch count: 155, Avg. per-sample expected Loss: 0.22865
# Batch count: 156, Avg. per-sample expected Loss: 0.20435
# Batch count: 157, Avg. per-sample expected Loss: 0.21425
# Batch count: 158, Avg. per-sample expected Loss: 0.22932
# Batch count: 159, Avg. per-sample expected Loss: 0.23661
# Batch count: 160, Avg. per-sample expected Loss: 0.22504
# Batch count: 161, Avg. per-sample expected Loss: 0.23916
# Batch count: 162, Avg. per-sample expected Loss: 0.23337
# Batch count: 163, Avg. per-sample expected Loss: 0.21432
# Batch count: 164, Avg. per-sample expected Loss: 0.21169
# Batch count: 165, Avg. per-sample expected Loss: 0.18761
# Batch count: 166, Avg. per-sample expected Loss: 0.21009
# Batch count: 167, Avg. per-sample expected Loss: 0.20737
# Batch count: 168, Avg. per-sample expected Loss: 0.19570
# Batch count: 169, Avg. per-sample expected Loss: 0.20192
# Batch count: 170, Avg. per-sample expected Loss: 0.21861
# Batch count: 171, Avg. per-sample expected Loss: 0.21833
# Batch count: 172, Avg. per-sample expected Loss: 0.22753
# Batch count: 173, Avg. per-sample expected Loss: 0.20856
# Batch count: 174, Avg. per-sample expected Loss: 0.21320
# Batch count: 175, Avg. per-sample expected Loss: 0.23515
# Batch count: 176, Avg. per-sample expected Loss: 0.21754
# Batch count: 177, Avg. per-sample expected Loss: 0.21331
# Batch count: 178, Avg. per-sample expected Loss: 0.21950
# Batch count: 179, Avg. per-sample expected Loss: 0.22632
# Batch count: 180, Avg. per-sample expected Loss: 0.21379
# Batch count: 181, Avg. per-sample expected Loss: 0.22491
# Batch count: 182, Avg. per-sample expected Loss: 0.21100
# Batch count: 183, Avg. per-sample expected Loss: 0.21702
# Batch count: 184, Avg. per-sample expected Loss: 0.20732
# Batch count: 185, Avg. per-sample expected Loss: 0.19541
# Batch count: 186, Avg. per-sample expected Loss: 0.20617
# Batch count: 187, Avg. per-sample expected Loss: 0.21488
# Batch count: 188, Avg. per-sample expected Loss: 0.19189
# Batch count: 189, Avg. per-sample expected Loss: 0.19106
# Batch count: 190, Avg. per-sample expected Loss: 0.20047
# Batch count: 191, Avg. per-sample expected Loss: 0.18721
# Batch count: 192, Avg. per-sample expected Loss: 0.20962
# Batch count: 193, Avg. per-sample expected Loss: 0.19397
# Batch count: 194, Avg. per-sample expected Loss: 0.20253
# Batch count: 195, Avg. per-sample expected Loss: 0.19675
# Batch count: 196, Avg. per-sample expected Loss: 0.19991
# Batch count: 197, Avg. per-sample expected Loss: 0.19463
# Batch count: 198, Avg. per-sample expected Loss: 0.19078
# Batch count: 199, Avg. per-sample expected Loss: 0.20856
# Batch count: 200, Avg. per-sample expected Loss: 0.18674
# Batch count: 201, Avg. per-sample expected Loss: 0.20090
# Batch count: 202, Avg. per-sample expected Loss: 0.18307
# Batch count: 203, Avg. per-sample expected Loss: 0.19416
# Batch count: 204, Avg. per-sample expected Loss: 0.19721
# Batch count: 205, Avg. per-sample expected Loss: 0.19104
# Batch count: 206, Avg. per-sample expected Loss: 0.20579
# Batch count: 207, Avg. per-sample expected Loss: 0.21293
# Batch count: 208, Avg. per-sample expected Loss: 0.19911
# Batch count: 209, Avg. per-sample expected Loss: 0.19235
# Batch count: 210, Avg. per-sample expected Loss: 0.19533
# Batch count: 211, Avg. per-sample expected Loss: 0.18863
# Batch count: 212, Avg. per-sample expected Loss: 0.20362
# Batch count: 213, Avg. per-sample expected Loss: 0.18628
# Batch count: 214, Avg. per-sample expected Loss: 0.18060
# Batch count: 215, Avg. per-sample expected Loss: 0.18529
# Batch count: 216, Avg. per-sample expected Loss: 0.18533
# Batch count: 217, Avg. per-sample expected Loss: 0.18781
# Batch count: 218, Avg. per-sample expected Loss: 0.19317
# Batch count: 219, Avg. per-sample expected Loss: 0.18327
# Batch count: 220, Avg. per-sample expected Loss: 0.18394
# Batch count: 221, Avg. per-sample expected Loss: 0.18164
# Batch count: 222, Avg. per-sample expected Loss: 0.17637
# Batch count: 223, Avg. per-sample expected Loss: 0.18947
# Batch count: 224, Avg. per-sample expected Loss: 0.17693
# Batch count: 225, Avg. per-sample expected Loss: 0.17697
# Batch count: 226, Avg. per-sample expected Loss: 0.18488
# Batch count: 227, Avg. per-sample expected Loss: 0.17862
# Batch count: 228, Avg. per-sample expected Loss: 0.19674
# Batch count: 229, Avg. per-sample expected Loss: 0.18774
# Batch count: 230, Avg. per-sample expected Loss: 0.16407
# Batch count: 231, Avg. per-sample expected Loss: 0.18610
# Batch count: 232, Avg. per-sample expected Loss: 0.17334
# Batch count: 233, Avg. per-sample expected Loss: 0.19101
# Batch count: 234, Avg. per-sample expected Loss: 0.19370
# Batch count: 235, Avg. per-sample expected Loss: 0.18590
# Batch count: 236, Avg. per-sample expected Loss: 0.18965
# Batch count: 237, Avg. per-sample expected Loss: 0.18761
# Batch count: 238, Avg. per-sample expected Loss: 0.17350
# Batch count: 239, Avg. per-sample expected Loss: 0.18770
# Batch count: 240, Avg. per-sample expected Loss: 0.18341
# Batch count: 241, Avg. per-sample expected Loss: 0.17776
# Batch count: 242, Avg. per-sample expected Loss: 0.18275
# Batch count: 243, Avg. per-sample expected Loss: 0.18538
# Batch count: 244, Avg. per-sample expected Loss: 0.17532
# Batch count: 245, Avg. per-sample expected Loss: 0.15908
# Batch count: 246, Avg. per-sample expected Loss: 0.17452
# Batch count: 247, Avg. per-sample expected Loss: 0.17700
# Batch count: 248, Avg. per-sample expected Loss: 0.16755
# Batch count: 249, Avg. per-sample expected Loss: 0.19489
# Batch count: 250, Avg. per-sample expected Loss: 0.18299
# Batch count: 251, Avg. per-sample expected Loss: 0.17920
# Batch count: 252, Avg. per-sample expected Loss: 0.18429
# Batch count: 253, Avg. per-sample expected Loss: 0.16726
# Batch count: 254, Avg. per-sample expected Loss: 0.18561
# Batch count: 255, Avg. per-sample expected Loss: 0.17069
# Batch count: 256, Avg. per-sample expected Loss: 0.18159
# Batch count: 257, Avg. per-sample expected Loss: 0.17958
# Batch count: 258, Avg. per-sample expected Loss: 0.18619
# Batch count: 259, Avg. per-sample expected Loss: 0.17046
# Batch count: 260, Avg. per-sample expected Loss: 0.17853
# Batch count: 261, Avg. per-sample expected Loss: 0.16611
# Batch count: 262, Avg. per-sample expected Loss: 0.17253
# Batch count: 263, Avg. per-sample expected Loss: 0.17126
# Batch count: 264, Avg. per-sample expected Loss: 0.16674
# Batch count: 265, Avg. per-sample expected Loss: 0.17240
# Batch count: 266, Avg. per-sample expected Loss: 0.16958
# Batch count: 267, Avg. per-sample expected Loss: 0.18254
# Batch count: 268, Avg. per-sample expected Loss: 0.17646
# Batch count: 269, Avg. per-sample expected Loss: 0.17228
# Batch count: 270, Avg. per-sample expected Loss: 0.17733
# Batch count: 271, Avg. per-sample expected Loss: 0.17529
# Batch count: 272, Avg. per-sample expected Loss: 0.16527
# Batch count: 273, Avg. per-sample expected Loss: 0.17224
# Batch count: 274, Avg. per-sample expected Loss: 0.16112
# Batch count: 275, Avg. per-sample expected Loss: 0.17321
# Batch count: 276, Avg. per-sample expected Loss: 0.17258
# Batch count: 277, Avg. per-sample expected Loss: 0.17155
# Batch count: 278, Avg. per-sample expected Loss: 0.17268
# Batch count: 279, Avg. per-sample expected Loss: 0.16381
# Batch count: 280, Avg. per-sample expected Loss: 0.16874
# Batch count: 281, Avg. per-sample expected Loss: 0.18166
# Batch count: 282, Avg. per-sample expected Loss: 0.16466
# Batch count: 283, Avg. per-sample expected Loss: 0.16060
# Batch count: 284, Avg. per-sample expected Loss: 0.16987
# Batch count: 285, Avg. per-sample expected Loss: 0.16045
# Batch count: 286, Avg. per-sample expected Loss: 0.15990
# Batch count: 287, Avg. per-sample expected Loss: 0.15718
# Batch count: 288, Avg. per-sample expected Loss: 0.15930
# Batch count: 289, Avg. per-sample expected Loss: 0.15909
# Batch count: 290, Avg. per-sample expected Loss: 0.15360
# Batch count: 291, Avg. per-sample expected Loss: 0.16739
# Batch count: 292, Avg. per-sample expected Loss: 0.16456
# Batch count: 293, Avg. per-sample expected Loss: 0.15879
# Batch count: 294, Avg. per-sample expected Loss: 0.18078
# Batch count: 295, Avg. per-sample expected Loss: 0.17070
# Batch count: 296, Avg. per-sample expected Loss: 0.16114
# Batch count: 297, Avg. per-sample expected Loss: 0.16766
# Batch count: 298, Avg. per-sample expected Loss: 0.15585
# Batch count: 299, Avg. per-sample expected Loss: 0.16818
# Batch count: 300, Avg. per-sample expected Loss: 0.16148
# Batch count: 301, Avg. per-sample expected Loss: 0.17138
# Batch count: 302, Avg. per-sample expected Loss: 0.16369
# Batch count: 303, Avg. per-sample expected Loss: 0.15200
# Batch count: 304, Avg. per-sample expected Loss: 0.16832
# Batch count: 305, Avg. per-sample expected Loss: 0.14668
# Batch count: 306, Avg. per-sample expected Loss: 0.16434
# Batch count: 307, Avg. per-sample expected Loss: 0.15835
# Batch count: 308, Avg. per-sample expected Loss: 0.16352
# Batch count: 309, Avg. per-sample expected Loss: 0.15092
# Batch count: 310, Avg. per-sample expected Loss: 0.16271
# Batch count: 311, Avg. per-sample expected Loss: 0.15067
# Batch count: 312, Avg. per-sample expected Loss: 0.15643
# Batch count: 313, Avg. per-sample expected Loss: 0.17832
# Batch count: 314, Avg. per-sample expected Loss: 0.15552
# Batch count: 315, Avg. per-sample expected Loss: 0.15325
# Batch count: 316, Avg. per-sample expected Loss: 0.16084
# Batch count: 317, Avg. per-sample expected Loss: 0.16577
# Batch count: 318, Avg. per-sample expected Loss: 0.15342
# Batch count: 319, Avg. per-sample expected Loss: 0.16281
# Batch count: 320, Avg. per-sample expected Loss: 0.16360
# Batch count: 321, Avg. per-sample expected Loss: 0.15849
# Batch count: 322, Avg. per-sample expected Loss: 0.15593
# Batch count: 323, Avg. per-sample expected Loss: 0.16020
# Batch count: 324, Avg. per-sample expected Loss: 0.16750
# Batch count: 325, Avg. per-sample expected Loss: 0.16859
# Batch count: 326, Avg. per-sample expected Loss: 0.15798
# Batch count: 327, Avg. per-sample expected Loss: 0.15510
# Batch count: 328, Avg. per-sample expected Loss: 0.16691
# Batch count: 329, Avg. per-sample expected Loss: 0.16443
# Batch count: 330, Avg. per-sample expected Loss: 0.15783
# Batch count: 331, Avg. per-sample expected Loss: 0.15562
# Batch count: 332, Avg. per-sample expected Loss: 0.15461
# Batch count: 333, Avg. per-sample expected Loss: 0.15679
# Batch count: 334, Avg. per-sample expected Loss: 0.16743
# Batch count: 335, Avg. per-sample expected Loss: 0.16924
# Batch count: 336, Avg. per-sample expected Loss: 0.15613
# Batch count: 337, Avg. per-sample expected Loss: 0.15422
# Batch count: 338, Avg. per-sample expected Loss: 0.15194
# Batch count: 339, Avg. per-sample expected Loss: 0.16132
# Batch count: 340, Avg. per-sample expected Loss: 0.16658
# Batch count: 341, Avg. per-sample expected Loss: 0.14500
# Batch count: 342, Avg. per-sample expected Loss: 0.15930
# Batch count: 343, Avg. per-sample expected Loss: 0.15711
# Batch count: 344, Avg. per-sample expected Loss: 0.15219
# Batch count: 345, Avg. per-sample expected Loss: 0.15370
# Batch count: 346, Avg. per-sample expected Loss: 0.16130
# Batch count: 347, Avg. per-sample expected Loss: 0.15963
# Batch count: 348, Avg. per-sample expected Loss: 0.15810
# Batch count: 349, Avg. per-sample expected Loss: 0.15191

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")

plt.title("Training using 2-QNSCD and 2-RQSGD (6 samples per itr)")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("2RSGD_6s.png")
plt.show()

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")
plt.plot(SGD6c_cost, "g", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")
plt.plot(SGD6c_Ecost, "g.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training 2-QNSCD and 2-RQSGD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("RQSGD.png")
plt.show()

# %% [markdown]
# ## Testing Phase

# %%
### Saving Final Parameters:
file_name1 = "5Q 2-QNSCD params"
file_name2 = "5Q 2-RQSGD_6s params"
file_name3 = "5Q 6-RQSGD params"

np.save(file_name1,NCGDparams)
np.save(file_name2,SGD6params)
np.save(file_name3,SGD6cparams)

# %%
phiTest = np.load('5-qubitsPhiTest_v1.npy')
labelTest = np.load('5-qubitsLabelTest_v1.npy')

phiTest.requires_grad = False
labelTest.requires_grad = False

# %%
nTest = 1000

NCGDparams_opt = NCGDparams 
SGD6params_opt = SGD6params
SGD6cparams_opt = SGD6cparams

# %%
### Optimal Expected Loss
expOperator = 0

for i in range(nTest):
    op = np.matmul(phiTest[:,i].reshape(dim,1),phiTest[:,i].reshape(1,dim))
    expOperator = expOperator + labelTest[i]*op
expOperator = expOperator/(nTest)
opt_value = 0.5*(1+sum(abs(np.linalg.svd(expOperator)[1])))

# %%
NCGD_rslt = []
SGD6_rslt = []
SGD6c_rslt = []

for i in range(int(1e1)):
    NCGDcount = 0
    SGD6count = 0
    SGD6ccount = 0

    for itr in range(nTest):
        if circuit_test(NCGDparams_opt,phiTest[:,itr]) == labelTest[itr]:
            NCGDcount += 1 
        if circuit_test(SGD6params_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6count += 1
        if circuit_test(SGD6cparams_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6ccount += 1
    
    NCGD_rslt.append(NCGDcount/nTest)
    SGD6_rslt.append(SGD6count/nTest)
    SGD6c_rslt.append(SGD6ccount/nTest)
#     print("itr = ",i)

# %%
print("Optimal: {:.3f} \nNCGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n2-RQSGD_6s: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n6-RQSGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f}"\
      .format(opt_value,np.average(NCGD_rslt),np.std(NCGD_rslt),max(NCGD_rslt),min(NCGD_rslt),\
              np.average(SGD6_rslt),np.std(SGD6_rslt),max(SGD6_rslt),min(SGD6_rslt), \
              np.average(SGD6c_rslt),np.std(SGD6c_rslt),max(SGD6c_rslt),min(SGD6c_rslt)))
# Out:
# Optimal: 0.877
# NCGD: 0.840 / 0.010 max: 0.860 min: 0.826
# 2-RQSGD_6s: 0.836 / 0.011 max: 0.853 min: 0.819
# 6-RQSGD: 0.843 / 0.011 max: 0.861 min: 0.823
