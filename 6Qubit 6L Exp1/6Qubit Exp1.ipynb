# %%
import pennylane as qml
from pennylane import numpy as np
import scipy
import matplotlib.pyplot as plt
from globalVars import *
from model_6qubit import *

from GRADest_6Q import EstGrad
from EQFIMest_6Q import Est_EQFIM

# %% [markdown]
# ## Quantum Neural Network

# %%
random_state = np.random.rand(dim)
random_state = random_state /np.linalg.norm(random_state)
qml.draw_mpl(QNN)(np.zeros(nparams),random_state)
# Out:
# (<Figure size 1400x700 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### Model Initialization

# %%
S_pItr = 6  # no. of samples used per-iteration 

nStep = 500
nItr = 100
step_size = 0.0025

Bsize = S_pItr*nItr

# %%
phiTrain = np.load('6-qubitsPhiTrain_v1.npy')
labelTrain = np.load('6-qubitsLabelTrain_v1.npy')

phiTrain.requires_grad = False
labelTrain.requires_grad = False

# %%
'QNSCD Dataset'
phiTrainNCGD = phiTrain
labelTrainNCGD = labelTrain

'SGD Dataset'
phiTrainSGD = phiTrain
labelTrainSGD = labelTrain

# %%
### Optimal Expected Loss
Opt_cost = []
itrBatch = np.linspace(0,Bsize*nStep,nStep,endpoint = False,dtype = 'int').tolist()
for itr1 in itrBatch:
    expOperator = 0
    for itr2 in range(Bsize):
        temp_phi = phiTrain[:,itr1+itr2]
        op = np.matmul(temp_phi.reshape(dim,1),temp_phi.reshape(1,dim))
        expOperator = expOperator + labelTrain[itr1+itr2]*op
    expOperator = expOperator/Bsize
    opt_value = 0.5*(1-sum(abs(np.linalg.svd(expOperator)[1])))
    Opt_cost.append(opt_value)

file_name = "6Q-Minimum Expected Loss"
np.save(file_name,Opt_cost)

# %% [markdown]
# # Optimizers

# %%
'QNN outputs yhat'
dev = qml.device("default.qubit", wires=nqubits, shots=1)

@qml.qnode(dev,interface='autograd')
def circuit_test(params,state):
    QNN(params,state)
    return qml.sample(qml.Hermitian(M,wires=list(range(nqubits))))

# %%
init_params = np.random.uniform(low=0, high=2*np.pi, size=nparams, requires_grad=True)
init_params = np.array([2.94602518, 0.14266397, 1.3191475,  0.05636539, 4.38662109, 0.36273276,
 0.05480177, 4.26665892, 5.03296912, 1.70548666, 4.18023765, 2.01642987,
 2.40686088, 1.71192262, 4.90288085, 4.21878701, 4.13803515, 4.60476545,
 1.83972118, 5.3472782,  3.71654977, 6.0863638, 6.21881011, 2.13757013,
 5.20661968, 1.43250993, 0.96729225, 1.93195703, 4.30050347, 2.66909105,
 2.28358243, 0.70209337, 3.27067294, 0.2078603,  0.3820314,  5.70779781],requires_grad = True)

'cost initialization'
phiTrain0 = phiTrain[:,-1*(Bsize+1):-1]
labelTrain0 = labelTrain[-1*(Bsize+1):-1]
temp_cost = sum([ps_expLoss(init_params,phiTrain0[:,itr],labelTrain0[itr]) for itr in range(Bsize)])/Bsize
print("Initial Average Per-Sample Expected Loss: ",temp_cost)

count = 0
for itr in range(Bsize):
    if circuit_test(init_params,phiTrain0[:,itr]) != labelTrain0[itr]:
        count += 1
temp_Ecost = count/Bsize
print("Initial Average Empirical Loss", temp_Ecost)
# Out:
# Initial Average Per-Sample Expected Loss:  0.506359435788294
# Initial Average Empirical Loss 0.5166666666666667

# %% [markdown]
# ## Quantum Natural Stochastic Pairwise Coordinate Descent (2-QNSCD)

# %%
NCGDparams = np.array(init_params)
NCGD_cost = []
NCGD_Ecost = []

NCGD_cost.append(temp_cost)
NCGD_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainNCGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainNCGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a pair of coordinate
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())

        ### Gradient estimation
        y1, b1 = EstGrad(NCGDparams,phiT[:,itr3],idx[0])
        y2, b2 = EstGrad(NCGDparams,phiT[:,itr3+1],idx[1])
        b1 = (1-b1)/2
        b2 = (1-b2)/2

        grad = [-1*((-1)**b1)*loss(y1,labelT[itr3]),-1*((-1)**b2)*loss(y2,labelT[itr3+1])]
        
        ### E-QFIM estimation
        metric = Est_EQFIM(NCGDparams,idx,phiT[:,itr3+2:itr3+S_pItr])

        ### double-parameters update
        NCGDparams[idx] = NCGDparams[idx] - (step_size)*np.dot(np.linalg.inv(metric),grad) 
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(NCGDparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    NCGD_cost.append(energy)
    
    ### average empirical loss calculation
    NCGDcount = 0
    for itr in range(Bsize):
        if circuit_test(NCGDparams,phiT[:,itr]) != labelT[itr]:
            NCGDcount += 1
    NCGD_Ecost.append(NCGDcount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))

file_name1 = "6Q 2-QNSCD Expected Loss"
file_name2 = "6Q 2-QNSCD Empirical Loss"

np.save(file_name1,NCGD_cost)
np.save(file_name2,NCGD_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.50636
# Batch count:  1, Avg. per-sample expected Loss: 0.50490
# Batch count:  2, Avg. per-sample expected Loss: 0.49651
# Batch count:  3, Avg. per-sample expected Loss: 0.49850
# Batch count:  4, Avg. per-sample expected Loss: 0.49249
# Batch count:  5, Avg. per-sample expected Loss: 0.50128
# Batch count:  6, Avg. per-sample expected Loss: 0.49964
# Batch count:  7, Avg. per-sample expected Loss: 0.49694
# Batch count:  8, Avg. per-sample expected Loss: 0.49611
# Batch count:  9, Avg. per-sample expected Loss: 0.50374
# Batch count: 10, Avg. per-sample expected Loss: 0.49492
# Batch count: 11, Avg. per-sample expected Loss: 0.49524
# Batch count: 12, Avg. per-sample expected Loss: 0.49065
# Batch count: 13, Avg. per-sample expected Loss: 0.49253
# Batch count: 14, Avg. per-sample expected Loss: 0.48434
# Batch count: 15, Avg. per-sample expected Loss: 0.48765
# Batch count: 16, Avg. per-sample expected Loss: 0.47262
# Batch count: 17, Avg. per-sample expected Loss: 0.48076
# Batch count: 18, Avg. per-sample expected Loss: 0.47561
# Batch count: 19, Avg. per-sample expected Loss: 0.47579
# Batch count: 20, Avg. per-sample expected Loss: 0.47375
# Batch count: 21, Avg. per-sample expected Loss: 0.48150
# Batch count: 22, Avg. per-sample expected Loss: 0.47959
# Batch count: 23, Avg. per-sample expected Loss: 0.47738
# Batch count: 24, Avg. per-sample expected Loss: 0.48554
# Batch count: 25, Avg. per-sample expected Loss: 0.48156
# Batch count: 26, Avg. per-sample expected Loss: 0.48429
# Batch count: 27, Avg. per-sample expected Loss: 0.48253
# Batch count: 28, Avg. per-sample expected Loss: 0.47586
# Batch count: 29, Avg. per-sample expected Loss: 0.46491
# Batch count: 30, Avg. per-sample expected Loss: 0.46295
# Batch count: 31, Avg. per-sample expected Loss: 0.45788
# Batch count: 32, Avg. per-sample expected Loss: 0.46604
# Batch count: 33, Avg. per-sample expected Loss: 0.45529
# Batch count: 34, Avg. per-sample expected Loss: 0.46375
# Batch count: 35, Avg. per-sample expected Loss: 0.46660
# Batch count: 36, Avg. per-sample expected Loss: 0.45767
# Batch count: 37, Avg. per-sample expected Loss: 0.46445
# Batch count: 38, Avg. per-sample expected Loss: 0.46026
# Batch count: 39, Avg. per-sample expected Loss: 0.46224
# Batch count: 40, Avg. per-sample expected Loss: 0.46274
# Batch count: 41, Avg. per-sample expected Loss: 0.46085
# Batch count: 42, Avg. per-sample expected Loss: 0.46314
# Batch count: 43, Avg. per-sample expected Loss: 0.46956
# Batch count: 44, Avg. per-sample expected Loss: 0.47475
# Batch count: 45, Avg. per-sample expected Loss: 0.46847
# Batch count: 46, Avg. per-sample expected Loss: 0.47513
# Batch count: 47, Avg. per-sample expected Loss: 0.47768
# Batch count: 48, Avg. per-sample expected Loss: 0.46714
# Batch count: 49, Avg. per-sample expected Loss: 0.46422
# Batch count: 50, Avg. per-sample expected Loss: 0.46689
# Batch count: 51, Avg. per-sample expected Loss: 0.46818
# Batch count: 52, Avg. per-sample expected Loss: 0.46077
# Batch count: 53, Avg. per-sample expected Loss: 0.46295
# Batch count: 54, Avg. per-sample expected Loss: 0.46616
# Batch count: 55, Avg. per-sample expected Loss: 0.47310
# Batch count: 56, Avg. per-sample expected Loss: 0.47240
# Batch count: 57, Avg. per-sample expected Loss: 0.46964
# Batch count: 58, Avg. per-sample expected Loss: 0.45696
# Batch count: 59, Avg. per-sample expected Loss: 0.46418
# Batch count: 60, Avg. per-sample expected Loss: 0.46646
# Batch count: 61, Avg. per-sample expected Loss: 0.46681
# Batch count: 62, Avg. per-sample expected Loss: 0.47156
# Batch count: 63, Avg. per-sample expected Loss: 0.46441
# Batch count: 64, Avg. per-sample expected Loss: 0.46765
# Batch count: 65, Avg. per-sample expected Loss: 0.46761
# Batch count: 66, Avg. per-sample expected Loss: 0.46542
# Batch count: 67, Avg. per-sample expected Loss: 0.47035
# Batch count: 68, Avg. per-sample expected Loss: 0.45807
# Batch count: 69, Avg. per-sample expected Loss: 0.46415
# Batch count: 70, Avg. per-sample expected Loss: 0.45429
# Batch count: 71, Avg. per-sample expected Loss: 0.46254
# Batch count: 72, Avg. per-sample expected Loss: 0.45936
# Batch count: 73, Avg. per-sample expected Loss: 0.46622
# Batch count: 74, Avg. per-sample expected Loss: 0.46469
# Batch count: 75, Avg. per-sample expected Loss: 0.46091
# Batch count: 76, Avg. per-sample expected Loss: 0.46243
# Batch count: 77, Avg. per-sample expected Loss: 0.45816
# Batch count: 78, Avg. per-sample expected Loss: 0.46788
# Batch count: 79, Avg. per-sample expected Loss: 0.47604
# Batch count: 80, Avg. per-sample expected Loss: 0.48126
# Batch count: 81, Avg. per-sample expected Loss: 0.47724
# Batch count: 82, Avg. per-sample expected Loss: 0.47847
# Batch count: 83, Avg. per-sample expected Loss: 0.47393
# Batch count: 84, Avg. per-sample expected Loss: 0.47736
# Batch count: 85, Avg. per-sample expected Loss: 0.47047
# Batch count: 86, Avg. per-sample expected Loss: 0.46445
# Batch count: 87, Avg. per-sample expected Loss: 0.46246
# Batch count: 88, Avg. per-sample expected Loss: 0.46970
# Batch count: 89, Avg. per-sample expected Loss: 0.46546
# Batch count: 90, Avg. per-sample expected Loss: 0.45750
# Batch count: 91, Avg. per-sample expected Loss: 0.45913
# Batch count: 92, Avg. per-sample expected Loss: 0.46199
# Batch count: 93, Avg. per-sample expected Loss: 0.46513
# Batch count: 94, Avg. per-sample expected Loss: 0.46140
# Batch count: 95, Avg. per-sample expected Loss: 0.46789
# Batch count: 96, Avg. per-sample expected Loss: 0.46546
# Batch count: 97, Avg. per-sample expected Loss: 0.45873
# Batch count: 98, Avg. per-sample expected Loss: 0.46042
# Batch count: 99, Avg. per-sample expected Loss: 0.46542
# Batch count: 100, Avg. per-sample expected Loss: 0.46058
# Batch count: 101, Avg. per-sample expected Loss: 0.45673
# Batch count: 102, Avg. per-sample expected Loss: 0.45437
# Batch count: 103, Avg. per-sample expected Loss: 0.46523
# Batch count: 104, Avg. per-sample expected Loss: 0.46025
# Batch count: 105, Avg. per-sample expected Loss: 0.46181
# Batch count: 106, Avg. per-sample expected Loss: 0.46031
# Batch count: 107, Avg. per-sample expected Loss: 0.44785
# Batch count: 108, Avg. per-sample expected Loss: 0.45394
# Batch count: 109, Avg. per-sample expected Loss: 0.45490
# Batch count: 110, Avg. per-sample expected Loss: 0.45088
# Batch count: 111, Avg. per-sample expected Loss: 0.46346
# Batch count: 112, Avg. per-sample expected Loss: 0.46430
# Batch count: 113, Avg. per-sample expected Loss: 0.45393
# Batch count: 114, Avg. per-sample expected Loss: 0.44727
# Batch count: 115, Avg. per-sample expected Loss: 0.43981
# Batch count: 116, Avg. per-sample expected Loss: 0.44163
# Batch count: 117, Avg. per-sample expected Loss: 0.43406
# Batch count: 118, Avg. per-sample expected Loss: 0.42886
# Batch count: 119, Avg. per-sample expected Loss: 0.42130
# Batch count: 120, Avg. per-sample expected Loss: 0.41979
# Batch count: 121, Avg. per-sample expected Loss: 0.42989
# Batch count: 122, Avg. per-sample expected Loss: 0.43441
# Batch count: 123, Avg. per-sample expected Loss: 0.43476
# Batch count: 124, Avg. per-sample expected Loss: 0.42898
# Batch count: 125, Avg. per-sample expected Loss: 0.42568
# Batch count: 126, Avg. per-sample expected Loss: 0.42700
# Batch count: 127, Avg. per-sample expected Loss: 0.42033
# Batch count: 128, Avg. per-sample expected Loss: 0.42628
# Batch count: 129, Avg. per-sample expected Loss: 0.42009
# Batch count: 130, Avg. per-sample expected Loss: 0.42281
# Batch count: 131, Avg. per-sample expected Loss: 0.42647
# Batch count: 132, Avg. per-sample expected Loss: 0.42223
# Batch count: 133, Avg. per-sample expected Loss: 0.42854
# Batch count: 134, Avg. per-sample expected Loss: 0.43398
# Batch count: 135, Avg. per-sample expected Loss: 0.44172
# Batch count: 136, Avg. per-sample expected Loss: 0.44024
# Batch count: 137, Avg. per-sample expected Loss: 0.43826
# Batch count: 138, Avg. per-sample expected Loss: 0.43702
# Batch count: 139, Avg. per-sample expected Loss: 0.43887
# Batch count: 140, Avg. per-sample expected Loss: 0.44946
# Batch count: 141, Avg. per-sample expected Loss: 0.44480
# Batch count: 142, Avg. per-sample expected Loss: 0.43513
# Batch count: 143, Avg. per-sample expected Loss: 0.44179
# Batch count: 144, Avg. per-sample expected Loss: 0.43784
# Batch count: 145, Avg. per-sample expected Loss: 0.44306
# Batch count: 146, Avg. per-sample expected Loss: 0.43370
# Batch count: 147, Avg. per-sample expected Loss: 0.43241
# Batch count: 148, Avg. per-sample expected Loss: 0.42843
# Batch count: 149, Avg. per-sample expected Loss: 0.42456
# Batch count: 150, Avg. per-sample expected Loss: 0.41807
# Batch count: 151, Avg. per-sample expected Loss: 0.42154
# Batch count: 152, Avg. per-sample expected Loss: 0.41607
# Batch count: 153, Avg. per-sample expected Loss: 0.42095
# Batch count: 154, Avg. per-sample expected Loss: 0.41137
# Batch count: 155, Avg. per-sample expected Loss: 0.41575
# Batch count: 156, Avg. per-sample expected Loss: 0.41619
# Batch count: 157, Avg. per-sample expected Loss: 0.41786
# Batch count: 158, Avg. per-sample expected Loss: 0.41301
# Batch count: 159, Avg. per-sample expected Loss: 0.40777
# Batch count: 160, Avg. per-sample expected Loss: 0.40059
# Batch count: 161, Avg. per-sample expected Loss: 0.40182
# Batch count: 162, Avg. per-sample expected Loss: 0.39847
# Batch count: 163, Avg. per-sample expected Loss: 0.39082
# Batch count: 164, Avg. per-sample expected Loss: 0.38984
# Batch count: 165, Avg. per-sample expected Loss: 0.39683
# Batch count: 166, Avg. per-sample expected Loss: 0.40236
# Batch count: 167, Avg. per-sample expected Loss: 0.39298
# Batch count: 168, Avg. per-sample expected Loss: 0.40037
# Batch count: 169, Avg. per-sample expected Loss: 0.39659
# Batch count: 170, Avg. per-sample expected Loss: 0.40833
# Batch count: 171, Avg. per-sample expected Loss: 0.40392
# Batch count: 172, Avg. per-sample expected Loss: 0.41013
# Batch count: 173, Avg. per-sample expected Loss: 0.40076
# Batch count: 174, Avg. per-sample expected Loss: 0.41365
# Batch count: 175, Avg. per-sample expected Loss: 0.40341
# Batch count: 176, Avg. per-sample expected Loss: 0.39583
# Batch count: 177, Avg. per-sample expected Loss: 0.39932
# Batch count: 178, Avg. per-sample expected Loss: 0.41041
# Batch count: 179, Avg. per-sample expected Loss: 0.38651
# Batch count: 180, Avg. per-sample expected Loss: 0.35809
# Batch count: 181, Avg. per-sample expected Loss: 0.36578
# Batch count: 182, Avg. per-sample expected Loss: 0.36586
# Batch count: 183, Avg. per-sample expected Loss: 0.36837
# Batch count: 184, Avg. per-sample expected Loss: 0.36687
# Batch count: 185, Avg. per-sample expected Loss: 0.36726
# Batch count: 186, Avg. per-sample expected Loss: 0.35415
# Batch count: 187, Avg. per-sample expected Loss: 0.35540
# Batch count: 188, Avg. per-sample expected Loss: 0.35867
# Batch count: 189, Avg. per-sample expected Loss: 0.36542
# Batch count: 190, Avg. per-sample expected Loss: 0.36862
# Batch count: 191, Avg. per-sample expected Loss: 0.36262
# Batch count: 192, Avg. per-sample expected Loss: 0.35820
# Batch count: 193, Avg. per-sample expected Loss: 0.35264
# Batch count: 194, Avg. per-sample expected Loss: 0.35189
# Batch count: 195, Avg. per-sample expected Loss: 0.33943
# Batch count: 196, Avg. per-sample expected Loss: 0.34170
# Batch count: 197, Avg. per-sample expected Loss: 0.33783
# Batch count: 198, Avg. per-sample expected Loss: 0.33855
# Batch count: 199, Avg. per-sample expected Loss: 0.33993
# Batch count: 200, Avg. per-sample expected Loss: 0.34177
# Batch count: 201, Avg. per-sample expected Loss: 0.32793
# Batch count: 202, Avg. per-sample expected Loss: 0.33066
# Batch count: 203, Avg. per-sample expected Loss: 0.32262
# Batch count: 204, Avg. per-sample expected Loss: 0.32622
# Batch count: 205, Avg. per-sample expected Loss: 0.31765
# Batch count: 206, Avg. per-sample expected Loss: 0.31611
# Batch count: 207, Avg. per-sample expected Loss: 0.32252
# Batch count: 208, Avg. per-sample expected Loss: 0.32306
# Batch count: 209, Avg. per-sample expected Loss: 0.31082
# Batch count: 210, Avg. per-sample expected Loss: 0.30506
# Batch count: 211, Avg. per-sample expected Loss: 0.29636
# Batch count: 212, Avg. per-sample expected Loss: 0.29584
# Batch count: 213, Avg. per-sample expected Loss: 0.29238
# Batch count: 214, Avg. per-sample expected Loss: 0.29064
# Batch count: 215, Avg. per-sample expected Loss: 0.30345
# Batch count: 216, Avg. per-sample expected Loss: 0.30190
# Batch count: 217, Avg. per-sample expected Loss: 0.30370
# Batch count: 218, Avg. per-sample expected Loss: 0.29461
# Batch count: 219, Avg. per-sample expected Loss: 0.30314
# Batch count: 220, Avg. per-sample expected Loss: 0.29821
# Batch count: 221, Avg. per-sample expected Loss: 0.30448
# Batch count: 222, Avg. per-sample expected Loss: 0.30214
# Batch count: 223, Avg. per-sample expected Loss: 0.30168
# Batch count: 224, Avg. per-sample expected Loss: 0.29897
# Batch count: 225, Avg. per-sample expected Loss: 0.28862
# Batch count: 226, Avg. per-sample expected Loss: 0.29389
# Batch count: 227, Avg. per-sample expected Loss: 0.30291
# Batch count: 228, Avg. per-sample expected Loss: 0.29661
# Batch count: 229, Avg. per-sample expected Loss: 0.29657
# Batch count: 230, Avg. per-sample expected Loss: 0.28397
# Batch count: 231, Avg. per-sample expected Loss: 0.28817
# Batch count: 232, Avg. per-sample expected Loss: 0.28675
# Batch count: 233, Avg. per-sample expected Loss: 0.28045
# Batch count: 234, Avg. per-sample expected Loss: 0.27246
# Batch count: 235, Avg. per-sample expected Loss: 0.27773
# Batch count: 236, Avg. per-sample expected Loss: 0.27940
# Batch count: 237, Avg. per-sample expected Loss: 0.26136
# Batch count: 238, Avg. per-sample expected Loss: 0.27113
# Batch count: 239, Avg. per-sample expected Loss: 0.25182
# Batch count: 240, Avg. per-sample expected Loss: 0.24897
# Batch count: 241, Avg. per-sample expected Loss: 0.25758
# Batch count: 242, Avg. per-sample expected Loss: 0.24629
# Batch count: 243, Avg. per-sample expected Loss: 0.25390
# Batch count: 244, Avg. per-sample expected Loss: 0.25244
# Batch count: 245, Avg. per-sample expected Loss: 0.25389
# Batch count: 246, Avg. per-sample expected Loss: 0.25167
# Batch count: 247, Avg. per-sample expected Loss: 0.26201
# Batch count: 248, Avg. per-sample expected Loss: 0.26726
# Batch count: 249, Avg. per-sample expected Loss: 0.26676
# Batch count: 250, Avg. per-sample expected Loss: 0.26422
# Batch count: 251, Avg. per-sample expected Loss: 0.26493
# Batch count: 252, Avg. per-sample expected Loss: 0.26540
# Batch count: 253, Avg. per-sample expected Loss: 0.26009
# Batch count: 254, Avg. per-sample expected Loss: 0.25064
# Batch count: 255, Avg. per-sample expected Loss: 0.25007
# Batch count: 256, Avg. per-sample expected Loss: 0.24560
# Batch count: 257, Avg. per-sample expected Loss: 0.23741
# Batch count: 258, Avg. per-sample expected Loss: 0.23478
# Batch count: 259, Avg. per-sample expected Loss: 0.22882
# Batch count: 260, Avg. per-sample expected Loss: 0.22417
# Batch count: 261, Avg. per-sample expected Loss: 0.21950
# Batch count: 262, Avg. per-sample expected Loss: 0.21654
# Batch count: 263, Avg. per-sample expected Loss: 0.22703
# Batch count: 264, Avg. per-sample expected Loss: 0.22394
# Batch count: 265, Avg. per-sample expected Loss: 0.22969
# Batch count: 266, Avg. per-sample expected Loss: 0.22107
# Batch count: 267, Avg. per-sample expected Loss: 0.21703
# Batch count: 268, Avg. per-sample expected Loss: 0.21287
# Batch count: 269, Avg. per-sample expected Loss: 0.20792
# Batch count: 270, Avg. per-sample expected Loss: 0.20412
# Batch count: 271, Avg. per-sample expected Loss: 0.21192
# Batch count: 272, Avg. per-sample expected Loss: 0.20136
# Batch count: 273, Avg. per-sample expected Loss: 0.20073
# Batch count: 274, Avg. per-sample expected Loss: 0.20483
# Batch count: 275, Avg. per-sample expected Loss: 0.19002
# Batch count: 276, Avg. per-sample expected Loss: 0.19774
# Batch count: 277, Avg. per-sample expected Loss: 0.17856
# Batch count: 278, Avg. per-sample expected Loss: 0.19956
# Batch count: 279, Avg. per-sample expected Loss: 0.20332
# Batch count: 280, Avg. per-sample expected Loss: 0.19956
# Batch count: 281, Avg. per-sample expected Loss: 0.20279
# Batch count: 282, Avg. per-sample expected Loss: 0.19287
# Batch count: 283, Avg. per-sample expected Loss: 0.18499
# Batch count: 284, Avg. per-sample expected Loss: 0.19659
# Batch count: 285, Avg. per-sample expected Loss: 0.19798
# Batch count: 286, Avg. per-sample expected Loss: 0.19610
# Batch count: 287, Avg. per-sample expected Loss: 0.19340
# Batch count: 288, Avg. per-sample expected Loss: 0.18496
# Batch count: 289, Avg. per-sample expected Loss: 0.18914
# Batch count: 290, Avg. per-sample expected Loss: 0.18051
# Batch count: 291, Avg. per-sample expected Loss: 0.18126
# Batch count: 292, Avg. per-sample expected Loss: 0.17672
# Batch count: 293, Avg. per-sample expected Loss: 0.17954
# Batch count: 294, Avg. per-sample expected Loss: 0.18257
# Batch count: 295, Avg. per-sample expected Loss: 0.17700
# Batch count: 296, Avg. per-sample expected Loss: 0.18284
# Batch count: 297, Avg. per-sample expected Loss: 0.17999
# Batch count: 298, Avg. per-sample expected Loss: 0.18107
# Batch count: 299, Avg. per-sample expected Loss: 0.18162
# Batch count: 300, Avg. per-sample expected Loss: 0.18566
# Batch count: 301, Avg. per-sample expected Loss: 0.18795
# Batch count: 302, Avg. per-sample expected Loss: 0.17922
# Batch count: 303, Avg. per-sample expected Loss: 0.17593
# Batch count: 304, Avg. per-sample expected Loss: 0.17330
# Batch count: 305, Avg. per-sample expected Loss: 0.16086
# Batch count: 306, Avg. per-sample expected Loss: 0.17260
# Batch count: 307, Avg. per-sample expected Loss: 0.17129
# Batch count: 308, Avg. per-sample expected Loss: 0.17182
# Batch count: 309, Avg. per-sample expected Loss: 0.17071
# Batch count: 310, Avg. per-sample expected Loss: 0.15818
# Batch count: 311, Avg. per-sample expected Loss: 0.17696
# Batch count: 312, Avg. per-sample expected Loss: 0.17869
# Batch count: 313, Avg. per-sample expected Loss: 0.17772
# Batch count: 314, Avg. per-sample expected Loss: 0.17109
# Batch count: 315, Avg. per-sample expected Loss: 0.17155
# Batch count: 316, Avg. per-sample expected Loss: 0.17330
# Batch count: 317, Avg. per-sample expected Loss: 0.15598
# Batch count: 318, Avg. per-sample expected Loss: 0.16569
# Batch count: 319, Avg. per-sample expected Loss: 0.15567
# Batch count: 320, Avg. per-sample expected Loss: 0.15304
# Batch count: 321, Avg. per-sample expected Loss: 0.16021
# Batch count: 322, Avg. per-sample expected Loss: 0.15812
# Batch count: 323, Avg. per-sample expected Loss: 0.15961
# Batch count: 324, Avg. per-sample expected Loss: 0.16161
# Batch count: 325, Avg. per-sample expected Loss: 0.15939
# Batch count: 326, Avg. per-sample expected Loss: 0.15099
# Batch count: 327, Avg. per-sample expected Loss: 0.15264
# Batch count: 328, Avg. per-sample expected Loss: 0.15874
# Batch count: 329, Avg. per-sample expected Loss: 0.16062
# Batch count: 330, Avg. per-sample expected Loss: 0.15918
# Batch count: 331, Avg. per-sample expected Loss: 0.16243
# Batch count: 332, Avg. per-sample expected Loss: 0.15898
# Batch count: 333, Avg. per-sample expected Loss: 0.15955
# Batch count: 334, Avg. per-sample expected Loss: 0.16031
# Batch count: 335, Avg. per-sample expected Loss: 0.16467
# Batch count: 336, Avg. per-sample expected Loss: 0.16346
# Batch count: 337, Avg. per-sample expected Loss: 0.16088
# Batch count: 338, Avg. per-sample expected Loss: 0.16058
# Batch count: 339, Avg. per-sample expected Loss: 0.16505
# Batch count: 340, Avg. per-sample expected Loss: 0.16404
# Batch count: 341, Avg. per-sample expected Loss: 0.15702
# Batch count: 342, Avg. per-sample expected Loss: 0.16984
# Batch count: 343, Avg. per-sample expected Loss: 0.16255
# Batch count: 344, Avg. per-sample expected Loss: 0.16124
# Batch count: 345, Avg. per-sample expected Loss: 0.16020
# Batch count: 346, Avg. per-sample expected Loss: 0.16013
# Batch count: 347, Avg. per-sample expected Loss: 0.15991
# Batch count: 348, Avg. per-sample expected Loss: 0.16166
# Batch count: 349, Avg. per-sample expected Loss: 0.16218
# Batch count: 350, Avg. per-sample expected Loss: 0.16034
# Batch count: 351, Avg. per-sample expected Loss: 0.15806
# Batch count: 352, Avg. per-sample expected Loss: 0.15914
# Batch count: 353, Avg. per-sample expected Loss: 0.14850
# Batch count: 354, Avg. per-sample expected Loss: 0.15730
# Batch count: 355, Avg. per-sample expected Loss: 0.16350
# Batch count: 356, Avg. per-sample expected Loss: 0.15144
# Batch count: 357, Avg. per-sample expected Loss: 0.16187
# Batch count: 358, Avg. per-sample expected Loss: 0.16163
# Batch count: 359, Avg. per-sample expected Loss: 0.16369
# Batch count: 360, Avg. per-sample expected Loss: 0.15872
# Batch count: 361, Avg. per-sample expected Loss: 0.17377
# Batch count: 362, Avg. per-sample expected Loss: 0.15399
# Batch count: 363, Avg. per-sample expected Loss: 0.13869
# Batch count: 364, Avg. per-sample expected Loss: 0.15665
# Batch count: 365, Avg. per-sample expected Loss: 0.15900
# Batch count: 366, Avg. per-sample expected Loss: 0.16486
# Batch count: 367, Avg. per-sample expected Loss: 0.15915
# Batch count: 368, Avg. per-sample expected Loss: 0.16767
# Batch count: 369, Avg. per-sample expected Loss: 0.16594
# Batch count: 370, Avg. per-sample expected Loss: 0.15897
# Batch count: 371, Avg. per-sample expected Loss: 0.16428
# Batch count: 372, Avg. per-sample expected Loss: 0.16443
# Batch count: 373, Avg. per-sample expected Loss: 0.16454
# Batch count: 374, Avg. per-sample expected Loss: 0.16374
# Batch count: 375, Avg. per-sample expected Loss: 0.16126
# Batch count: 376, Avg. per-sample expected Loss: 0.17680
# Batch count: 377, Avg. per-sample expected Loss: 0.16564
# Batch count: 378, Avg. per-sample expected Loss: 0.16769
# Batch count: 379, Avg. per-sample expected Loss: 0.15089
# Batch count: 380, Avg. per-sample expected Loss: 0.15850
# Batch count: 381, Avg. per-sample expected Loss: 0.15459
# Batch count: 382, Avg. per-sample expected Loss: 0.15687
# Batch count: 383, Avg. per-sample expected Loss: 0.15237
# Batch count: 384, Avg. per-sample expected Loss: 0.15981
# Batch count: 385, Avg. per-sample expected Loss: 0.14997
# Batch count: 386, Avg. per-sample expected Loss: 0.15979
# Batch count: 387, Avg. per-sample expected Loss: 0.15184
# Batch count: 388, Avg. per-sample expected Loss: 0.16025
# Batch count: 389, Avg. per-sample expected Loss: 0.15756
# Batch count: 390, Avg. per-sample expected Loss: 0.16744
# Batch count: 391, Avg. per-sample expected Loss: 0.15608
# Batch count: 392, Avg. per-sample expected Loss: 0.16133
# Batch count: 393, Avg. per-sample expected Loss: 0.16795
# Batch count: 394, Avg. per-sample expected Loss: 0.16189
# Batch count: 395, Avg. per-sample expected Loss: 0.15667
# Batch count: 396, Avg. per-sample expected Loss: 0.16241
# Batch count: 397, Avg. per-sample expected Loss: 0.16555
# Batch count: 398, Avg. per-sample expected Loss: 0.16670
# Batch count: 399, Avg. per-sample expected Loss: 0.16019
# Batch count: 400, Avg. per-sample expected Loss: 0.16093
# Batch count: 401, Avg. per-sample expected Loss: 0.16220
# Batch count: 402, Avg. per-sample expected Loss: 0.16510
# Batch count: 403, Avg. per-sample expected Loss: 0.17189
# Batch count: 404, Avg. per-sample expected Loss: 0.17703
# Batch count: 405, Avg. per-sample expected Loss: 0.17671
# Batch count: 406, Avg. per-sample expected Loss: 0.15759
# Batch count: 407, Avg. per-sample expected Loss: 0.15713
# Batch count: 408, Avg. per-sample expected Loss: 0.15791
# Batch count: 409, Avg. per-sample expected Loss: 0.15125
# Batch count: 410, Avg. per-sample expected Loss: 0.16702
# Batch count: 411, Avg. per-sample expected Loss: 0.16161
# Batch count: 412, Avg. per-sample expected Loss: 0.16770
# Batch count: 413, Avg. per-sample expected Loss: 0.16902
# Batch count: 414, Avg. per-sample expected Loss: 0.15706
# Batch count: 415, Avg. per-sample expected Loss: 0.16657
# Batch count: 416, Avg. per-sample expected Loss: 0.16000
# Batch count: 417, Avg. per-sample expected Loss: 0.16485
# Batch count: 418, Avg. per-sample expected Loss: 0.16407
# Batch count: 419, Avg. per-sample expected Loss: 0.16975
# Batch count: 420, Avg. per-sample expected Loss: 0.16995
# Batch count: 421, Avg. per-sample expected Loss: 0.17247
# Batch count: 422, Avg. per-sample expected Loss: 0.16487
# Batch count: 423, Avg. per-sample expected Loss: 0.15764
# Batch count: 424, Avg. per-sample expected Loss: 0.16311
# Batch count: 425, Avg. per-sample expected Loss: 0.16731
# Batch count: 426, Avg. per-sample expected Loss: 0.16620
# Batch count: 427, Avg. per-sample expected Loss: 0.14991
# Batch count: 428, Avg. per-sample expected Loss: 0.15673
# Batch count: 429, Avg. per-sample expected Loss: 0.16550
# Batch count: 430, Avg. per-sample expected Loss: 0.17368
# Batch count: 431, Avg. per-sample expected Loss: 0.16808
# Batch count: 432, Avg. per-sample expected Loss: 0.16700
# Batch count: 433, Avg. per-sample expected Loss: 0.15504
# Batch count: 434, Avg. per-sample expected Loss: 0.15524
# Batch count: 435, Avg. per-sample expected Loss: 0.16197
# Batch count: 436, Avg. per-sample expected Loss: 0.16286
# Batch count: 437, Avg. per-sample expected Loss: 0.16462
# Batch count: 438, Avg. per-sample expected Loss: 0.15844
# Batch count: 439, Avg. per-sample expected Loss: 0.16456
# Batch count: 440, Avg. per-sample expected Loss: 0.16802
# Batch count: 441, Avg. per-sample expected Loss: 0.15999
# Batch count: 442, Avg. per-sample expected Loss: 0.16374
# Batch count: 443, Avg. per-sample expected Loss: 0.15207
# Batch count: 444, Avg. per-sample expected Loss: 0.15487
# Batch count: 445, Avg. per-sample expected Loss: 0.15976
# Batch count: 446, Avg. per-sample expected Loss: 0.16223
# Batch count: 447, Avg. per-sample expected Loss: 0.16019
# Batch count: 448, Avg. per-sample expected Loss: 0.16616
# Batch count: 449, Avg. per-sample expected Loss: 0.14669
# Batch count: 450, Avg. per-sample expected Loss: 0.15520
# Batch count: 451, Avg. per-sample expected Loss: 0.17282
# Batch count: 452, Avg. per-sample expected Loss: 0.15860
# Batch count: 453, Avg. per-sample expected Loss: 0.15058
# Batch count: 454, Avg. per-sample expected Loss: 0.15615
# Batch count: 455, Avg. per-sample expected Loss: 0.15366
# Batch count: 456, Avg. per-sample expected Loss: 0.15698
# Batch count: 457, Avg. per-sample expected Loss: 0.15521
# Batch count: 458, Avg. per-sample expected Loss: 0.15678
# Batch count: 459, Avg. per-sample expected Loss: 0.15403
# Batch count: 460, Avg. per-sample expected Loss: 0.15328
# Batch count: 461, Avg. per-sample expected Loss: 0.15602
# Batch count: 462, Avg. per-sample expected Loss: 0.15027
# Batch count: 463, Avg. per-sample expected Loss: 0.16309
# Batch count: 464, Avg. per-sample expected Loss: 0.15828
# Batch count: 465, Avg. per-sample expected Loss: 0.16402
# Batch count: 466, Avg. per-sample expected Loss: 0.17545
# Batch count: 467, Avg. per-sample expected Loss: 0.16527
# Batch count: 468, Avg. per-sample expected Loss: 0.17450
# Batch count: 469, Avg. per-sample expected Loss: 0.16777
# Batch count: 470, Avg. per-sample expected Loss: 0.16367
# Batch count: 471, Avg. per-sample expected Loss: 0.15581
# Batch count: 472, Avg. per-sample expected Loss: 0.16547
# Batch count: 473, Avg. per-sample expected Loss: 0.16146
# Batch count: 474, Avg. per-sample expected Loss: 0.15940
# Batch count: 475, Avg. per-sample expected Loss: 0.15936
# Batch count: 476, Avg. per-sample expected Loss: 0.16863
# Batch count: 477, Avg. per-sample expected Loss: 0.16142
# Batch count: 478, Avg. per-sample expected Loss: 0.16452
# Batch count: 479, Avg. per-sample expected Loss: 0.15718
# Batch count: 480, Avg. per-sample expected Loss: 0.15691
# Batch count: 481, Avg. per-sample expected Loss: 0.14752
# Batch count: 482, Avg. per-sample expected Loss: 0.15797
# Batch count: 483, Avg. per-sample expected Loss: 0.14258
# Batch count: 484, Avg. per-sample expected Loss: 0.15170
# Batch count: 485, Avg. per-sample expected Loss: 0.15241
# Batch count: 486, Avg. per-sample expected Loss: 0.15017
# Batch count: 487, Avg. per-sample expected Loss: 0.15809
# Batch count: 488, Avg. per-sample expected Loss: 0.17044
# Batch count: 489, Avg. per-sample expected Loss: 0.17114
# Batch count: 490, Avg. per-sample expected Loss: 0.16565
# Batch count: 491, Avg. per-sample expected Loss: 0.17284
# Batch count: 492, Avg. per-sample expected Loss: 0.15693
# Batch count: 493, Avg. per-sample expected Loss: 0.16692
# Batch count: 494, Avg. per-sample expected Loss: 0.16925
# Batch count: 495, Avg. per-sample expected Loss: 0.16865
# Batch count: 496, Avg. per-sample expected Loss: 0.16984
# Batch count: 497, Avg. per-sample expected Loss: 0.16962
# Batch count: 498, Avg. per-sample expected Loss: 0.16078
# Batch count: 499, Avg. per-sample expected Loss: 0.15812

# %% [markdown]
# ## Plots

# %%
plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "b", label="2-QNSCD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.", label="2-QNSCD Empirical Loss")

plt.title("Training using 2-QNSCD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.show()

# %% [markdown]
# ## 6-RQSGD using 600 samples per step

# %%
SGD6cparams = np.array(init_params)
SGD6c_cost = []
SGD6c_Ecost = []

SGD6c_cost.append(temp_cost)
SGD6c_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 6 coordinates
        idx = sorted(np.random.permutation(nparams)[0:6].tolist())
        
        grad = []
        
        ### Gradient estimation
        for i_grad in range(6):
            y_hat,b = EstGrad(SGD6cparams,phiT[:,itr3+i_grad],idx[i_grad])
            b = (1-b)/2
            grad.append((-1)*((-1)**b)*loss(y_hat,labelT[itr3+i_grad]))

        ### single-parameter update
        SGD6cparams[idx] = SGD6cparams[idx] - np.dot(step_size,grad)
    
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6cparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6c_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6ccount = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6cparams,phiT[:,itr]) != labelT[itr]:
            SGD6ccount += 1
    SGD6c_Ecost.append(SGD6ccount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "6Q 6-RQSGD Expected Loss"
file_name2 = "6Q 6-RQSGD Empirical Loss"

np.save(file_name1,SGD6c_cost)
np.save(file_name2,SGD6c_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.50636
# Batch count:  1, Avg. per-sample expected Loss: 0.50721
# Batch count:  2, Avg. per-sample expected Loss: 0.50090
# Batch count:  3, Avg. per-sample expected Loss: 0.50087
# Batch count:  4, Avg. per-sample expected Loss: 0.49758
# Batch count:  5, Avg. per-sample expected Loss: 0.50108
# Batch count:  6, Avg. per-sample expected Loss: 0.49691
# Batch count:  7, Avg. per-sample expected Loss: 0.50198
# Batch count:  8, Avg. per-sample expected Loss: 0.49950
# Batch count:  9, Avg. per-sample expected Loss: 0.50199
# Batch count: 10, Avg. per-sample expected Loss: 0.49989
# Batch count: 11, Avg. per-sample expected Loss: 0.49527
# Batch count: 12, Avg. per-sample expected Loss: 0.49383
# Batch count: 13, Avg. per-sample expected Loss: 0.49367
# Batch count: 14, Avg. per-sample expected Loss: 0.49116
# Batch count: 15, Avg. per-sample expected Loss: 0.49141
# Batch count: 16, Avg. per-sample expected Loss: 0.48810
# Batch count: 17, Avg. per-sample expected Loss: 0.49168
# Batch count: 18, Avg. per-sample expected Loss: 0.48949
# Batch count: 19, Avg. per-sample expected Loss: 0.48665
# Batch count: 20, Avg. per-sample expected Loss: 0.49210
# Batch count: 21, Avg. per-sample expected Loss: 0.48859
# Batch count: 22, Avg. per-sample expected Loss: 0.48825
# Batch count: 23, Avg. per-sample expected Loss: 0.49218
# Batch count: 24, Avg. per-sample expected Loss: 0.49970
# Batch count: 25, Avg. per-sample expected Loss: 0.49438
# Batch count: 26, Avg. per-sample expected Loss: 0.48826
# Batch count: 27, Avg. per-sample expected Loss: 0.49526
# Batch count: 28, Avg. per-sample expected Loss: 0.49223
# Batch count: 29, Avg. per-sample expected Loss: 0.49108
# Batch count: 30, Avg. per-sample expected Loss: 0.48891
# Batch count: 31, Avg. per-sample expected Loss: 0.48520
# Batch count: 32, Avg. per-sample expected Loss: 0.48624
# Batch count: 33, Avg. per-sample expected Loss: 0.47965
# Batch count: 34, Avg. per-sample expected Loss: 0.48980
# Batch count: 35, Avg. per-sample expected Loss: 0.48738
# Batch count: 36, Avg. per-sample expected Loss: 0.48482
# Batch count: 37, Avg. per-sample expected Loss: 0.49059
# Batch count: 38, Avg. per-sample expected Loss: 0.48281
# Batch count: 39, Avg. per-sample expected Loss: 0.48238
# Batch count: 40, Avg. per-sample expected Loss: 0.48129
# Batch count: 41, Avg. per-sample expected Loss: 0.48645
# Batch count: 42, Avg. per-sample expected Loss: 0.48401
# Batch count: 43, Avg. per-sample expected Loss: 0.48404
# Batch count: 44, Avg. per-sample expected Loss: 0.48588
# Batch count: 45, Avg. per-sample expected Loss: 0.48914
# Batch count: 46, Avg. per-sample expected Loss: 0.48240
# Batch count: 47, Avg. per-sample expected Loss: 0.47800
# Batch count: 48, Avg. per-sample expected Loss: 0.47963
# Batch count: 49, Avg. per-sample expected Loss: 0.47708
# Batch count: 50, Avg. per-sample expected Loss: 0.47948
# Batch count: 51, Avg. per-sample expected Loss: 0.47936
# Batch count: 52, Avg. per-sample expected Loss: 0.48335
# Batch count: 53, Avg. per-sample expected Loss: 0.48349
# Batch count: 54, Avg. per-sample expected Loss: 0.48156
# Batch count: 55, Avg. per-sample expected Loss: 0.48308
# Batch count: 56, Avg. per-sample expected Loss: 0.48286
# Batch count: 57, Avg. per-sample expected Loss: 0.47921
# Batch count: 58, Avg. per-sample expected Loss: 0.47049
# Batch count: 59, Avg. per-sample expected Loss: 0.47985
# Batch count: 60, Avg. per-sample expected Loss: 0.48519
# Batch count: 61, Avg. per-sample expected Loss: 0.47481
# Batch count: 62, Avg. per-sample expected Loss: 0.48331
# Batch count: 63, Avg. per-sample expected Loss: 0.47805
# Batch count: 64, Avg. per-sample expected Loss: 0.47810
# Batch count: 65, Avg. per-sample expected Loss: 0.46774
# Batch count: 66, Avg. per-sample expected Loss: 0.47216
# Batch count: 67, Avg. per-sample expected Loss: 0.47173
# Batch count: 68, Avg. per-sample expected Loss: 0.46729
# Batch count: 69, Avg. per-sample expected Loss: 0.47368
# Batch count: 70, Avg. per-sample expected Loss: 0.46327
# Batch count: 71, Avg. per-sample expected Loss: 0.46754
# Batch count: 72, Avg. per-sample expected Loss: 0.46796
# Batch count: 73, Avg. per-sample expected Loss: 0.47401
# Batch count: 74, Avg. per-sample expected Loss: 0.46952
# Batch count: 75, Avg. per-sample expected Loss: 0.46519
# Batch count: 76, Avg. per-sample expected Loss: 0.47143
# Batch count: 77, Avg. per-sample expected Loss: 0.46810
# Batch count: 78, Avg. per-sample expected Loss: 0.46739
# Batch count: 79, Avg. per-sample expected Loss: 0.46773
# Batch count: 80, Avg. per-sample expected Loss: 0.46724
# Batch count: 81, Avg. per-sample expected Loss: 0.46940
# Batch count: 82, Avg. per-sample expected Loss: 0.46343
# Batch count: 83, Avg. per-sample expected Loss: 0.46300
# Batch count: 84, Avg. per-sample expected Loss: 0.46380
# Batch count: 85, Avg. per-sample expected Loss: 0.46487
# Batch count: 86, Avg. per-sample expected Loss: 0.46151
# Batch count: 87, Avg. per-sample expected Loss: 0.45236
# Batch count: 88, Avg. per-sample expected Loss: 0.45863
# Batch count: 89, Avg. per-sample expected Loss: 0.45850
# Batch count: 90, Avg. per-sample expected Loss: 0.45958
# Batch count: 91, Avg. per-sample expected Loss: 0.46145
# Batch count: 92, Avg. per-sample expected Loss: 0.46387
# Batch count: 93, Avg. per-sample expected Loss: 0.45611
# Batch count: 94, Avg. per-sample expected Loss: 0.45823
# Batch count: 95, Avg. per-sample expected Loss: 0.45644
# Batch count: 96, Avg. per-sample expected Loss: 0.45304
# Batch count: 97, Avg. per-sample expected Loss: 0.45316
# Batch count: 98, Avg. per-sample expected Loss: 0.45383
# Batch count: 99, Avg. per-sample expected Loss: 0.45644
# Batch count: 100, Avg. per-sample expected Loss: 0.44539
# Batch count: 101, Avg. per-sample expected Loss: 0.44897
# Batch count: 102, Avg. per-sample expected Loss: 0.45625
# Batch count: 103, Avg. per-sample expected Loss: 0.45182
# Batch count: 104, Avg. per-sample expected Loss: 0.45580
# Batch count: 105, Avg. per-sample expected Loss: 0.44185
# Batch count: 106, Avg. per-sample expected Loss: 0.44907
# Batch count: 107, Avg. per-sample expected Loss: 0.45639
# Batch count: 108, Avg. per-sample expected Loss: 0.45131
# Batch count: 109, Avg. per-sample expected Loss: 0.45525
# Batch count: 110, Avg. per-sample expected Loss: 0.45431
# Batch count: 111, Avg. per-sample expected Loss: 0.45274
# Batch count: 112, Avg. per-sample expected Loss: 0.44888
# Batch count: 113, Avg. per-sample expected Loss: 0.44985
# Batch count: 114, Avg. per-sample expected Loss: 0.44277
# Batch count: 115, Avg. per-sample expected Loss: 0.45380
# Batch count: 116, Avg. per-sample expected Loss: 0.44279
# Batch count: 117, Avg. per-sample expected Loss: 0.44353
# Batch count: 118, Avg. per-sample expected Loss: 0.44023
# Batch count: 119, Avg. per-sample expected Loss: 0.44851
# Batch count: 120, Avg. per-sample expected Loss: 0.44397
# Batch count: 121, Avg. per-sample expected Loss: 0.43984
# Batch count: 122, Avg. per-sample expected Loss: 0.43625
# Batch count: 123, Avg. per-sample expected Loss: 0.44057
# Batch count: 124, Avg. per-sample expected Loss: 0.43903
# Batch count: 125, Avg. per-sample expected Loss: 0.44108
# Batch count: 126, Avg. per-sample expected Loss: 0.43987
# Batch count: 127, Avg. per-sample expected Loss: 0.43742
# Batch count: 128, Avg. per-sample expected Loss: 0.43550
# Batch count: 129, Avg. per-sample expected Loss: 0.43543
# Batch count: 130, Avg. per-sample expected Loss: 0.43423
# Batch count: 131, Avg. per-sample expected Loss: 0.43005
# Batch count: 132, Avg. per-sample expected Loss: 0.44062
# Batch count: 133, Avg. per-sample expected Loss: 0.43598
# Batch count: 134, Avg. per-sample expected Loss: 0.42824
# Batch count: 135, Avg. per-sample expected Loss: 0.43144
# Batch count: 136, Avg. per-sample expected Loss: 0.43276
# Batch count: 137, Avg. per-sample expected Loss: 0.42792
# Batch count: 138, Avg. per-sample expected Loss: 0.42579
# Batch count: 139, Avg. per-sample expected Loss: 0.42053
# Batch count: 140, Avg. per-sample expected Loss: 0.41887
# Batch count: 141, Avg. per-sample expected Loss: 0.42544
# Batch count: 142, Avg. per-sample expected Loss: 0.42717
# Batch count: 143, Avg. per-sample expected Loss: 0.41493
# Batch count: 144, Avg. per-sample expected Loss: 0.41375
# Batch count: 145, Avg. per-sample expected Loss: 0.40395
# Batch count: 146, Avg. per-sample expected Loss: 0.41838
# Batch count: 147, Avg. per-sample expected Loss: 0.42069
# Batch count: 148, Avg. per-sample expected Loss: 0.41481
# Batch count: 149, Avg. per-sample expected Loss: 0.42026
# Batch count: 150, Avg. per-sample expected Loss: 0.42288
# Batch count: 151, Avg. per-sample expected Loss: 0.41240
# Batch count: 152, Avg. per-sample expected Loss: 0.41963
# Batch count: 153, Avg. per-sample expected Loss: 0.41784
# Batch count: 154, Avg. per-sample expected Loss: 0.42494
# Batch count: 155, Avg. per-sample expected Loss: 0.40457
# Batch count: 156, Avg. per-sample expected Loss: 0.41274
# Batch count: 157, Avg. per-sample expected Loss: 0.40251
# Batch count: 158, Avg. per-sample expected Loss: 0.40866
# Batch count: 159, Avg. per-sample expected Loss: 0.41936
# Batch count: 160, Avg. per-sample expected Loss: 0.40812
# Batch count: 161, Avg. per-sample expected Loss: 0.40422
# Batch count: 162, Avg. per-sample expected Loss: 0.40652
# Batch count: 163, Avg. per-sample expected Loss: 0.40647
# Batch count: 164, Avg. per-sample expected Loss: 0.40053
# Batch count: 165, Avg. per-sample expected Loss: 0.39792
# Batch count: 166, Avg. per-sample expected Loss: 0.40547
# Batch count: 167, Avg. per-sample expected Loss: 0.40742
# Batch count: 168, Avg. per-sample expected Loss: 0.39532
# Batch count: 169, Avg. per-sample expected Loss: 0.39966
# Batch count: 170, Avg. per-sample expected Loss: 0.40516
# Batch count: 171, Avg. per-sample expected Loss: 0.39399
# Batch count: 172, Avg. per-sample expected Loss: 0.39742
# Batch count: 173, Avg. per-sample expected Loss: 0.39744
# Batch count: 174, Avg. per-sample expected Loss: 0.39439
# Batch count: 175, Avg. per-sample expected Loss: 0.40280
# Batch count: 176, Avg. per-sample expected Loss: 0.38905
# Batch count: 177, Avg. per-sample expected Loss: 0.38966
# Batch count: 178, Avg. per-sample expected Loss: 0.38625
# Batch count: 179, Avg. per-sample expected Loss: 0.39177
# Batch count: 180, Avg. per-sample expected Loss: 0.40063
# Batch count: 181, Avg. per-sample expected Loss: 0.39304
# Batch count: 182, Avg. per-sample expected Loss: 0.38269
# Batch count: 183, Avg. per-sample expected Loss: 0.39060
# Batch count: 184, Avg. per-sample expected Loss: 0.38555
# Batch count: 185, Avg. per-sample expected Loss: 0.38281
# Batch count: 186, Avg. per-sample expected Loss: 0.39778
# Batch count: 187, Avg. per-sample expected Loss: 0.38340
# Batch count: 188, Avg. per-sample expected Loss: 0.37781
# Batch count: 189, Avg. per-sample expected Loss: 0.37419
# Batch count: 190, Avg. per-sample expected Loss: 0.38599
# Batch count: 191, Avg. per-sample expected Loss: 0.37836
# Batch count: 192, Avg. per-sample expected Loss: 0.37574
# Batch count: 193, Avg. per-sample expected Loss: 0.37629
# Batch count: 194, Avg. per-sample expected Loss: 0.38109
# Batch count: 195, Avg. per-sample expected Loss: 0.37786
# Batch count: 196, Avg. per-sample expected Loss: 0.38248
# Batch count: 197, Avg. per-sample expected Loss: 0.37979
# Batch count: 198, Avg. per-sample expected Loss: 0.38141
# Batch count: 199, Avg. per-sample expected Loss: 0.37386
# Batch count: 200, Avg. per-sample expected Loss: 0.37253
# Batch count: 201, Avg. per-sample expected Loss: 0.36874
# Batch count: 202, Avg. per-sample expected Loss: 0.37353
# Batch count: 203, Avg. per-sample expected Loss: 0.37709
# Batch count: 204, Avg. per-sample expected Loss: 0.37801
# Batch count: 205, Avg. per-sample expected Loss: 0.36608
# Batch count: 206, Avg. per-sample expected Loss: 0.37233
# Batch count: 207, Avg. per-sample expected Loss: 0.36680
# Batch count: 208, Avg. per-sample expected Loss: 0.37141
# Batch count: 209, Avg. per-sample expected Loss: 0.35955
# Batch count: 210, Avg. per-sample expected Loss: 0.36221
# Batch count: 211, Avg. per-sample expected Loss: 0.36262
# Batch count: 212, Avg. per-sample expected Loss: 0.37482
# Batch count: 213, Avg. per-sample expected Loss: 0.37533
# Batch count: 214, Avg. per-sample expected Loss: 0.36355
# Batch count: 215, Avg. per-sample expected Loss: 0.36639
# Batch count: 216, Avg. per-sample expected Loss: 0.35751
# Batch count: 217, Avg. per-sample expected Loss: 0.34952
# Batch count: 218, Avg. per-sample expected Loss: 0.37170
# Batch count: 219, Avg. per-sample expected Loss: 0.34946
# Batch count: 220, Avg. per-sample expected Loss: 0.36446
# Batch count: 221, Avg. per-sample expected Loss: 0.34816
# Batch count: 222, Avg. per-sample expected Loss: 0.35703
# Batch count: 223, Avg. per-sample expected Loss: 0.34596
# Batch count: 224, Avg. per-sample expected Loss: 0.35585
# Batch count: 225, Avg. per-sample expected Loss: 0.35567
# Batch count: 226, Avg. per-sample expected Loss: 0.35280
# Batch count: 227, Avg. per-sample expected Loss: 0.35170
# Batch count: 228, Avg. per-sample expected Loss: 0.35287
# Batch count: 229, Avg. per-sample expected Loss: 0.35540
# Batch count: 230, Avg. per-sample expected Loss: 0.35111
# Batch count: 231, Avg. per-sample expected Loss: 0.35110
# Batch count: 232, Avg. per-sample expected Loss: 0.35571
# Batch count: 233, Avg. per-sample expected Loss: 0.34928
# Batch count: 234, Avg. per-sample expected Loss: 0.35420
# Batch count: 235, Avg. per-sample expected Loss: 0.34700
# Batch count: 236, Avg. per-sample expected Loss: 0.35364
# Batch count: 237, Avg. per-sample expected Loss: 0.35140
# Batch count: 238, Avg. per-sample expected Loss: 0.33903
# Batch count: 239, Avg. per-sample expected Loss: 0.36222
# Batch count: 240, Avg. per-sample expected Loss: 0.34201
# Batch count: 241, Avg. per-sample expected Loss: 0.34212
# Batch count: 242, Avg. per-sample expected Loss: 0.34437
# Batch count: 243, Avg. per-sample expected Loss: 0.33673
# Batch count: 244, Avg. per-sample expected Loss: 0.35010
# Batch count: 245, Avg. per-sample expected Loss: 0.34277
# Batch count: 246, Avg. per-sample expected Loss: 0.34842
# Batch count: 247, Avg. per-sample expected Loss: 0.34714
# Batch count: 248, Avg. per-sample expected Loss: 0.31581
# Batch count: 249, Avg. per-sample expected Loss: 0.33342
# Batch count: 250, Avg. per-sample expected Loss: 0.33506
# Batch count: 251, Avg. per-sample expected Loss: 0.32626
# Batch count: 252, Avg. per-sample expected Loss: 0.33080
# Batch count: 253, Avg. per-sample expected Loss: 0.33487
# Batch count: 254, Avg. per-sample expected Loss: 0.34227
# Batch count: 255, Avg. per-sample expected Loss: 0.33988
# Batch count: 256, Avg. per-sample expected Loss: 0.32692
# Batch count: 257, Avg. per-sample expected Loss: 0.32527
# Batch count: 258, Avg. per-sample expected Loss: 0.32521
# Batch count: 259, Avg. per-sample expected Loss: 0.33085
# Batch count: 260, Avg. per-sample expected Loss: 0.32022
# Batch count: 261, Avg. per-sample expected Loss: 0.32434
# Batch count: 262, Avg. per-sample expected Loss: 0.32392
# Batch count: 263, Avg. per-sample expected Loss: 0.32330
# Batch count: 264, Avg. per-sample expected Loss: 0.32244
# Batch count: 265, Avg. per-sample expected Loss: 0.32205
# Batch count: 266, Avg. per-sample expected Loss: 0.32495
# Batch count: 267, Avg. per-sample expected Loss: 0.32508
# Batch count: 268, Avg. per-sample expected Loss: 0.32078
# Batch count: 269, Avg. per-sample expected Loss: 0.32546
# Batch count: 270, Avg. per-sample expected Loss: 0.32565
# Batch count: 271, Avg. per-sample expected Loss: 0.31803
# Batch count: 272, Avg. per-sample expected Loss: 0.32081
# Batch count: 273, Avg. per-sample expected Loss: 0.31826
# Batch count: 274, Avg. per-sample expected Loss: 0.31248
# Batch count: 275, Avg. per-sample expected Loss: 0.32480
# Batch count: 276, Avg. per-sample expected Loss: 0.31193
# Batch count: 277, Avg. per-sample expected Loss: 0.32216
# Batch count: 278, Avg. per-sample expected Loss: 0.30615
# Batch count: 279, Avg. per-sample expected Loss: 0.30135
# Batch count: 280, Avg. per-sample expected Loss: 0.31366
# Batch count: 281, Avg. per-sample expected Loss: 0.30339
# Batch count: 282, Avg. per-sample expected Loss: 0.31274
# Batch count: 283, Avg. per-sample expected Loss: 0.32001
# Batch count: 284, Avg. per-sample expected Loss: 0.31484
# Batch count: 285, Avg. per-sample expected Loss: 0.31103
# Batch count: 286, Avg. per-sample expected Loss: 0.32197
# Batch count: 287, Avg. per-sample expected Loss: 0.31223
# Batch count: 288, Avg. per-sample expected Loss: 0.31122
# Batch count: 289, Avg. per-sample expected Loss: 0.31055
# Batch count: 290, Avg. per-sample expected Loss: 0.31739
# Batch count: 291, Avg. per-sample expected Loss: 0.31926
# Batch count: 292, Avg. per-sample expected Loss: 0.32179
# Batch count: 293, Avg. per-sample expected Loss: 0.32517
# Batch count: 294, Avg. per-sample expected Loss: 0.31164
# Batch count: 295, Avg. per-sample expected Loss: 0.31822
# Batch count: 296, Avg. per-sample expected Loss: 0.31449
# Batch count: 297, Avg. per-sample expected Loss: 0.31472
# Batch count: 298, Avg. per-sample expected Loss: 0.31848
# Batch count: 299, Avg. per-sample expected Loss: 0.31963
# Batch count: 300, Avg. per-sample expected Loss: 0.31832
# Batch count: 301, Avg. per-sample expected Loss: 0.31000
# Batch count: 302, Avg. per-sample expected Loss: 0.31628
# Batch count: 303, Avg. per-sample expected Loss: 0.31729
# Batch count: 304, Avg. per-sample expected Loss: 0.31936
# Batch count: 305, Avg. per-sample expected Loss: 0.32263
# Batch count: 306, Avg. per-sample expected Loss: 0.30870
# Batch count: 307, Avg. per-sample expected Loss: 0.31553
# Batch count: 308, Avg. per-sample expected Loss: 0.31466
# Batch count: 309, Avg. per-sample expected Loss: 0.30802
# Batch count: 310, Avg. per-sample expected Loss: 0.32454
# Batch count: 311, Avg. per-sample expected Loss: 0.31115
# Batch count: 312, Avg. per-sample expected Loss: 0.30931
# Batch count: 313, Avg. per-sample expected Loss: 0.30681
# Batch count: 314, Avg. per-sample expected Loss: 0.31684
# Batch count: 315, Avg. per-sample expected Loss: 0.31077
# Batch count: 316, Avg. per-sample expected Loss: 0.29855
# Batch count: 317, Avg. per-sample expected Loss: 0.31652
# Batch count: 318, Avg. per-sample expected Loss: 0.29414
# Batch count: 319, Avg. per-sample expected Loss: 0.31574
# Batch count: 320, Avg. per-sample expected Loss: 0.31233
# Batch count: 321, Avg. per-sample expected Loss: 0.30661
# Batch count: 322, Avg. per-sample expected Loss: 0.30841
# Batch count: 323, Avg. per-sample expected Loss: 0.31039
# Batch count: 324, Avg. per-sample expected Loss: 0.30040
# Batch count: 325, Avg. per-sample expected Loss: 0.30066
# Batch count: 326, Avg. per-sample expected Loss: 0.31172
# Batch count: 327, Avg. per-sample expected Loss: 0.30746
# Batch count: 328, Avg. per-sample expected Loss: 0.30045
# Batch count: 329, Avg. per-sample expected Loss: 0.28973
# Batch count: 330, Avg. per-sample expected Loss: 0.30653
# Batch count: 331, Avg. per-sample expected Loss: 0.29745
# Batch count: 332, Avg. per-sample expected Loss: 0.29394
# Batch count: 333, Avg. per-sample expected Loss: 0.30254
# Batch count: 334, Avg. per-sample expected Loss: 0.30978
# Batch count: 335, Avg. per-sample expected Loss: 0.28969
# Batch count: 336, Avg. per-sample expected Loss: 0.29799
# Batch count: 337, Avg. per-sample expected Loss: 0.30523
# Batch count: 338, Avg. per-sample expected Loss: 0.30158
# Batch count: 339, Avg. per-sample expected Loss: 0.30435
# Batch count: 340, Avg. per-sample expected Loss: 0.30612
# Batch count: 341, Avg. per-sample expected Loss: 0.31140
# Batch count: 342, Avg. per-sample expected Loss: 0.29472
# Batch count: 343, Avg. per-sample expected Loss: 0.30280
# Batch count: 344, Avg. per-sample expected Loss: 0.29767
# Batch count: 345, Avg. per-sample expected Loss: 0.30069
# Batch count: 346, Avg. per-sample expected Loss: 0.29949
# Batch count: 347, Avg. per-sample expected Loss: 0.30185
# Batch count: 348, Avg. per-sample expected Loss: 0.29852
# Batch count: 349, Avg. per-sample expected Loss: 0.29372
# Batch count: 350, Avg. per-sample expected Loss: 0.29897
# Batch count: 351, Avg. per-sample expected Loss: 0.29767
# Batch count: 352, Avg. per-sample expected Loss: 0.29802
# Batch count: 353, Avg. per-sample expected Loss: 0.30543
# Batch count: 354, Avg. per-sample expected Loss: 0.30127
# Batch count: 355, Avg. per-sample expected Loss: 0.29196
# Batch count: 356, Avg. per-sample expected Loss: 0.30593
# Batch count: 357, Avg. per-sample expected Loss: 0.30058
# Batch count: 358, Avg. per-sample expected Loss: 0.29262
# Batch count: 359, Avg. per-sample expected Loss: 0.30026
# Batch count: 360, Avg. per-sample expected Loss: 0.29914
# Batch count: 361, Avg. per-sample expected Loss: 0.28558
# Batch count: 362, Avg. per-sample expected Loss: 0.29716
# Batch count: 363, Avg. per-sample expected Loss: 0.30386
# Batch count: 364, Avg. per-sample expected Loss: 0.29460
# Batch count: 365, Avg. per-sample expected Loss: 0.30464
# Batch count: 366, Avg. per-sample expected Loss: 0.29332
# Batch count: 367, Avg. per-sample expected Loss: 0.28606
# Batch count: 368, Avg. per-sample expected Loss: 0.29323
# Batch count: 369, Avg. per-sample expected Loss: 0.29219
# Batch count: 370, Avg. per-sample expected Loss: 0.29700
# Batch count: 371, Avg. per-sample expected Loss: 0.29505
# Batch count: 372, Avg. per-sample expected Loss: 0.29591
# Batch count: 373, Avg. per-sample expected Loss: 0.29463
# Batch count: 374, Avg. per-sample expected Loss: 0.29372
# Batch count: 375, Avg. per-sample expected Loss: 0.29449
# Batch count: 376, Avg. per-sample expected Loss: 0.28662
# Batch count: 377, Avg. per-sample expected Loss: 0.29035
# Batch count: 378, Avg. per-sample expected Loss: 0.28778
# Batch count: 379, Avg. per-sample expected Loss: 0.29504
# Batch count: 380, Avg. per-sample expected Loss: 0.29559
# Batch count: 381, Avg. per-sample expected Loss: 0.28664
# Batch count: 382, Avg. per-sample expected Loss: 0.28670
# Batch count: 383, Avg. per-sample expected Loss: 0.28493
# Batch count: 384, Avg. per-sample expected Loss: 0.28176
# Batch count: 385, Avg. per-sample expected Loss: 0.28712
# Batch count: 386, Avg. per-sample expected Loss: 0.28552
# Batch count: 387, Avg. per-sample expected Loss: 0.29344
# Batch count: 388, Avg. per-sample expected Loss: 0.28652
# Batch count: 389, Avg. per-sample expected Loss: 0.28799
# Batch count: 390, Avg. per-sample expected Loss: 0.27643
# Batch count: 391, Avg. per-sample expected Loss: 0.28937
# Batch count: 392, Avg. per-sample expected Loss: 0.28624
# Batch count: 393, Avg. per-sample expected Loss: 0.28082
# Batch count: 394, Avg. per-sample expected Loss: 0.28557
# Batch count: 395, Avg. per-sample expected Loss: 0.28700
# Batch count: 396, Avg. per-sample expected Loss: 0.28188
# Batch count: 397, Avg. per-sample expected Loss: 0.28585
# Batch count: 398, Avg. per-sample expected Loss: 0.28312
# Batch count: 399, Avg. per-sample expected Loss: 0.28506
# Batch count: 400, Avg. per-sample expected Loss: 0.28479
# Batch count: 401, Avg. per-sample expected Loss: 0.28526
# Batch count: 402, Avg. per-sample expected Loss: 0.28080
# Batch count: 403, Avg. per-sample expected Loss: 0.27675
# Batch count: 404, Avg. per-sample expected Loss: 0.28117
# Batch count: 405, Avg. per-sample expected Loss: 0.27693
# Batch count: 406, Avg. per-sample expected Loss: 0.28163
# Batch count: 407, Avg. per-sample expected Loss: 0.28124
# Batch count: 408, Avg. per-sample expected Loss: 0.27799
# Batch count: 409, Avg. per-sample expected Loss: 0.27976
# Batch count: 410, Avg. per-sample expected Loss: 0.27149
# Batch count: 411, Avg. per-sample expected Loss: 0.27784
# Batch count: 412, Avg. per-sample expected Loss: 0.27746
# Batch count: 413, Avg. per-sample expected Loss: 0.28010
# Batch count: 414, Avg. per-sample expected Loss: 0.28650
# Batch count: 415, Avg. per-sample expected Loss: 0.28098
# Batch count: 416, Avg. per-sample expected Loss: 0.27689
# Batch count: 417, Avg. per-sample expected Loss: 0.27686
# Batch count: 418, Avg. per-sample expected Loss: 0.27433
# Batch count: 419, Avg. per-sample expected Loss: 0.27661
# Batch count: 420, Avg. per-sample expected Loss: 0.27723
# Batch count: 421, Avg. per-sample expected Loss: 0.27180
# Batch count: 422, Avg. per-sample expected Loss: 0.27600
# Batch count: 423, Avg. per-sample expected Loss: 0.28014
# Batch count: 424, Avg. per-sample expected Loss: 0.27765
# Batch count: 425, Avg. per-sample expected Loss: 0.27111
# Batch count: 426, Avg. per-sample expected Loss: 0.27477
# Batch count: 427, Avg. per-sample expected Loss: 0.27931
# Batch count: 428, Avg. per-sample expected Loss: 0.27811
# Batch count: 429, Avg. per-sample expected Loss: 0.27313
# Batch count: 430, Avg. per-sample expected Loss: 0.27046
# Batch count: 431, Avg. per-sample expected Loss: 0.27072
# Batch count: 432, Avg. per-sample expected Loss: 0.26920
# Batch count: 433, Avg. per-sample expected Loss: 0.27489
# Batch count: 434, Avg. per-sample expected Loss: 0.27593
# Batch count: 435, Avg. per-sample expected Loss: 0.27377
# Batch count: 436, Avg. per-sample expected Loss: 0.27154
# Batch count: 437, Avg. per-sample expected Loss: 0.26876
# Batch count: 438, Avg. per-sample expected Loss: 0.27160
# Batch count: 439, Avg. per-sample expected Loss: 0.26880
# Batch count: 440, Avg. per-sample expected Loss: 0.26726
# Batch count: 441, Avg. per-sample expected Loss: 0.27028
# Batch count: 442, Avg. per-sample expected Loss: 0.26685
# Batch count: 443, Avg. per-sample expected Loss: 0.26827
# Batch count: 444, Avg. per-sample expected Loss: 0.27278
# Batch count: 445, Avg. per-sample expected Loss: 0.26501
# Batch count: 446, Avg. per-sample expected Loss: 0.26148
# Batch count: 447, Avg. per-sample expected Loss: 0.26225
# Batch count: 448, Avg. per-sample expected Loss: 0.26549
# Batch count: 449, Avg. per-sample expected Loss: 0.27743
# Batch count: 450, Avg. per-sample expected Loss: 0.26678
# Batch count: 451, Avg. per-sample expected Loss: 0.26620
# Batch count: 452, Avg. per-sample expected Loss: 0.26724
# Batch count: 453, Avg. per-sample expected Loss: 0.26686
# Batch count: 454, Avg. per-sample expected Loss: 0.26402
# Batch count: 455, Avg. per-sample expected Loss: 0.26372
# Batch count: 456, Avg. per-sample expected Loss: 0.26259
# Batch count: 457, Avg. per-sample expected Loss: 0.26751
# Batch count: 458, Avg. per-sample expected Loss: 0.26776
# Batch count: 459, Avg. per-sample expected Loss: 0.26380
# Batch count: 460, Avg. per-sample expected Loss: 0.26205
# Batch count: 461, Avg. per-sample expected Loss: 0.26759
# Batch count: 462, Avg. per-sample expected Loss: 0.27068
# Batch count: 463, Avg. per-sample expected Loss: 0.26768
# Batch count: 464, Avg. per-sample expected Loss: 0.26757
# Batch count: 465, Avg. per-sample expected Loss: 0.26434
# Batch count: 466, Avg. per-sample expected Loss: 0.26537
# Batch count: 467, Avg. per-sample expected Loss: 0.26727
# Batch count: 468, Avg. per-sample expected Loss: 0.25859
# Batch count: 469, Avg. per-sample expected Loss: 0.26178
# Batch count: 470, Avg. per-sample expected Loss: 0.26374
# Batch count: 471, Avg. per-sample expected Loss: 0.26018
# Batch count: 472, Avg. per-sample expected Loss: 0.26181
# Batch count: 473, Avg. per-sample expected Loss: 0.26363
# Batch count: 474, Avg. per-sample expected Loss: 0.25615
# Batch count: 475, Avg. per-sample expected Loss: 0.26329
# Batch count: 476, Avg. per-sample expected Loss: 0.26602
# Batch count: 477, Avg. per-sample expected Loss: 0.25761
# Batch count: 478, Avg. per-sample expected Loss: 0.25991
# Batch count: 479, Avg. per-sample expected Loss: 0.26266
# Batch count: 480, Avg. per-sample expected Loss: 0.25762
# Batch count: 481, Avg. per-sample expected Loss: 0.25882
# Batch count: 482, Avg. per-sample expected Loss: 0.25598
# Batch count: 483, Avg. per-sample expected Loss: 0.25394
# Batch count: 484, Avg. per-sample expected Loss: 0.25438
# Batch count: 485, Avg. per-sample expected Loss: 0.25946
# Batch count: 486, Avg. per-sample expected Loss: 0.25966
# Batch count: 487, Avg. per-sample expected Loss: 0.25241
# Batch count: 488, Avg. per-sample expected Loss: 0.26135
# Batch count: 489, Avg. per-sample expected Loss: 0.24942
# Batch count: 490, Avg. per-sample expected Loss: 0.25648
# Batch count: 491, Avg. per-sample expected Loss: 0.25139
# Batch count: 492, Avg. per-sample expected Loss: 0.24475
# Batch count: 493, Avg. per-sample expected Loss: 0.25349
# Batch count: 494, Avg. per-sample expected Loss: 0.24639
# Batch count: 495, Avg. per-sample expected Loss: 0.25142
# Batch count: 496, Avg. per-sample expected Loss: 0.24211
# Batch count: 497, Avg. per-sample expected Loss: 0.24926
# Batch count: 498, Avg. per-sample expected Loss: 0.24667
# Batch count: 499, Avg. per-sample expected Loss: 0.24410

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6c_cost, "b", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6c_Ecost, "c.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training using 2-QNSCD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("6-RQSGD.png")
plt.show()

# %% [markdown]
# ## 2-RQSGD using 600 samples per step and 6 samples per itr

# %%
SGD6params = np.array(init_params)
SGD6_cost = []
SGD6_Ecost = []

SGD6_cost.append(temp_cost)
SGD6_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 2 coordinates
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())
        
        grad = []
        
        ### Gradient estimation
        y_hat01,b01 = EstGrad(SGD6params,phiT[:,itr3+0],idx[0])
        b01 = (1-b01)/2
        y_hat02,b02 = EstGrad(SGD6params,phiT[:,itr3+1],idx[0])
        b02 = (1-b02)/2
        y_hat03,b03 = EstGrad(SGD6params,phiT[:,itr3+2],idx[0])
        b03 = (1-b03)/2
        
        temp0 = ((-1)**b01)*loss(y_hat01,labelT[itr3+0]) \
              + ((-1)**b02)*loss(y_hat02,labelT[itr3+1]) \
              + ((-1)**b03)*loss(y_hat03,labelT[itr3+2])

        grad.append((-1)*temp0/3)
        
        y_hat11,b11 = EstGrad(SGD6params,phiT[:,itr3+3],idx[1])
        b11 = (1-b11)/2
        y_hat12,b12 = EstGrad(SGD6params,phiT[:,itr3+4],idx[1])
        b12 = (1-b12)/2
        y_hat13,b13 = EstGrad(SGD6params,phiT[:,itr3+5],idx[1])
        b13 = (1-b13)/2
        
        temp1 = ((-1)**b11)*loss(y_hat11,labelT[itr3+3]) \
              + ((-1)**b12)*loss(y_hat12,labelT[itr3+4]) \
              + ((-1)**b13)*loss(y_hat13,labelT[itr3+5])

        grad.append((-1)*temp1/3)

        ### single-parameter update
        SGD6params[idx] = SGD6params[idx] - np.dot(step_size,grad)
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6params,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6count = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6params,phiT[:,itr]) != labelT[itr]:
            SGD6count += 1
    SGD6_Ecost.append(SGD6count/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "6Q 2-RQSGD_6s Expected Loss"
file_name2 = "6Q 2-RQSGD_6s Empirical Loss"

np.save(file_name1,SGD6_cost)
np.save(file_name2,SGD6_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.50636
# Batch count:  1, Avg. per-sample expected Loss: 0.50888
# Batch count:  2, Avg. per-sample expected Loss: 0.50302
# Batch count:  3, Avg. per-sample expected Loss: 0.50249
# Batch count:  4, Avg. per-sample expected Loss: 0.49888
# Batch count:  5, Avg. per-sample expected Loss: 0.50341
# Batch count:  6, Avg. per-sample expected Loss: 0.49872
# Batch count:  7, Avg. per-sample expected Loss: 0.50367
# Batch count:  8, Avg. per-sample expected Loss: 0.50148
# Batch count:  9, Avg. per-sample expected Loss: 0.50590
# Batch count: 10, Avg. per-sample expected Loss: 0.50467
# Batch count: 11, Avg. per-sample expected Loss: 0.50121
# Batch count: 12, Avg. per-sample expected Loss: 0.50042
# Batch count: 13, Avg. per-sample expected Loss: 0.50109
# Batch count: 14, Avg. per-sample expected Loss: 0.49809
# Batch count: 15, Avg. per-sample expected Loss: 0.49940
# Batch count: 16, Avg. per-sample expected Loss: 0.49553
# Batch count: 17, Avg. per-sample expected Loss: 0.49999
# Batch count: 18, Avg. per-sample expected Loss: 0.49767
# Batch count: 19, Avg. per-sample expected Loss: 0.49498
# Batch count: 20, Avg. per-sample expected Loss: 0.50045
# Batch count: 21, Avg. per-sample expected Loss: 0.49794
# Batch count: 22, Avg. per-sample expected Loss: 0.49751
# Batch count: 23, Avg. per-sample expected Loss: 0.50032
# Batch count: 24, Avg. per-sample expected Loss: 0.50909
# Batch count: 25, Avg. per-sample expected Loss: 0.50422
# Batch count: 26, Avg. per-sample expected Loss: 0.50051
# Batch count: 27, Avg. per-sample expected Loss: 0.50390
# Batch count: 28, Avg. per-sample expected Loss: 0.50207
# Batch count: 29, Avg. per-sample expected Loss: 0.50026
# Batch count: 30, Avg. per-sample expected Loss: 0.49994
# Batch count: 31, Avg. per-sample expected Loss: 0.49604
# Batch count: 32, Avg. per-sample expected Loss: 0.49715
# Batch count: 33, Avg. per-sample expected Loss: 0.49235
# Batch count: 34, Avg. per-sample expected Loss: 0.50056
# Batch count: 35, Avg. per-sample expected Loss: 0.49944
# Batch count: 36, Avg. per-sample expected Loss: 0.49285
# Batch count: 37, Avg. per-sample expected Loss: 0.49892
# Batch count: 38, Avg. per-sample expected Loss: 0.49446
# Batch count: 39, Avg. per-sample expected Loss: 0.49320
# Batch count: 40, Avg. per-sample expected Loss: 0.49400
# Batch count: 41, Avg. per-sample expected Loss: 0.49619
# Batch count: 42, Avg. per-sample expected Loss: 0.49486
# Batch count: 43, Avg. per-sample expected Loss: 0.49433
# Batch count: 44, Avg. per-sample expected Loss: 0.49619
# Batch count: 45, Avg. per-sample expected Loss: 0.49800
# Batch count: 46, Avg. per-sample expected Loss: 0.49540
# Batch count: 47, Avg. per-sample expected Loss: 0.49338
# Batch count: 48, Avg. per-sample expected Loss: 0.49192
# Batch count: 49, Avg. per-sample expected Loss: 0.49118
# Batch count: 50, Avg. per-sample expected Loss: 0.49132
# Batch count: 51, Avg. per-sample expected Loss: 0.49174
# Batch count: 52, Avg. per-sample expected Loss: 0.49752
# Batch count: 53, Avg. per-sample expected Loss: 0.49506
# Batch count: 54, Avg. per-sample expected Loss: 0.49480
# Batch count: 55, Avg. per-sample expected Loss: 0.49645
# Batch count: 56, Avg. per-sample expected Loss: 0.49534
# Batch count: 57, Avg. per-sample expected Loss: 0.49349
# Batch count: 58, Avg. per-sample expected Loss: 0.48437
# Batch count: 59, Avg. per-sample expected Loss: 0.49292
# Batch count: 60, Avg. per-sample expected Loss: 0.49577
# Batch count: 61, Avg. per-sample expected Loss: 0.48732
# Batch count: 62, Avg. per-sample expected Loss: 0.49443
# Batch count: 63, Avg. per-sample expected Loss: 0.49049
# Batch count: 64, Avg. per-sample expected Loss: 0.49270
# Batch count: 65, Avg. per-sample expected Loss: 0.48680
# Batch count: 66, Avg. per-sample expected Loss: 0.48992
# Batch count: 67, Avg. per-sample expected Loss: 0.48844
# Batch count: 68, Avg. per-sample expected Loss: 0.48409
# Batch count: 69, Avg. per-sample expected Loss: 0.48971
# Batch count: 70, Avg. per-sample expected Loss: 0.48215
# Batch count: 71, Avg. per-sample expected Loss: 0.48832
# Batch count: 72, Avg. per-sample expected Loss: 0.48579
# Batch count: 73, Avg. per-sample expected Loss: 0.49260
# Batch count: 74, Avg. per-sample expected Loss: 0.49009
# Batch count: 75, Avg. per-sample expected Loss: 0.48570
# Batch count: 76, Avg. per-sample expected Loss: 0.49074
# Batch count: 77, Avg. per-sample expected Loss: 0.48572
# Batch count: 78, Avg. per-sample expected Loss: 0.48631
# Batch count: 79, Avg. per-sample expected Loss: 0.48616
# Batch count: 80, Avg. per-sample expected Loss: 0.48808
# Batch count: 81, Avg. per-sample expected Loss: 0.48966
# Batch count: 82, Avg. per-sample expected Loss: 0.48795
# Batch count: 83, Avg. per-sample expected Loss: 0.48778
# Batch count: 84, Avg. per-sample expected Loss: 0.48916
# Batch count: 85, Avg. per-sample expected Loss: 0.48904
# Batch count: 86, Avg. per-sample expected Loss: 0.48403
# Batch count: 87, Avg. per-sample expected Loss: 0.48138
# Batch count: 88, Avg. per-sample expected Loss: 0.48817
# Batch count: 89, Avg. per-sample expected Loss: 0.48661
# Batch count: 90, Avg. per-sample expected Loss: 0.48452
# Batch count: 91, Avg. per-sample expected Loss: 0.48948
# Batch count: 92, Avg. per-sample expected Loss: 0.48624
# Batch count: 93, Avg. per-sample expected Loss: 0.48332
# Batch count: 94, Avg. per-sample expected Loss: 0.48347
# Batch count: 95, Avg. per-sample expected Loss: 0.48239
# Batch count: 96, Avg. per-sample expected Loss: 0.47946
# Batch count: 97, Avg. per-sample expected Loss: 0.48050
# Batch count: 98, Avg. per-sample expected Loss: 0.48020
# Batch count: 99, Avg. per-sample expected Loss: 0.48449
# Batch count: 100, Avg. per-sample expected Loss: 0.47302
# Batch count: 101, Avg. per-sample expected Loss: 0.47708
# Batch count: 102, Avg. per-sample expected Loss: 0.48533
# Batch count: 103, Avg. per-sample expected Loss: 0.48407
# Batch count: 104, Avg. per-sample expected Loss: 0.48745
# Batch count: 105, Avg. per-sample expected Loss: 0.47726
# Batch count: 106, Avg. per-sample expected Loss: 0.48101
# Batch count: 107, Avg. per-sample expected Loss: 0.48531
# Batch count: 108, Avg. per-sample expected Loss: 0.48347
# Batch count: 109, Avg. per-sample expected Loss: 0.48687
# Batch count: 110, Avg. per-sample expected Loss: 0.48488
# Batch count: 111, Avg. per-sample expected Loss: 0.48340
# Batch count: 112, Avg. per-sample expected Loss: 0.48243
# Batch count: 113, Avg. per-sample expected Loss: 0.48217
# Batch count: 114, Avg. per-sample expected Loss: 0.47613
# Batch count: 115, Avg. per-sample expected Loss: 0.48428
# Batch count: 116, Avg. per-sample expected Loss: 0.47753
# Batch count: 117, Avg. per-sample expected Loss: 0.47809
# Batch count: 118, Avg. per-sample expected Loss: 0.47823
# Batch count: 119, Avg. per-sample expected Loss: 0.48484
# Batch count: 120, Avg. per-sample expected Loss: 0.47853
# Batch count: 121, Avg. per-sample expected Loss: 0.48057
# Batch count: 122, Avg. per-sample expected Loss: 0.47656
# Batch count: 123, Avg. per-sample expected Loss: 0.47952
# Batch count: 124, Avg. per-sample expected Loss: 0.47730
# Batch count: 125, Avg. per-sample expected Loss: 0.47906
# Batch count: 126, Avg. per-sample expected Loss: 0.48000
# Batch count: 127, Avg. per-sample expected Loss: 0.47808
# Batch count: 128, Avg. per-sample expected Loss: 0.47705
# Batch count: 129, Avg. per-sample expected Loss: 0.47617
# Batch count: 130, Avg. per-sample expected Loss: 0.47563
# Batch count: 131, Avg. per-sample expected Loss: 0.47108
# Batch count: 132, Avg. per-sample expected Loss: 0.47847
# Batch count: 133, Avg. per-sample expected Loss: 0.47438
# Batch count: 134, Avg. per-sample expected Loss: 0.46981
# Batch count: 135, Avg. per-sample expected Loss: 0.47270
# Batch count: 136, Avg. per-sample expected Loss: 0.47519
# Batch count: 137, Avg. per-sample expected Loss: 0.47091
# Batch count: 138, Avg. per-sample expected Loss: 0.47312
# Batch count: 139, Avg. per-sample expected Loss: 0.47061
# Batch count: 140, Avg. per-sample expected Loss: 0.46736
# Batch count: 141, Avg. per-sample expected Loss: 0.47306
# Batch count: 142, Avg. per-sample expected Loss: 0.47558
# Batch count: 143, Avg. per-sample expected Loss: 0.46865
# Batch count: 144, Avg. per-sample expected Loss: 0.47202
# Batch count: 145, Avg. per-sample expected Loss: 0.46542
# Batch count: 146, Avg. per-sample expected Loss: 0.47339
# Batch count: 147, Avg. per-sample expected Loss: 0.47516
# Batch count: 148, Avg. per-sample expected Loss: 0.47214
# Batch count: 149, Avg. per-sample expected Loss: 0.47433
# Batch count: 150, Avg. per-sample expected Loss: 0.47773
# Batch count: 151, Avg. per-sample expected Loss: 0.46983
# Batch count: 152, Avg. per-sample expected Loss: 0.47861
# Batch count: 153, Avg. per-sample expected Loss: 0.47601
# Batch count: 154, Avg. per-sample expected Loss: 0.48054
# Batch count: 155, Avg. per-sample expected Loss: 0.46538
# Batch count: 156, Avg. per-sample expected Loss: 0.47007
# Batch count: 157, Avg. per-sample expected Loss: 0.46446
# Batch count: 158, Avg. per-sample expected Loss: 0.46660
# Batch count: 159, Avg. per-sample expected Loss: 0.47529
# Batch count: 160, Avg. per-sample expected Loss: 0.46736
# Batch count: 161, Avg. per-sample expected Loss: 0.46535
# Batch count: 162, Avg. per-sample expected Loss: 0.46861
# Batch count: 163, Avg. per-sample expected Loss: 0.46852
# Batch count: 164, Avg. per-sample expected Loss: 0.46252
# Batch count: 165, Avg. per-sample expected Loss: 0.46161
# Batch count: 166, Avg. per-sample expected Loss: 0.46905
# Batch count: 167, Avg. per-sample expected Loss: 0.47066
# Batch count: 168, Avg. per-sample expected Loss: 0.46223
# Batch count: 169, Avg. per-sample expected Loss: 0.46457
# Batch count: 170, Avg. per-sample expected Loss: 0.46718
# Batch count: 171, Avg. per-sample expected Loss: 0.46528
# Batch count: 172, Avg. per-sample expected Loss: 0.46353
# Batch count: 173, Avg. per-sample expected Loss: 0.46627
# Batch count: 174, Avg. per-sample expected Loss: 0.45998
# Batch count: 175, Avg. per-sample expected Loss: 0.46710
# Batch count: 176, Avg. per-sample expected Loss: 0.46275
# Batch count: 177, Avg. per-sample expected Loss: 0.46149
# Batch count: 178, Avg. per-sample expected Loss: 0.45812
# Batch count: 179, Avg. per-sample expected Loss: 0.46320
# Batch count: 180, Avg. per-sample expected Loss: 0.47353
# Batch count: 181, Avg. per-sample expected Loss: 0.46982
# Batch count: 182, Avg. per-sample expected Loss: 0.46055
# Batch count: 183, Avg. per-sample expected Loss: 0.46458
# Batch count: 184, Avg. per-sample expected Loss: 0.46498
# Batch count: 185, Avg. per-sample expected Loss: 0.46350
# Batch count: 186, Avg. per-sample expected Loss: 0.47511
# Batch count: 187, Avg. per-sample expected Loss: 0.46840
# Batch count: 188, Avg. per-sample expected Loss: 0.46701
# Batch count: 189, Avg. per-sample expected Loss: 0.45755
# Batch count: 190, Avg. per-sample expected Loss: 0.46856
# Batch count: 191, Avg. per-sample expected Loss: 0.46327
# Batch count: 192, Avg. per-sample expected Loss: 0.46148
# Batch count: 193, Avg. per-sample expected Loss: 0.46347
# Batch count: 194, Avg. per-sample expected Loss: 0.46480
# Batch count: 195, Avg. per-sample expected Loss: 0.46322
# Batch count: 196, Avg. per-sample expected Loss: 0.46607
# Batch count: 197, Avg. per-sample expected Loss: 0.46438
# Batch count: 198, Avg. per-sample expected Loss: 0.46441
# Batch count: 199, Avg. per-sample expected Loss: 0.46091
# Batch count: 200, Avg. per-sample expected Loss: 0.46192
# Batch count: 201, Avg. per-sample expected Loss: 0.46248
# Batch count: 202, Avg. per-sample expected Loss: 0.45938
# Batch count: 203, Avg. per-sample expected Loss: 0.46485
# Batch count: 204, Avg. per-sample expected Loss: 0.46236
# Batch count: 205, Avg. per-sample expected Loss: 0.45835
# Batch count: 206, Avg. per-sample expected Loss: 0.46124
# Batch count: 207, Avg. per-sample expected Loss: 0.45874
# Batch count: 208, Avg. per-sample expected Loss: 0.46065
# Batch count: 209, Avg. per-sample expected Loss: 0.45528
# Batch count: 210, Avg. per-sample expected Loss: 0.45877
# Batch count: 211, Avg. per-sample expected Loss: 0.45837
# Batch count: 212, Avg. per-sample expected Loss: 0.46460
# Batch count: 213, Avg. per-sample expected Loss: 0.46305
# Batch count: 214, Avg. per-sample expected Loss: 0.45931
# Batch count: 215, Avg. per-sample expected Loss: 0.46204
# Batch count: 216, Avg. per-sample expected Loss: 0.45708
# Batch count: 217, Avg. per-sample expected Loss: 0.45236
# Batch count: 218, Avg. per-sample expected Loss: 0.46885
# Batch count: 219, Avg. per-sample expected Loss: 0.45207
# Batch count: 220, Avg. per-sample expected Loss: 0.46236
# Batch count: 221, Avg. per-sample expected Loss: 0.45073
# Batch count: 222, Avg. per-sample expected Loss: 0.45640
# Batch count: 223, Avg. per-sample expected Loss: 0.45175
# Batch count: 224, Avg. per-sample expected Loss: 0.45756
# Batch count: 225, Avg. per-sample expected Loss: 0.45827
# Batch count: 226, Avg. per-sample expected Loss: 0.45496
# Batch count: 227, Avg. per-sample expected Loss: 0.45247
# Batch count: 228, Avg. per-sample expected Loss: 0.45335
# Batch count: 229, Avg. per-sample expected Loss: 0.45105
# Batch count: 230, Avg. per-sample expected Loss: 0.45127
# Batch count: 231, Avg. per-sample expected Loss: 0.44726
# Batch count: 232, Avg. per-sample expected Loss: 0.44794
# Batch count: 233, Avg. per-sample expected Loss: 0.44632
# Batch count: 234, Avg. per-sample expected Loss: 0.45542
# Batch count: 235, Avg. per-sample expected Loss: 0.45273
# Batch count: 236, Avg. per-sample expected Loss: 0.45328
# Batch count: 237, Avg. per-sample expected Loss: 0.45318
# Batch count: 238, Avg. per-sample expected Loss: 0.44691
# Batch count: 239, Avg. per-sample expected Loss: 0.45881
# Batch count: 240, Avg. per-sample expected Loss: 0.44996
# Batch count: 241, Avg. per-sample expected Loss: 0.44741
# Batch count: 242, Avg. per-sample expected Loss: 0.44948
# Batch count: 243, Avg. per-sample expected Loss: 0.44925
# Batch count: 244, Avg. per-sample expected Loss: 0.45102
# Batch count: 245, Avg. per-sample expected Loss: 0.44839
# Batch count: 246, Avg. per-sample expected Loss: 0.45118
# Batch count: 247, Avg. per-sample expected Loss: 0.45292
# Batch count: 248, Avg. per-sample expected Loss: 0.43149
# Batch count: 249, Avg. per-sample expected Loss: 0.44301
# Batch count: 250, Avg. per-sample expected Loss: 0.44517
# Batch count: 251, Avg. per-sample expected Loss: 0.44084
# Batch count: 252, Avg. per-sample expected Loss: 0.44541
# Batch count: 253, Avg. per-sample expected Loss: 0.44596
# Batch count: 254, Avg. per-sample expected Loss: 0.45694
# Batch count: 255, Avg. per-sample expected Loss: 0.45525
# Batch count: 256, Avg. per-sample expected Loss: 0.44127
# Batch count: 257, Avg. per-sample expected Loss: 0.44173
# Batch count: 258, Avg. per-sample expected Loss: 0.44479
# Batch count: 259, Avg. per-sample expected Loss: 0.44927
# Batch count: 260, Avg. per-sample expected Loss: 0.44065
# Batch count: 261, Avg. per-sample expected Loss: 0.44172
# Batch count: 262, Avg. per-sample expected Loss: 0.44029
# Batch count: 263, Avg. per-sample expected Loss: 0.44491
# Batch count: 264, Avg. per-sample expected Loss: 0.44365
# Batch count: 265, Avg. per-sample expected Loss: 0.44137
# Batch count: 266, Avg. per-sample expected Loss: 0.44597
# Batch count: 267, Avg. per-sample expected Loss: 0.44364
# Batch count: 268, Avg. per-sample expected Loss: 0.44181
# Batch count: 269, Avg. per-sample expected Loss: 0.44749
# Batch count: 270, Avg. per-sample expected Loss: 0.44991
# Batch count: 271, Avg. per-sample expected Loss: 0.44501
# Batch count: 272, Avg. per-sample expected Loss: 0.44442
# Batch count: 273, Avg. per-sample expected Loss: 0.44354
# Batch count: 274, Avg. per-sample expected Loss: 0.44017
# Batch count: 275, Avg. per-sample expected Loss: 0.45006
# Batch count: 276, Avg. per-sample expected Loss: 0.43368
# Batch count: 277, Avg. per-sample expected Loss: 0.44573
# Batch count: 278, Avg. per-sample expected Loss: 0.43586
# Batch count: 279, Avg. per-sample expected Loss: 0.43229
# Batch count: 280, Avg. per-sample expected Loss: 0.43887
# Batch count: 281, Avg. per-sample expected Loss: 0.43466
# Batch count: 282, Avg. per-sample expected Loss: 0.43779
# Batch count: 283, Avg. per-sample expected Loss: 0.44300
# Batch count: 284, Avg. per-sample expected Loss: 0.43967
# Batch count: 285, Avg. per-sample expected Loss: 0.43719
# Batch count: 286, Avg. per-sample expected Loss: 0.44588
# Batch count: 287, Avg. per-sample expected Loss: 0.43668
# Batch count: 288, Avg. per-sample expected Loss: 0.43599
# Batch count: 289, Avg. per-sample expected Loss: 0.43863
# Batch count: 290, Avg. per-sample expected Loss: 0.44099
# Batch count: 291, Avg. per-sample expected Loss: 0.44245
# Batch count: 292, Avg. per-sample expected Loss: 0.44416
# Batch count: 293, Avg. per-sample expected Loss: 0.44727
# Batch count: 294, Avg. per-sample expected Loss: 0.43222
# Batch count: 295, Avg. per-sample expected Loss: 0.44815
# Batch count: 296, Avg. per-sample expected Loss: 0.44337
# Batch count: 297, Avg. per-sample expected Loss: 0.43294
# Batch count: 298, Avg. per-sample expected Loss: 0.44197
# Batch count: 299, Avg. per-sample expected Loss: 0.44042
# Batch count: 300, Avg. per-sample expected Loss: 0.44137
# Batch count: 301, Avg. per-sample expected Loss: 0.43507
# Batch count: 302, Avg. per-sample expected Loss: 0.43860
# Batch count: 303, Avg. per-sample expected Loss: 0.44316
# Batch count: 304, Avg. per-sample expected Loss: 0.44082
# Batch count: 305, Avg. per-sample expected Loss: 0.44272
# Batch count: 306, Avg. per-sample expected Loss: 0.42955
# Batch count: 307, Avg. per-sample expected Loss: 0.43726
# Batch count: 308, Avg. per-sample expected Loss: 0.43527
# Batch count: 309, Avg. per-sample expected Loss: 0.43208
# Batch count: 310, Avg. per-sample expected Loss: 0.44015
# Batch count: 311, Avg. per-sample expected Loss: 0.43202
# Batch count: 312, Avg. per-sample expected Loss: 0.43272
# Batch count: 313, Avg. per-sample expected Loss: 0.43525
# Batch count: 314, Avg. per-sample expected Loss: 0.43665
# Batch count: 315, Avg. per-sample expected Loss: 0.43163
# Batch count: 316, Avg. per-sample expected Loss: 0.41920
# Batch count: 317, Avg. per-sample expected Loss: 0.43017
# Batch count: 318, Avg. per-sample expected Loss: 0.42113
# Batch count: 319, Avg. per-sample expected Loss: 0.43478
# Batch count: 320, Avg. per-sample expected Loss: 0.43132
# Batch count: 321, Avg. per-sample expected Loss: 0.43145
# Batch count: 322, Avg. per-sample expected Loss: 0.43433
# Batch count: 323, Avg. per-sample expected Loss: 0.43627
# Batch count: 324, Avg. per-sample expected Loss: 0.42353
# Batch count: 325, Avg. per-sample expected Loss: 0.42482
# Batch count: 326, Avg. per-sample expected Loss: 0.43294
# Batch count: 327, Avg. per-sample expected Loss: 0.42894
# Batch count: 328, Avg. per-sample expected Loss: 0.42836
# Batch count: 329, Avg. per-sample expected Loss: 0.41874
# Batch count: 330, Avg. per-sample expected Loss: 0.43744
# Batch count: 331, Avg. per-sample expected Loss: 0.42280
# Batch count: 332, Avg. per-sample expected Loss: 0.41748
# Batch count: 333, Avg. per-sample expected Loss: 0.43051
# Batch count: 334, Avg. per-sample expected Loss: 0.43519
# Batch count: 335, Avg. per-sample expected Loss: 0.42130
# Batch count: 336, Avg. per-sample expected Loss: 0.42793
# Batch count: 337, Avg. per-sample expected Loss: 0.43370
# Batch count: 338, Avg. per-sample expected Loss: 0.42959
# Batch count: 339, Avg. per-sample expected Loss: 0.43239
# Batch count: 340, Avg. per-sample expected Loss: 0.42927
# Batch count: 341, Avg. per-sample expected Loss: 0.43231
# Batch count: 342, Avg. per-sample expected Loss: 0.41952
# Batch count: 343, Avg. per-sample expected Loss: 0.42556
# Batch count: 344, Avg. per-sample expected Loss: 0.42017
# Batch count: 345, Avg. per-sample expected Loss: 0.42561
# Batch count: 346, Avg. per-sample expected Loss: 0.42263
# Batch count: 347, Avg. per-sample expected Loss: 0.42413
# Batch count: 348, Avg. per-sample expected Loss: 0.42428
# Batch count: 349, Avg. per-sample expected Loss: 0.42066
# Batch count: 350, Avg. per-sample expected Loss: 0.42871
# Batch count: 351, Avg. per-sample expected Loss: 0.42513
# Batch count: 352, Avg. per-sample expected Loss: 0.42113
# Batch count: 353, Avg. per-sample expected Loss: 0.42919
# Batch count: 354, Avg. per-sample expected Loss: 0.42668
# Batch count: 355, Avg. per-sample expected Loss: 0.41523
# Batch count: 356, Avg. per-sample expected Loss: 0.42748
# Batch count: 357, Avg. per-sample expected Loss: 0.42740
# Batch count: 358, Avg. per-sample expected Loss: 0.41792
# Batch count: 359, Avg. per-sample expected Loss: 0.42861
# Batch count: 360, Avg. per-sample expected Loss: 0.42446
# Batch count: 361, Avg. per-sample expected Loss: 0.41457
# Batch count: 362, Avg. per-sample expected Loss: 0.42302
# Batch count: 363, Avg. per-sample expected Loss: 0.42065
# Batch count: 364, Avg. per-sample expected Loss: 0.41519
# Batch count: 365, Avg. per-sample expected Loss: 0.42688
# Batch count: 366, Avg. per-sample expected Loss: 0.41626
# Batch count: 367, Avg. per-sample expected Loss: 0.40790
# Batch count: 368, Avg. per-sample expected Loss: 0.41608
# Batch count: 369, Avg. per-sample expected Loss: 0.41594
# Batch count: 370, Avg. per-sample expected Loss: 0.41937
# Batch count: 371, Avg. per-sample expected Loss: 0.42024
# Batch count: 372, Avg. per-sample expected Loss: 0.42133
# Batch count: 373, Avg. per-sample expected Loss: 0.42157
# Batch count: 374, Avg. per-sample expected Loss: 0.42484
# Batch count: 375, Avg. per-sample expected Loss: 0.42369
# Batch count: 376, Avg. per-sample expected Loss: 0.41495
# Batch count: 377, Avg. per-sample expected Loss: 0.41398
# Batch count: 378, Avg. per-sample expected Loss: 0.41241
# Batch count: 379, Avg. per-sample expected Loss: 0.42649
# Batch count: 380, Avg. per-sample expected Loss: 0.42583
# Batch count: 381, Avg. per-sample expected Loss: 0.41560
# Batch count: 382, Avg. per-sample expected Loss: 0.41456
# Batch count: 383, Avg. per-sample expected Loss: 0.41529
# Batch count: 384, Avg. per-sample expected Loss: 0.41091
# Batch count: 385, Avg. per-sample expected Loss: 0.41461
# Batch count: 386, Avg. per-sample expected Loss: 0.41129
# Batch count: 387, Avg. per-sample expected Loss: 0.42397
# Batch count: 388, Avg. per-sample expected Loss: 0.41143
# Batch count: 389, Avg. per-sample expected Loss: 0.41901
# Batch count: 390, Avg. per-sample expected Loss: 0.39941
# Batch count: 391, Avg. per-sample expected Loss: 0.41779
# Batch count: 392, Avg. per-sample expected Loss: 0.41461
# Batch count: 393, Avg. per-sample expected Loss: 0.40625
# Batch count: 394, Avg. per-sample expected Loss: 0.41934
# Batch count: 395, Avg. per-sample expected Loss: 0.41146
# Batch count: 396, Avg. per-sample expected Loss: 0.40698
# Batch count: 397, Avg. per-sample expected Loss: 0.41505
# Batch count: 398, Avg. per-sample expected Loss: 0.41393
# Batch count: 399, Avg. per-sample expected Loss: 0.41478
# Batch count: 400, Avg. per-sample expected Loss: 0.41397
# Batch count: 401, Avg. per-sample expected Loss: 0.41407
# Batch count: 402, Avg. per-sample expected Loss: 0.40864
# Batch count: 403, Avg. per-sample expected Loss: 0.40613
# Batch count: 404, Avg. per-sample expected Loss: 0.41418
# Batch count: 405, Avg. per-sample expected Loss: 0.41038
# Batch count: 406, Avg. per-sample expected Loss: 0.41247
# Batch count: 407, Avg. per-sample expected Loss: 0.41278
# Batch count: 408, Avg. per-sample expected Loss: 0.40857
# Batch count: 409, Avg. per-sample expected Loss: 0.41368
# Batch count: 410, Avg. per-sample expected Loss: 0.39667
# Batch count: 411, Avg. per-sample expected Loss: 0.40959
# Batch count: 412, Avg. per-sample expected Loss: 0.41042
# Batch count: 413, Avg. per-sample expected Loss: 0.40783
# Batch count: 414, Avg. per-sample expected Loss: 0.42416
# Batch count: 415, Avg. per-sample expected Loss: 0.41202
# Batch count: 416, Avg. per-sample expected Loss: 0.40297
# Batch count: 417, Avg. per-sample expected Loss: 0.40268
# Batch count: 418, Avg. per-sample expected Loss: 0.40152
# Batch count: 419, Avg. per-sample expected Loss: 0.40558
# Batch count: 420, Avg. per-sample expected Loss: 0.40554
# Batch count: 421, Avg. per-sample expected Loss: 0.39907
# Batch count: 422, Avg. per-sample expected Loss: 0.40508
# Batch count: 423, Avg. per-sample expected Loss: 0.40941
# Batch count: 424, Avg. per-sample expected Loss: 0.41123
# Batch count: 425, Avg. per-sample expected Loss: 0.39064
# Batch count: 426, Avg. per-sample expected Loss: 0.40059
# Batch count: 427, Avg. per-sample expected Loss: 0.40808
# Batch count: 428, Avg. per-sample expected Loss: 0.41104
# Batch count: 429, Avg. per-sample expected Loss: 0.40029
# Batch count: 430, Avg. per-sample expected Loss: 0.38911
# Batch count: 431, Avg. per-sample expected Loss: 0.39472
# Batch count: 432, Avg. per-sample expected Loss: 0.39388
# Batch count: 433, Avg. per-sample expected Loss: 0.40350
# Batch count: 434, Avg. per-sample expected Loss: 0.40967
# Batch count: 435, Avg. per-sample expected Loss: 0.40364
# Batch count: 436, Avg. per-sample expected Loss: 0.40260
# Batch count: 437, Avg. per-sample expected Loss: 0.39745
# Batch count: 438, Avg. per-sample expected Loss: 0.40390
# Batch count: 439, Avg. per-sample expected Loss: 0.39702
# Batch count: 440, Avg. per-sample expected Loss: 0.39514
# Batch count: 441, Avg. per-sample expected Loss: 0.40171
# Batch count: 442, Avg. per-sample expected Loss: 0.39813
# Batch count: 443, Avg. per-sample expected Loss: 0.40253
# Batch count: 444, Avg. per-sample expected Loss: 0.41169
# Batch count: 445, Avg. per-sample expected Loss: 0.39762
# Batch count: 446, Avg. per-sample expected Loss: 0.38405
# Batch count: 447, Avg. per-sample expected Loss: 0.38613
# Batch count: 448, Avg. per-sample expected Loss: 0.39271
# Batch count: 449, Avg. per-sample expected Loss: 0.41607
# Batch count: 450, Avg. per-sample expected Loss: 0.39842
# Batch count: 451, Avg. per-sample expected Loss: 0.39126
# Batch count: 452, Avg. per-sample expected Loss: 0.40015
# Batch count: 453, Avg. per-sample expected Loss: 0.39856
# Batch count: 454, Avg. per-sample expected Loss: 0.39869
# Batch count: 455, Avg. per-sample expected Loss: 0.39608
# Batch count: 456, Avg. per-sample expected Loss: 0.39619
# Batch count: 457, Avg. per-sample expected Loss: 0.40254
# Batch count: 458, Avg. per-sample expected Loss: 0.39608
# Batch count: 459, Avg. per-sample expected Loss: 0.38888
# Batch count: 460, Avg. per-sample expected Loss: 0.38785
# Batch count: 461, Avg. per-sample expected Loss: 0.39475
# Batch count: 462, Avg. per-sample expected Loss: 0.40759
# Batch count: 463, Avg. per-sample expected Loss: 0.39692
# Batch count: 464, Avg. per-sample expected Loss: 0.39667
# Batch count: 465, Avg. per-sample expected Loss: 0.39059
# Batch count: 466, Avg. per-sample expected Loss: 0.39344
# Batch count: 467, Avg. per-sample expected Loss: 0.40157
# Batch count: 468, Avg. per-sample expected Loss: 0.38060
# Batch count: 469, Avg. per-sample expected Loss: 0.38778
# Batch count: 470, Avg. per-sample expected Loss: 0.39262
# Batch count: 471, Avg. per-sample expected Loss: 0.39386
# Batch count: 472, Avg. per-sample expected Loss: 0.38979
# Batch count: 473, Avg. per-sample expected Loss: 0.39328
# Batch count: 474, Avg. per-sample expected Loss: 0.38341
# Batch count: 475, Avg. per-sample expected Loss: 0.39829
# Batch count: 476, Avg. per-sample expected Loss: 0.39781
# Batch count: 477, Avg. per-sample expected Loss: 0.38934
# Batch count: 478, Avg. per-sample expected Loss: 0.38899
# Batch count: 479, Avg. per-sample expected Loss: 0.40029
# Batch count: 480, Avg. per-sample expected Loss: 0.38852
# Batch count: 481, Avg. per-sample expected Loss: 0.39436
# Batch count: 482, Avg. per-sample expected Loss: 0.38351
# Batch count: 483, Avg. per-sample expected Loss: 0.39011
# Batch count: 484, Avg. per-sample expected Loss: 0.38690
# Batch count: 485, Avg. per-sample expected Loss: 0.39336
# Batch count: 486, Avg. per-sample expected Loss: 0.39660
# Batch count: 487, Avg. per-sample expected Loss: 0.38407
# Batch count: 488, Avg. per-sample expected Loss: 0.39669
# Batch count: 489, Avg. per-sample expected Loss: 0.37578
# Batch count: 490, Avg. per-sample expected Loss: 0.39612
# Batch count: 491, Avg. per-sample expected Loss: 0.38273
# Batch count: 492, Avg. per-sample expected Loss: 0.38469
# Batch count: 493, Avg. per-sample expected Loss: 0.39567
# Batch count: 494, Avg. per-sample expected Loss: 0.38112
# Batch count: 495, Avg. per-sample expected Loss: 0.39255
# Batch count: 496, Avg. per-sample expected Loss: 0.37802
# Batch count: 497, Avg. per-sample expected Loss: 0.38963
# Batch count: 498, Avg. per-sample expected Loss: 0.39067
# Batch count: 499, Avg. per-sample expected Loss: 0.38957

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")

plt.title("Training using 2-QNSCD and 2-RQSGD (6 samples per itr)")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("2RSGD_6s.png")
plt.show()

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")
plt.plot(SGD6c_cost, "g", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")
plt.plot(SGD6c_Ecost, "g.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training 2-QNSCD and 2-RQSGD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("RQSGD.png")
plt.show()

# %% [markdown]
# ## Testing Phase

# %%
### Saving Final Parameters:
file_name1 = "6Q 2-QNSCD params"
file_name2 = "6Q 2-RQSGD_6s params"
file_name3 = "6Q 6-RQSGD params"

np.save(file_name1,NCGDparams)
np.save(file_name2,SGD6params)
np.save(file_name3,SGD6cparams)

# %%
phiTest = np.load('6-qubitsPhiTest_v1.npy')
labelTest = np.load('6-qubitsLabelTest_v1.npy')

phiTest.requires_grad = False
labelTest.requires_grad = False

# %%
nTest = 1000

NCGDparams_opt = NCGDparams 
SGD6params_opt = SGD6params
SGD6cparams_opt = SGD6cparams

# %%
### Optimal Expected Loss
expOperator = 0

for i in range(nTest):
    op = np.matmul(phiTest[:,i].reshape(dim,1),phiTest[:,i].reshape(1,dim))
    expOperator = expOperator + labelTest[i]*op
expOperator = expOperator/(nTest)
opt_value = 0.5*(1+sum(abs(np.linalg.svd(expOperator)[1])))

# %%
NCGD_rslt = []
SGD6_rslt = []
SGD6c_rslt = []

for i in range(int(1e1)):
    NCGDcount = 0
    SGD6count = 0
    SGD6ccount = 0

    for itr in range(nTest):
        if circuit_test(NCGDparams_opt,phiTest[:,itr]) == labelTest[itr]:
            NCGDcount += 1 
        if circuit_test(SGD6params_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6count += 1
        if circuit_test(SGD6cparams_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6ccount += 1
    
    NCGD_rslt.append(NCGDcount/nTest)
    SGD6_rslt.append(SGD6count/nTest)
    SGD6c_rslt.append(SGD6ccount/nTest)
#     print("itr = ",i)

# %%
print("Optimal: {:.3f} \nNCGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n2-RQSGD_6s: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n6-RQSGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f}"\
      .format(opt_value,np.average(NCGD_rslt),np.std(NCGD_rslt),max(NCGD_rslt),min(NCGD_rslt),\
              np.average(SGD6_rslt),np.std(SGD6_rslt),max(SGD6_rslt),min(SGD6_rslt), \
              np.average(SGD6c_rslt),np.std(SGD6c_rslt),max(SGD6c_rslt),min(SGD6c_rslt)))
# Out:
# Optimal: 0.880
# NCGD: 0.831 / 0.010 max: 0.845 min: 0.809
# 2-RQSGD_6s: 0.619 / 0.017 max: 0.662 min: 0.601
# 6-RQSGD: 0.756 / 0.011 max: 0.774 min: 0.731
