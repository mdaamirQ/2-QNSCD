# %%
import pennylane as qml
from pennylane import numpy as np
import scipy
import matplotlib.pyplot as plt
from globalVars import *
from model_6qubit import *

from GRADest_6Q import EstGrad
from EQFIMest_6Q import Est_EQFIM

# %% [markdown]
# ## Quantum Neural Network

# %%
random_state = np.random.rand(dim)
random_state = random_state /np.linalg.norm(random_state)
qml.draw_mpl(QNN)(np.zeros(nparams),random_state)
# Out:
# (<Figure size 1400x700 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### Model Initialization

# %%
S_pItr = 6  # no. of samples used per-iteration 

nStep = 350
nItr = 100
step_size = 0.0025

Bsize = S_pItr*nItr

# %%
phiTrain = np.load('6-qubitsPhiTrain_v1.npy')
labelTrain = np.load('6-qubitsLabelTrain_v1.npy')

phiTrain.requires_grad = False
labelTrain.requires_grad = False

# %%
'QNSCD Dataset'
phiTrainNCGD = phiTrain
labelTrainNCGD = labelTrain

'SGD Dataset'
phiTrainSGD = phiTrain
labelTrainSGD = labelTrain

# %%
### Optimal Expected Loss
Opt_cost = []
itrBatch = np.linspace(0,Bsize*nStep,nStep,endpoint = False,dtype = 'int').tolist()
for itr1 in itrBatch:
    expOperator = 0
    for itr2 in range(Bsize):
        temp_phi = phiTrain[:,itr1+itr2]
        op = np.matmul(temp_phi.reshape(dim,1),temp_phi.reshape(1,dim))
        expOperator = expOperator + labelTrain[itr1+itr2]*op
    expOperator = expOperator/Bsize
    opt_value = 0.5*(1-sum(abs(np.linalg.svd(expOperator)[1])))
    Opt_cost.append(opt_value)

file_name = "6Q-Minimum Expected Loss"
np.save(file_name,Opt_cost)

# %% [markdown]
# # Optimizers

# %%
'QNN outputs yhat'
dev = qml.device("default.qubit", wires=nqubits, shots=1)

@qml.qnode(dev,interface='autograd')
def circuit_test(params,state):
    QNN(params,state)
    return qml.sample(qml.Hermitian(M,wires=list(range(nqubits))))

# %%
init_params = np.random.uniform(low=0, high=2*np.pi, size=nparams, requires_grad=True)
init_params = np.array([4.47223436, 4.72314131, 3.14340011, 3.2658928,  6.15924206, 1.86641595,
 1.68428304, 0.62733931, 3.202971,   0.46525576, 4.97576801, 2.2485411,
 5.58758145, 5.75317779, 4.67339748, 0.71862413, 2.60192139, 4.2381242,
 1.43745953, 5.2214462,  2.5574245,  0.10724895, 3.69591693, 3.11757346,
 3.8869035,  4.1659682,  1.54997768, 6.2717338,  3.41765364, 0.74520338,
 0.18692038, 1.76531085, 5.85708271, 0.75103565, 5.74953692, 0.83595564], requires_grad=True)

'cost initialization'
phiTrain0 = phiTrain[:,-1*(Bsize+1):-1]
labelTrain0 = labelTrain[-1*(Bsize+1):-1]
temp_cost = sum([ps_expLoss(init_params,phiTrain0[:,itr],labelTrain0[itr]) for itr in range(Bsize)])/Bsize
print("Initial Average Per-Sample Expected Loss: ",temp_cost)

count = 0
for itr in range(Bsize):
    if circuit_test(init_params,phiTrain0[:,itr]) != labelTrain0[itr]:
        count += 1
temp_Ecost = count/Bsize
print("Initial Average Empirical Loss", temp_Ecost)
# Out:
# Initial Average Per-Sample Expected Loss:  0.5413127286686608
# Initial Average Empirical Loss 0.5383333333333333

# %% [markdown]
# ## Quantum Natural Stochastic Pairwise Coordinate Descent (2-QNSCD)

# %%
NCGDparams = np.array(init_params)
NCGD_cost = []
NCGD_Ecost = []

NCGD_cost.append(temp_cost)
NCGD_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainNCGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainNCGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a pair of coordinate
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())

        ### Gradient estimation
        y1, b1 = EstGrad(NCGDparams,phiT[:,itr3],idx[0])
        y2, b2 = EstGrad(NCGDparams,phiT[:,itr3+1],idx[1])
        b1 = (1-b1)/2
        b2 = (1-b2)/2

        grad = [-1*((-1)**b1)*loss(y1,labelT[itr3]),-1*((-1)**b2)*loss(y2,labelT[itr3+1])]
        
        ### E-QFIM estimation
        metric = Est_EQFIM(NCGDparams,idx,phiT[:,itr3+2:itr3+S_pItr])

        ### double-parameters update
        NCGDparams[idx] = NCGDparams[idx] - (step_size)*np.dot(np.linalg.inv(metric),grad) 
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(NCGDparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    NCGD_cost.append(energy)
    
    ### average empirical loss calculation
    NCGDcount = 0
    for itr in range(Bsize):
        if circuit_test(NCGDparams,phiT[:,itr]) != labelT[itr]:
            NCGDcount += 1
    NCGD_Ecost.append(NCGDcount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))

file_name1 = "6Q 2-QNSCD Expected Loss"
file_name2 = "6Q 2-QNSCD Empirical Loss"

np.save(file_name1,NCGD_cost)
np.save(file_name2,NCGD_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.54131
# Batch count:  1, Avg. per-sample expected Loss: 0.54040
# Batch count:  2, Avg. per-sample expected Loss: 0.54000
# Batch count:  3, Avg. per-sample expected Loss: 0.54214
# Batch count:  4, Avg. per-sample expected Loss: 0.53718
# Batch count:  5, Avg. per-sample expected Loss: 0.54177
# Batch count:  6, Avg. per-sample expected Loss: 0.54219
# Batch count:  7, Avg. per-sample expected Loss: 0.53728
# Batch count:  8, Avg. per-sample expected Loss: 0.53927
# Batch count:  9, Avg. per-sample expected Loss: 0.53907
# Batch count: 10, Avg. per-sample expected Loss: 0.53565
# Batch count: 11, Avg. per-sample expected Loss: 0.53925
# Batch count: 12, Avg. per-sample expected Loss: 0.53501
# Batch count: 13, Avg. per-sample expected Loss: 0.53179
# Batch count: 14, Avg. per-sample expected Loss: 0.53250
# Batch count: 15, Avg. per-sample expected Loss: 0.53259
# Batch count: 16, Avg. per-sample expected Loss: 0.52968
# Batch count: 17, Avg. per-sample expected Loss: 0.53093
# Batch count: 18, Avg. per-sample expected Loss: 0.53346
# Batch count: 19, Avg. per-sample expected Loss: 0.52885
# Batch count: 20, Avg. per-sample expected Loss: 0.53017
# Batch count: 21, Avg. per-sample expected Loss: 0.53514
# Batch count: 22, Avg. per-sample expected Loss: 0.53497
# Batch count: 23, Avg. per-sample expected Loss: 0.53891
# Batch count: 24, Avg. per-sample expected Loss: 0.53145
# Batch count: 25, Avg. per-sample expected Loss: 0.53377
# Batch count: 26, Avg. per-sample expected Loss: 0.53539
# Batch count: 27, Avg. per-sample expected Loss: 0.53406
# Batch count: 28, Avg. per-sample expected Loss: 0.53239
# Batch count: 29, Avg. per-sample expected Loss: 0.53497
# Batch count: 30, Avg. per-sample expected Loss: 0.53934
# Batch count: 31, Avg. per-sample expected Loss: 0.53969
# Batch count: 32, Avg. per-sample expected Loss: 0.54199
# Batch count: 33, Avg. per-sample expected Loss: 0.54310
# Batch count: 34, Avg. per-sample expected Loss: 0.54105
# Batch count: 35, Avg. per-sample expected Loss: 0.53769
# Batch count: 36, Avg. per-sample expected Loss: 0.54412
# Batch count: 37, Avg. per-sample expected Loss: 0.54096
# Batch count: 38, Avg. per-sample expected Loss: 0.53960
# Batch count: 39, Avg. per-sample expected Loss: 0.53890
# Batch count: 40, Avg. per-sample expected Loss: 0.53901
# Batch count: 41, Avg. per-sample expected Loss: 0.53805
# Batch count: 42, Avg. per-sample expected Loss: 0.54096
# Batch count: 43, Avg. per-sample expected Loss: 0.54372
# Batch count: 44, Avg. per-sample expected Loss: 0.54119
# Batch count: 45, Avg. per-sample expected Loss: 0.54496
# Batch count: 46, Avg. per-sample expected Loss: 0.54033
# Batch count: 47, Avg. per-sample expected Loss: 0.53975
# Batch count: 48, Avg. per-sample expected Loss: 0.54089
# Batch count: 49, Avg. per-sample expected Loss: 0.53860
# Batch count: 50, Avg. per-sample expected Loss: 0.53777
# Batch count: 51, Avg. per-sample expected Loss: 0.53184
# Batch count: 52, Avg. per-sample expected Loss: 0.52753
# Batch count: 53, Avg. per-sample expected Loss: 0.52743
# Batch count: 54, Avg. per-sample expected Loss: 0.52618
# Batch count: 55, Avg. per-sample expected Loss: 0.51959
# Batch count: 56, Avg. per-sample expected Loss: 0.52016
# Batch count: 57, Avg. per-sample expected Loss: 0.51490
# Batch count: 58, Avg. per-sample expected Loss: 0.51785
# Batch count: 59, Avg. per-sample expected Loss: 0.51137
# Batch count: 60, Avg. per-sample expected Loss: 0.51194
# Batch count: 61, Avg. per-sample expected Loss: 0.50817
# Batch count: 62, Avg. per-sample expected Loss: 0.50369
# Batch count: 63, Avg. per-sample expected Loss: 0.50296
# Batch count: 64, Avg. per-sample expected Loss: 0.50264
# Batch count: 65, Avg. per-sample expected Loss: 0.50619
# Batch count: 66, Avg. per-sample expected Loss: 0.50190
# Batch count: 67, Avg. per-sample expected Loss: 0.49974
# Batch count: 68, Avg. per-sample expected Loss: 0.49994
# Batch count: 69, Avg. per-sample expected Loss: 0.49858
# Batch count: 70, Avg. per-sample expected Loss: 0.49931
# Batch count: 71, Avg. per-sample expected Loss: 0.50212
# Batch count: 72, Avg. per-sample expected Loss: 0.49595
# Batch count: 73, Avg. per-sample expected Loss: 0.49437
# Batch count: 74, Avg. per-sample expected Loss: 0.49710
# Batch count: 75, Avg. per-sample expected Loss: 0.49741
# Batch count: 76, Avg. per-sample expected Loss: 0.50034
# Batch count: 77, Avg. per-sample expected Loss: 0.49478
# Batch count: 78, Avg. per-sample expected Loss: 0.49431
# Batch count: 79, Avg. per-sample expected Loss: 0.49356
# Batch count: 80, Avg. per-sample expected Loss: 0.49610
# Batch count: 81, Avg. per-sample expected Loss: 0.49228
# Batch count: 82, Avg. per-sample expected Loss: 0.49433
# Batch count: 83, Avg. per-sample expected Loss: 0.49314
# Batch count: 84, Avg. per-sample expected Loss: 0.49171
# Batch count: 85, Avg. per-sample expected Loss: 0.49064
# Batch count: 86, Avg. per-sample expected Loss: 0.48732
# Batch count: 87, Avg. per-sample expected Loss: 0.48448
# Batch count: 88, Avg. per-sample expected Loss: 0.48038
# Batch count: 89, Avg. per-sample expected Loss: 0.47124
# Batch count: 90, Avg. per-sample expected Loss: 0.46886
# Batch count: 91, Avg. per-sample expected Loss: 0.47659
# Batch count: 92, Avg. per-sample expected Loss: 0.46572
# Batch count: 93, Avg. per-sample expected Loss: 0.47641
# Batch count: 94, Avg. per-sample expected Loss: 0.46491
# Batch count: 95, Avg. per-sample expected Loss: 0.46739
# Batch count: 96, Avg. per-sample expected Loss: 0.46386
# Batch count: 97, Avg. per-sample expected Loss: 0.46040
# Batch count: 98, Avg. per-sample expected Loss: 0.45900
# Batch count: 99, Avg. per-sample expected Loss: 0.46281
# Batch count: 100, Avg. per-sample expected Loss: 0.46050
# Batch count: 101, Avg. per-sample expected Loss: 0.45541
# Batch count: 102, Avg. per-sample expected Loss: 0.45582
# Batch count: 103, Avg. per-sample expected Loss: 0.46276
# Batch count: 104, Avg. per-sample expected Loss: 0.46165
# Batch count: 105, Avg. per-sample expected Loss: 0.46934
# Batch count: 106, Avg. per-sample expected Loss: 0.46397
# Batch count: 107, Avg. per-sample expected Loss: 0.46142
# Batch count: 108, Avg. per-sample expected Loss: 0.45913
# Batch count: 109, Avg. per-sample expected Loss: 0.46251
# Batch count: 110, Avg. per-sample expected Loss: 0.45233
# Batch count: 111, Avg. per-sample expected Loss: 0.45551
# Batch count: 112, Avg. per-sample expected Loss: 0.46123
# Batch count: 113, Avg. per-sample expected Loss: 0.45332
# Batch count: 114, Avg. per-sample expected Loss: 0.45926
# Batch count: 115, Avg. per-sample expected Loss: 0.45073
# Batch count: 116, Avg. per-sample expected Loss: 0.44863
# Batch count: 117, Avg. per-sample expected Loss: 0.44655
# Batch count: 118, Avg. per-sample expected Loss: 0.44267
# Batch count: 119, Avg. per-sample expected Loss: 0.44858
# Batch count: 120, Avg. per-sample expected Loss: 0.44522
# Batch count: 121, Avg. per-sample expected Loss: 0.44791
# Batch count: 122, Avg. per-sample expected Loss: 0.44953
# Batch count: 123, Avg. per-sample expected Loss: 0.44842
# Batch count: 124, Avg. per-sample expected Loss: 0.44639
# Batch count: 125, Avg. per-sample expected Loss: 0.44563
# Batch count: 126, Avg. per-sample expected Loss: 0.44083
# Batch count: 127, Avg. per-sample expected Loss: 0.44352
# Batch count: 128, Avg. per-sample expected Loss: 0.44604
# Batch count: 129, Avg. per-sample expected Loss: 0.44679
# Batch count: 130, Avg. per-sample expected Loss: 0.44861
# Batch count: 131, Avg. per-sample expected Loss: 0.44513
# Batch count: 132, Avg. per-sample expected Loss: 0.44398
# Batch count: 133, Avg. per-sample expected Loss: 0.43774
# Batch count: 134, Avg. per-sample expected Loss: 0.44503
# Batch count: 135, Avg. per-sample expected Loss: 0.44469
# Batch count: 136, Avg. per-sample expected Loss: 0.44793
# Batch count: 137, Avg. per-sample expected Loss: 0.44893
# Batch count: 138, Avg. per-sample expected Loss: 0.45007
# Batch count: 139, Avg. per-sample expected Loss: 0.44532
# Batch count: 140, Avg. per-sample expected Loss: 0.44301
# Batch count: 141, Avg. per-sample expected Loss: 0.44129
# Batch count: 142, Avg. per-sample expected Loss: 0.43614
# Batch count: 143, Avg. per-sample expected Loss: 0.43895
# Batch count: 144, Avg. per-sample expected Loss: 0.43414
# Batch count: 145, Avg. per-sample expected Loss: 0.43373
# Batch count: 146, Avg. per-sample expected Loss: 0.42225
# Batch count: 147, Avg. per-sample expected Loss: 0.42115
# Batch count: 148, Avg. per-sample expected Loss: 0.41812
# Batch count: 149, Avg. per-sample expected Loss: 0.41640
# Batch count: 150, Avg. per-sample expected Loss: 0.41700
# Batch count: 151, Avg. per-sample expected Loss: 0.41859
# Batch count: 152, Avg. per-sample expected Loss: 0.42106
# Batch count: 153, Avg. per-sample expected Loss: 0.41321
# Batch count: 154, Avg. per-sample expected Loss: 0.40844
# Batch count: 155, Avg. per-sample expected Loss: 0.41475
# Batch count: 156, Avg. per-sample expected Loss: 0.40373
# Batch count: 157, Avg. per-sample expected Loss: 0.40401
# Batch count: 158, Avg. per-sample expected Loss: 0.39786
# Batch count: 159, Avg. per-sample expected Loss: 0.39141
# Batch count: 160, Avg. per-sample expected Loss: 0.39498
# Batch count: 161, Avg. per-sample expected Loss: 0.38803
# Batch count: 162, Avg. per-sample expected Loss: 0.39099
# Batch count: 163, Avg. per-sample expected Loss: 0.38755
# Batch count: 164, Avg. per-sample expected Loss: 0.38358
# Batch count: 165, Avg. per-sample expected Loss: 0.37285
# Batch count: 166, Avg. per-sample expected Loss: 0.34818
# Batch count: 167, Avg. per-sample expected Loss: 0.34932
# Batch count: 168, Avg. per-sample expected Loss: 0.34771
# Batch count: 169, Avg. per-sample expected Loss: 0.34040
# Batch count: 170, Avg. per-sample expected Loss: 0.33637
# Batch count: 171, Avg. per-sample expected Loss: 0.34919
# Batch count: 172, Avg. per-sample expected Loss: 0.34246
# Batch count: 173, Avg. per-sample expected Loss: 0.34367
# Batch count: 174, Avg. per-sample expected Loss: 0.32915
# Batch count: 175, Avg. per-sample expected Loss: 0.32993
# Batch count: 176, Avg. per-sample expected Loss: 0.33844
# Batch count: 177, Avg. per-sample expected Loss: 0.33093
# Batch count: 178, Avg. per-sample expected Loss: 0.31858
# Batch count: 179, Avg. per-sample expected Loss: 0.31686
# Batch count: 180, Avg. per-sample expected Loss: 0.31108
# Batch count: 181, Avg. per-sample expected Loss: 0.30691
# Batch count: 182, Avg. per-sample expected Loss: 0.29372
# Batch count: 183, Avg. per-sample expected Loss: 0.28946
# Batch count: 184, Avg. per-sample expected Loss: 0.29193
# Batch count: 185, Avg. per-sample expected Loss: 0.28316
# Batch count: 186, Avg. per-sample expected Loss: 0.27830
# Batch count: 187, Avg. per-sample expected Loss: 0.28555
# Batch count: 188, Avg. per-sample expected Loss: 0.29025
# Batch count: 189, Avg. per-sample expected Loss: 0.27618
# Batch count: 190, Avg. per-sample expected Loss: 0.27630
# Batch count: 191, Avg. per-sample expected Loss: 0.28011
# Batch count: 192, Avg. per-sample expected Loss: 0.28196
# Batch count: 193, Avg. per-sample expected Loss: 0.27621
# Batch count: 194, Avg. per-sample expected Loss: 0.26554
# Batch count: 195, Avg. per-sample expected Loss: 0.26529
# Batch count: 196, Avg. per-sample expected Loss: 0.26286
# Batch count: 197, Avg. per-sample expected Loss: 0.25806
# Batch count: 198, Avg. per-sample expected Loss: 0.25588
# Batch count: 199, Avg. per-sample expected Loss: 0.25254
# Batch count: 200, Avg. per-sample expected Loss: 0.25262
# Batch count: 201, Avg. per-sample expected Loss: 0.25547
# Batch count: 202, Avg. per-sample expected Loss: 0.24526
# Batch count: 203, Avg. per-sample expected Loss: 0.23866
# Batch count: 204, Avg. per-sample expected Loss: 0.23449
# Batch count: 205, Avg. per-sample expected Loss: 0.23777
# Batch count: 206, Avg. per-sample expected Loss: 0.23540
# Batch count: 207, Avg. per-sample expected Loss: 0.22898
# Batch count: 208, Avg. per-sample expected Loss: 0.22104
# Batch count: 209, Avg. per-sample expected Loss: 0.23212
# Batch count: 210, Avg. per-sample expected Loss: 0.22506
# Batch count: 211, Avg. per-sample expected Loss: 0.23793
# Batch count: 212, Avg. per-sample expected Loss: 0.23102
# Batch count: 213, Avg. per-sample expected Loss: 0.22234
# Batch count: 214, Avg. per-sample expected Loss: 0.23025
# Batch count: 215, Avg. per-sample expected Loss: 0.21908
# Batch count: 216, Avg. per-sample expected Loss: 0.21947
# Batch count: 217, Avg. per-sample expected Loss: 0.22126
# Batch count: 218, Avg. per-sample expected Loss: 0.20727
# Batch count: 219, Avg. per-sample expected Loss: 0.20086
# Batch count: 220, Avg. per-sample expected Loss: 0.20173
# Batch count: 221, Avg. per-sample expected Loss: 0.20879
# Batch count: 222, Avg. per-sample expected Loss: 0.19971
# Batch count: 223, Avg. per-sample expected Loss: 0.20065
# Batch count: 224, Avg. per-sample expected Loss: 0.19651
# Batch count: 225, Avg. per-sample expected Loss: 0.19675
# Batch count: 226, Avg. per-sample expected Loss: 0.20261
# Batch count: 227, Avg. per-sample expected Loss: 0.19988
# Batch count: 228, Avg. per-sample expected Loss: 0.19938
# Batch count: 229, Avg. per-sample expected Loss: 0.19603
# Batch count: 230, Avg. per-sample expected Loss: 0.20095
# Batch count: 231, Avg. per-sample expected Loss: 0.19548
# Batch count: 232, Avg. per-sample expected Loss: 0.18699
# Batch count: 233, Avg. per-sample expected Loss: 0.19171
# Batch count: 234, Avg. per-sample expected Loss: 0.19858
# Batch count: 235, Avg. per-sample expected Loss: 0.19517
# Batch count: 236, Avg. per-sample expected Loss: 0.18256
# Batch count: 237, Avg. per-sample expected Loss: 0.18333
# Batch count: 238, Avg. per-sample expected Loss: 0.19863
# Batch count: 239, Avg. per-sample expected Loss: 0.17562
# Batch count: 240, Avg. per-sample expected Loss: 0.19053
# Batch count: 241, Avg. per-sample expected Loss: 0.19147
# Batch count: 242, Avg. per-sample expected Loss: 0.19302
# Batch count: 243, Avg. per-sample expected Loss: 0.20124
# Batch count: 244, Avg. per-sample expected Loss: 0.18663
# Batch count: 245, Avg. per-sample expected Loss: 0.19308
# Batch count: 246, Avg. per-sample expected Loss: 0.18166
# Batch count: 247, Avg. per-sample expected Loss: 0.18776
# Batch count: 248, Avg. per-sample expected Loss: 0.19684
# Batch count: 249, Avg. per-sample expected Loss: 0.19071
# Batch count: 250, Avg. per-sample expected Loss: 0.19086
# Batch count: 251, Avg. per-sample expected Loss: 0.18867
# Batch count: 252, Avg. per-sample expected Loss: 0.18334
# Batch count: 253, Avg. per-sample expected Loss: 0.17901
# Batch count: 254, Avg. per-sample expected Loss: 0.16966
# Batch count: 255, Avg. per-sample expected Loss: 0.16592
# Batch count: 256, Avg. per-sample expected Loss: 0.17069
# Batch count: 257, Avg. per-sample expected Loss: 0.17025
# Batch count: 258, Avg. per-sample expected Loss: 0.17115
# Batch count: 259, Avg. per-sample expected Loss: 0.16588
# Batch count: 260, Avg. per-sample expected Loss: 0.16639
# Batch count: 261, Avg. per-sample expected Loss: 0.15863
# Batch count: 262, Avg. per-sample expected Loss: 0.15517
# Batch count: 263, Avg. per-sample expected Loss: 0.15703
# Batch count: 264, Avg. per-sample expected Loss: 0.15900
# Batch count: 265, Avg. per-sample expected Loss: 0.15987
# Batch count: 266, Avg. per-sample expected Loss: 0.15544
# Batch count: 267, Avg. per-sample expected Loss: 0.15286
# Batch count: 268, Avg. per-sample expected Loss: 0.15931
# Batch count: 269, Avg. per-sample expected Loss: 0.15120
# Batch count: 270, Avg. per-sample expected Loss: 0.14691
# Batch count: 271, Avg. per-sample expected Loss: 0.15250
# Batch count: 272, Avg. per-sample expected Loss: 0.14506
# Batch count: 273, Avg. per-sample expected Loss: 0.14607
# Batch count: 274, Avg. per-sample expected Loss: 0.15238
# Batch count: 275, Avg. per-sample expected Loss: 0.14541
# Batch count: 276, Avg. per-sample expected Loss: 0.14206
# Batch count: 277, Avg. per-sample expected Loss: 0.13972
# Batch count: 278, Avg. per-sample expected Loss: 0.15620
# Batch count: 279, Avg. per-sample expected Loss: 0.15040
# Batch count: 280, Avg. per-sample expected Loss: 0.13991
# Batch count: 281, Avg. per-sample expected Loss: 0.14871
# Batch count: 282, Avg. per-sample expected Loss: 0.13847
# Batch count: 283, Avg. per-sample expected Loss: 0.13079
# Batch count: 284, Avg. per-sample expected Loss: 0.13987
# Batch count: 285, Avg. per-sample expected Loss: 0.13783
# Batch count: 286, Avg. per-sample expected Loss: 0.13641
# Batch count: 287, Avg. per-sample expected Loss: 0.14054
# Batch count: 288, Avg. per-sample expected Loss: 0.13662
# Batch count: 289, Avg. per-sample expected Loss: 0.14698
# Batch count: 290, Avg. per-sample expected Loss: 0.13495
# Batch count: 291, Avg. per-sample expected Loss: 0.13560
# Batch count: 292, Avg. per-sample expected Loss: 0.13435
# Batch count: 293, Avg. per-sample expected Loss: 0.13554
# Batch count: 294, Avg. per-sample expected Loss: 0.13901
# Batch count: 295, Avg. per-sample expected Loss: 0.14314
# Batch count: 296, Avg. per-sample expected Loss: 0.14429
# Batch count: 297, Avg. per-sample expected Loss: 0.13566
# Batch count: 298, Avg. per-sample expected Loss: 0.14083
# Batch count: 299, Avg. per-sample expected Loss: 0.13821
# Batch count: 300, Avg. per-sample expected Loss: 0.14181
# Batch count: 301, Avg. per-sample expected Loss: 0.14902
# Batch count: 302, Avg. per-sample expected Loss: 0.14250
# Batch count: 303, Avg. per-sample expected Loss: 0.13853
# Batch count: 304, Avg. per-sample expected Loss: 0.13679
# Batch count: 305, Avg. per-sample expected Loss: 0.12538
# Batch count: 306, Avg. per-sample expected Loss: 0.13888
# Batch count: 307, Avg. per-sample expected Loss: 0.13448
# Batch count: 308, Avg. per-sample expected Loss: 0.13668
# Batch count: 309, Avg. per-sample expected Loss: 0.14171
# Batch count: 310, Avg. per-sample expected Loss: 0.11716
# Batch count: 311, Avg. per-sample expected Loss: 0.13938
# Batch count: 312, Avg. per-sample expected Loss: 0.14376
# Batch count: 313, Avg. per-sample expected Loss: 0.15118
# Batch count: 314, Avg. per-sample expected Loss: 0.13524
# Batch count: 315, Avg. per-sample expected Loss: 0.13811
# Batch count: 316, Avg. per-sample expected Loss: 0.14526
# Batch count: 317, Avg. per-sample expected Loss: 0.12686
# Batch count: 318, Avg. per-sample expected Loss: 0.14527
# Batch count: 319, Avg. per-sample expected Loss: 0.13376
# Batch count: 320, Avg. per-sample expected Loss: 0.13231
# Batch count: 321, Avg. per-sample expected Loss: 0.14215
# Batch count: 322, Avg. per-sample expected Loss: 0.13970
# Batch count: 323, Avg. per-sample expected Loss: 0.13829
# Batch count: 324, Avg. per-sample expected Loss: 0.14034
# Batch count: 325, Avg. per-sample expected Loss: 0.13844
# Batch count: 326, Avg. per-sample expected Loss: 0.12739
# Batch count: 327, Avg. per-sample expected Loss: 0.13152
# Batch count: 328, Avg. per-sample expected Loss: 0.13652
# Batch count: 329, Avg. per-sample expected Loss: 0.14122
# Batch count: 330, Avg. per-sample expected Loss: 0.13661
# Batch count: 331, Avg. per-sample expected Loss: 0.13782
# Batch count: 332, Avg. per-sample expected Loss: 0.13387
# Batch count: 333, Avg. per-sample expected Loss: 0.13088
# Batch count: 334, Avg. per-sample expected Loss: 0.13414
# Batch count: 335, Avg. per-sample expected Loss: 0.14309
# Batch count: 336, Avg. per-sample expected Loss: 0.13654
# Batch count: 337, Avg. per-sample expected Loss: 0.13277
# Batch count: 338, Avg. per-sample expected Loss: 0.13353
# Batch count: 339, Avg. per-sample expected Loss: 0.13358
# Batch count: 340, Avg. per-sample expected Loss: 0.13401
# Batch count: 341, Avg. per-sample expected Loss: 0.13135
# Batch count: 342, Avg. per-sample expected Loss: 0.14546
# Batch count: 343, Avg. per-sample expected Loss: 0.14025
# Batch count: 344, Avg. per-sample expected Loss: 0.13872
# Batch count: 345, Avg. per-sample expected Loss: 0.13802
# Batch count: 346, Avg. per-sample expected Loss: 0.13695
# Batch count: 347, Avg. per-sample expected Loss: 0.13864
# Batch count: 348, Avg. per-sample expected Loss: 0.14178
# Batch count: 349, Avg. per-sample expected Loss: 0.14035

# %% [markdown]
# ## Plots

# %%
plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "b", label="2-QNSCD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.", label="2-QNSCD Empirical Loss")

plt.title("Training using 2-QNSCD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.show()

# %% [markdown]
# ## 6-RQSGD using 600 samples per step

# %%
SGD6cparams = np.array(init_params)
SGD6c_cost = []
SGD6c_Ecost = []

SGD6c_cost.append(temp_cost)
SGD6c_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 6 coordinates
        idx = sorted(np.random.permutation(nparams)[0:6].tolist())
        
        grad = []
        
        ### Gradient estimation
        for i_grad in range(6):
            y_hat,b = EstGrad(SGD6cparams,phiT[:,itr3+i_grad],idx[i_grad])
            b = (1-b)/2
            grad.append((-1)*((-1)**b)*loss(y_hat,labelT[itr3+i_grad]))

        ### single-parameter update
        SGD6cparams[idx] = SGD6cparams[idx] - np.dot(step_size,grad)
    
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6cparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6c_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6ccount = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6cparams,phiT[:,itr]) != labelT[itr]:
            SGD6ccount += 1
    SGD6c_Ecost.append(SGD6ccount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "6Q 6-RQSGD Expected Loss"
file_name2 = "6Q 6-RQSGD Empirical Loss"

np.save(file_name1,SGD6c_cost)
np.save(file_name2,SGD6c_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.54131
# Batch count:  1, Avg. per-sample expected Loss: 0.54102
# Batch count:  2, Avg. per-sample expected Loss: 0.54100
# Batch count:  3, Avg. per-sample expected Loss: 0.54084
# Batch count:  4, Avg. per-sample expected Loss: 0.53978
# Batch count:  5, Avg. per-sample expected Loss: 0.54047
# Batch count:  6, Avg. per-sample expected Loss: 0.54051
# Batch count:  7, Avg. per-sample expected Loss: 0.53835
# Batch count:  8, Avg. per-sample expected Loss: 0.53891
# Batch count:  9, Avg. per-sample expected Loss: 0.53947
# Batch count: 10, Avg. per-sample expected Loss: 0.53676
# Batch count: 11, Avg. per-sample expected Loss: 0.53888
# Batch count: 12, Avg. per-sample expected Loss: 0.53603
# Batch count: 13, Avg. per-sample expected Loss: 0.53527
# Batch count: 14, Avg. per-sample expected Loss: 0.53925
# Batch count: 15, Avg. per-sample expected Loss: 0.53868
# Batch count: 16, Avg. per-sample expected Loss: 0.53723
# Batch count: 17, Avg. per-sample expected Loss: 0.53909
# Batch count: 18, Avg. per-sample expected Loss: 0.53957
# Batch count: 19, Avg. per-sample expected Loss: 0.53415
# Batch count: 20, Avg. per-sample expected Loss: 0.53270
# Batch count: 21, Avg. per-sample expected Loss: 0.53638
# Batch count: 22, Avg. per-sample expected Loss: 0.53251
# Batch count: 23, Avg. per-sample expected Loss: 0.53312
# Batch count: 24, Avg. per-sample expected Loss: 0.52778
# Batch count: 25, Avg. per-sample expected Loss: 0.52683
# Batch count: 26, Avg. per-sample expected Loss: 0.52931
# Batch count: 27, Avg. per-sample expected Loss: 0.52742
# Batch count: 28, Avg. per-sample expected Loss: 0.52370
# Batch count: 29, Avg. per-sample expected Loss: 0.52307
# Batch count: 30, Avg. per-sample expected Loss: 0.52491
# Batch count: 31, Avg. per-sample expected Loss: 0.52434
# Batch count: 32, Avg. per-sample expected Loss: 0.52439
# Batch count: 33, Avg. per-sample expected Loss: 0.52735
# Batch count: 34, Avg. per-sample expected Loss: 0.52759
# Batch count: 35, Avg. per-sample expected Loss: 0.52583
# Batch count: 36, Avg. per-sample expected Loss: 0.52583
# Batch count: 37, Avg. per-sample expected Loss: 0.52359
# Batch count: 38, Avg. per-sample expected Loss: 0.52425
# Batch count: 39, Avg. per-sample expected Loss: 0.52376
# Batch count: 40, Avg. per-sample expected Loss: 0.52455
# Batch count: 41, Avg. per-sample expected Loss: 0.52302
# Batch count: 42, Avg. per-sample expected Loss: 0.52351
# Batch count: 43, Avg. per-sample expected Loss: 0.52395
# Batch count: 44, Avg. per-sample expected Loss: 0.52186
# Batch count: 45, Avg. per-sample expected Loss: 0.52481
# Batch count: 46, Avg. per-sample expected Loss: 0.52386
# Batch count: 47, Avg. per-sample expected Loss: 0.52310
# Batch count: 48, Avg. per-sample expected Loss: 0.52009
# Batch count: 49, Avg. per-sample expected Loss: 0.52028
# Batch count: 50, Avg. per-sample expected Loss: 0.52031
# Batch count: 51, Avg. per-sample expected Loss: 0.52082
# Batch count: 52, Avg. per-sample expected Loss: 0.51845
# Batch count: 53, Avg. per-sample expected Loss: 0.51892
# Batch count: 54, Avg. per-sample expected Loss: 0.51621
# Batch count: 55, Avg. per-sample expected Loss: 0.51680
# Batch count: 56, Avg. per-sample expected Loss: 0.51668
# Batch count: 57, Avg. per-sample expected Loss: 0.51567
# Batch count: 58, Avg. per-sample expected Loss: 0.51940
# Batch count: 59, Avg. per-sample expected Loss: 0.51541
# Batch count: 60, Avg. per-sample expected Loss: 0.51601
# Batch count: 61, Avg. per-sample expected Loss: 0.51977
# Batch count: 62, Avg. per-sample expected Loss: 0.51628
# Batch count: 63, Avg. per-sample expected Loss: 0.51514
# Batch count: 64, Avg. per-sample expected Loss: 0.51607
# Batch count: 65, Avg. per-sample expected Loss: 0.51807
# Batch count: 66, Avg. per-sample expected Loss: 0.51671
# Batch count: 67, Avg. per-sample expected Loss: 0.51572
# Batch count: 68, Avg. per-sample expected Loss: 0.51503
# Batch count: 69, Avg. per-sample expected Loss: 0.51607
# Batch count: 70, Avg. per-sample expected Loss: 0.51505
# Batch count: 71, Avg. per-sample expected Loss: 0.51513
# Batch count: 72, Avg. per-sample expected Loss: 0.51093
# Batch count: 73, Avg. per-sample expected Loss: 0.51266
# Batch count: 74, Avg. per-sample expected Loss: 0.51189
# Batch count: 75, Avg. per-sample expected Loss: 0.51218
# Batch count: 76, Avg. per-sample expected Loss: 0.51354
# Batch count: 77, Avg. per-sample expected Loss: 0.50814
# Batch count: 78, Avg. per-sample expected Loss: 0.50963
# Batch count: 79, Avg. per-sample expected Loss: 0.51334
# Batch count: 80, Avg. per-sample expected Loss: 0.50938
# Batch count: 81, Avg. per-sample expected Loss: 0.50963
# Batch count: 82, Avg. per-sample expected Loss: 0.50887
# Batch count: 83, Avg. per-sample expected Loss: 0.50903
# Batch count: 84, Avg. per-sample expected Loss: 0.50834
# Batch count: 85, Avg. per-sample expected Loss: 0.50538
# Batch count: 86, Avg. per-sample expected Loss: 0.50440
# Batch count: 87, Avg. per-sample expected Loss: 0.50956
# Batch count: 88, Avg. per-sample expected Loss: 0.50752
# Batch count: 89, Avg. per-sample expected Loss: 0.50614
# Batch count: 90, Avg. per-sample expected Loss: 0.50220
# Batch count: 91, Avg. per-sample expected Loss: 0.50605
# Batch count: 92, Avg. per-sample expected Loss: 0.50252
# Batch count: 93, Avg. per-sample expected Loss: 0.50505
# Batch count: 94, Avg. per-sample expected Loss: 0.50066
# Batch count: 95, Avg. per-sample expected Loss: 0.50002
# Batch count: 96, Avg. per-sample expected Loss: 0.49988
# Batch count: 97, Avg. per-sample expected Loss: 0.50045
# Batch count: 98, Avg. per-sample expected Loss: 0.50012
# Batch count: 99, Avg. per-sample expected Loss: 0.49830
# Batch count: 100, Avg. per-sample expected Loss: 0.49555
# Batch count: 101, Avg. per-sample expected Loss: 0.49368
# Batch count: 102, Avg. per-sample expected Loss: 0.49586
# Batch count: 103, Avg. per-sample expected Loss: 0.49752
# Batch count: 104, Avg. per-sample expected Loss: 0.49464
# Batch count: 105, Avg. per-sample expected Loss: 0.49667
# Batch count: 106, Avg. per-sample expected Loss: 0.49294
# Batch count: 107, Avg. per-sample expected Loss: 0.49282
# Batch count: 108, Avg. per-sample expected Loss: 0.49123
# Batch count: 109, Avg. per-sample expected Loss: 0.49295
# Batch count: 110, Avg. per-sample expected Loss: 0.49403
# Batch count: 111, Avg. per-sample expected Loss: 0.49252
# Batch count: 112, Avg. per-sample expected Loss: 0.49042
# Batch count: 113, Avg. per-sample expected Loss: 0.49064
# Batch count: 114, Avg. per-sample expected Loss: 0.49187
# Batch count: 115, Avg. per-sample expected Loss: 0.49104
# Batch count: 116, Avg. per-sample expected Loss: 0.48958
# Batch count: 117, Avg. per-sample expected Loss: 0.49063
# Batch count: 118, Avg. per-sample expected Loss: 0.48960
# Batch count: 119, Avg. per-sample expected Loss: 0.48891
# Batch count: 120, Avg. per-sample expected Loss: 0.48767
# Batch count: 121, Avg. per-sample expected Loss: 0.48698
# Batch count: 122, Avg. per-sample expected Loss: 0.48673
# Batch count: 123, Avg. per-sample expected Loss: 0.48736
# Batch count: 124, Avg. per-sample expected Loss: 0.48551
# Batch count: 125, Avg. per-sample expected Loss: 0.48520
# Batch count: 126, Avg. per-sample expected Loss: 0.48333
# Batch count: 127, Avg. per-sample expected Loss: 0.48416
# Batch count: 128, Avg. per-sample expected Loss: 0.48256
# Batch count: 129, Avg. per-sample expected Loss: 0.48269
# Batch count: 130, Avg. per-sample expected Loss: 0.48493
# Batch count: 131, Avg. per-sample expected Loss: 0.48351
# Batch count: 132, Avg. per-sample expected Loss: 0.48352
# Batch count: 133, Avg. per-sample expected Loss: 0.48131
# Batch count: 134, Avg. per-sample expected Loss: 0.48151
# Batch count: 135, Avg. per-sample expected Loss: 0.48427
# Batch count: 136, Avg. per-sample expected Loss: 0.48180
# Batch count: 137, Avg. per-sample expected Loss: 0.48223
# Batch count: 138, Avg. per-sample expected Loss: 0.48272
# Batch count: 139, Avg. per-sample expected Loss: 0.48171
# Batch count: 140, Avg. per-sample expected Loss: 0.48422
# Batch count: 141, Avg. per-sample expected Loss: 0.48227
# Batch count: 142, Avg. per-sample expected Loss: 0.48297
# Batch count: 143, Avg. per-sample expected Loss: 0.48446
# Batch count: 144, Avg. per-sample expected Loss: 0.48196
# Batch count: 145, Avg. per-sample expected Loss: 0.47925
# Batch count: 146, Avg. per-sample expected Loss: 0.47439
# Batch count: 147, Avg. per-sample expected Loss: 0.47455
# Batch count: 148, Avg. per-sample expected Loss: 0.47463
# Batch count: 149, Avg. per-sample expected Loss: 0.47341
# Batch count: 150, Avg. per-sample expected Loss: 0.46967
# Batch count: 151, Avg. per-sample expected Loss: 0.47170
# Batch count: 152, Avg. per-sample expected Loss: 0.47187
# Batch count: 153, Avg. per-sample expected Loss: 0.47111
# Batch count: 154, Avg. per-sample expected Loss: 0.47224
# Batch count: 155, Avg. per-sample expected Loss: 0.47020
# Batch count: 156, Avg. per-sample expected Loss: 0.47007
# Batch count: 157, Avg. per-sample expected Loss: 0.47223
# Batch count: 158, Avg. per-sample expected Loss: 0.47075
# Batch count: 159, Avg. per-sample expected Loss: 0.46863
# Batch count: 160, Avg. per-sample expected Loss: 0.46649
# Batch count: 161, Avg. per-sample expected Loss: 0.46926
# Batch count: 162, Avg. per-sample expected Loss: 0.46822
# Batch count: 163, Avg. per-sample expected Loss: 0.46598
# Batch count: 164, Avg. per-sample expected Loss: 0.46745
# Batch count: 165, Avg. per-sample expected Loss: 0.46814
# Batch count: 166, Avg. per-sample expected Loss: 0.46235
# Batch count: 167, Avg. per-sample expected Loss: 0.46268
# Batch count: 168, Avg. per-sample expected Loss: 0.46334
# Batch count: 169, Avg. per-sample expected Loss: 0.46160
# Batch count: 170, Avg. per-sample expected Loss: 0.46024
# Batch count: 171, Avg. per-sample expected Loss: 0.46100
# Batch count: 172, Avg. per-sample expected Loss: 0.45673
# Batch count: 173, Avg. per-sample expected Loss: 0.45960
# Batch count: 174, Avg. per-sample expected Loss: 0.45138
# Batch count: 175, Avg. per-sample expected Loss: 0.45268
# Batch count: 176, Avg. per-sample expected Loss: 0.45187
# Batch count: 177, Avg. per-sample expected Loss: 0.44930
# Batch count: 178, Avg. per-sample expected Loss: 0.44782
# Batch count: 179, Avg. per-sample expected Loss: 0.44612
# Batch count: 180, Avg. per-sample expected Loss: 0.44558
# Batch count: 181, Avg. per-sample expected Loss: 0.44551
# Batch count: 182, Avg. per-sample expected Loss: 0.44102
# Batch count: 183, Avg. per-sample expected Loss: 0.43942
# Batch count: 184, Avg. per-sample expected Loss: 0.44084
# Batch count: 185, Avg. per-sample expected Loss: 0.43997
# Batch count: 186, Avg. per-sample expected Loss: 0.43638
# Batch count: 187, Avg. per-sample expected Loss: 0.43745
# Batch count: 188, Avg. per-sample expected Loss: 0.43645
# Batch count: 189, Avg. per-sample expected Loss: 0.43425
# Batch count: 190, Avg. per-sample expected Loss: 0.43003
# Batch count: 191, Avg. per-sample expected Loss: 0.43161
# Batch count: 192, Avg. per-sample expected Loss: 0.43126
# Batch count: 193, Avg. per-sample expected Loss: 0.42878
# Batch count: 194, Avg. per-sample expected Loss: 0.42994
# Batch count: 195, Avg. per-sample expected Loss: 0.42720
# Batch count: 196, Avg. per-sample expected Loss: 0.42304
# Batch count: 197, Avg. per-sample expected Loss: 0.42161
# Batch count: 198, Avg. per-sample expected Loss: 0.42115
# Batch count: 199, Avg. per-sample expected Loss: 0.41982
# Batch count: 200, Avg. per-sample expected Loss: 0.42008
# Batch count: 201, Avg. per-sample expected Loss: 0.42134
# Batch count: 202, Avg. per-sample expected Loss: 0.41729
# Batch count: 203, Avg. per-sample expected Loss: 0.41857
# Batch count: 204, Avg. per-sample expected Loss: 0.41773
# Batch count: 205, Avg. per-sample expected Loss: 0.41752
# Batch count: 206, Avg. per-sample expected Loss: 0.41707
# Batch count: 207, Avg. per-sample expected Loss: 0.41602
# Batch count: 208, Avg. per-sample expected Loss: 0.41294
# Batch count: 209, Avg. per-sample expected Loss: 0.41334
# Batch count: 210, Avg. per-sample expected Loss: 0.41111
# Batch count: 211, Avg. per-sample expected Loss: 0.41086
# Batch count: 212, Avg. per-sample expected Loss: 0.41061
# Batch count: 213, Avg. per-sample expected Loss: 0.40676
# Batch count: 214, Avg. per-sample expected Loss: 0.40385
# Batch count: 215, Avg. per-sample expected Loss: 0.40487
# Batch count: 216, Avg. per-sample expected Loss: 0.40569
# Batch count: 217, Avg. per-sample expected Loss: 0.40534
# Batch count: 218, Avg. per-sample expected Loss: 0.39827
# Batch count: 219, Avg. per-sample expected Loss: 0.39927
# Batch count: 220, Avg. per-sample expected Loss: 0.39868
# Batch count: 221, Avg. per-sample expected Loss: 0.39707
# Batch count: 222, Avg. per-sample expected Loss: 0.39516
# Batch count: 223, Avg. per-sample expected Loss: 0.39230
# Batch count: 224, Avg. per-sample expected Loss: 0.39490
# Batch count: 225, Avg. per-sample expected Loss: 0.39411
# Batch count: 226, Avg. per-sample expected Loss: 0.38935
# Batch count: 227, Avg. per-sample expected Loss: 0.38592
# Batch count: 228, Avg. per-sample expected Loss: 0.38834
# Batch count: 229, Avg. per-sample expected Loss: 0.38537
# Batch count: 230, Avg. per-sample expected Loss: 0.38163
# Batch count: 231, Avg. per-sample expected Loss: 0.38020
# Batch count: 232, Avg. per-sample expected Loss: 0.37487
# Batch count: 233, Avg. per-sample expected Loss: 0.37550
# Batch count: 234, Avg. per-sample expected Loss: 0.37323
# Batch count: 235, Avg. per-sample expected Loss: 0.37463
# Batch count: 236, Avg. per-sample expected Loss: 0.36738
# Batch count: 237, Avg. per-sample expected Loss: 0.36091
# Batch count: 238, Avg. per-sample expected Loss: 0.35873
# Batch count: 239, Avg. per-sample expected Loss: 0.35296
# Batch count: 240, Avg. per-sample expected Loss: 0.35430
# Batch count: 241, Avg. per-sample expected Loss: 0.34711
# Batch count: 242, Avg. per-sample expected Loss: 0.34329
# Batch count: 243, Avg. per-sample expected Loss: 0.34162
# Batch count: 244, Avg. per-sample expected Loss: 0.33350
# Batch count: 245, Avg. per-sample expected Loss: 0.33408
# Batch count: 246, Avg. per-sample expected Loss: 0.33140
# Batch count: 247, Avg. per-sample expected Loss: 0.32836
# Batch count: 248, Avg. per-sample expected Loss: 0.33004
# Batch count: 249, Avg. per-sample expected Loss: 0.32625
# Batch count: 250, Avg. per-sample expected Loss: 0.32359
# Batch count: 251, Avg. per-sample expected Loss: 0.32062
# Batch count: 252, Avg. per-sample expected Loss: 0.31645
# Batch count: 253, Avg. per-sample expected Loss: 0.31025
# Batch count: 254, Avg. per-sample expected Loss: 0.30895
# Batch count: 255, Avg. per-sample expected Loss: 0.30580
# Batch count: 256, Avg. per-sample expected Loss: 0.30457
# Batch count: 257, Avg. per-sample expected Loss: 0.30371
# Batch count: 258, Avg. per-sample expected Loss: 0.30364
# Batch count: 259, Avg. per-sample expected Loss: 0.30146
# Batch count: 260, Avg. per-sample expected Loss: 0.29518
# Batch count: 261, Avg. per-sample expected Loss: 0.29184
# Batch count: 262, Avg. per-sample expected Loss: 0.28885
# Batch count: 263, Avg. per-sample expected Loss: 0.28447
# Batch count: 264, Avg. per-sample expected Loss: 0.28105
# Batch count: 265, Avg. per-sample expected Loss: 0.27925
# Batch count: 266, Avg. per-sample expected Loss: 0.27917
# Batch count: 267, Avg. per-sample expected Loss: 0.27116
# Batch count: 268, Avg. per-sample expected Loss: 0.27252
# Batch count: 269, Avg. per-sample expected Loss: 0.26545
# Batch count: 270, Avg. per-sample expected Loss: 0.26042
# Batch count: 271, Avg. per-sample expected Loss: 0.26311
# Batch count: 272, Avg. per-sample expected Loss: 0.25849
# Batch count: 273, Avg. per-sample expected Loss: 0.25709
# Batch count: 274, Avg. per-sample expected Loss: 0.25746
# Batch count: 275, Avg. per-sample expected Loss: 0.25316
# Batch count: 276, Avg. per-sample expected Loss: 0.24623
# Batch count: 277, Avg. per-sample expected Loss: 0.23955
# Batch count: 278, Avg. per-sample expected Loss: 0.24821
# Batch count: 279, Avg. per-sample expected Loss: 0.24356
# Batch count: 280, Avg. per-sample expected Loss: 0.24161
# Batch count: 281, Avg. per-sample expected Loss: 0.24492
# Batch count: 282, Avg. per-sample expected Loss: 0.23918
# Batch count: 283, Avg. per-sample expected Loss: 0.23235
# Batch count: 284, Avg. per-sample expected Loss: 0.23373
# Batch count: 285, Avg. per-sample expected Loss: 0.22777
# Batch count: 286, Avg. per-sample expected Loss: 0.22509
# Batch count: 287, Avg. per-sample expected Loss: 0.22157
# Batch count: 288, Avg. per-sample expected Loss: 0.21693
# Batch count: 289, Avg. per-sample expected Loss: 0.22210
# Batch count: 290, Avg. per-sample expected Loss: 0.21159
# Batch count: 291, Avg. per-sample expected Loss: 0.20968
# Batch count: 292, Avg. per-sample expected Loss: 0.20642
# Batch count: 293, Avg. per-sample expected Loss: 0.20680
# Batch count: 294, Avg. per-sample expected Loss: 0.20757
# Batch count: 295, Avg. per-sample expected Loss: 0.20644
# Batch count: 296, Avg. per-sample expected Loss: 0.20599
# Batch count: 297, Avg. per-sample expected Loss: 0.19590
# Batch count: 298, Avg. per-sample expected Loss: 0.20227
# Batch count: 299, Avg. per-sample expected Loss: 0.20015
# Batch count: 300, Avg. per-sample expected Loss: 0.20273
# Batch count: 301, Avg. per-sample expected Loss: 0.20596
# Batch count: 302, Avg. per-sample expected Loss: 0.20162
# Batch count: 303, Avg. per-sample expected Loss: 0.19653
# Batch count: 304, Avg. per-sample expected Loss: 0.19406
# Batch count: 305, Avg. per-sample expected Loss: 0.18593
# Batch count: 306, Avg. per-sample expected Loss: 0.19135
# Batch count: 307, Avg. per-sample expected Loss: 0.18713
# Batch count: 308, Avg. per-sample expected Loss: 0.18677
# Batch count: 309, Avg. per-sample expected Loss: 0.18828
# Batch count: 310, Avg. per-sample expected Loss: 0.17255
# Batch count: 311, Avg. per-sample expected Loss: 0.18474
# Batch count: 312, Avg. per-sample expected Loss: 0.18862
# Batch count: 313, Avg. per-sample expected Loss: 0.18841
# Batch count: 314, Avg. per-sample expected Loss: 0.17528
# Batch count: 315, Avg. per-sample expected Loss: 0.17252
# Batch count: 316, Avg. per-sample expected Loss: 0.17737
# Batch count: 317, Avg. per-sample expected Loss: 0.16397
# Batch count: 318, Avg. per-sample expected Loss: 0.17412
# Batch count: 319, Avg. per-sample expected Loss: 0.16695
# Batch count: 320, Avg. per-sample expected Loss: 0.16476
# Batch count: 321, Avg. per-sample expected Loss: 0.17114
# Batch count: 322, Avg. per-sample expected Loss: 0.16856
# Batch count: 323, Avg. per-sample expected Loss: 0.16757
# Batch count: 324, Avg. per-sample expected Loss: 0.16791
# Batch count: 325, Avg. per-sample expected Loss: 0.16558
# Batch count: 326, Avg. per-sample expected Loss: 0.15558
# Batch count: 327, Avg. per-sample expected Loss: 0.15503
# Batch count: 328, Avg. per-sample expected Loss: 0.15823
# Batch count: 329, Avg. per-sample expected Loss: 0.15797
# Batch count: 330, Avg. per-sample expected Loss: 0.15689
# Batch count: 331, Avg. per-sample expected Loss: 0.15786
# Batch count: 332, Avg. per-sample expected Loss: 0.15573
# Batch count: 333, Avg. per-sample expected Loss: 0.15580
# Batch count: 334, Avg. per-sample expected Loss: 0.15636
# Batch count: 335, Avg. per-sample expected Loss: 0.15944
# Batch count: 336, Avg. per-sample expected Loss: 0.15483
# Batch count: 337, Avg. per-sample expected Loss: 0.15319
# Batch count: 338, Avg. per-sample expected Loss: 0.15026
# Batch count: 339, Avg. per-sample expected Loss: 0.14862
# Batch count: 340, Avg. per-sample expected Loss: 0.14897
# Batch count: 341, Avg. per-sample expected Loss: 0.14349
# Batch count: 342, Avg. per-sample expected Loss: 0.15450
# Batch count: 343, Avg. per-sample expected Loss: 0.15065
# Batch count: 344, Avg. per-sample expected Loss: 0.14996
# Batch count: 345, Avg. per-sample expected Loss: 0.14928
# Batch count: 346, Avg. per-sample expected Loss: 0.14701
# Batch count: 347, Avg. per-sample expected Loss: 0.15128
# Batch count: 348, Avg. per-sample expected Loss: 0.15244
# Batch count: 349, Avg. per-sample expected Loss: 0.15301

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6c_cost, "b", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6c_Ecost, "c.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training using 2-QNSCD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("6-RQSGD.png")
plt.show()

# %% [markdown]
# ## 2-RQSGD using 600 samples per step and 6 samples per itr

# %%
SGD6params = np.array(init_params)
SGD6_cost = []
SGD6_Ecost = []

SGD6_cost.append(temp_cost)
SGD6_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 2 coordinates
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())
        
        grad = []
        
        ### Gradient estimation
        y_hat01,b01 = EstGrad(SGD6params,phiT[:,itr3+0],idx[0])
        b01 = (1-b01)/2
        y_hat02,b02 = EstGrad(SGD6params,phiT[:,itr3+1],idx[0])
        b02 = (1-b02)/2
        y_hat03,b03 = EstGrad(SGD6params,phiT[:,itr3+2],idx[0])
        b03 = (1-b03)/2
        
        temp0 = ((-1)**b01)*loss(y_hat01,labelT[itr3+0]) \
              + ((-1)**b02)*loss(y_hat02,labelT[itr3+1]) \
              + ((-1)**b03)*loss(y_hat03,labelT[itr3+2])

        grad.append((-1)*temp0/3)
        
        y_hat11,b11 = EstGrad(SGD6params,phiT[:,itr3+3],idx[1])
        b11 = (1-b11)/2
        y_hat12,b12 = EstGrad(SGD6params,phiT[:,itr3+4],idx[1])
        b12 = (1-b12)/2
        y_hat13,b13 = EstGrad(SGD6params,phiT[:,itr3+5],idx[1])
        b13 = (1-b13)/2
        
        temp1 = ((-1)**b11)*loss(y_hat11,labelT[itr3+3]) \
              + ((-1)**b12)*loss(y_hat12,labelT[itr3+4]) \
              + ((-1)**b13)*loss(y_hat13,labelT[itr3+5])

        grad.append((-1)*temp1/3)

        ### single-parameter update
        SGD6params[idx] = SGD6params[idx] - np.dot(step_size,grad)
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6params,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6count = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6params,phiT[:,itr]) != labelT[itr]:
            SGD6count += 1
    SGD6_Ecost.append(SGD6count/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "6Q 2-RQSGD_6s Expected Loss"
file_name2 = "6Q 2-RQSGD_6s Empirical Loss"

np.save(file_name1,SGD6_cost)
np.save(file_name2,SGD6_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.54131
# Batch count:  1, Avg. per-sample expected Loss: 0.54051
# Batch count:  2, Avg. per-sample expected Loss: 0.54075
# Batch count:  3, Avg. per-sample expected Loss: 0.54138
# Batch count:  4, Avg. per-sample expected Loss: 0.54024
# Batch count:  5, Avg. per-sample expected Loss: 0.54101
# Batch count:  6, Avg. per-sample expected Loss: 0.54161
# Batch count:  7, Avg. per-sample expected Loss: 0.53931
# Batch count:  8, Avg. per-sample expected Loss: 0.53934
# Batch count:  9, Avg. per-sample expected Loss: 0.54016
# Batch count: 10, Avg. per-sample expected Loss: 0.53799
# Batch count: 11, Avg. per-sample expected Loss: 0.54022
# Batch count: 12, Avg. per-sample expected Loss: 0.53744
# Batch count: 13, Avg. per-sample expected Loss: 0.53638
# Batch count: 14, Avg. per-sample expected Loss: 0.53997
# Batch count: 15, Avg. per-sample expected Loss: 0.54059
# Batch count: 16, Avg. per-sample expected Loss: 0.53882
# Batch count: 17, Avg. per-sample expected Loss: 0.54125
# Batch count: 18, Avg. per-sample expected Loss: 0.54147
# Batch count: 19, Avg. per-sample expected Loss: 0.53787
# Batch count: 20, Avg. per-sample expected Loss: 0.53601
# Batch count: 21, Avg. per-sample expected Loss: 0.53972
# Batch count: 22, Avg. per-sample expected Loss: 0.53952
# Batch count: 23, Avg. per-sample expected Loss: 0.54066
# Batch count: 24, Avg. per-sample expected Loss: 0.53533
# Batch count: 25, Avg. per-sample expected Loss: 0.53715
# Batch count: 26, Avg. per-sample expected Loss: 0.53916
# Batch count: 27, Avg. per-sample expected Loss: 0.53796
# Batch count: 28, Avg. per-sample expected Loss: 0.53411
# Batch count: 29, Avg. per-sample expected Loss: 0.53543
# Batch count: 30, Avg. per-sample expected Loss: 0.53716
# Batch count: 31, Avg. per-sample expected Loss: 0.53690
# Batch count: 32, Avg. per-sample expected Loss: 0.53621
# Batch count: 33, Avg. per-sample expected Loss: 0.53776
# Batch count: 34, Avg. per-sample expected Loss: 0.53640
# Batch count: 35, Avg. per-sample expected Loss: 0.53410
# Batch count: 36, Avg. per-sample expected Loss: 0.53579
# Batch count: 37, Avg. per-sample expected Loss: 0.53376
# Batch count: 38, Avg. per-sample expected Loss: 0.53437
# Batch count: 39, Avg. per-sample expected Loss: 0.53337
# Batch count: 40, Avg. per-sample expected Loss: 0.53318
# Batch count: 41, Avg. per-sample expected Loss: 0.53252
# Batch count: 42, Avg. per-sample expected Loss: 0.53341
# Batch count: 43, Avg. per-sample expected Loss: 0.53492
# Batch count: 44, Avg. per-sample expected Loss: 0.53243
# Batch count: 45, Avg. per-sample expected Loss: 0.53474
# Batch count: 46, Avg. per-sample expected Loss: 0.53509
# Batch count: 47, Avg. per-sample expected Loss: 0.53456
# Batch count: 48, Avg. per-sample expected Loss: 0.53355
# Batch count: 49, Avg. per-sample expected Loss: 0.53305
# Batch count: 50, Avg. per-sample expected Loss: 0.53344
# Batch count: 51, Avg. per-sample expected Loss: 0.53511
# Batch count: 52, Avg. per-sample expected Loss: 0.53218
# Batch count: 53, Avg. per-sample expected Loss: 0.53264
# Batch count: 54, Avg. per-sample expected Loss: 0.53148
# Batch count: 55, Avg. per-sample expected Loss: 0.53163
# Batch count: 56, Avg. per-sample expected Loss: 0.53153
# Batch count: 57, Avg. per-sample expected Loss: 0.53062
# Batch count: 58, Avg. per-sample expected Loss: 0.53385
# Batch count: 59, Avg. per-sample expected Loss: 0.52987
# Batch count: 60, Avg. per-sample expected Loss: 0.53049
# Batch count: 61, Avg. per-sample expected Loss: 0.53500
# Batch count: 62, Avg. per-sample expected Loss: 0.53195
# Batch count: 63, Avg. per-sample expected Loss: 0.53148
# Batch count: 64, Avg. per-sample expected Loss: 0.53304
# Batch count: 65, Avg. per-sample expected Loss: 0.53463
# Batch count: 66, Avg. per-sample expected Loss: 0.53311
# Batch count: 67, Avg. per-sample expected Loss: 0.53187
# Batch count: 68, Avg. per-sample expected Loss: 0.53133
# Batch count: 69, Avg. per-sample expected Loss: 0.53211
# Batch count: 70, Avg. per-sample expected Loss: 0.53316
# Batch count: 71, Avg. per-sample expected Loss: 0.53315
# Batch count: 72, Avg. per-sample expected Loss: 0.53037
# Batch count: 73, Avg. per-sample expected Loss: 0.53059
# Batch count: 74, Avg. per-sample expected Loss: 0.53068
# Batch count: 75, Avg. per-sample expected Loss: 0.53078
# Batch count: 76, Avg. per-sample expected Loss: 0.53247
# Batch count: 77, Avg. per-sample expected Loss: 0.52819
# Batch count: 78, Avg. per-sample expected Loss: 0.52970
# Batch count: 79, Avg. per-sample expected Loss: 0.53257
# Batch count: 80, Avg. per-sample expected Loss: 0.52852
# Batch count: 81, Avg. per-sample expected Loss: 0.52930
# Batch count: 82, Avg. per-sample expected Loss: 0.52767
# Batch count: 83, Avg. per-sample expected Loss: 0.52895
# Batch count: 84, Avg. per-sample expected Loss: 0.52904
# Batch count: 85, Avg. per-sample expected Loss: 0.52615
# Batch count: 86, Avg. per-sample expected Loss: 0.52672
# Batch count: 87, Avg. per-sample expected Loss: 0.53124
# Batch count: 88, Avg. per-sample expected Loss: 0.52787
# Batch count: 89, Avg. per-sample expected Loss: 0.52898
# Batch count: 90, Avg. per-sample expected Loss: 0.52631
# Batch count: 91, Avg. per-sample expected Loss: 0.52903
# Batch count: 92, Avg. per-sample expected Loss: 0.52765
# Batch count: 93, Avg. per-sample expected Loss: 0.52880
# Batch count: 94, Avg. per-sample expected Loss: 0.52593
# Batch count: 95, Avg. per-sample expected Loss: 0.52632
# Batch count: 96, Avg. per-sample expected Loss: 0.52746
# Batch count: 97, Avg. per-sample expected Loss: 0.52920
# Batch count: 98, Avg. per-sample expected Loss: 0.53028
# Batch count: 99, Avg. per-sample expected Loss: 0.52708
# Batch count: 100, Avg. per-sample expected Loss: 0.52564
# Batch count: 101, Avg. per-sample expected Loss: 0.52532
# Batch count: 102, Avg. per-sample expected Loss: 0.52488
# Batch count: 103, Avg. per-sample expected Loss: 0.52623
# Batch count: 104, Avg. per-sample expected Loss: 0.52444
# Batch count: 105, Avg. per-sample expected Loss: 0.52742
# Batch count: 106, Avg. per-sample expected Loss: 0.52468
# Batch count: 107, Avg. per-sample expected Loss: 0.52218
# Batch count: 108, Avg. per-sample expected Loss: 0.52105
# Batch count: 109, Avg. per-sample expected Loss: 0.52204
# Batch count: 110, Avg. per-sample expected Loss: 0.52360
# Batch count: 111, Avg. per-sample expected Loss: 0.52290
# Batch count: 112, Avg. per-sample expected Loss: 0.52121
# Batch count: 113, Avg. per-sample expected Loss: 0.52235
# Batch count: 114, Avg. per-sample expected Loss: 0.52335
# Batch count: 115, Avg. per-sample expected Loss: 0.52289
# Batch count: 116, Avg. per-sample expected Loss: 0.52133
# Batch count: 117, Avg. per-sample expected Loss: 0.52355
# Batch count: 118, Avg. per-sample expected Loss: 0.52283
# Batch count: 119, Avg. per-sample expected Loss: 0.52102
# Batch count: 120, Avg. per-sample expected Loss: 0.52037
# Batch count: 121, Avg. per-sample expected Loss: 0.52044
# Batch count: 122, Avg. per-sample expected Loss: 0.52135
# Batch count: 123, Avg. per-sample expected Loss: 0.52091
# Batch count: 124, Avg. per-sample expected Loss: 0.51900
# Batch count: 125, Avg. per-sample expected Loss: 0.51890
# Batch count: 126, Avg. per-sample expected Loss: 0.51930
# Batch count: 127, Avg. per-sample expected Loss: 0.52034
# Batch count: 128, Avg. per-sample expected Loss: 0.51909
# Batch count: 129, Avg. per-sample expected Loss: 0.51969
# Batch count: 130, Avg. per-sample expected Loss: 0.52056
# Batch count: 131, Avg. per-sample expected Loss: 0.52040
# Batch count: 132, Avg. per-sample expected Loss: 0.51969
# Batch count: 133, Avg. per-sample expected Loss: 0.51787
# Batch count: 134, Avg. per-sample expected Loss: 0.51696
# Batch count: 135, Avg. per-sample expected Loss: 0.51969
# Batch count: 136, Avg. per-sample expected Loss: 0.51755
# Batch count: 137, Avg. per-sample expected Loss: 0.51778
# Batch count: 138, Avg. per-sample expected Loss: 0.51721
# Batch count: 139, Avg. per-sample expected Loss: 0.51698
# Batch count: 140, Avg. per-sample expected Loss: 0.51956
# Batch count: 141, Avg. per-sample expected Loss: 0.51650
# Batch count: 142, Avg. per-sample expected Loss: 0.51866
# Batch count: 143, Avg. per-sample expected Loss: 0.51870
# Batch count: 144, Avg. per-sample expected Loss: 0.51748
# Batch count: 145, Avg. per-sample expected Loss: 0.51713
# Batch count: 146, Avg. per-sample expected Loss: 0.51342
# Batch count: 147, Avg. per-sample expected Loss: 0.51317
# Batch count: 148, Avg. per-sample expected Loss: 0.51638
# Batch count: 149, Avg. per-sample expected Loss: 0.51340
# Batch count: 150, Avg. per-sample expected Loss: 0.51101
# Batch count: 151, Avg. per-sample expected Loss: 0.51557
# Batch count: 152, Avg. per-sample expected Loss: 0.51450
# Batch count: 153, Avg. per-sample expected Loss: 0.51321
# Batch count: 154, Avg. per-sample expected Loss: 0.51590
# Batch count: 155, Avg. per-sample expected Loss: 0.51544
# Batch count: 156, Avg. per-sample expected Loss: 0.51389
# Batch count: 157, Avg. per-sample expected Loss: 0.51665
# Batch count: 158, Avg. per-sample expected Loss: 0.51433
# Batch count: 159, Avg. per-sample expected Loss: 0.51116
# Batch count: 160, Avg. per-sample expected Loss: 0.51226
# Batch count: 161, Avg. per-sample expected Loss: 0.51582
# Batch count: 162, Avg. per-sample expected Loss: 0.51536
# Batch count: 163, Avg. per-sample expected Loss: 0.51464
# Batch count: 164, Avg. per-sample expected Loss: 0.51523
# Batch count: 165, Avg. per-sample expected Loss: 0.51626
# Batch count: 166, Avg. per-sample expected Loss: 0.51172
# Batch count: 167, Avg. per-sample expected Loss: 0.51235
# Batch count: 168, Avg. per-sample expected Loss: 0.51393
# Batch count: 169, Avg. per-sample expected Loss: 0.51355
# Batch count: 170, Avg. per-sample expected Loss: 0.51334
# Batch count: 171, Avg. per-sample expected Loss: 0.51288
# Batch count: 172, Avg. per-sample expected Loss: 0.51410
# Batch count: 173, Avg. per-sample expected Loss: 0.51388
# Batch count: 174, Avg. per-sample expected Loss: 0.51063
# Batch count: 175, Avg. per-sample expected Loss: 0.51279
# Batch count: 176, Avg. per-sample expected Loss: 0.51323
# Batch count: 177, Avg. per-sample expected Loss: 0.51318
# Batch count: 178, Avg. per-sample expected Loss: 0.51412
# Batch count: 179, Avg. per-sample expected Loss: 0.51172
# Batch count: 180, Avg. per-sample expected Loss: 0.51188
# Batch count: 181, Avg. per-sample expected Loss: 0.51140
# Batch count: 182, Avg. per-sample expected Loss: 0.51011
# Batch count: 183, Avg. per-sample expected Loss: 0.50878
# Batch count: 184, Avg. per-sample expected Loss: 0.51048
# Batch count: 185, Avg. per-sample expected Loss: 0.50983
# Batch count: 186, Avg. per-sample expected Loss: 0.50778
# Batch count: 187, Avg. per-sample expected Loss: 0.50848
# Batch count: 188, Avg. per-sample expected Loss: 0.50914
# Batch count: 189, Avg. per-sample expected Loss: 0.51155
# Batch count: 190, Avg. per-sample expected Loss: 0.50734
# Batch count: 191, Avg. per-sample expected Loss: 0.50944
# Batch count: 192, Avg. per-sample expected Loss: 0.51026
# Batch count: 193, Avg. per-sample expected Loss: 0.50738
# Batch count: 194, Avg. per-sample expected Loss: 0.51036
# Batch count: 195, Avg. per-sample expected Loss: 0.50578
# Batch count: 196, Avg. per-sample expected Loss: 0.50630
# Batch count: 197, Avg. per-sample expected Loss: 0.50693
# Batch count: 198, Avg. per-sample expected Loss: 0.50674
# Batch count: 199, Avg. per-sample expected Loss: 0.50450
# Batch count: 200, Avg. per-sample expected Loss: 0.50579
# Batch count: 201, Avg. per-sample expected Loss: 0.50775
# Batch count: 202, Avg. per-sample expected Loss: 0.50350
# Batch count: 203, Avg. per-sample expected Loss: 0.50433
# Batch count: 204, Avg. per-sample expected Loss: 0.50553
# Batch count: 205, Avg. per-sample expected Loss: 0.50629
# Batch count: 206, Avg. per-sample expected Loss: 0.50526
# Batch count: 207, Avg. per-sample expected Loss: 0.50605
# Batch count: 208, Avg. per-sample expected Loss: 0.50528
# Batch count: 209, Avg. per-sample expected Loss: 0.50773
# Batch count: 210, Avg. per-sample expected Loss: 0.50744
# Batch count: 211, Avg. per-sample expected Loss: 0.50552
# Batch count: 212, Avg. per-sample expected Loss: 0.50444
# Batch count: 213, Avg. per-sample expected Loss: 0.50260
# Batch count: 214, Avg. per-sample expected Loss: 0.50234
# Batch count: 215, Avg. per-sample expected Loss: 0.50445
# Batch count: 216, Avg. per-sample expected Loss: 0.50335
# Batch count: 217, Avg. per-sample expected Loss: 0.50363
# Batch count: 218, Avg. per-sample expected Loss: 0.50177
# Batch count: 219, Avg. per-sample expected Loss: 0.50302
# Batch count: 220, Avg. per-sample expected Loss: 0.50253
# Batch count: 221, Avg. per-sample expected Loss: 0.50256
# Batch count: 222, Avg. per-sample expected Loss: 0.50063
# Batch count: 223, Avg. per-sample expected Loss: 0.50030
# Batch count: 224, Avg. per-sample expected Loss: 0.50307
# Batch count: 225, Avg. per-sample expected Loss: 0.50434
# Batch count: 226, Avg. per-sample expected Loss: 0.50186
# Batch count: 227, Avg. per-sample expected Loss: 0.49967
# Batch count: 228, Avg. per-sample expected Loss: 0.50407
# Batch count: 229, Avg. per-sample expected Loss: 0.50181
# Batch count: 230, Avg. per-sample expected Loss: 0.50091
# Batch count: 231, Avg. per-sample expected Loss: 0.50284
# Batch count: 232, Avg. per-sample expected Loss: 0.49959
# Batch count: 233, Avg. per-sample expected Loss: 0.50088
# Batch count: 234, Avg. per-sample expected Loss: 0.50076
# Batch count: 235, Avg. per-sample expected Loss: 0.50246
# Batch count: 236, Avg. per-sample expected Loss: 0.49873
# Batch count: 237, Avg. per-sample expected Loss: 0.49803
# Batch count: 238, Avg. per-sample expected Loss: 0.49845
# Batch count: 239, Avg. per-sample expected Loss: 0.49734
# Batch count: 240, Avg. per-sample expected Loss: 0.50427
# Batch count: 241, Avg. per-sample expected Loss: 0.49950
# Batch count: 242, Avg. per-sample expected Loss: 0.50004
# Batch count: 243, Avg. per-sample expected Loss: 0.50173
# Batch count: 244, Avg. per-sample expected Loss: 0.50049
# Batch count: 245, Avg. per-sample expected Loss: 0.49857
# Batch count: 246, Avg. per-sample expected Loss: 0.49910
# Batch count: 247, Avg. per-sample expected Loss: 0.49613
# Batch count: 248, Avg. per-sample expected Loss: 0.50146
# Batch count: 249, Avg. per-sample expected Loss: 0.49861
# Batch count: 250, Avg. per-sample expected Loss: 0.49786
# Batch count: 251, Avg. per-sample expected Loss: 0.49896
# Batch count: 252, Avg. per-sample expected Loss: 0.49752
# Batch count: 253, Avg. per-sample expected Loss: 0.49556
# Batch count: 254, Avg. per-sample expected Loss: 0.49777
# Batch count: 255, Avg. per-sample expected Loss: 0.49462
# Batch count: 256, Avg. per-sample expected Loss: 0.49510
# Batch count: 257, Avg. per-sample expected Loss: 0.49659
# Batch count: 258, Avg. per-sample expected Loss: 0.49564
# Batch count: 259, Avg. per-sample expected Loss: 0.49503
# Batch count: 260, Avg. per-sample expected Loss: 0.49515
# Batch count: 261, Avg. per-sample expected Loss: 0.49458
# Batch count: 262, Avg. per-sample expected Loss: 0.49636
# Batch count: 263, Avg. per-sample expected Loss: 0.49496
# Batch count: 264, Avg. per-sample expected Loss: 0.49331
# Batch count: 265, Avg. per-sample expected Loss: 0.49298
# Batch count: 266, Avg. per-sample expected Loss: 0.49435
# Batch count: 267, Avg. per-sample expected Loss: 0.49326
# Batch count: 268, Avg. per-sample expected Loss: 0.49568
# Batch count: 269, Avg. per-sample expected Loss: 0.49510
# Batch count: 270, Avg. per-sample expected Loss: 0.49419
# Batch count: 271, Avg. per-sample expected Loss: 0.49252
# Batch count: 272, Avg. per-sample expected Loss: 0.49205
# Batch count: 273, Avg. per-sample expected Loss: 0.49155
# Batch count: 274, Avg. per-sample expected Loss: 0.49399
# Batch count: 275, Avg. per-sample expected Loss: 0.49428
# Batch count: 276, Avg. per-sample expected Loss: 0.49442
# Batch count: 277, Avg. per-sample expected Loss: 0.49242
# Batch count: 278, Avg. per-sample expected Loss: 0.49479
# Batch count: 279, Avg. per-sample expected Loss: 0.49392
# Batch count: 280, Avg. per-sample expected Loss: 0.49269
# Batch count: 281, Avg. per-sample expected Loss: 0.49052
# Batch count: 282, Avg. per-sample expected Loss: 0.49052
# Batch count: 283, Avg. per-sample expected Loss: 0.48908
# Batch count: 284, Avg. per-sample expected Loss: 0.49342
# Batch count: 285, Avg. per-sample expected Loss: 0.49189
# Batch count: 286, Avg. per-sample expected Loss: 0.49145
# Batch count: 287, Avg. per-sample expected Loss: 0.49202
# Batch count: 288, Avg. per-sample expected Loss: 0.49253
# Batch count: 289, Avg. per-sample expected Loss: 0.49125
# Batch count: 290, Avg. per-sample expected Loss: 0.49292
# Batch count: 291, Avg. per-sample expected Loss: 0.48918
# Batch count: 292, Avg. per-sample expected Loss: 0.48972
# Batch count: 293, Avg. per-sample expected Loss: 0.48804
# Batch count: 294, Avg. per-sample expected Loss: 0.48924
# Batch count: 295, Avg. per-sample expected Loss: 0.48954
# Batch count: 296, Avg. per-sample expected Loss: 0.49168
# Batch count: 297, Avg. per-sample expected Loss: 0.48786
# Batch count: 298, Avg. per-sample expected Loss: 0.48804
# Batch count: 299, Avg. per-sample expected Loss: 0.48647
# Batch count: 300, Avg. per-sample expected Loss: 0.48619
# Batch count: 301, Avg. per-sample expected Loss: 0.48681
# Batch count: 302, Avg. per-sample expected Loss: 0.48768
# Batch count: 303, Avg. per-sample expected Loss: 0.48658
# Batch count: 304, Avg. per-sample expected Loss: 0.48769
# Batch count: 305, Avg. per-sample expected Loss: 0.48820
# Batch count: 306, Avg. per-sample expected Loss: 0.48694
# Batch count: 307, Avg. per-sample expected Loss: 0.48483
# Batch count: 308, Avg. per-sample expected Loss: 0.48342
# Batch count: 309, Avg. per-sample expected Loss: 0.48384
# Batch count: 310, Avg. per-sample expected Loss: 0.48463
# Batch count: 311, Avg. per-sample expected Loss: 0.48484
# Batch count: 312, Avg. per-sample expected Loss: 0.48669
# Batch count: 313, Avg. per-sample expected Loss: 0.48466
# Batch count: 314, Avg. per-sample expected Loss: 0.48355
# Batch count: 315, Avg. per-sample expected Loss: 0.48155
# Batch count: 316, Avg. per-sample expected Loss: 0.48245
# Batch count: 317, Avg. per-sample expected Loss: 0.48340
# Batch count: 318, Avg. per-sample expected Loss: 0.48505
# Batch count: 319, Avg. per-sample expected Loss: 0.48146
# Batch count: 320, Avg. per-sample expected Loss: 0.48167
# Batch count: 321, Avg. per-sample expected Loss: 0.48489
# Batch count: 322, Avg. per-sample expected Loss: 0.48119
# Batch count: 323, Avg. per-sample expected Loss: 0.48087
# Batch count: 324, Avg. per-sample expected Loss: 0.48451
# Batch count: 325, Avg. per-sample expected Loss: 0.48374
# Batch count: 326, Avg. per-sample expected Loss: 0.48159
# Batch count: 327, Avg. per-sample expected Loss: 0.48004
# Batch count: 328, Avg. per-sample expected Loss: 0.48079
# Batch count: 329, Avg. per-sample expected Loss: 0.48240
# Batch count: 330, Avg. per-sample expected Loss: 0.48270
# Batch count: 331, Avg. per-sample expected Loss: 0.48394
# Batch count: 332, Avg. per-sample expected Loss: 0.48050
# Batch count: 333, Avg. per-sample expected Loss: 0.48129
# Batch count: 334, Avg. per-sample expected Loss: 0.47852
# Batch count: 335, Avg. per-sample expected Loss: 0.47857
# Batch count: 336, Avg. per-sample expected Loss: 0.48003
# Batch count: 337, Avg. per-sample expected Loss: 0.47740
# Batch count: 338, Avg. per-sample expected Loss: 0.47753
# Batch count: 339, Avg. per-sample expected Loss: 0.47981
# Batch count: 340, Avg. per-sample expected Loss: 0.47615
# Batch count: 341, Avg. per-sample expected Loss: 0.47500
# Batch count: 342, Avg. per-sample expected Loss: 0.47927
# Batch count: 343, Avg. per-sample expected Loss: 0.47756
# Batch count: 344, Avg. per-sample expected Loss: 0.47896
# Batch count: 345, Avg. per-sample expected Loss: 0.47502
# Batch count: 346, Avg. per-sample expected Loss: 0.47760
# Batch count: 347, Avg. per-sample expected Loss: 0.47357
# Batch count: 348, Avg. per-sample expected Loss: 0.47497
# Batch count: 349, Avg. per-sample expected Loss: 0.47729

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")

plt.title("Training using 2-QNSCD and 2-RQSGD (6 samples per itr)")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("2RSGD_6s.png")
plt.show()

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")
plt.plot(SGD6c_cost, "g", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")
plt.plot(SGD6c_Ecost, "g.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training 2-QNSCD and 2-RQSGD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("RQSGD.png")
plt.show()

# %% [markdown]
# ## Testing Phase

# %%
### Saving Final Parameters:
file_name1 = "6Q 2-QNSCD params"
file_name2 = "6Q 2-RQSGD_6s params"
file_name3 = "6Q 6-RQSGD params"

np.save(file_name1,NCGDparams)
np.save(file_name2,SGD6params)
np.save(file_name3,SGD6cparams)

# %%
phiTest = np.load('6-qubitsPhiTest_v1.npy')
labelTest = np.load('6-qubitsLabelTest_v1.npy')

phiTest.requires_grad = False
labelTest.requires_grad = False

# %%
nTest = 1000

NCGDparams_opt = NCGDparams 
SGD6params_opt = SGD6params
SGD6cparams_opt = SGD6cparams

# %%
### Optimal Expected Loss
expOperator = 0

for i in range(nTest):
    op = np.matmul(phiTest[:,i].reshape(dim,1),phiTest[:,i].reshape(1,dim))
    expOperator = expOperator + labelTest[i]*op
expOperator = expOperator/(nTest)
opt_value = 0.5*(1+sum(abs(np.linalg.svd(expOperator)[1])))

# %%
NCGD_rslt = []
SGD6_rslt = []
SGD6c_rslt = []

for i in range(int(1e1)):
    NCGDcount = 0
    SGD6count = 0
    SGD6ccount = 0

    for itr in range(nTest):
        if circuit_test(NCGDparams_opt,phiTest[:,itr]) == labelTest[itr]:
            NCGDcount += 1 
        if circuit_test(SGD6params_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6count += 1
        if circuit_test(SGD6cparams_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6ccount += 1
    
    NCGD_rslt.append(NCGDcount/nTest)
    SGD6_rslt.append(SGD6count/nTest)
    SGD6c_rslt.append(SGD6ccount/nTest)
#     print("itr = ",i)

# %%
print("Optimal: {:.3f} \nNCGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n2-RQSGD_6s: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n6-RQSGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f}"\
      .format(opt_value,np.average(NCGD_rslt),np.std(NCGD_rslt),max(NCGD_rslt),min(NCGD_rslt),\
              np.average(SGD6_rslt),np.std(SGD6_rslt),max(SGD6_rslt),min(SGD6_rslt), \
              np.average(SGD6c_rslt),np.std(SGD6c_rslt),max(SGD6c_rslt),min(SGD6c_rslt)))
# Out:
# Optimal: 0.880
# NCGD: 0.856 / 0.012 max: 0.875 min: 0.839
# 2-RQSGD_6s: 0.528 / 0.013 max: 0.546 min: 0.501
# 6-RQSGD: 0.843 / 0.014 max: 0.865 min: 0.819
