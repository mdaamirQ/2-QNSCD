# %%
import pennylane as qml
from pennylane import numpy as np
import scipy
import matplotlib.pyplot as plt
from globalVars import *
from model_6qubit import *

from GRADest_6Q import EstGrad
from EQFIMest_6Q import Est_EQFIM

# %% [markdown]
# ## Quantum Neural Network

# %%
random_state = np.random.rand(dim)
random_state = random_state /np.linalg.norm(random_state)
qml.draw_mpl(QNN)(np.zeros(nparams),random_state)
# Out:
# (<Figure size 1500x700 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### Model Initialization

# %%
S_pItr = 6  # no. of samples used per-iteration 

nStep = 400
nItr = 100
step_size = 0.0025

Bsize = S_pItr*nItr

# %%
phiTrain = np.load('6-qubitsPhiTrain_v1.npy')
labelTrain = np.load('6-qubitsLabelTrain_v1.npy')

phiTrain.requires_grad = False
labelTrain.requires_grad = False

# %%
'QNSCD Dataset'
phiTrainNCGD = phiTrain
labelTrainNCGD = labelTrain

'SGD Dataset'
phiTrainSGD = phiTrain
labelTrainSGD = labelTrain

# %%
### Optimal Expected Loss
Opt_cost = []
itrBatch = np.linspace(0,Bsize*nStep,nStep,endpoint = False,dtype = 'int').tolist()
for itr1 in itrBatch:
    expOperator = 0
    for itr2 in range(Bsize):
        temp_phi = phiTrain[:,itr1+itr2]
        op = np.matmul(temp_phi.reshape(dim,1),temp_phi.reshape(1,dim))
        expOperator = expOperator + labelTrain[itr1+itr2]*op
    expOperator = expOperator/Bsize
    opt_value = 0.5*(1-sum(abs(np.linalg.svd(expOperator)[1])))
    Opt_cost.append(opt_value)

file_name = "6Q-Minimum Expected Loss"
np.save(file_name,Opt_cost)

# %% [markdown]
# # Optimizers

# %%
'QNN outputs yhat'
dev = qml.device("default.qubit", wires=nqubits, shots=1)

@qml.qnode(dev,interface='autograd')
def circuit_test(params,state):
    QNN(params,state)
    return qml.sample(qml.Hermitian(M,wires=list(range(nqubits))))

# %%
init_params = np.random.uniform(low=0, high=2*np.pi, size=nparams, requires_grad=True)
init_params = np.array([2.7906838,  0.31512482, 4.21519967, 4.57105865, 5.89424537, 0.16774979,
 0.86686308, 0.13743499, 2.21323183, 1.77928538, 5.18722227, 0.29293255,
 3.29003696, 0.67906535, 6.28087333, 1.44635918, 1.64423782, 5.6171104,
 4.91935638, 1.5489724,  5.5046532,  3.18739548, 4.53290425, 5.98480648,
 3.13678399, 0.56131204, 4.73927398, 2.93489426, 3.64851649, 1.47404811,
 4.93284696, 4.26137878, 1.14803802, 4.17139993, 2.11538648, 0.35691027,
 5.41243459, 2.36358472, 3.94870743, 3.96502782, 5.33711361, 0.01526141,
 4.00331096, 2.54161393, 4.65794868, 2.91847434, 4.77226774, 1.42748314],requires_grad = True)

'cost initialization'
phiTrain0 = phiTrain[:,-1*(Bsize+1):-1]
labelTrain0 = labelTrain[-1*(Bsize+1):-1]
temp_cost = sum([ps_expLoss(init_params,phiTrain0[:,itr],labelTrain0[itr]) for itr in range(Bsize)])/Bsize
print("Initial Average Per-Sample Expected Loss: ",temp_cost)

count = 0
for itr in range(Bsize):
    if circuit_test(init_params,phiTrain0[:,itr]) != labelTrain0[itr]:
        count += 1
temp_Ecost = count/Bsize
print("Initial Average Empirical Loss", temp_Ecost)
# Out:
# Initial Average Per-Sample Expected Loss:  0.497985305270733
# Initial Average Empirical Loss 0.475

# %% [markdown]
# ## Quantum Natural Stochastic Pairwise Coordinate Descent (2-QNSCD)

# %%
NCGDparams = np.array(init_params)
NCGD_cost = []
NCGD_Ecost = []

NCGD_cost.append(temp_cost)
NCGD_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainNCGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainNCGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a pair of coordinate
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())

        ### Gradient estimation
        y1, b1 = EstGrad(NCGDparams,phiT[:,itr3],idx[0])
        y2, b2 = EstGrad(NCGDparams,phiT[:,itr3+1],idx[1])
        b1 = (1-b1)/2
        b2 = (1-b2)/2

        grad = [-1*((-1)**b1)*loss(y1,labelT[itr3]),-1*((-1)**b2)*loss(y2,labelT[itr3+1])]
        
        ### E-QFIM estimation
        metric = Est_EQFIM(NCGDparams,idx,phiT[:,itr3+2:itr3+S_pItr])

        ### double-parameters update
        NCGDparams[idx] = NCGDparams[idx] - (step_size)*np.dot(np.linalg.inv(metric),grad) 
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(NCGDparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    NCGD_cost.append(energy)
    
    ### average empirical loss calculation
    NCGDcount = 0
    for itr in range(Bsize):
        if circuit_test(NCGDparams,phiT[:,itr]) != labelT[itr]:
            NCGDcount += 1
    NCGD_Ecost.append(NCGDcount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))

file_name1 = "6Q 2-QNSCD Expected Loss"
file_name2 = "6Q 2-QNSCD Empirical Loss"

np.save(file_name1,NCGD_cost)
np.save(file_name2,NCGD_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.49799
# Batch count:  1, Avg. per-sample expected Loss: 0.49564
# Batch count:  2, Avg. per-sample expected Loss: 0.49763
# Batch count:  3, Avg. per-sample expected Loss: 0.49696
# Batch count:  4, Avg. per-sample expected Loss: 0.49495
# Batch count:  5, Avg. per-sample expected Loss: 0.49769
# Batch count:  6, Avg. per-sample expected Loss: 0.49751
# Batch count:  7, Avg. per-sample expected Loss: 0.49646
# Batch count:  8, Avg. per-sample expected Loss: 0.49242
# Batch count:  9, Avg. per-sample expected Loss: 0.49366
# Batch count: 10, Avg. per-sample expected Loss: 0.49300
# Batch count: 11, Avg. per-sample expected Loss: 0.49235
# Batch count: 12, Avg. per-sample expected Loss: 0.49527
# Batch count: 13, Avg. per-sample expected Loss: 0.49279
# Batch count: 14, Avg. per-sample expected Loss: 0.49416
# Batch count: 15, Avg. per-sample expected Loss: 0.49574
# Batch count: 16, Avg. per-sample expected Loss: 0.49719
# Batch count: 17, Avg. per-sample expected Loss: 0.49223
# Batch count: 18, Avg. per-sample expected Loss: 0.49261
# Batch count: 19, Avg. per-sample expected Loss: 0.49603
# Batch count: 20, Avg. per-sample expected Loss: 0.49613
# Batch count: 21, Avg. per-sample expected Loss: 0.49990
# Batch count: 22, Avg. per-sample expected Loss: 0.49842
# Batch count: 23, Avg. per-sample expected Loss: 0.49771
# Batch count: 24, Avg. per-sample expected Loss: 0.49406
# Batch count: 25, Avg. per-sample expected Loss: 0.49407
# Batch count: 26, Avg. per-sample expected Loss: 0.48981
# Batch count: 27, Avg. per-sample expected Loss: 0.49346
# Batch count: 28, Avg. per-sample expected Loss: 0.49105
# Batch count: 29, Avg. per-sample expected Loss: 0.49412
# Batch count: 30, Avg. per-sample expected Loss: 0.48854
# Batch count: 31, Avg. per-sample expected Loss: 0.48950
# Batch count: 32, Avg. per-sample expected Loss: 0.48868
# Batch count: 33, Avg. per-sample expected Loss: 0.49041
# Batch count: 34, Avg. per-sample expected Loss: 0.49017
# Batch count: 35, Avg. per-sample expected Loss: 0.48738
# Batch count: 36, Avg. per-sample expected Loss: 0.49332
# Batch count: 37, Avg. per-sample expected Loss: 0.49914
# Batch count: 38, Avg. per-sample expected Loss: 0.49732
# Batch count: 39, Avg. per-sample expected Loss: 0.49482
# Batch count: 40, Avg. per-sample expected Loss: 0.50138
# Batch count: 41, Avg. per-sample expected Loss: 0.50397
# Batch count: 42, Avg. per-sample expected Loss: 0.50520
# Batch count: 43, Avg. per-sample expected Loss: 0.50616
# Batch count: 44, Avg. per-sample expected Loss: 0.49850
# Batch count: 45, Avg. per-sample expected Loss: 0.50202
# Batch count: 46, Avg. per-sample expected Loss: 0.49575
# Batch count: 47, Avg. per-sample expected Loss: 0.50126
# Batch count: 48, Avg. per-sample expected Loss: 0.50738
# Batch count: 49, Avg. per-sample expected Loss: 0.50844
# Batch count: 50, Avg. per-sample expected Loss: 0.50892
# Batch count: 51, Avg. per-sample expected Loss: 0.50537
# Batch count: 52, Avg. per-sample expected Loss: 0.49737
# Batch count: 53, Avg. per-sample expected Loss: 0.49998
# Batch count: 54, Avg. per-sample expected Loss: 0.49443
# Batch count: 55, Avg. per-sample expected Loss: 0.49238
# Batch count: 56, Avg. per-sample expected Loss: 0.49201
# Batch count: 57, Avg. per-sample expected Loss: 0.48925
# Batch count: 58, Avg. per-sample expected Loss: 0.49252
# Batch count: 59, Avg. per-sample expected Loss: 0.48602
# Batch count: 60, Avg. per-sample expected Loss: 0.48577
# Batch count: 61, Avg. per-sample expected Loss: 0.48752
# Batch count: 62, Avg. per-sample expected Loss: 0.48672
# Batch count: 63, Avg. per-sample expected Loss: 0.48885
# Batch count: 64, Avg. per-sample expected Loss: 0.48612
# Batch count: 65, Avg. per-sample expected Loss: 0.48737
# Batch count: 66, Avg. per-sample expected Loss: 0.49010
# Batch count: 67, Avg. per-sample expected Loss: 0.48741
# Batch count: 68, Avg. per-sample expected Loss: 0.48986
# Batch count: 69, Avg. per-sample expected Loss: 0.48924
# Batch count: 70, Avg. per-sample expected Loss: 0.48978
# Batch count: 71, Avg. per-sample expected Loss: 0.48930
# Batch count: 72, Avg. per-sample expected Loss: 0.49218
# Batch count: 73, Avg. per-sample expected Loss: 0.48878
# Batch count: 74, Avg. per-sample expected Loss: 0.48923
# Batch count: 75, Avg. per-sample expected Loss: 0.49057
# Batch count: 76, Avg. per-sample expected Loss: 0.48988
# Batch count: 77, Avg. per-sample expected Loss: 0.49251
# Batch count: 78, Avg. per-sample expected Loss: 0.48983
# Batch count: 79, Avg. per-sample expected Loss: 0.49029
# Batch count: 80, Avg. per-sample expected Loss: 0.49008
# Batch count: 81, Avg. per-sample expected Loss: 0.49158
# Batch count: 82, Avg. per-sample expected Loss: 0.49134
# Batch count: 83, Avg. per-sample expected Loss: 0.49080
# Batch count: 84, Avg. per-sample expected Loss: 0.49223
# Batch count: 85, Avg. per-sample expected Loss: 0.49232
# Batch count: 86, Avg. per-sample expected Loss: 0.49243
# Batch count: 87, Avg. per-sample expected Loss: 0.49267
# Batch count: 88, Avg. per-sample expected Loss: 0.49193
# Batch count: 89, Avg. per-sample expected Loss: 0.49275
# Batch count: 90, Avg. per-sample expected Loss: 0.48948
# Batch count: 91, Avg. per-sample expected Loss: 0.49142
# Batch count: 92, Avg. per-sample expected Loss: 0.48954
# Batch count: 93, Avg. per-sample expected Loss: 0.49059
# Batch count: 94, Avg. per-sample expected Loss: 0.49323
# Batch count: 95, Avg. per-sample expected Loss: 0.49344
# Batch count: 96, Avg. per-sample expected Loss: 0.49234
# Batch count: 97, Avg. per-sample expected Loss: 0.49161
# Batch count: 98, Avg. per-sample expected Loss: 0.49283
# Batch count: 99, Avg. per-sample expected Loss: 0.49377
# Batch count: 100, Avg. per-sample expected Loss: 0.49259
# Batch count: 101, Avg. per-sample expected Loss: 0.49293
# Batch count: 102, Avg. per-sample expected Loss: 0.49119
# Batch count: 103, Avg. per-sample expected Loss: 0.49082
# Batch count: 104, Avg. per-sample expected Loss: 0.48988
# Batch count: 105, Avg. per-sample expected Loss: 0.49034
# Batch count: 106, Avg. per-sample expected Loss: 0.48866
# Batch count: 107, Avg. per-sample expected Loss: 0.48928
# Batch count: 108, Avg. per-sample expected Loss: 0.48738
# Batch count: 109, Avg. per-sample expected Loss: 0.48864
# Batch count: 110, Avg. per-sample expected Loss: 0.48689
# Batch count: 111, Avg. per-sample expected Loss: 0.48509
# Batch count: 112, Avg. per-sample expected Loss: 0.48638
# Batch count: 113, Avg. per-sample expected Loss: 0.48682
# Batch count: 114, Avg. per-sample expected Loss: 0.48729
# Batch count: 115, Avg. per-sample expected Loss: 0.48864
# Batch count: 116, Avg. per-sample expected Loss: 0.48699
# Batch count: 117, Avg. per-sample expected Loss: 0.48601
# Batch count: 118, Avg. per-sample expected Loss: 0.48984
# Batch count: 119, Avg. per-sample expected Loss: 0.48903
# Batch count: 120, Avg. per-sample expected Loss: 0.48826
# Batch count: 121, Avg. per-sample expected Loss: 0.49032
# Batch count: 122, Avg. per-sample expected Loss: 0.48911
# Batch count: 123, Avg. per-sample expected Loss: 0.48905
# Batch count: 124, Avg. per-sample expected Loss: 0.48783
# Batch count: 125, Avg. per-sample expected Loss: 0.48638
# Batch count: 126, Avg. per-sample expected Loss: 0.48673
# Batch count: 127, Avg. per-sample expected Loss: 0.48701
# Batch count: 128, Avg. per-sample expected Loss: 0.48569
# Batch count: 129, Avg. per-sample expected Loss: 0.48331
# Batch count: 130, Avg. per-sample expected Loss: 0.48404
# Batch count: 131, Avg. per-sample expected Loss: 0.48416
# Batch count: 132, Avg. per-sample expected Loss: 0.48444
# Batch count: 133, Avg. per-sample expected Loss: 0.48108
# Batch count: 134, Avg. per-sample expected Loss: 0.48115
# Batch count: 135, Avg. per-sample expected Loss: 0.48194
# Batch count: 136, Avg. per-sample expected Loss: 0.48543
# Batch count: 137, Avg. per-sample expected Loss: 0.48185
# Batch count: 138, Avg. per-sample expected Loss: 0.47991
# Batch count: 139, Avg. per-sample expected Loss: 0.47824
# Batch count: 140, Avg. per-sample expected Loss: 0.47357
# Batch count: 141, Avg. per-sample expected Loss: 0.46864
# Batch count: 142, Avg. per-sample expected Loss: 0.46641
# Batch count: 143, Avg. per-sample expected Loss: 0.46558
# Batch count: 144, Avg. per-sample expected Loss: 0.46530
# Batch count: 145, Avg. per-sample expected Loss: 0.46159
# Batch count: 146, Avg. per-sample expected Loss: 0.44937
# Batch count: 147, Avg. per-sample expected Loss: 0.44748
# Batch count: 148, Avg. per-sample expected Loss: 0.44570
# Batch count: 149, Avg. per-sample expected Loss: 0.43983
# Batch count: 150, Avg. per-sample expected Loss: 0.44445
# Batch count: 151, Avg. per-sample expected Loss: 0.43387
# Batch count: 152, Avg. per-sample expected Loss: 0.43453
# Batch count: 153, Avg. per-sample expected Loss: 0.44067
# Batch count: 154, Avg. per-sample expected Loss: 0.44835
# Batch count: 155, Avg. per-sample expected Loss: 0.45023
# Batch count: 156, Avg. per-sample expected Loss: 0.43353
# Batch count: 157, Avg. per-sample expected Loss: 0.43463
# Batch count: 158, Avg. per-sample expected Loss: 0.43459
# Batch count: 159, Avg. per-sample expected Loss: 0.42785
# Batch count: 160, Avg. per-sample expected Loss: 0.42705
# Batch count: 161, Avg. per-sample expected Loss: 0.42145
# Batch count: 162, Avg. per-sample expected Loss: 0.41643
# Batch count: 163, Avg. per-sample expected Loss: 0.42236
# Batch count: 164, Avg. per-sample expected Loss: 0.42213
# Batch count: 165, Avg. per-sample expected Loss: 0.42763
# Batch count: 166, Avg. per-sample expected Loss: 0.42287
# Batch count: 167, Avg. per-sample expected Loss: 0.42393
# Batch count: 168, Avg. per-sample expected Loss: 0.41819
# Batch count: 169, Avg. per-sample expected Loss: 0.41363
# Batch count: 170, Avg. per-sample expected Loss: 0.40539
# Batch count: 171, Avg. per-sample expected Loss: 0.41355
# Batch count: 172, Avg. per-sample expected Loss: 0.41013
# Batch count: 173, Avg. per-sample expected Loss: 0.41381
# Batch count: 174, Avg. per-sample expected Loss: 0.40600
# Batch count: 175, Avg. per-sample expected Loss: 0.40586
# Batch count: 176, Avg. per-sample expected Loss: 0.41272
# Batch count: 177, Avg. per-sample expected Loss: 0.41058
# Batch count: 178, Avg. per-sample expected Loss: 0.40681
# Batch count: 179, Avg. per-sample expected Loss: 0.39916
# Batch count: 180, Avg. per-sample expected Loss: 0.40373
# Batch count: 181, Avg. per-sample expected Loss: 0.41092
# Batch count: 182, Avg. per-sample expected Loss: 0.40935
# Batch count: 183, Avg. per-sample expected Loss: 0.40396
# Batch count: 184, Avg. per-sample expected Loss: 0.41414
# Batch count: 185, Avg. per-sample expected Loss: 0.41029
# Batch count: 186, Avg. per-sample expected Loss: 0.41771
# Batch count: 187, Avg. per-sample expected Loss: 0.41867
# Batch count: 188, Avg. per-sample expected Loss: 0.42443
# Batch count: 189, Avg. per-sample expected Loss: 0.41143
# Batch count: 190, Avg. per-sample expected Loss: 0.41702
# Batch count: 191, Avg. per-sample expected Loss: 0.41943
# Batch count: 192, Avg. per-sample expected Loss: 0.42156
# Batch count: 193, Avg. per-sample expected Loss: 0.41923
# Batch count: 194, Avg. per-sample expected Loss: 0.41572
# Batch count: 195, Avg. per-sample expected Loss: 0.42036
# Batch count: 196, Avg. per-sample expected Loss: 0.41407
# Batch count: 197, Avg. per-sample expected Loss: 0.40364
# Batch count: 198, Avg. per-sample expected Loss: 0.39945
# Batch count: 199, Avg. per-sample expected Loss: 0.40331
# Batch count: 200, Avg. per-sample expected Loss: 0.40152
# Batch count: 201, Avg. per-sample expected Loss: 0.41968
# Batch count: 202, Avg. per-sample expected Loss: 0.40655
# Batch count: 203, Avg. per-sample expected Loss: 0.41212
# Batch count: 204, Avg. per-sample expected Loss: 0.39692
# Batch count: 205, Avg. per-sample expected Loss: 0.40726
# Batch count: 206, Avg. per-sample expected Loss: 0.39974
# Batch count: 207, Avg. per-sample expected Loss: 0.39644
# Batch count: 208, Avg. per-sample expected Loss: 0.38635
# Batch count: 209, Avg. per-sample expected Loss: 0.38162
# Batch count: 210, Avg. per-sample expected Loss: 0.38023
# Batch count: 211, Avg. per-sample expected Loss: 0.37937
# Batch count: 212, Avg. per-sample expected Loss: 0.36032
# Batch count: 213, Avg. per-sample expected Loss: 0.36300
# Batch count: 214, Avg. per-sample expected Loss: 0.37590
# Batch count: 215, Avg. per-sample expected Loss: 0.37066
# Batch count: 216, Avg. per-sample expected Loss: 0.37628
# Batch count: 217, Avg. per-sample expected Loss: 0.37114
# Batch count: 218, Avg. per-sample expected Loss: 0.35627
# Batch count: 219, Avg. per-sample expected Loss: 0.35366
# Batch count: 220, Avg. per-sample expected Loss: 0.33540
# Batch count: 221, Avg. per-sample expected Loss: 0.35837
# Batch count: 222, Avg. per-sample expected Loss: 0.35097
# Batch count: 223, Avg. per-sample expected Loss: 0.34713
# Batch count: 224, Avg. per-sample expected Loss: 0.34103
# Batch count: 225, Avg. per-sample expected Loss: 0.33838
# Batch count: 226, Avg. per-sample expected Loss: 0.34017
# Batch count: 227, Avg. per-sample expected Loss: 0.32766
# Batch count: 228, Avg. per-sample expected Loss: 0.32695
# Batch count: 229, Avg. per-sample expected Loss: 0.31557
# Batch count: 230, Avg. per-sample expected Loss: 0.32280
# Batch count: 231, Avg. per-sample expected Loss: 0.31998
# Batch count: 232, Avg. per-sample expected Loss: 0.29686
# Batch count: 233, Avg. per-sample expected Loss: 0.30683
# Batch count: 234, Avg. per-sample expected Loss: 0.31218
# Batch count: 235, Avg. per-sample expected Loss: 0.32392
# Batch count: 236, Avg. per-sample expected Loss: 0.31375
# Batch count: 237, Avg. per-sample expected Loss: 0.30830
# Batch count: 238, Avg. per-sample expected Loss: 0.33421
# Batch count: 239, Avg. per-sample expected Loss: 0.30619
# Batch count: 240, Avg. per-sample expected Loss: 0.32421
# Batch count: 241, Avg. per-sample expected Loss: 0.31997
# Batch count: 242, Avg. per-sample expected Loss: 0.31746
# Batch count: 243, Avg. per-sample expected Loss: 0.33309
# Batch count: 244, Avg. per-sample expected Loss: 0.30707
# Batch count: 245, Avg. per-sample expected Loss: 0.30499
# Batch count: 246, Avg. per-sample expected Loss: 0.28824
# Batch count: 247, Avg. per-sample expected Loss: 0.29262
# Batch count: 248, Avg. per-sample expected Loss: 0.31142
# Batch count: 249, Avg. per-sample expected Loss: 0.30397
# Batch count: 250, Avg. per-sample expected Loss: 0.29869
# Batch count: 251, Avg. per-sample expected Loss: 0.29234
# Batch count: 252, Avg. per-sample expected Loss: 0.28381
# Batch count: 253, Avg. per-sample expected Loss: 0.27341
# Batch count: 254, Avg. per-sample expected Loss: 0.26597
# Batch count: 255, Avg. per-sample expected Loss: 0.27504
# Batch count: 256, Avg. per-sample expected Loss: 0.27966
# Batch count: 257, Avg. per-sample expected Loss: 0.27437
# Batch count: 258, Avg. per-sample expected Loss: 0.27397
# Batch count: 259, Avg. per-sample expected Loss: 0.26588
# Batch count: 260, Avg. per-sample expected Loss: 0.26345
# Batch count: 261, Avg. per-sample expected Loss: 0.25283
# Batch count: 262, Avg. per-sample expected Loss: 0.24431
# Batch count: 263, Avg. per-sample expected Loss: 0.24545
# Batch count: 264, Avg. per-sample expected Loss: 0.25211
# Batch count: 265, Avg. per-sample expected Loss: 0.25032
# Batch count: 266, Avg. per-sample expected Loss: 0.24943
# Batch count: 267, Avg. per-sample expected Loss: 0.25336
# Batch count: 268, Avg. per-sample expected Loss: 0.26700
# Batch count: 269, Avg. per-sample expected Loss: 0.25348
# Batch count: 270, Avg. per-sample expected Loss: 0.24549
# Batch count: 271, Avg. per-sample expected Loss: 0.26197
# Batch count: 272, Avg. per-sample expected Loss: 0.24869
# Batch count: 273, Avg. per-sample expected Loss: 0.24940
# Batch count: 274, Avg. per-sample expected Loss: 0.25184
# Batch count: 275, Avg. per-sample expected Loss: 0.23893
# Batch count: 276, Avg. per-sample expected Loss: 0.23542
# Batch count: 277, Avg. per-sample expected Loss: 0.23058
# Batch count: 278, Avg. per-sample expected Loss: 0.26171
# Batch count: 279, Avg. per-sample expected Loss: 0.26419
# Batch count: 280, Avg. per-sample expected Loss: 0.24148
# Batch count: 281, Avg. per-sample expected Loss: 0.25578
# Batch count: 282, Avg. per-sample expected Loss: 0.23924
# Batch count: 283, Avg. per-sample expected Loss: 0.22727
# Batch count: 284, Avg. per-sample expected Loss: 0.24109
# Batch count: 285, Avg. per-sample expected Loss: 0.23974
# Batch count: 286, Avg. per-sample expected Loss: 0.22112
# Batch count: 287, Avg. per-sample expected Loss: 0.22597
# Batch count: 288, Avg. per-sample expected Loss: 0.22354
# Batch count: 289, Avg. per-sample expected Loss: 0.23635
# Batch count: 290, Avg. per-sample expected Loss: 0.21733
# Batch count: 291, Avg. per-sample expected Loss: 0.21940
# Batch count: 292, Avg. per-sample expected Loss: 0.21564
# Batch count: 293, Avg. per-sample expected Loss: 0.22429
# Batch count: 294, Avg. per-sample expected Loss: 0.22976
# Batch count: 295, Avg. per-sample expected Loss: 0.23131
# Batch count: 296, Avg. per-sample expected Loss: 0.22319
# Batch count: 297, Avg. per-sample expected Loss: 0.20717
# Batch count: 298, Avg. per-sample expected Loss: 0.21545
# Batch count: 299, Avg. per-sample expected Loss: 0.20970
# Batch count: 300, Avg. per-sample expected Loss: 0.21059
# Batch count: 301, Avg. per-sample expected Loss: 0.21563
# Batch count: 302, Avg. per-sample expected Loss: 0.21424
# Batch count: 303, Avg. per-sample expected Loss: 0.21135
# Batch count: 304, Avg. per-sample expected Loss: 0.20850
# Batch count: 305, Avg. per-sample expected Loss: 0.20276
# Batch count: 306, Avg. per-sample expected Loss: 0.21226
# Batch count: 307, Avg. per-sample expected Loss: 0.20765
# Batch count: 308, Avg. per-sample expected Loss: 0.20566
# Batch count: 309, Avg. per-sample expected Loss: 0.20851
# Batch count: 310, Avg. per-sample expected Loss: 0.18215
# Batch count: 311, Avg. per-sample expected Loss: 0.19755
# Batch count: 312, Avg. per-sample expected Loss: 0.20626
# Batch count: 313, Avg. per-sample expected Loss: 0.21476
# Batch count: 314, Avg. per-sample expected Loss: 0.19149
# Batch count: 315, Avg. per-sample expected Loss: 0.19459
# Batch count: 316, Avg. per-sample expected Loss: 0.20275
# Batch count: 317, Avg. per-sample expected Loss: 0.18362
# Batch count: 318, Avg. per-sample expected Loss: 0.20359
# Batch count: 319, Avg. per-sample expected Loss: 0.18829
# Batch count: 320, Avg. per-sample expected Loss: 0.18518
# Batch count: 321, Avg. per-sample expected Loss: 0.19193
# Batch count: 322, Avg. per-sample expected Loss: 0.19045
# Batch count: 323, Avg. per-sample expected Loss: 0.19632
# Batch count: 324, Avg. per-sample expected Loss: 0.19670
# Batch count: 325, Avg. per-sample expected Loss: 0.19718
# Batch count: 326, Avg. per-sample expected Loss: 0.18291
# Batch count: 327, Avg. per-sample expected Loss: 0.18546
# Batch count: 328, Avg. per-sample expected Loss: 0.20032
# Batch count: 329, Avg. per-sample expected Loss: 0.20517
# Batch count: 330, Avg. per-sample expected Loss: 0.19964
# Batch count: 331, Avg. per-sample expected Loss: 0.19975
# Batch count: 332, Avg. per-sample expected Loss: 0.19470
# Batch count: 333, Avg. per-sample expected Loss: 0.19506
# Batch count: 334, Avg. per-sample expected Loss: 0.18941
# Batch count: 335, Avg. per-sample expected Loss: 0.20310
# Batch count: 336, Avg. per-sample expected Loss: 0.19585
# Batch count: 337, Avg. per-sample expected Loss: 0.18979
# Batch count: 338, Avg. per-sample expected Loss: 0.18807
# Batch count: 339, Avg. per-sample expected Loss: 0.18939
# Batch count: 340, Avg. per-sample expected Loss: 0.18586
# Batch count: 341, Avg. per-sample expected Loss: 0.17541
# Batch count: 342, Avg. per-sample expected Loss: 0.19496
# Batch count: 343, Avg. per-sample expected Loss: 0.18707
# Batch count: 344, Avg. per-sample expected Loss: 0.18459
# Batch count: 345, Avg. per-sample expected Loss: 0.18477
# Batch count: 346, Avg. per-sample expected Loss: 0.18149
# Batch count: 347, Avg. per-sample expected Loss: 0.18222
# Batch count: 348, Avg. per-sample expected Loss: 0.18508
# Batch count: 349, Avg. per-sample expected Loss: 0.18466
# Batch count: 350, Avg. per-sample expected Loss: 0.18840
# Batch count: 351, Avg. per-sample expected Loss: 0.18244
# Batch count: 352, Avg. per-sample expected Loss: 0.18021
# Batch count: 353, Avg. per-sample expected Loss: 0.16817
# Batch count: 354, Avg. per-sample expected Loss: 0.17749
# Batch count: 355, Avg. per-sample expected Loss: 0.18258
# Batch count: 356, Avg. per-sample expected Loss: 0.17048
# Batch count: 357, Avg. per-sample expected Loss: 0.17160
# Batch count: 358, Avg. per-sample expected Loss: 0.17305
# Batch count: 359, Avg. per-sample expected Loss: 0.17376
# Batch count: 360, Avg. per-sample expected Loss: 0.16901
# Batch count: 361, Avg. per-sample expected Loss: 0.18769
# Batch count: 362, Avg. per-sample expected Loss: 0.16726
# Batch count: 363, Avg. per-sample expected Loss: 0.14883
# Batch count: 364, Avg. per-sample expected Loss: 0.16827
# Batch count: 365, Avg. per-sample expected Loss: 0.16809
# Batch count: 366, Avg. per-sample expected Loss: 0.17534
# Batch count: 367, Avg. per-sample expected Loss: 0.16960
# Batch count: 368, Avg. per-sample expected Loss: 0.18516
# Batch count: 369, Avg. per-sample expected Loss: 0.18461
# Batch count: 370, Avg. per-sample expected Loss: 0.16988
# Batch count: 371, Avg. per-sample expected Loss: 0.17645
# Batch count: 372, Avg. per-sample expected Loss: 0.17703
# Batch count: 373, Avg. per-sample expected Loss: 0.16442
# Batch count: 374, Avg. per-sample expected Loss: 0.16628
# Batch count: 375, Avg. per-sample expected Loss: 0.15664
# Batch count: 376, Avg. per-sample expected Loss: 0.17854
# Batch count: 377, Avg. per-sample expected Loss: 0.16098
# Batch count: 378, Avg. per-sample expected Loss: 0.16594
# Batch count: 379, Avg. per-sample expected Loss: 0.15078
# Batch count: 380, Avg. per-sample expected Loss: 0.16115
# Batch count: 381, Avg. per-sample expected Loss: 0.16195
# Batch count: 382, Avg. per-sample expected Loss: 0.16094
# Batch count: 383, Avg. per-sample expected Loss: 0.15790
# Batch count: 384, Avg. per-sample expected Loss: 0.16701
# Batch count: 385, Avg. per-sample expected Loss: 0.15617
# Batch count: 386, Avg. per-sample expected Loss: 0.16071
# Batch count: 387, Avg. per-sample expected Loss: 0.15470
# Batch count: 388, Avg. per-sample expected Loss: 0.16230
# Batch count: 389, Avg. per-sample expected Loss: 0.16044
# Batch count: 390, Avg. per-sample expected Loss: 0.16330
# Batch count: 391, Avg. per-sample expected Loss: 0.15497
# Batch count: 392, Avg. per-sample expected Loss: 0.15860
# Batch count: 393, Avg. per-sample expected Loss: 0.16322
# Batch count: 394, Avg. per-sample expected Loss: 0.16053
# Batch count: 395, Avg. per-sample expected Loss: 0.15484
# Batch count: 396, Avg. per-sample expected Loss: 0.15926
# Batch count: 397, Avg. per-sample expected Loss: 0.16472
# Batch count: 398, Avg. per-sample expected Loss: 0.17167
# Batch count: 399, Avg. per-sample expected Loss: 0.17030

# %% [markdown]
# ## Plots

# %%
plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "b", label="2-QNSCD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.", label="2-QNSCD Empirical Loss")

plt.title("Training using 2-QNSCD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.show()

# %% [markdown]
# ## 6-RQSGD using 600 samples per step

# %%
SGD6cparams = np.array(init_params)
SGD6c_cost = []
SGD6c_Ecost = []

SGD6c_cost.append(temp_cost)
SGD6c_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 6 coordinates
        idx = sorted(np.random.permutation(nparams)[0:6].tolist())
        
        grad = []
        
        ### Gradient estimation
        for i_grad in range(6):
            y_hat,b = EstGrad(SGD6cparams,phiT[:,itr3+i_grad],idx[i_grad])
            b = (1-b)/2
            grad.append((-1)*((-1)**b)*loss(y_hat,labelT[itr3+i_grad]))

        ### single-parameter update
        SGD6cparams[idx] = SGD6cparams[idx] - np.dot(step_size,grad)
    
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6cparams,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6c_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6ccount = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6cparams,phiT[:,itr]) != labelT[itr]:
            SGD6ccount += 1
    SGD6c_Ecost.append(SGD6ccount/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "6Q 6-RQSGD Expected Loss"
file_name2 = "6Q 6-RQSGD Empirical Loss"

np.save(file_name1,SGD6c_cost)
np.save(file_name2,SGD6c_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.49799
# Batch count:  1, Avg. per-sample expected Loss: 0.49624
# Batch count:  2, Avg. per-sample expected Loss: 0.49809
# Batch count:  3, Avg. per-sample expected Loss: 0.49728
# Batch count:  4, Avg. per-sample expected Loss: 0.49628
# Batch count:  5, Avg. per-sample expected Loss: 0.49953
# Batch count:  6, Avg. per-sample expected Loss: 0.49947
# Batch count:  7, Avg. per-sample expected Loss: 0.49939
# Batch count:  8, Avg. per-sample expected Loss: 0.49604
# Batch count:  9, Avg. per-sample expected Loss: 0.49732
# Batch count: 10, Avg. per-sample expected Loss: 0.49637
# Batch count: 11, Avg. per-sample expected Loss: 0.49567
# Batch count: 12, Avg. per-sample expected Loss: 0.49662
# Batch count: 13, Avg. per-sample expected Loss: 0.49481
# Batch count: 14, Avg. per-sample expected Loss: 0.49518
# Batch count: 15, Avg. per-sample expected Loss: 0.49670
# Batch count: 16, Avg. per-sample expected Loss: 0.49783
# Batch count: 17, Avg. per-sample expected Loss: 0.49397
# Batch count: 18, Avg. per-sample expected Loss: 0.49237
# Batch count: 19, Avg. per-sample expected Loss: 0.49471
# Batch count: 20, Avg. per-sample expected Loss: 0.49449
# Batch count: 21, Avg. per-sample expected Loss: 0.49692
# Batch count: 22, Avg. per-sample expected Loss: 0.49572
# Batch count: 23, Avg. per-sample expected Loss: 0.49499
# Batch count: 24, Avg. per-sample expected Loss: 0.49548
# Batch count: 25, Avg. per-sample expected Loss: 0.49495
# Batch count: 26, Avg. per-sample expected Loss: 0.49550
# Batch count: 27, Avg. per-sample expected Loss: 0.49686
# Batch count: 28, Avg. per-sample expected Loss: 0.49452
# Batch count: 29, Avg. per-sample expected Loss: 0.49561
# Batch count: 30, Avg. per-sample expected Loss: 0.49278
# Batch count: 31, Avg. per-sample expected Loss: 0.49353
# Batch count: 32, Avg. per-sample expected Loss: 0.49463
# Batch count: 33, Avg. per-sample expected Loss: 0.49421
# Batch count: 34, Avg. per-sample expected Loss: 0.49416
# Batch count: 35, Avg. per-sample expected Loss: 0.49321
# Batch count: 36, Avg. per-sample expected Loss: 0.49449
# Batch count: 37, Avg. per-sample expected Loss: 0.49423
# Batch count: 38, Avg. per-sample expected Loss: 0.49497
# Batch count: 39, Avg. per-sample expected Loss: 0.49236
# Batch count: 40, Avg. per-sample expected Loss: 0.49637
# Batch count: 41, Avg. per-sample expected Loss: 0.49488
# Batch count: 42, Avg. per-sample expected Loss: 0.49388
# Batch count: 43, Avg. per-sample expected Loss: 0.49324
# Batch count: 44, Avg. per-sample expected Loss: 0.49225
# Batch count: 45, Avg. per-sample expected Loss: 0.49232
# Batch count: 46, Avg. per-sample expected Loss: 0.49144
# Batch count: 47, Avg. per-sample expected Loss: 0.49152
# Batch count: 48, Avg. per-sample expected Loss: 0.49104
# Batch count: 49, Avg. per-sample expected Loss: 0.49406
# Batch count: 50, Avg. per-sample expected Loss: 0.49315
# Batch count: 51, Avg. per-sample expected Loss: 0.49184
# Batch count: 52, Avg. per-sample expected Loss: 0.49205
# Batch count: 53, Avg. per-sample expected Loss: 0.49345
# Batch count: 54, Avg. per-sample expected Loss: 0.49263
# Batch count: 55, Avg. per-sample expected Loss: 0.49147
# Batch count: 56, Avg. per-sample expected Loss: 0.49148
# Batch count: 57, Avg. per-sample expected Loss: 0.49073
# Batch count: 58, Avg. per-sample expected Loss: 0.49285
# Batch count: 59, Avg. per-sample expected Loss: 0.49180
# Batch count: 60, Avg. per-sample expected Loss: 0.49172
# Batch count: 61, Avg. per-sample expected Loss: 0.49212
# Batch count: 62, Avg. per-sample expected Loss: 0.49256
# Batch count: 63, Avg. per-sample expected Loss: 0.49375
# Batch count: 64, Avg. per-sample expected Loss: 0.49173
# Batch count: 65, Avg. per-sample expected Loss: 0.49200
# Batch count: 66, Avg. per-sample expected Loss: 0.49421
# Batch count: 67, Avg. per-sample expected Loss: 0.49071
# Batch count: 68, Avg. per-sample expected Loss: 0.49277
# Batch count: 69, Avg. per-sample expected Loss: 0.49188
# Batch count: 70, Avg. per-sample expected Loss: 0.49294
# Batch count: 71, Avg. per-sample expected Loss: 0.49210
# Batch count: 72, Avg. per-sample expected Loss: 0.49273
# Batch count: 73, Avg. per-sample expected Loss: 0.48987
# Batch count: 74, Avg. per-sample expected Loss: 0.49149
# Batch count: 75, Avg. per-sample expected Loss: 0.49149
# Batch count: 76, Avg. per-sample expected Loss: 0.49102
# Batch count: 77, Avg. per-sample expected Loss: 0.49163
# Batch count: 78, Avg. per-sample expected Loss: 0.48911
# Batch count: 79, Avg. per-sample expected Loss: 0.49040
# Batch count: 80, Avg. per-sample expected Loss: 0.49007
# Batch count: 81, Avg. per-sample expected Loss: 0.49130
# Batch count: 82, Avg. per-sample expected Loss: 0.49145
# Batch count: 83, Avg. per-sample expected Loss: 0.48967
# Batch count: 84, Avg. per-sample expected Loss: 0.49134
# Batch count: 85, Avg. per-sample expected Loss: 0.49068
# Batch count: 86, Avg. per-sample expected Loss: 0.49016
# Batch count: 87, Avg. per-sample expected Loss: 0.49150
# Batch count: 88, Avg. per-sample expected Loss: 0.49060
# Batch count: 89, Avg. per-sample expected Loss: 0.49127
# Batch count: 90, Avg. per-sample expected Loss: 0.49009
# Batch count: 91, Avg. per-sample expected Loss: 0.48969
# Batch count: 92, Avg. per-sample expected Loss: 0.49032
# Batch count: 93, Avg. per-sample expected Loss: 0.48951
# Batch count: 94, Avg. per-sample expected Loss: 0.48921
# Batch count: 95, Avg. per-sample expected Loss: 0.49006
# Batch count: 96, Avg. per-sample expected Loss: 0.48870
# Batch count: 97, Avg. per-sample expected Loss: 0.49091
# Batch count: 98, Avg. per-sample expected Loss: 0.49074
# Batch count: 99, Avg. per-sample expected Loss: 0.49050
# Batch count: 100, Avg. per-sample expected Loss: 0.48742
# Batch count: 101, Avg. per-sample expected Loss: 0.49160
# Batch count: 102, Avg. per-sample expected Loss: 0.49212
# Batch count: 103, Avg. per-sample expected Loss: 0.48980
# Batch count: 104, Avg. per-sample expected Loss: 0.48882
# Batch count: 105, Avg. per-sample expected Loss: 0.48927
# Batch count: 106, Avg. per-sample expected Loss: 0.48962
# Batch count: 107, Avg. per-sample expected Loss: 0.49049
# Batch count: 108, Avg. per-sample expected Loss: 0.48874
# Batch count: 109, Avg. per-sample expected Loss: 0.48968
# Batch count: 110, Avg. per-sample expected Loss: 0.48881
# Batch count: 111, Avg. per-sample expected Loss: 0.48798
# Batch count: 112, Avg. per-sample expected Loss: 0.48706
# Batch count: 113, Avg. per-sample expected Loss: 0.48914
# Batch count: 114, Avg. per-sample expected Loss: 0.48741
# Batch count: 115, Avg. per-sample expected Loss: 0.48789
# Batch count: 116, Avg. per-sample expected Loss: 0.48709
# Batch count: 117, Avg. per-sample expected Loss: 0.48585
# Batch count: 118, Avg. per-sample expected Loss: 0.48830
# Batch count: 119, Avg. per-sample expected Loss: 0.48568
# Batch count: 120, Avg. per-sample expected Loss: 0.48554
# Batch count: 121, Avg. per-sample expected Loss: 0.48676
# Batch count: 122, Avg. per-sample expected Loss: 0.48531
# Batch count: 123, Avg. per-sample expected Loss: 0.48520
# Batch count: 124, Avg. per-sample expected Loss: 0.48481
# Batch count: 125, Avg. per-sample expected Loss: 0.48463
# Batch count: 126, Avg. per-sample expected Loss: 0.48273
# Batch count: 127, Avg. per-sample expected Loss: 0.48367
# Batch count: 128, Avg. per-sample expected Loss: 0.48473
# Batch count: 129, Avg. per-sample expected Loss: 0.48297
# Batch count: 130, Avg. per-sample expected Loss: 0.48459
# Batch count: 131, Avg. per-sample expected Loss: 0.48391
# Batch count: 132, Avg. per-sample expected Loss: 0.48288
# Batch count: 133, Avg. per-sample expected Loss: 0.48451
# Batch count: 134, Avg. per-sample expected Loss: 0.48461
# Batch count: 135, Avg. per-sample expected Loss: 0.48660
# Batch count: 136, Avg. per-sample expected Loss: 0.48542
# Batch count: 137, Avg. per-sample expected Loss: 0.48683
# Batch count: 138, Avg. per-sample expected Loss: 0.48597
# Batch count: 139, Avg. per-sample expected Loss: 0.48628
# Batch count: 140, Avg. per-sample expected Loss: 0.48336
# Batch count: 141, Avg. per-sample expected Loss: 0.48181
# Batch count: 142, Avg. per-sample expected Loss: 0.48475
# Batch count: 143, Avg. per-sample expected Loss: 0.48555
# Batch count: 144, Avg. per-sample expected Loss: 0.48438
# Batch count: 145, Avg. per-sample expected Loss: 0.48512
# Batch count: 146, Avg. per-sample expected Loss: 0.48413
# Batch count: 147, Avg. per-sample expected Loss: 0.48370
# Batch count: 148, Avg. per-sample expected Loss: 0.48423
# Batch count: 149, Avg. per-sample expected Loss: 0.48530
# Batch count: 150, Avg. per-sample expected Loss: 0.48485
# Batch count: 151, Avg. per-sample expected Loss: 0.48510
# Batch count: 152, Avg. per-sample expected Loss: 0.48444
# Batch count: 153, Avg. per-sample expected Loss: 0.48630
# Batch count: 154, Avg. per-sample expected Loss: 0.48621
# Batch count: 155, Avg. per-sample expected Loss: 0.48381
# Batch count: 156, Avg. per-sample expected Loss: 0.48612
# Batch count: 157, Avg. per-sample expected Loss: 0.48634
# Batch count: 158, Avg. per-sample expected Loss: 0.48535
# Batch count: 159, Avg. per-sample expected Loss: 0.48453
# Batch count: 160, Avg. per-sample expected Loss: 0.48466
# Batch count: 161, Avg. per-sample expected Loss: 0.48556
# Batch count: 162, Avg. per-sample expected Loss: 0.48286
# Batch count: 163, Avg. per-sample expected Loss: 0.48326
# Batch count: 164, Avg. per-sample expected Loss: 0.48380
# Batch count: 165, Avg. per-sample expected Loss: 0.48397
# Batch count: 166, Avg. per-sample expected Loss: 0.48253
# Batch count: 167, Avg. per-sample expected Loss: 0.48173
# Batch count: 168, Avg. per-sample expected Loss: 0.48323
# Batch count: 169, Avg. per-sample expected Loss: 0.48402
# Batch count: 170, Avg. per-sample expected Loss: 0.48388
# Batch count: 171, Avg. per-sample expected Loss: 0.48089
# Batch count: 172, Avg. per-sample expected Loss: 0.48493
# Batch count: 173, Avg. per-sample expected Loss: 0.48474
# Batch count: 174, Avg. per-sample expected Loss: 0.48407
# Batch count: 175, Avg. per-sample expected Loss: 0.48473
# Batch count: 176, Avg. per-sample expected Loss: 0.48133
# Batch count: 177, Avg. per-sample expected Loss: 0.48357
# Batch count: 178, Avg. per-sample expected Loss: 0.48289
# Batch count: 179, Avg. per-sample expected Loss: 0.48427
# Batch count: 180, Avg. per-sample expected Loss: 0.48301
# Batch count: 181, Avg. per-sample expected Loss: 0.48401
# Batch count: 182, Avg. per-sample expected Loss: 0.48382
# Batch count: 183, Avg. per-sample expected Loss: 0.48396
# Batch count: 184, Avg. per-sample expected Loss: 0.48263
# Batch count: 185, Avg. per-sample expected Loss: 0.48327
# Batch count: 186, Avg. per-sample expected Loss: 0.48413
# Batch count: 187, Avg. per-sample expected Loss: 0.48166
# Batch count: 188, Avg. per-sample expected Loss: 0.48102
# Batch count: 189, Avg. per-sample expected Loss: 0.48157
# Batch count: 190, Avg. per-sample expected Loss: 0.48205
# Batch count: 191, Avg. per-sample expected Loss: 0.48014
# Batch count: 192, Avg. per-sample expected Loss: 0.47914
# Batch count: 193, Avg. per-sample expected Loss: 0.48209
# Batch count: 194, Avg. per-sample expected Loss: 0.48065
# Batch count: 195, Avg. per-sample expected Loss: 0.47933
# Batch count: 196, Avg. per-sample expected Loss: 0.47920
# Batch count: 197, Avg. per-sample expected Loss: 0.47961
# Batch count: 198, Avg. per-sample expected Loss: 0.48011
# Batch count: 199, Avg. per-sample expected Loss: 0.47709
# Batch count: 200, Avg. per-sample expected Loss: 0.47727
# Batch count: 201, Avg. per-sample expected Loss: 0.47771
# Batch count: 202, Avg. per-sample expected Loss: 0.47625
# Batch count: 203, Avg. per-sample expected Loss: 0.47717
# Batch count: 204, Avg. per-sample expected Loss: 0.47590
# Batch count: 205, Avg. per-sample expected Loss: 0.47361
# Batch count: 206, Avg. per-sample expected Loss: 0.47370
# Batch count: 207, Avg. per-sample expected Loss: 0.47334
# Batch count: 208, Avg. per-sample expected Loss: 0.47289
# Batch count: 209, Avg. per-sample expected Loss: 0.47448
# Batch count: 210, Avg. per-sample expected Loss: 0.47084
# Batch count: 211, Avg. per-sample expected Loss: 0.47242
# Batch count: 212, Avg. per-sample expected Loss: 0.47054
# Batch count: 213, Avg. per-sample expected Loss: 0.47078
# Batch count: 214, Avg. per-sample expected Loss: 0.46932
# Batch count: 215, Avg. per-sample expected Loss: 0.46872
# Batch count: 216, Avg. per-sample expected Loss: 0.46875
# Batch count: 217, Avg. per-sample expected Loss: 0.46960
# Batch count: 218, Avg. per-sample expected Loss: 0.46451
# Batch count: 219, Avg. per-sample expected Loss: 0.46393
# Batch count: 220, Avg. per-sample expected Loss: 0.46393
# Batch count: 221, Avg. per-sample expected Loss: 0.46263
# Batch count: 222, Avg. per-sample expected Loss: 0.46026
# Batch count: 223, Avg. per-sample expected Loss: 0.45977
# Batch count: 224, Avg. per-sample expected Loss: 0.46187
# Batch count: 225, Avg. per-sample expected Loss: 0.45910
# Batch count: 226, Avg. per-sample expected Loss: 0.46139
# Batch count: 227, Avg. per-sample expected Loss: 0.46118
# Batch count: 228, Avg. per-sample expected Loss: 0.46106
# Batch count: 229, Avg. per-sample expected Loss: 0.46260
# Batch count: 230, Avg. per-sample expected Loss: 0.46237
# Batch count: 231, Avg. per-sample expected Loss: 0.46239
# Batch count: 232, Avg. per-sample expected Loss: 0.45934
# Batch count: 233, Avg. per-sample expected Loss: 0.46120
# Batch count: 234, Avg. per-sample expected Loss: 0.45726
# Batch count: 235, Avg. per-sample expected Loss: 0.45706
# Batch count: 236, Avg. per-sample expected Loss: 0.45570
# Batch count: 237, Avg. per-sample expected Loss: 0.45521
# Batch count: 238, Avg. per-sample expected Loss: 0.45850
# Batch count: 239, Avg. per-sample expected Loss: 0.45406
# Batch count: 240, Avg. per-sample expected Loss: 0.45689
# Batch count: 241, Avg. per-sample expected Loss: 0.45476
# Batch count: 242, Avg. per-sample expected Loss: 0.45577
# Batch count: 243, Avg. per-sample expected Loss: 0.45371
# Batch count: 244, Avg. per-sample expected Loss: 0.45191
# Batch count: 245, Avg. per-sample expected Loss: 0.45125
# Batch count: 246, Avg. per-sample expected Loss: 0.45138
# Batch count: 247, Avg. per-sample expected Loss: 0.45013
# Batch count: 248, Avg. per-sample expected Loss: 0.45261
# Batch count: 249, Avg. per-sample expected Loss: 0.45343
# Batch count: 250, Avg. per-sample expected Loss: 0.45205
# Batch count: 251, Avg. per-sample expected Loss: 0.45304
# Batch count: 252, Avg. per-sample expected Loss: 0.45140
# Batch count: 253, Avg. per-sample expected Loss: 0.44916
# Batch count: 254, Avg. per-sample expected Loss: 0.44754
# Batch count: 255, Avg. per-sample expected Loss: 0.44561
# Batch count: 256, Avg. per-sample expected Loss: 0.44544
# Batch count: 257, Avg. per-sample expected Loss: 0.44660
# Batch count: 258, Avg. per-sample expected Loss: 0.44659
# Batch count: 259, Avg. per-sample expected Loss: 0.44587
# Batch count: 260, Avg. per-sample expected Loss: 0.44455
# Batch count: 261, Avg. per-sample expected Loss: 0.44263
# Batch count: 262, Avg. per-sample expected Loss: 0.43855
# Batch count: 263, Avg. per-sample expected Loss: 0.44027
# Batch count: 264, Avg. per-sample expected Loss: 0.43964
# Batch count: 265, Avg. per-sample expected Loss: 0.43911
# Batch count: 266, Avg. per-sample expected Loss: 0.43651
# Batch count: 267, Avg. per-sample expected Loss: 0.43540
# Batch count: 268, Avg. per-sample expected Loss: 0.43869
# Batch count: 269, Avg. per-sample expected Loss: 0.43750
# Batch count: 270, Avg. per-sample expected Loss: 0.43405
# Batch count: 271, Avg. per-sample expected Loss: 0.43482
# Batch count: 272, Avg. per-sample expected Loss: 0.43327
# Batch count: 273, Avg. per-sample expected Loss: 0.43114
# Batch count: 274, Avg. per-sample expected Loss: 0.43234
# Batch count: 275, Avg. per-sample expected Loss: 0.43540
# Batch count: 276, Avg. per-sample expected Loss: 0.43146
# Batch count: 277, Avg. per-sample expected Loss: 0.42851
# Batch count: 278, Avg. per-sample expected Loss: 0.43167
# Batch count: 279, Avg. per-sample expected Loss: 0.42932
# Batch count: 280, Avg. per-sample expected Loss: 0.42572
# Batch count: 281, Avg. per-sample expected Loss: 0.42720
# Batch count: 282, Avg. per-sample expected Loss: 0.42484
# Batch count: 283, Avg. per-sample expected Loss: 0.42448
# Batch count: 284, Avg. per-sample expected Loss: 0.42248
# Batch count: 285, Avg. per-sample expected Loss: 0.42244
# Batch count: 286, Avg. per-sample expected Loss: 0.42094
# Batch count: 287, Avg. per-sample expected Loss: 0.42027
# Batch count: 288, Avg. per-sample expected Loss: 0.41841
# Batch count: 289, Avg. per-sample expected Loss: 0.41600
# Batch count: 290, Avg. per-sample expected Loss: 0.41216
# Batch count: 291, Avg. per-sample expected Loss: 0.41020
# Batch count: 292, Avg. per-sample expected Loss: 0.40815
# Batch count: 293, Avg. per-sample expected Loss: 0.40652
# Batch count: 294, Avg. per-sample expected Loss: 0.40716
# Batch count: 295, Avg. per-sample expected Loss: 0.40575
# Batch count: 296, Avg. per-sample expected Loss: 0.40495
# Batch count: 297, Avg. per-sample expected Loss: 0.40196
# Batch count: 298, Avg. per-sample expected Loss: 0.40118
# Batch count: 299, Avg. per-sample expected Loss: 0.39826
# Batch count: 300, Avg. per-sample expected Loss: 0.39814
# Batch count: 301, Avg. per-sample expected Loss: 0.40026
# Batch count: 302, Avg. per-sample expected Loss: 0.39706
# Batch count: 303, Avg. per-sample expected Loss: 0.39473
# Batch count: 304, Avg. per-sample expected Loss: 0.39411
# Batch count: 305, Avg. per-sample expected Loss: 0.38805
# Batch count: 306, Avg. per-sample expected Loss: 0.39157
# Batch count: 307, Avg. per-sample expected Loss: 0.38478
# Batch count: 308, Avg. per-sample expected Loss: 0.38266
# Batch count: 309, Avg. per-sample expected Loss: 0.38017
# Batch count: 310, Avg. per-sample expected Loss: 0.36717
# Batch count: 311, Avg. per-sample expected Loss: 0.37289
# Batch count: 312, Avg. per-sample expected Loss: 0.37213
# Batch count: 313, Avg. per-sample expected Loss: 0.37367
# Batch count: 314, Avg. per-sample expected Loss: 0.36313
# Batch count: 315, Avg. per-sample expected Loss: 0.35891
# Batch count: 316, Avg. per-sample expected Loss: 0.36642
# Batch count: 317, Avg. per-sample expected Loss: 0.35401
# Batch count: 318, Avg. per-sample expected Loss: 0.36198
# Batch count: 319, Avg. per-sample expected Loss: 0.34952
# Batch count: 320, Avg. per-sample expected Loss: 0.34860
# Batch count: 321, Avg. per-sample expected Loss: 0.34947
# Batch count: 322, Avg. per-sample expected Loss: 0.34701
# Batch count: 323, Avg. per-sample expected Loss: 0.34341
# Batch count: 324, Avg. per-sample expected Loss: 0.34688
# Batch count: 325, Avg. per-sample expected Loss: 0.34144
# Batch count: 326, Avg. per-sample expected Loss: 0.33320
# Batch count: 327, Avg. per-sample expected Loss: 0.33364
# Batch count: 328, Avg. per-sample expected Loss: 0.33406
# Batch count: 329, Avg. per-sample expected Loss: 0.33447
# Batch count: 330, Avg. per-sample expected Loss: 0.32600
# Batch count: 331, Avg. per-sample expected Loss: 0.33097
# Batch count: 332, Avg. per-sample expected Loss: 0.33364
# Batch count: 333, Avg. per-sample expected Loss: 0.32551
# Batch count: 334, Avg. per-sample expected Loss: 0.32151
# Batch count: 335, Avg. per-sample expected Loss: 0.32832
# Batch count: 336, Avg. per-sample expected Loss: 0.32036
# Batch count: 337, Avg. per-sample expected Loss: 0.31373
# Batch count: 338, Avg. per-sample expected Loss: 0.31100
# Batch count: 339, Avg. per-sample expected Loss: 0.30967
# Batch count: 340, Avg. per-sample expected Loss: 0.31393
# Batch count: 341, Avg. per-sample expected Loss: 0.30866
# Batch count: 342, Avg. per-sample expected Loss: 0.31900
# Batch count: 343, Avg. per-sample expected Loss: 0.31126
# Batch count: 344, Avg. per-sample expected Loss: 0.31017
# Batch count: 345, Avg. per-sample expected Loss: 0.30235
# Batch count: 346, Avg. per-sample expected Loss: 0.30193
# Batch count: 347, Avg. per-sample expected Loss: 0.30220
# Batch count: 348, Avg. per-sample expected Loss: 0.30222
# Batch count: 349, Avg. per-sample expected Loss: 0.30523
# Batch count: 350, Avg. per-sample expected Loss: 0.30364
# Batch count: 351, Avg. per-sample expected Loss: 0.29900
# Batch count: 352, Avg. per-sample expected Loss: 0.29586
# Batch count: 353, Avg. per-sample expected Loss: 0.28039
# Batch count: 354, Avg. per-sample expected Loss: 0.28295
# Batch count: 355, Avg. per-sample expected Loss: 0.28943
# Batch count: 356, Avg. per-sample expected Loss: 0.27385
# Batch count: 357, Avg. per-sample expected Loss: 0.27231
# Batch count: 358, Avg. per-sample expected Loss: 0.27293
# Batch count: 359, Avg. per-sample expected Loss: 0.26767
# Batch count: 360, Avg. per-sample expected Loss: 0.26230
# Batch count: 361, Avg. per-sample expected Loss: 0.27583
# Batch count: 362, Avg. per-sample expected Loss: 0.25950
# Batch count: 363, Avg. per-sample expected Loss: 0.24723
# Batch count: 364, Avg. per-sample expected Loss: 0.26050
# Batch count: 365, Avg. per-sample expected Loss: 0.25573
# Batch count: 366, Avg. per-sample expected Loss: 0.25870
# Batch count: 367, Avg. per-sample expected Loss: 0.25563
# Batch count: 368, Avg. per-sample expected Loss: 0.25678
# Batch count: 369, Avg. per-sample expected Loss: 0.25093
# Batch count: 370, Avg. per-sample expected Loss: 0.23899
# Batch count: 371, Avg. per-sample expected Loss: 0.24083
# Batch count: 372, Avg. per-sample expected Loss: 0.23546
# Batch count: 373, Avg. per-sample expected Loss: 0.23495
# Batch count: 374, Avg. per-sample expected Loss: 0.23240
# Batch count: 375, Avg. per-sample expected Loss: 0.22422
# Batch count: 376, Avg. per-sample expected Loss: 0.24048
# Batch count: 377, Avg. per-sample expected Loss: 0.22855
# Batch count: 378, Avg. per-sample expected Loss: 0.23026
# Batch count: 379, Avg. per-sample expected Loss: 0.21411
# Batch count: 380, Avg. per-sample expected Loss: 0.22148
# Batch count: 381, Avg. per-sample expected Loss: 0.22339
# Batch count: 382, Avg. per-sample expected Loss: 0.22301
# Batch count: 383, Avg. per-sample expected Loss: 0.21876
# Batch count: 384, Avg. per-sample expected Loss: 0.22740
# Batch count: 385, Avg. per-sample expected Loss: 0.21340
# Batch count: 386, Avg. per-sample expected Loss: 0.22033
# Batch count: 387, Avg. per-sample expected Loss: 0.20522
# Batch count: 388, Avg. per-sample expected Loss: 0.21733
# Batch count: 389, Avg. per-sample expected Loss: 0.21293
# Batch count: 390, Avg. per-sample expected Loss: 0.22505
# Batch count: 391, Avg. per-sample expected Loss: 0.20479
# Batch count: 392, Avg. per-sample expected Loss: 0.21059
# Batch count: 393, Avg. per-sample expected Loss: 0.21683
# Batch count: 394, Avg. per-sample expected Loss: 0.20779
# Batch count: 395, Avg. per-sample expected Loss: 0.20402
# Batch count: 396, Avg. per-sample expected Loss: 0.20891
# Batch count: 397, Avg. per-sample expected Loss: 0.20658
# Batch count: 398, Avg. per-sample expected Loss: 0.21082
# Batch count: 399, Avg. per-sample expected Loss: 0.20233

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6c_cost, "b", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6c_Ecost, "c.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training using 2-QNSCD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("6-RQSGD.png")
plt.show()

# %% [markdown]
# ## 2-RQSGD using 600 samples per step and 6 samples per itr

# %%
SGD6params = np.array(init_params)
SGD6_cost = []
SGD6_Ecost = []

SGD6_cost.append(temp_cost)
SGD6_Ecost.append(temp_Ecost)

itrSample = np.linspace(0,Bsize,nItr,endpoint = False,dtype = 'int').tolist()
for itr1 in range(nStep):
    phiT = phiTrainSGD[:,Bsize*itr1:Bsize*(itr1+1)]
    labelT = labelTrainSGD[Bsize*itr1:Bsize*(itr1+1)]
    
    for itr2 in range(nItr):
        itr3 = itrSample[itr2]
        
        ### Randomly selecting a 2 coordinates
        idx = sorted(np.random.permutation(nparams)[0:2].tolist())
        
        grad = []
        
        ### Gradient estimation
        y_hat01,b01 = EstGrad(SGD6params,phiT[:,itr3+0],idx[0])
        b01 = (1-b01)/2
        y_hat02,b02 = EstGrad(SGD6params,phiT[:,itr3+1],idx[0])
        b02 = (1-b02)/2
        y_hat03,b03 = EstGrad(SGD6params,phiT[:,itr3+2],idx[0])
        b03 = (1-b03)/2
        
        temp0 = ((-1)**b01)*loss(y_hat01,labelT[itr3+0]) \
              + ((-1)**b02)*loss(y_hat02,labelT[itr3+1]) \
              + ((-1)**b03)*loss(y_hat03,labelT[itr3+2])

        grad.append((-1)*temp0/3)
        
        y_hat11,b11 = EstGrad(SGD6params,phiT[:,itr3+3],idx[1])
        b11 = (1-b11)/2
        y_hat12,b12 = EstGrad(SGD6params,phiT[:,itr3+4],idx[1])
        b12 = (1-b12)/2
        y_hat13,b13 = EstGrad(SGD6params,phiT[:,itr3+5],idx[1])
        b13 = (1-b13)/2
        
        temp1 = ((-1)**b11)*loss(y_hat11,labelT[itr3+3]) \
              + ((-1)**b12)*loss(y_hat12,labelT[itr3+4]) \
              + ((-1)**b13)*loss(y_hat13,labelT[itr3+5])

        grad.append((-1)*temp1/3)

        ### single-parameter update
        SGD6params[idx] = SGD6params[idx] - np.dot(step_size,grad)
        
    ### average per-sample expectd loss calculation
    energy = sum([ps_expLoss(SGD6params,phiT[:,itr],labelT[itr]) for itr in range(Bsize)])/Bsize
    SGD6_cost.append(energy)
    
    ### average empirical loss calculation
    SGD6count = 0   
    for itr in range(Bsize):
        if circuit_test(SGD6params,phiT[:,itr]) != labelT[itr]:
            SGD6count += 1
    SGD6_Ecost.append(SGD6count/Bsize)
    
    print("Batch count: {:2d}, Avg. per-sample expected Loss: {:.5f}".format(itr1,energy))


file_name1 = "6Q 2-RQSGD_6s Expected Loss"
file_name2 = "6Q 2-RQSGD_6s Empirical Loss"

np.save(file_name1,SGD6_cost)
np.save(file_name2,SGD6_Ecost)
# Out:
# Batch count:  0, Avg. per-sample expected Loss: 0.49799
# Batch count:  1, Avg. per-sample expected Loss: 0.49612
# Batch count:  2, Avg. per-sample expected Loss: 0.49805
# Batch count:  3, Avg. per-sample expected Loss: 0.49731
# Batch count:  4, Avg. per-sample expected Loss: 0.49634
# Batch count:  5, Avg. per-sample expected Loss: 0.49961
# Batch count:  6, Avg. per-sample expected Loss: 0.49950
# Batch count:  7, Avg. per-sample expected Loss: 0.49965
# Batch count:  8, Avg. per-sample expected Loss: 0.49650
# Batch count:  9, Avg. per-sample expected Loss: 0.49861
# Batch count: 10, Avg. per-sample expected Loss: 0.49744
# Batch count: 11, Avg. per-sample expected Loss: 0.49775
# Batch count: 12, Avg. per-sample expected Loss: 0.49802
# Batch count: 13, Avg. per-sample expected Loss: 0.49624
# Batch count: 14, Avg. per-sample expected Loss: 0.49632
# Batch count: 15, Avg. per-sample expected Loss: 0.49859
# Batch count: 16, Avg. per-sample expected Loss: 0.49985
# Batch count: 17, Avg. per-sample expected Loss: 0.49679
# Batch count: 18, Avg. per-sample expected Loss: 0.49467
# Batch count: 19, Avg. per-sample expected Loss: 0.49710
# Batch count: 20, Avg. per-sample expected Loss: 0.49596
# Batch count: 21, Avg. per-sample expected Loss: 0.49844
# Batch count: 22, Avg. per-sample expected Loss: 0.49736
# Batch count: 23, Avg. per-sample expected Loss: 0.49679
# Batch count: 24, Avg. per-sample expected Loss: 0.49738
# Batch count: 25, Avg. per-sample expected Loss: 0.49634
# Batch count: 26, Avg. per-sample expected Loss: 0.49670
# Batch count: 27, Avg. per-sample expected Loss: 0.49874
# Batch count: 28, Avg. per-sample expected Loss: 0.49713
# Batch count: 29, Avg. per-sample expected Loss: 0.49835
# Batch count: 30, Avg. per-sample expected Loss: 0.49618
# Batch count: 31, Avg. per-sample expected Loss: 0.49654
# Batch count: 32, Avg. per-sample expected Loss: 0.49759
# Batch count: 33, Avg. per-sample expected Loss: 0.49732
# Batch count: 34, Avg. per-sample expected Loss: 0.49801
# Batch count: 35, Avg. per-sample expected Loss: 0.49705
# Batch count: 36, Avg. per-sample expected Loss: 0.49796
# Batch count: 37, Avg. per-sample expected Loss: 0.49805
# Batch count: 38, Avg. per-sample expected Loss: 0.49831
# Batch count: 39, Avg. per-sample expected Loss: 0.49496
# Batch count: 40, Avg. per-sample expected Loss: 0.49981
# Batch count: 41, Avg. per-sample expected Loss: 0.49786
# Batch count: 42, Avg. per-sample expected Loss: 0.49718
# Batch count: 43, Avg. per-sample expected Loss: 0.49682
# Batch count: 44, Avg. per-sample expected Loss: 0.49640
# Batch count: 45, Avg. per-sample expected Loss: 0.49606
# Batch count: 46, Avg. per-sample expected Loss: 0.49615
# Batch count: 47, Avg. per-sample expected Loss: 0.49612
# Batch count: 48, Avg. per-sample expected Loss: 0.49460
# Batch count: 49, Avg. per-sample expected Loss: 0.49816
# Batch count: 50, Avg. per-sample expected Loss: 0.49701
# Batch count: 51, Avg. per-sample expected Loss: 0.49559
# Batch count: 52, Avg. per-sample expected Loss: 0.49673
# Batch count: 53, Avg. per-sample expected Loss: 0.49727
# Batch count: 54, Avg. per-sample expected Loss: 0.49582
# Batch count: 55, Avg. per-sample expected Loss: 0.49504
# Batch count: 56, Avg. per-sample expected Loss: 0.49422
# Batch count: 57, Avg. per-sample expected Loss: 0.49364
# Batch count: 58, Avg. per-sample expected Loss: 0.49489
# Batch count: 59, Avg. per-sample expected Loss: 0.49489
# Batch count: 60, Avg. per-sample expected Loss: 0.49522
# Batch count: 61, Avg. per-sample expected Loss: 0.49541
# Batch count: 62, Avg. per-sample expected Loss: 0.49662
# Batch count: 63, Avg. per-sample expected Loss: 0.49797
# Batch count: 64, Avg. per-sample expected Loss: 0.49517
# Batch count: 65, Avg. per-sample expected Loss: 0.49581
# Batch count: 66, Avg. per-sample expected Loss: 0.49847
# Batch count: 67, Avg. per-sample expected Loss: 0.49394
# Batch count: 68, Avg. per-sample expected Loss: 0.49580
# Batch count: 69, Avg. per-sample expected Loss: 0.49450
# Batch count: 70, Avg. per-sample expected Loss: 0.49617
# Batch count: 71, Avg. per-sample expected Loss: 0.49641
# Batch count: 72, Avg. per-sample expected Loss: 0.49683
# Batch count: 73, Avg. per-sample expected Loss: 0.49321
# Batch count: 74, Avg. per-sample expected Loss: 0.49546
# Batch count: 75, Avg. per-sample expected Loss: 0.49599
# Batch count: 76, Avg. per-sample expected Loss: 0.49533
# Batch count: 77, Avg. per-sample expected Loss: 0.49602
# Batch count: 78, Avg. per-sample expected Loss: 0.49284
# Batch count: 79, Avg. per-sample expected Loss: 0.49475
# Batch count: 80, Avg. per-sample expected Loss: 0.49573
# Batch count: 81, Avg. per-sample expected Loss: 0.49737
# Batch count: 82, Avg. per-sample expected Loss: 0.49731
# Batch count: 83, Avg. per-sample expected Loss: 0.49495
# Batch count: 84, Avg. per-sample expected Loss: 0.49697
# Batch count: 85, Avg. per-sample expected Loss: 0.49495
# Batch count: 86, Avg. per-sample expected Loss: 0.49421
# Batch count: 87, Avg. per-sample expected Loss: 0.49633
# Batch count: 88, Avg. per-sample expected Loss: 0.49600
# Batch count: 89, Avg. per-sample expected Loss: 0.49586
# Batch count: 90, Avg. per-sample expected Loss: 0.49428
# Batch count: 91, Avg. per-sample expected Loss: 0.49523
# Batch count: 92, Avg. per-sample expected Loss: 0.49536
# Batch count: 93, Avg. per-sample expected Loss: 0.49589
# Batch count: 94, Avg. per-sample expected Loss: 0.49417
# Batch count: 95, Avg. per-sample expected Loss: 0.49413
# Batch count: 96, Avg. per-sample expected Loss: 0.49244
# Batch count: 97, Avg. per-sample expected Loss: 0.49524
# Batch count: 98, Avg. per-sample expected Loss: 0.49465
# Batch count: 99, Avg. per-sample expected Loss: 0.49550
# Batch count: 100, Avg. per-sample expected Loss: 0.49117
# Batch count: 101, Avg. per-sample expected Loss: 0.49572
# Batch count: 102, Avg. per-sample expected Loss: 0.49766
# Batch count: 103, Avg. per-sample expected Loss: 0.49473
# Batch count: 104, Avg. per-sample expected Loss: 0.49346
# Batch count: 105, Avg. per-sample expected Loss: 0.49342
# Batch count: 106, Avg. per-sample expected Loss: 0.49336
# Batch count: 107, Avg. per-sample expected Loss: 0.49564
# Batch count: 108, Avg. per-sample expected Loss: 0.49276
# Batch count: 109, Avg. per-sample expected Loss: 0.49407
# Batch count: 110, Avg. per-sample expected Loss: 0.49319
# Batch count: 111, Avg. per-sample expected Loss: 0.49161
# Batch count: 112, Avg. per-sample expected Loss: 0.49124
# Batch count: 113, Avg. per-sample expected Loss: 0.49483
# Batch count: 114, Avg. per-sample expected Loss: 0.49120
# Batch count: 115, Avg. per-sample expected Loss: 0.49320
# Batch count: 116, Avg. per-sample expected Loss: 0.49180
# Batch count: 117, Avg. per-sample expected Loss: 0.49013
# Batch count: 118, Avg. per-sample expected Loss: 0.49394
# Batch count: 119, Avg. per-sample expected Loss: 0.49203
# Batch count: 120, Avg. per-sample expected Loss: 0.49229
# Batch count: 121, Avg. per-sample expected Loss: 0.49380
# Batch count: 122, Avg. per-sample expected Loss: 0.49140
# Batch count: 123, Avg. per-sample expected Loss: 0.49193
# Batch count: 124, Avg. per-sample expected Loss: 0.49210
# Batch count: 125, Avg. per-sample expected Loss: 0.49275
# Batch count: 126, Avg. per-sample expected Loss: 0.49137
# Batch count: 127, Avg. per-sample expected Loss: 0.49091
# Batch count: 128, Avg. per-sample expected Loss: 0.49266
# Batch count: 129, Avg. per-sample expected Loss: 0.49055
# Batch count: 130, Avg. per-sample expected Loss: 0.49331
# Batch count: 131, Avg. per-sample expected Loss: 0.49082
# Batch count: 132, Avg. per-sample expected Loss: 0.49016
# Batch count: 133, Avg. per-sample expected Loss: 0.49158
# Batch count: 134, Avg. per-sample expected Loss: 0.49035
# Batch count: 135, Avg. per-sample expected Loss: 0.49229
# Batch count: 136, Avg. per-sample expected Loss: 0.49206
# Batch count: 137, Avg. per-sample expected Loss: 0.49311
# Batch count: 138, Avg. per-sample expected Loss: 0.49291
# Batch count: 139, Avg. per-sample expected Loss: 0.49260
# Batch count: 140, Avg. per-sample expected Loss: 0.49047
# Batch count: 141, Avg. per-sample expected Loss: 0.48899
# Batch count: 142, Avg. per-sample expected Loss: 0.49160
# Batch count: 143, Avg. per-sample expected Loss: 0.49176
# Batch count: 144, Avg. per-sample expected Loss: 0.49026
# Batch count: 145, Avg. per-sample expected Loss: 0.49002
# Batch count: 146, Avg. per-sample expected Loss: 0.48918
# Batch count: 147, Avg. per-sample expected Loss: 0.48948
# Batch count: 148, Avg. per-sample expected Loss: 0.48908
# Batch count: 149, Avg. per-sample expected Loss: 0.49004
# Batch count: 150, Avg. per-sample expected Loss: 0.48852
# Batch count: 151, Avg. per-sample expected Loss: 0.48865
# Batch count: 152, Avg. per-sample expected Loss: 0.48843
# Batch count: 153, Avg. per-sample expected Loss: 0.48991
# Batch count: 154, Avg. per-sample expected Loss: 0.49086
# Batch count: 155, Avg. per-sample expected Loss: 0.48788
# Batch count: 156, Avg. per-sample expected Loss: 0.49023
# Batch count: 157, Avg. per-sample expected Loss: 0.49113
# Batch count: 158, Avg. per-sample expected Loss: 0.48962
# Batch count: 159, Avg. per-sample expected Loss: 0.48907
# Batch count: 160, Avg. per-sample expected Loss: 0.48978
# Batch count: 161, Avg. per-sample expected Loss: 0.49194
# Batch count: 162, Avg. per-sample expected Loss: 0.48927
# Batch count: 163, Avg. per-sample expected Loss: 0.48993
# Batch count: 164, Avg. per-sample expected Loss: 0.49046
# Batch count: 165, Avg. per-sample expected Loss: 0.49102
# Batch count: 166, Avg. per-sample expected Loss: 0.48914
# Batch count: 167, Avg. per-sample expected Loss: 0.48762
# Batch count: 168, Avg. per-sample expected Loss: 0.48816
# Batch count: 169, Avg. per-sample expected Loss: 0.48781
# Batch count: 170, Avg. per-sample expected Loss: 0.48754
# Batch count: 171, Avg. per-sample expected Loss: 0.48562
# Batch count: 172, Avg. per-sample expected Loss: 0.48863
# Batch count: 173, Avg. per-sample expected Loss: 0.48890
# Batch count: 174, Avg. per-sample expected Loss: 0.48802
# Batch count: 175, Avg. per-sample expected Loss: 0.48926
# Batch count: 176, Avg. per-sample expected Loss: 0.48567
# Batch count: 177, Avg. per-sample expected Loss: 0.48750
# Batch count: 178, Avg. per-sample expected Loss: 0.48729
# Batch count: 179, Avg. per-sample expected Loss: 0.48845
# Batch count: 180, Avg. per-sample expected Loss: 0.48749
# Batch count: 181, Avg. per-sample expected Loss: 0.48845
# Batch count: 182, Avg. per-sample expected Loss: 0.48795
# Batch count: 183, Avg. per-sample expected Loss: 0.48803
# Batch count: 184, Avg. per-sample expected Loss: 0.48665
# Batch count: 185, Avg. per-sample expected Loss: 0.48777
# Batch count: 186, Avg. per-sample expected Loss: 0.48969
# Batch count: 187, Avg. per-sample expected Loss: 0.48705
# Batch count: 188, Avg. per-sample expected Loss: 0.48704
# Batch count: 189, Avg. per-sample expected Loss: 0.48763
# Batch count: 190, Avg. per-sample expected Loss: 0.48828
# Batch count: 191, Avg. per-sample expected Loss: 0.48595
# Batch count: 192, Avg. per-sample expected Loss: 0.48607
# Batch count: 193, Avg. per-sample expected Loss: 0.48953
# Batch count: 194, Avg. per-sample expected Loss: 0.48913
# Batch count: 195, Avg. per-sample expected Loss: 0.48702
# Batch count: 196, Avg. per-sample expected Loss: 0.48651
# Batch count: 197, Avg. per-sample expected Loss: 0.48756
# Batch count: 198, Avg. per-sample expected Loss: 0.48870
# Batch count: 199, Avg. per-sample expected Loss: 0.48613
# Batch count: 200, Avg. per-sample expected Loss: 0.48607
# Batch count: 201, Avg. per-sample expected Loss: 0.48739
# Batch count: 202, Avg. per-sample expected Loss: 0.48538
# Batch count: 203, Avg. per-sample expected Loss: 0.48709
# Batch count: 204, Avg. per-sample expected Loss: 0.48669
# Batch count: 205, Avg. per-sample expected Loss: 0.48503
# Batch count: 206, Avg. per-sample expected Loss: 0.48615
# Batch count: 207, Avg. per-sample expected Loss: 0.48743
# Batch count: 208, Avg. per-sample expected Loss: 0.48638
# Batch count: 209, Avg. per-sample expected Loss: 0.48818
# Batch count: 210, Avg. per-sample expected Loss: 0.48578
# Batch count: 211, Avg. per-sample expected Loss: 0.48770
# Batch count: 212, Avg. per-sample expected Loss: 0.48582
# Batch count: 213, Avg. per-sample expected Loss: 0.48683
# Batch count: 214, Avg. per-sample expected Loss: 0.48679
# Batch count: 215, Avg. per-sample expected Loss: 0.48708
# Batch count: 216, Avg. per-sample expected Loss: 0.48656
# Batch count: 217, Avg. per-sample expected Loss: 0.48787
# Batch count: 218, Avg. per-sample expected Loss: 0.48452
# Batch count: 219, Avg. per-sample expected Loss: 0.48409
# Batch count: 220, Avg. per-sample expected Loss: 0.48614
# Batch count: 221, Avg. per-sample expected Loss: 0.48337
# Batch count: 222, Avg. per-sample expected Loss: 0.48416
# Batch count: 223, Avg. per-sample expected Loss: 0.48341
# Batch count: 224, Avg. per-sample expected Loss: 0.48674
# Batch count: 225, Avg. per-sample expected Loss: 0.48387
# Batch count: 226, Avg. per-sample expected Loss: 0.48595
# Batch count: 227, Avg. per-sample expected Loss: 0.48456
# Batch count: 228, Avg. per-sample expected Loss: 0.48542
# Batch count: 229, Avg. per-sample expected Loss: 0.48614
# Batch count: 230, Avg. per-sample expected Loss: 0.48635
# Batch count: 231, Avg. per-sample expected Loss: 0.48653
# Batch count: 232, Avg. per-sample expected Loss: 0.48534
# Batch count: 233, Avg. per-sample expected Loss: 0.48797
# Batch count: 234, Avg. per-sample expected Loss: 0.48546
# Batch count: 235, Avg. per-sample expected Loss: 0.48699
# Batch count: 236, Avg. per-sample expected Loss: 0.48659
# Batch count: 237, Avg. per-sample expected Loss: 0.48427
# Batch count: 238, Avg. per-sample expected Loss: 0.48488
# Batch count: 239, Avg. per-sample expected Loss: 0.48577
# Batch count: 240, Avg. per-sample expected Loss: 0.48712
# Batch count: 241, Avg. per-sample expected Loss: 0.48478
# Batch count: 242, Avg. per-sample expected Loss: 0.48701
# Batch count: 243, Avg. per-sample expected Loss: 0.48421
# Batch count: 244, Avg. per-sample expected Loss: 0.48625
# Batch count: 245, Avg. per-sample expected Loss: 0.48463
# Batch count: 246, Avg. per-sample expected Loss: 0.48630
# Batch count: 247, Avg. per-sample expected Loss: 0.48570
# Batch count: 248, Avg. per-sample expected Loss: 0.48466
# Batch count: 249, Avg. per-sample expected Loss: 0.48519
# Batch count: 250, Avg. per-sample expected Loss: 0.48537
# Batch count: 251, Avg. per-sample expected Loss: 0.48670
# Batch count: 252, Avg. per-sample expected Loss: 0.48683
# Batch count: 253, Avg. per-sample expected Loss: 0.48602
# Batch count: 254, Avg. per-sample expected Loss: 0.48720
# Batch count: 255, Avg. per-sample expected Loss: 0.48615
# Batch count: 256, Avg. per-sample expected Loss: 0.48269
# Batch count: 257, Avg. per-sample expected Loss: 0.48454
# Batch count: 258, Avg. per-sample expected Loss: 0.48472
# Batch count: 259, Avg. per-sample expected Loss: 0.48422
# Batch count: 260, Avg. per-sample expected Loss: 0.48469
# Batch count: 261, Avg. per-sample expected Loss: 0.48408
# Batch count: 262, Avg. per-sample expected Loss: 0.48358
# Batch count: 263, Avg. per-sample expected Loss: 0.48408
# Batch count: 264, Avg. per-sample expected Loss: 0.48495
# Batch count: 265, Avg. per-sample expected Loss: 0.48616
# Batch count: 266, Avg. per-sample expected Loss: 0.48482
# Batch count: 267, Avg. per-sample expected Loss: 0.48213
# Batch count: 268, Avg. per-sample expected Loss: 0.48471
# Batch count: 269, Avg. per-sample expected Loss: 0.48695
# Batch count: 270, Avg. per-sample expected Loss: 0.48447
# Batch count: 271, Avg. per-sample expected Loss: 0.48358
# Batch count: 272, Avg. per-sample expected Loss: 0.48445
# Batch count: 273, Avg. per-sample expected Loss: 0.48399
# Batch count: 274, Avg. per-sample expected Loss: 0.48422
# Batch count: 275, Avg. per-sample expected Loss: 0.48716
# Batch count: 276, Avg. per-sample expected Loss: 0.48467
# Batch count: 277, Avg. per-sample expected Loss: 0.48649
# Batch count: 278, Avg. per-sample expected Loss: 0.48526
# Batch count: 279, Avg. per-sample expected Loss: 0.48348
# Batch count: 280, Avg. per-sample expected Loss: 0.48294
# Batch count: 281, Avg. per-sample expected Loss: 0.48422
# Batch count: 282, Avg. per-sample expected Loss: 0.48413
# Batch count: 283, Avg. per-sample expected Loss: 0.48541
# Batch count: 284, Avg. per-sample expected Loss: 0.48366
# Batch count: 285, Avg. per-sample expected Loss: 0.48438
# Batch count: 286, Avg. per-sample expected Loss: 0.48505
# Batch count: 287, Avg. per-sample expected Loss: 0.48324
# Batch count: 288, Avg. per-sample expected Loss: 0.48353
# Batch count: 289, Avg. per-sample expected Loss: 0.48433
# Batch count: 290, Avg. per-sample expected Loss: 0.48559
# Batch count: 291, Avg. per-sample expected Loss: 0.48604
# Batch count: 292, Avg. per-sample expected Loss: 0.48498
# Batch count: 293, Avg. per-sample expected Loss: 0.48628
# Batch count: 294, Avg. per-sample expected Loss: 0.48505
# Batch count: 295, Avg. per-sample expected Loss: 0.48475
# Batch count: 296, Avg. per-sample expected Loss: 0.48515
# Batch count: 297, Avg. per-sample expected Loss: 0.48388
# Batch count: 298, Avg. per-sample expected Loss: 0.48605
# Batch count: 299, Avg. per-sample expected Loss: 0.48423
# Batch count: 300, Avg. per-sample expected Loss: 0.48529
# Batch count: 301, Avg. per-sample expected Loss: 0.48338
# Batch count: 302, Avg. per-sample expected Loss: 0.48607
# Batch count: 303, Avg. per-sample expected Loss: 0.48561
# Batch count: 304, Avg. per-sample expected Loss: 0.48604
# Batch count: 305, Avg. per-sample expected Loss: 0.48624
# Batch count: 306, Avg. per-sample expected Loss: 0.48460
# Batch count: 307, Avg. per-sample expected Loss: 0.48358
# Batch count: 308, Avg. per-sample expected Loss: 0.48411
# Batch count: 309, Avg. per-sample expected Loss: 0.48413
# Batch count: 310, Avg. per-sample expected Loss: 0.48554
# Batch count: 311, Avg. per-sample expected Loss: 0.48208
# Batch count: 312, Avg. per-sample expected Loss: 0.48381
# Batch count: 313, Avg. per-sample expected Loss: 0.48472
# Batch count: 314, Avg. per-sample expected Loss: 0.48502
# Batch count: 315, Avg. per-sample expected Loss: 0.48436
# Batch count: 316, Avg. per-sample expected Loss: 0.48659
# Batch count: 317, Avg. per-sample expected Loss: 0.48423
# Batch count: 318, Avg. per-sample expected Loss: 0.48242
# Batch count: 319, Avg. per-sample expected Loss: 0.48604
# Batch count: 320, Avg. per-sample expected Loss: 0.48464
# Batch count: 321, Avg. per-sample expected Loss: 0.48271
# Batch count: 322, Avg. per-sample expected Loss: 0.48186
# Batch count: 323, Avg. per-sample expected Loss: 0.48244
# Batch count: 324, Avg. per-sample expected Loss: 0.48319
# Batch count: 325, Avg. per-sample expected Loss: 0.48245
# Batch count: 326, Avg. per-sample expected Loss: 0.48353
# Batch count: 327, Avg. per-sample expected Loss: 0.48418
# Batch count: 328, Avg. per-sample expected Loss: 0.48464
# Batch count: 329, Avg. per-sample expected Loss: 0.48327
# Batch count: 330, Avg. per-sample expected Loss: 0.48563
# Batch count: 331, Avg. per-sample expected Loss: 0.48221
# Batch count: 332, Avg. per-sample expected Loss: 0.48649
# Batch count: 333, Avg. per-sample expected Loss: 0.48428
# Batch count: 334, Avg. per-sample expected Loss: 0.48443
# Batch count: 335, Avg. per-sample expected Loss: 0.48596
# Batch count: 336, Avg. per-sample expected Loss: 0.48509
# Batch count: 337, Avg. per-sample expected Loss: 0.48493
# Batch count: 338, Avg. per-sample expected Loss: 0.48571
# Batch count: 339, Avg. per-sample expected Loss: 0.48555
# Batch count: 340, Avg. per-sample expected Loss: 0.48680
# Batch count: 341, Avg. per-sample expected Loss: 0.48626
# Batch count: 342, Avg. per-sample expected Loss: 0.48384
# Batch count: 343, Avg. per-sample expected Loss: 0.48518
# Batch count: 344, Avg. per-sample expected Loss: 0.48643
# Batch count: 345, Avg. per-sample expected Loss: 0.48341
# Batch count: 346, Avg. per-sample expected Loss: 0.48573
# Batch count: 347, Avg. per-sample expected Loss: 0.48598
# Batch count: 348, Avg. per-sample expected Loss: 0.48493
# Batch count: 349, Avg. per-sample expected Loss: 0.48597
# Batch count: 350, Avg. per-sample expected Loss: 0.48540
# Batch count: 351, Avg. per-sample expected Loss: 0.48616
# Batch count: 352, Avg. per-sample expected Loss: 0.48412
# Batch count: 353, Avg. per-sample expected Loss: 0.48502
# Batch count: 354, Avg. per-sample expected Loss: 0.48464
# Batch count: 355, Avg. per-sample expected Loss: 0.48476
# Batch count: 356, Avg. per-sample expected Loss: 0.48367
# Batch count: 357, Avg. per-sample expected Loss: 0.48170
# Batch count: 358, Avg. per-sample expected Loss: 0.48402
# Batch count: 359, Avg. per-sample expected Loss: 0.48208
# Batch count: 360, Avg. per-sample expected Loss: 0.48470
# Batch count: 361, Avg. per-sample expected Loss: 0.48301
# Batch count: 362, Avg. per-sample expected Loss: 0.48495
# Batch count: 363, Avg. per-sample expected Loss: 0.48648
# Batch count: 364, Avg. per-sample expected Loss: 0.48333
# Batch count: 365, Avg. per-sample expected Loss: 0.48549
# Batch count: 366, Avg. per-sample expected Loss: 0.48549
# Batch count: 367, Avg. per-sample expected Loss: 0.48430
# Batch count: 368, Avg. per-sample expected Loss: 0.48497
# Batch count: 369, Avg. per-sample expected Loss: 0.48292
# Batch count: 370, Avg. per-sample expected Loss: 0.48700
# Batch count: 371, Avg. per-sample expected Loss: 0.48491
# Batch count: 372, Avg. per-sample expected Loss: 0.48313
# Batch count: 373, Avg. per-sample expected Loss: 0.48483
# Batch count: 374, Avg. per-sample expected Loss: 0.48518
# Batch count: 375, Avg. per-sample expected Loss: 0.48505
# Batch count: 376, Avg. per-sample expected Loss: 0.47972
# Batch count: 377, Avg. per-sample expected Loss: 0.48264
# Batch count: 378, Avg. per-sample expected Loss: 0.48254
# Batch count: 379, Avg. per-sample expected Loss: 0.48374
# Batch count: 380, Avg. per-sample expected Loss: 0.48399
# Batch count: 381, Avg. per-sample expected Loss: 0.48026
# Batch count: 382, Avg. per-sample expected Loss: 0.48125
# Batch count: 383, Avg. per-sample expected Loss: 0.48300
# Batch count: 384, Avg. per-sample expected Loss: 0.48337
# Batch count: 385, Avg. per-sample expected Loss: 0.48038
# Batch count: 386, Avg. per-sample expected Loss: 0.48132
# Batch count: 387, Avg. per-sample expected Loss: 0.48079
# Batch count: 388, Avg. per-sample expected Loss: 0.48392
# Batch count: 389, Avg. per-sample expected Loss: 0.48375
# Batch count: 390, Avg. per-sample expected Loss: 0.48474
# Batch count: 391, Avg. per-sample expected Loss: 0.47921
# Batch count: 392, Avg. per-sample expected Loss: 0.48243
# Batch count: 393, Avg. per-sample expected Loss: 0.48057
# Batch count: 394, Avg. per-sample expected Loss: 0.48242
# Batch count: 395, Avg. per-sample expected Loss: 0.48204
# Batch count: 396, Avg. per-sample expected Loss: 0.48239
# Batch count: 397, Avg. per-sample expected Loss: 0.48091
# Batch count: 398, Avg. per-sample expected Loss: 0.47969
# Batch count: 399, Avg. per-sample expected Loss: 0.48131

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")

plt.title("Training using 2-QNSCD and 2-RQSGD (6 samples per itr)")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("2RSGD_6s.png")
plt.show()

# %%
# plt.style.use("seaborn-v0_8")
plt.plot(NCGD_cost, "darkred", label="2-QNSCD Expected Loss")
plt.plot(SGD6_cost, "b", label="2-RQSGD_6s Expected Loss")
plt.plot(SGD6c_cost, "g", label="6-RQSGD Expected Loss")

plt.plot(Opt_cost, "k", label="Minimum Expected Loss")
plt.plot(NCGD_Ecost, "r.",alpha=0.5, label="2-QNSCD Empirical Loss")
plt.plot(SGD6_Ecost, "c.",alpha=0.5, label="2-RQSGD_6s Empirical Loss")
plt.plot(SGD6c_Ecost, "g.",alpha=0.5, label="6-RQSGD Empirical Loss")

plt.title("Training 2-QNSCD and 2-RQSGD and 6-RQSGD")
plt.ylabel("Loss")
plt.xlabel("No. of Steps")
plt.legend()
plt.savefig("RQSGD.png")
plt.show()

# %% [markdown]
# ## Testing Phase

# %%
### Saving Final Parameters:
file_name1 = "6Q 2-QNSCD params"
file_name2 = "6Q 2-RQSGD_6s params"
file_name3 = "6Q 6-RQSGD params"

np.save(file_name1,NCGDparams)
np.save(file_name2,SGD6params)
np.save(file_name3,SGD6cparams)

# %%
phiTest = np.load('6-qubitsPhiTest_v1.npy')
labelTest = np.load('6-qubitsLabelTest_v1.npy')

phiTest.requires_grad = False
labelTest.requires_grad = False

# %%
nTest = 1000

NCGDparams_opt = NCGDparams 
SGD6params_opt = SGD6params
SGD6cparams_opt = SGD6cparams

# %%
### Optimal Expected Loss
expOperator = 0

for i in range(nTest):
    op = np.matmul(phiTest[:,i].reshape(dim,1),phiTest[:,i].reshape(1,dim))
    expOperator = expOperator + labelTest[i]*op
expOperator = expOperator/(nTest)
opt_value = 0.5*(1+sum(abs(np.linalg.svd(expOperator)[1])))

# %%
NCGD_rslt = []
SGD6_rslt = []
SGD6c_rslt = []

for i in range(int(1e1)):
    NCGDcount = 0
    SGD6count = 0
    SGD6ccount = 0

    for itr in range(nTest):
        if circuit_test(NCGDparams_opt,phiTest[:,itr]) == labelTest[itr]:
            NCGDcount += 1 
        if circuit_test(SGD6params_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6count += 1
        if circuit_test(SGD6cparams_opt,phiTest[:,itr]) == labelTest[itr]:
            SGD6ccount += 1
    
    NCGD_rslt.append(NCGDcount/nTest)
    SGD6_rslt.append(SGD6count/nTest)
    SGD6c_rslt.append(SGD6ccount/nTest)
#     print("itr = ",i)

# %%
print("Optimal: {:.3f} \nNCGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n2-RQSGD_6s: {:.3f} / {:.3f} max: {:.3f} min: {:.3f} \n6-RQSGD: {:.3f} / {:.3f} max: {:.3f} min: {:.3f}"\
      .format(opt_value,np.average(NCGD_rslt),np.std(NCGD_rslt),max(NCGD_rslt),min(NCGD_rslt),\
              np.average(SGD6_rslt),np.std(SGD6_rslt),max(SGD6_rslt),min(SGD6_rslt), \
              np.average(SGD6c_rslt),np.std(SGD6c_rslt),max(SGD6c_rslt),min(SGD6c_rslt)))
# Out:
# Optimal: 0.880
# NCGD: 0.814 / 0.010 max: 0.829 min: 0.802
# 2-RQSGD_6s: 0.524 / 0.022 max: 0.574 min: 0.490
# 6-RQSGD: 0.785 / 0.011 max: 0.800 min: 0.769
